# %% [markdown]
# <a href="https://colab.research.google.com/github/tuhinmallick/AI-for-Fashion/blob/main/Smaller_LLMs_with_AutoRound_Low_bit_Quantization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *More details in this article: [Intel AutoRound: Accurate Low-bit Quantization for LLMs](https://newsletter.kaitchup.com/p/intel-autoround-accurate-low-bit)*
#
# This notebook shows how to use Intel AutoRound to quantize LLMs.
#
# The first section runs AutoRound for Llama 3 8B with different hyperparameters.
# The second section evaluates the quantized models with the Evaluation Harness.
# The third section benchmarks the inference throughput with vLLM.
#
# #Quantization with AutoRound

# %%
# !pip install auto-round
# Out:
# Collecting auto-round
#   Downloading auto_round-0.2-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.0/66.0 kB 2.5 MB/s eta 0:00:00
# Collecting accelerate (from auto-round)
#   Downloading accelerate-0.31.0-py3-none-any.whl (309 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 7.5 MB/s eta 0:00:00
# Collecting auto-gptq (from auto-round)
#   Downloading auto_gptq-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 53.8 MB/s eta 0:00:00
# Collecting datasets (from auto-round)
#   Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 56.0 MB/s eta 0:00:00
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from auto-round) (9.0.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from auto-round) (0.1.99)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from auto-round) (2.3.0+cu121)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from auto-round) (4.41.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate->auto-round) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate->auto-round) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->auto-round) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate->auto-round) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate->auto-round) (0.23.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate->auto-round) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->auto-round) (3.15.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->auto-round) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->auto-round) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->auto-round) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->auto-round) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->auto-round) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->auto-round)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->auto-round)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->auto-round)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->auto-round)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->auto-round)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->auto-round)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->auto-round)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->auto-round)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->auto-round)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->auto-round)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->auto-round)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->auto-round) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->auto-round)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 71.4 MB/s eta 0:00:00
# Collecting rouge (from auto-gptq->auto-round)
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Collecting gekko (from auto-gptq->auto-round)
#   Downloading gekko-1.1.3-py3-none-any.whl (13.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 104.1 MB/s eta 0:00:00
# Collecting peft>=0.5.0 (from auto-gptq->auto-round)
#   Downloading peft-0.11.1-py3-none-any.whl (251 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 33.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from auto-gptq->auto-round) (4.66.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->auto-round) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->auto-round) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers->auto-round) (0.19.1)
# Collecting pyarrow>=15.0.0 (from datasets->auto-round)
#   Downloading pyarrow-16.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (40.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 42.7 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->auto-round) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->auto-round)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 19.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->auto-round) (2.0.3)
# Collecting requests (from transformers->auto-round)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 10.5 MB/s eta 0:00:00
# Collecting xxhash (from datasets->auto-round)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 28.4 MB/s eta 0:00:00
# Collecting multiprocess (from datasets->auto-round)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.8 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->auto-round) (3.9.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-round) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-round) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-round) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-round) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-round) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-round) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->auto-round) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->auto-round) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->auto-round) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->auto-round) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->auto-round) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-round) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-round) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-round) (2024.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge->auto-gptq->auto-round) (1.16.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->auto-round) (1.3.0)
# Installing collected packages: xxhash, rouge, requests, pyarrow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, gekko, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, nvidia-cusolver-cu12, datasets, accelerate, peft, auto-gptq, auto-round
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 16.1.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 16.1.0 which is incompatible.
# Successfully installed accelerate-0.31.0 auto-gptq-0.7.1 auto-round-0.2 datasets-2.20.0 dill-0.3.8 gekko-1.1.3 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 peft-0.11.1 pyarrow-16.1.0 requests-2.32.3 rouge-1.0.1 xxhash-3.4.1

# %% [markdown]
# The following code quantizes the model to 4-bit and saves it in the directory tmp_autoround

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
model_name = "meta-llama/Meta-Llama-3-8B"
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.float16)
tokenizer = AutoTokenizer.from_pretrained(model_name)

from auto_round import AutoRound

bits, group_size, sym = 4, 128, False
autoround = AutoRound(model, tokenizer, bits=bits, group_size=group_size, batch_size=2, seqlen=512, sym=sym, gradient_accumulate_steps=4, device='cuda')
autoround.quantize()
output_dir = "./tmp_autoround"
autoround.save_quantized(output_dir) ##save_quantized(output_dir,format=="auto_round")
# Out:
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/177 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-06-20 06:06:13 INFO autoround.py L464: using torch.float16 for quantization tuning
# Downloading readme:   0%|          | 0.00/373 [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/921 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/33.3M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/10000 [00:00<?, ? examples/s]
# 2024-06-20 06:07:15 INFO autoround.py L1306: quantizing 1/32, model.layers.0
# 2024-06-20 06:10:04 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000004 -> iter 194: 0.000001
# 2024-06-20 06:10:09 INFO autoround.py L1306: quantizing 2/32, model.layers.1
# 2024-06-20 06:12:56 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000076 -> iter 43: 0.000042
# 2024-06-20 06:13:00 INFO autoround.py L1306: quantizing 3/32, model.layers.2
# 2024-06-20 06:15:47 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000057 -> iter 198: 0.000036
# 2024-06-20 06:15:51 INFO autoround.py L1306: quantizing 4/32, model.layers.3
# 2024-06-20 06:18:38 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000062 -> iter 152: 0.000038
# 2024-06-20 06:18:42 INFO autoround.py L1306: quantizing 5/32, model.layers.4
# 2024-06-20 06:21:29 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000081 -> iter 196: 0.000047
# 2024-06-20 06:21:33 INFO autoround.py L1306: quantizing 6/32, model.layers.5
# 2024-06-20 06:24:20 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000090 -> iter 185: 0.000060
# 2024-06-20 06:24:24 INFO autoround.py L1306: quantizing 7/32, model.layers.6
# 2024-06-20 06:27:12 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000121 -> iter 178: 0.000081
# 2024-06-20 06:27:15 INFO autoround.py L1306: quantizing 8/32, model.layers.7
# 2024-06-20 06:30:03 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000146 -> iter 176: 0.000101
# 2024-06-20 06:30:06 INFO autoround.py L1306: quantizing 9/32, model.layers.8
# 2024-06-20 06:32:54 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000171 -> iter 198: 0.000116
# 2024-06-20 06:32:57 INFO autoround.py L1306: quantizing 10/32, model.layers.9
# 2024-06-20 06:35:45 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000194 -> iter 179: 0.000140
# 2024-06-20 06:35:49 INFO autoround.py L1306: quantizing 11/32, model.layers.10
# 2024-06-20 06:38:36 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000228 -> iter 192: 0.000157
# 2024-06-20 06:38:40 INFO autoround.py L1306: quantizing 12/32, model.layers.11
# 2024-06-20 06:41:27 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000263 -> iter 197: 0.000182
# 2024-06-20 06:41:31 INFO autoround.py L1306: quantizing 13/32, model.layers.12
# 2024-06-20 06:44:19 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000268 -> iter 181: 0.000193
# 2024-06-20 06:44:22 INFO autoround.py L1306: quantizing 14/32, model.layers.13
# 2024-06-20 06:47:10 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000324 -> iter 151: 0.000226
# 2024-06-20 06:47:13 INFO autoround.py L1306: quantizing 15/32, model.layers.14
# 2024-06-20 06:50:01 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000373 -> iter 143: 0.000243
# 2024-06-20 06:50:04 INFO autoround.py L1306: quantizing 16/32, model.layers.15
# 2024-06-20 06:52:52 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000403 -> iter 179: 0.000270
# 2024-06-20 06:52:55 INFO autoround.py L1306: quantizing 17/32, model.layers.16
# 2024-06-20 06:55:43 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000423 -> iter 170: 0.000314
# 2024-06-20 06:55:47 INFO autoround.py L1306: quantizing 18/32, model.layers.17
# 2024-06-20 06:58:34 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000498 -> iter 95: 0.000349
# 2024-06-20 06:58:38 INFO autoround.py L1306: quantizing 19/32, model.layers.18
# 2024-06-20 07:01:25 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000551 -> iter 155: 0.000419
# 2024-06-20 07:01:29 INFO autoround.py L1306: quantizing 20/32, model.layers.19
# 2024-06-20 07:04:16 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000668 -> iter 97: 0.000505
# 2024-06-20 07:04:20 INFO autoround.py L1306: quantizing 21/32, model.layers.20
# 2024-06-20 07:07:08 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000825 -> iter 139: 0.000574
# 2024-06-20 07:07:11 INFO autoround.py L1306: quantizing 22/32, model.layers.21
# 2024-06-20 07:09:59 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000885 -> iter 54: 0.000730
# 2024-06-20 07:10:02 INFO autoround.py L1306: quantizing 23/32, model.layers.22
# 2024-06-20 07:12:50 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.001159 -> iter 129: 0.000871
# 2024-06-20 07:12:53 INFO autoround.py L1306: quantizing 24/32, model.layers.23
# 2024-06-20 07:15:41 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.001356 -> iter 188: 0.001040
# 2024-06-20 07:15:45 INFO autoround.py L1306: quantizing 25/32, model.layers.24
# 2024-06-20 07:18:32 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.001613 -> iter 192: 0.001236
# 2024-06-20 07:18:36 INFO autoround.py L1306: quantizing 26/32, model.layers.25
# 2024-06-20 07:21:24 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.002011 -> iter 165: 0.001380
# 2024-06-20 07:21:27 INFO autoround.py L1306: quantizing 27/32, model.layers.26
# 2024-06-20 07:24:15 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.002272 -> iter 129: 0.001714
# 2024-06-20 07:24:18 INFO autoround.py L1306: quantizing 28/32, model.layers.27
# 2024-06-20 07:27:06 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.003695 -> iter 192: 0.002009
# 2024-06-20 07:27:10 INFO autoround.py L1306: quantizing 29/32, model.layers.28
# 2024-06-20 07:29:57 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.003507 -> iter 142: 0.002726
# 2024-06-20 07:30:01 INFO autoround.py L1306: quantizing 30/32, model.layers.29
# 2024-06-20 07:32:48 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.005573 -> iter 185: 0.003559
# 2024-06-20 07:32:52 INFO autoround.py L1306: quantizing 31/32, model.layers.30
# 2024-06-20 07:35:40 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.007735 -> iter 158: 0.005111
# 2024-06-20 07:35:43 INFO autoround.py L1306: quantizing 32/32, model.layers.31
# 2024-06-20 07:38:31 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.023330 -> iter 160: 0.011637
# 2024-06-20 07:38:35 INFO autoround.py L589: quantization tuning time 5542.122865200043
# 2024-06-20 07:38:35 INFO autoround.py L605: Summary: quantized 224/225 in the model,  ['lm_head'] have not been quantized
# 2024-06-20 07:38:35 INFO export_to_autogptq.py L69: Saving quantized model to autogptq format, this may take a while...
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda:CUDA extension not installed.
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda_old:CUDA extension not installed.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
model_name = "meta-llama/Meta-Llama-3-8B"
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.float16)
tokenizer = AutoTokenizer.from_pretrained(model_name)

from auto_round import AutoRound

bits, group_size, sym = 2, 128, False
autoround = AutoRound(model, tokenizer, bits=bits, group_size=group_size, batch_size=2, seqlen=512, sym=sym, gradient_accumulate_steps=4, device='cuda')
autoround.quantize()
output_dir = "./tmp_autoround_2bit"
autoround.save_quantized(output_dir) ##save_quantized(output_dir,format=="auto_round")
# Out:
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/177 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-06-24 10:32:28 INFO autoround.py L464: using torch.float16 for quantization tuning
# Downloading readme:   0%|          | 0.00/373 [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/921 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/33.3M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/10000 [00:00<?, ? examples/s]
# 2024-06-24 10:33:29 INFO autoround.py L1306: quantizing 1/32, model.layers.0
# 2024-06-24 10:36:18 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000065 -> iter 183: 0.000015
# 2024-06-24 10:36:22 INFO autoround.py L1306: quantizing 2/32, model.layers.1
# 2024-06-24 10:39:10 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000400 -> iter 51: 0.000151
# 2024-06-24 10:39:14 INFO autoround.py L1306: quantizing 3/32, model.layers.2
# 2024-06-24 10:42:01 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000490 -> iter 193: 0.000146
# 2024-06-24 10:42:04 INFO autoround.py L1306: quantizing 4/32, model.layers.3
# 2024-06-24 10:44:52 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000943 -> iter 190: 0.000297
# 2024-06-24 10:44:55 INFO autoround.py L1306: quantizing 5/32, model.layers.4
# 2024-06-24 10:47:43 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.001249 -> iter 192: 0.000461
# 2024-06-24 10:47:46 INFO autoround.py L1306: quantizing 6/32, model.layers.5
# 2024-06-24 10:50:34 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.001630 -> iter 191: 0.000670
# 2024-06-24 10:50:38 INFO autoround.py L1306: quantizing 7/32, model.layers.6
# 2024-06-24 10:53:25 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.002085 -> iter 183: 0.000953
# 2024-06-24 10:53:29 INFO autoround.py L1306: quantizing 8/32, model.layers.7
# 2024-06-24 10:56:17 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.002520 -> iter 167: 0.001185
# 2024-06-24 10:56:20 INFO autoround.py L1306: quantizing 9/32, model.layers.8
# 2024-06-24 10:59:08 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.003058 -> iter 165: 0.001432
# 2024-06-24 10:59:11 INFO autoround.py L1306: quantizing 10/32, model.layers.9
# 2024-06-24 11:01:59 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.003676 -> iter 160: 0.001700
# 2024-06-24 11:02:02 INFO autoround.py L1306: quantizing 11/32, model.layers.10
# 2024-06-24 11:04:50 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.003715 -> iter 179: 0.001893
# 2024-06-24 11:04:54 INFO autoround.py L1306: quantizing 12/32, model.layers.11
# 2024-06-24 11:07:41 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.004315 -> iter 197: 0.002147
# 2024-06-24 11:07:45 INFO autoround.py L1306: quantizing 13/32, model.layers.12
# 2024-06-24 11:10:33 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.004413 -> iter 164: 0.002264
# 2024-06-24 11:10:36 INFO autoround.py L1306: quantizing 14/32, model.layers.13
# 2024-06-24 11:13:24 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.005239 -> iter 162: 0.002611
# 2024-06-24 11:13:28 INFO autoround.py L1306: quantizing 15/32, model.layers.14
# 2024-06-24 11:16:15 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.005815 -> iter 182: 0.003017
# 2024-06-24 11:16:19 INFO autoround.py L1306: quantizing 16/32, model.layers.15
# 2024-06-24 11:19:07 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.006808 -> iter 193: 0.003432
# 2024-06-24 11:19:10 INFO autoround.py L1306: quantizing 17/32, model.layers.16
# 2024-06-24 11:21:58 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.007329 -> iter 198: 0.004014
# 2024-06-24 11:22:01 INFO autoround.py L1306: quantizing 18/32, model.layers.17
# 2024-06-24 11:24:49 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.008481 -> iter 173: 0.004845
# 2024-06-24 11:24:53 INFO autoround.py L1306: quantizing 19/32, model.layers.18
# 2024-06-24 11:27:40 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.009472 -> iter 138: 0.005504
# 2024-06-24 11:27:44 INFO autoround.py L1306: quantizing 20/32, model.layers.19
# 2024-06-24 11:30:32 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.010668 -> iter 171: 0.006737
# 2024-06-24 11:30:35 INFO autoround.py L1306: quantizing 21/32, model.layers.20
# 2024-06-24 11:33:23 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.012006 -> iter 117: 0.007752
# 2024-06-24 11:33:26 INFO autoround.py L1306: quantizing 22/32, model.layers.21
# 2024-06-24 11:36:14 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.015327 -> iter 186: 0.009239
# 2024-06-24 11:36:17 INFO autoround.py L1306: quantizing 23/32, model.layers.22
# 2024-06-24 11:39:05 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.017460 -> iter 192: 0.012094
# 2024-06-24 11:39:08 INFO autoround.py L1306: quantizing 24/32, model.layers.23
# 2024-06-24 11:41:56 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.021857 -> iter 70: 0.013588
# 2024-06-24 11:41:59 INFO autoround.py L1306: quantizing 25/32, model.layers.24
# 2024-06-24 11:44:47 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.025382 -> iter 107: 0.016970
# 2024-06-24 11:44:50 INFO autoround.py L1306: quantizing 26/32, model.layers.25
# 2024-06-24 11:47:38 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.030432 -> iter 172: 0.020433
# 2024-06-24 11:47:41 INFO autoround.py L1306: quantizing 27/32, model.layers.26
# 2024-06-24 11:50:28 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.039103 -> iter 155: 0.025296
# 2024-06-24 11:50:32 INFO autoround.py L1306: quantizing 28/32, model.layers.27
# 2024-06-24 11:53:19 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.047483 -> iter 180: 0.030534
# 2024-06-24 11:53:23 INFO autoround.py L1306: quantizing 29/32, model.layers.28
# 2024-06-24 11:56:10 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.060636 -> iter 162: 0.034903
# 2024-06-24 11:56:13 INFO autoround.py L1306: quantizing 30/32, model.layers.29
# 2024-06-24 11:59:01 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.073225 -> iter 189: 0.046704
# 2024-06-24 11:59:04 INFO autoround.py L1306: quantizing 31/32, model.layers.30
# 2024-06-24 12:01:52 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.127402 -> iter 162: 0.067131
# 2024-06-24 12:01:55 INFO autoround.py L1306: quantizing 32/32, model.layers.31
# 2024-06-24 12:04:43 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.506533 -> iter 185: 0.146706
# 2024-06-24 12:04:47 INFO autoround.py L589: quantization tuning time 5538.698270559311
# 2024-06-24 12:04:47 INFO autoround.py L605: Summary: quantized 224/225 in the model,  ['lm_head'] have not been quantized
# 2024-06-24 12:04:47 INFO export_to_autogptq.py L69: Saving quantized model to autogptq format, this may take a while...
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda:CUDA extension not installed.
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda_old:CUDA extension not installed.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
model_name = "meta-llama/Meta-Llama-3-8B"
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.float16)
tokenizer = AutoTokenizer.from_pretrained(model_name)

from auto_round import AutoRound

bits, group_size, sym = 2, 128, True
autoround = AutoRound(model, tokenizer, bits=bits, group_size=group_size, batch_size=2, seqlen=512, sym=sym, gradient_accumulate_steps=4, device='cuda')
autoround.quantize()
output_dir = "./Llama-3-8B-2bit-Sym-AutoRound-GPTQ/"
autoround.save_quantized(output_dir) ##save_quantized(output_dir,format=="auto_round")
# Out:
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/177 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-06-25 10:43:47 INFO autoround.py L464: using torch.float16 for quantization tuning
# Map:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/10000 [00:00<?, ? examples/s]
# 2024-06-25 10:44:38 INFO autoround.py L1306: quantizing 1/32, model.layers.0
# 2024-06-25 10:47:25 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000058 -> iter 199: 0.000015
# 2024-06-25 10:47:28 INFO autoround.py L1306: quantizing 2/32, model.layers.1
# 2024-06-25 10:50:15 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000404 -> iter 51: 0.000153
# 2024-06-25 10:50:19 INFO autoround.py L1306: quantizing 3/32, model.layers.2
# 2024-06-25 10:53:05 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000498 -> iter 192: 0.000152
# 2024-06-25 10:53:09 INFO autoround.py L1306: quantizing 4/32, model.layers.3
# 2024-06-25 10:55:56 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000957 -> iter 186: 0.000284
# 2024-06-25 10:55:59 INFO autoround.py L1306: quantizing 5/32, model.layers.4
# 2024-06-25 10:58:46 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.001160 -> iter 195: 0.000450
# 2024-06-25 10:58:50 INFO autoround.py L1306: quantizing 6/32, model.layers.5
# 2024-06-25 11:01:37 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.001612 -> iter 179: 0.000686
# 2024-06-25 11:01:40 INFO autoround.py L1306: quantizing 7/32, model.layers.6
# 2024-06-25 11:04:27 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.002098 -> iter 170: 0.000920
# 2024-06-25 11:04:31 INFO autoround.py L1306: quantizing 8/32, model.layers.7
# 2024-06-25 11:07:18 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.002786 -> iter 195: 0.001197
# 2024-06-25 11:07:22 INFO autoround.py L1306: quantizing 9/32, model.layers.8
# 2024-06-25 11:10:09 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.002887 -> iter 180: 0.001459
# 2024-06-25 11:10:12 INFO autoround.py L1306: quantizing 10/32, model.layers.9
# 2024-06-25 11:12:59 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.003600 -> iter 153: 0.001654
# 2024-06-25 11:13:03 INFO autoround.py L1306: quantizing 11/32, model.layers.10
# 2024-06-25 11:15:50 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.003953 -> iter 177: 0.001931
# 2024-06-25 11:15:53 INFO autoround.py L1306: quantizing 12/32, model.layers.11
# 2024-06-25 11:18:40 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.004459 -> iter 157: 0.002233
# 2024-06-25 11:18:44 INFO autoround.py L1306: quantizing 13/32, model.layers.12
# 2024-06-25 11:21:31 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.004798 -> iter 185: 0.002290
# 2024-06-25 11:21:34 INFO autoround.py L1306: quantizing 14/32, model.layers.13
# 2024-06-25 11:24:21 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.005201 -> iter 160: 0.002781
# 2024-06-25 11:24:25 INFO autoround.py L1306: quantizing 15/32, model.layers.14
# 2024-06-25 11:27:12 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.006010 -> iter 165: 0.003025
# 2024-06-25 11:27:16 INFO autoround.py L1306: quantizing 16/32, model.layers.15
# 2024-06-25 11:30:03 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.006775 -> iter 192: 0.003571
# 2024-06-25 11:30:06 INFO autoround.py L1306: quantizing 17/32, model.layers.16
# 2024-06-25 11:32:53 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.007289 -> iter 199: 0.003957
# 2024-06-25 11:32:57 INFO autoround.py L1306: quantizing 18/32, model.layers.17
# 2024-06-25 11:35:44 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.008398 -> iter 197: 0.004787
# 2024-06-25 11:35:47 INFO autoround.py L1306: quantizing 19/32, model.layers.18
# 2024-06-25 11:38:35 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.009001 -> iter 190: 0.005852
# 2024-06-25 11:38:38 INFO autoround.py L1306: quantizing 20/32, model.layers.19
# 2024-06-25 11:41:25 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.010271 -> iter 134: 0.006241
# 2024-06-25 11:41:29 INFO autoround.py L1306: quantizing 21/32, model.layers.20
# 2024-06-25 11:44:16 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.012224 -> iter 185: 0.007290
# 2024-06-25 11:44:20 INFO autoround.py L1306: quantizing 22/32, model.layers.21
# 2024-06-25 11:47:07 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.016014 -> iter 166: 0.010118
# 2024-06-25 11:47:11 INFO autoround.py L1306: quantizing 23/32, model.layers.22
# 2024-06-25 11:49:58 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.018160 -> iter 149: 0.011681
# 2024-06-25 11:50:01 INFO autoround.py L1306: quantizing 24/32, model.layers.23
# 2024-06-25 11:52:49 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.022042 -> iter 105: 0.013745
# 2024-06-25 11:52:52 INFO autoround.py L1306: quantizing 25/32, model.layers.24
# 2024-06-25 11:55:39 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.026268 -> iter 80: 0.016754
# 2024-06-25 11:55:43 INFO autoround.py L1306: quantizing 26/32, model.layers.25
# 2024-06-25 11:58:30 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.029616 -> iter 138: 0.020975
# 2024-06-25 11:58:34 INFO autoround.py L1306: quantizing 27/32, model.layers.26
# 2024-06-25 12:01:21 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.039102 -> iter 152: 0.024931
# 2024-06-25 12:01:25 INFO autoround.py L1306: quantizing 28/32, model.layers.27
# 2024-06-25 12:04:12 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.042363 -> iter 183: 0.029404
# 2024-06-25 12:04:16 INFO autoround.py L1306: quantizing 29/32, model.layers.28
# 2024-06-25 12:07:03 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.058621 -> iter 165: 0.036418
# 2024-06-25 12:07:07 INFO autoround.py L1306: quantizing 30/32, model.layers.29
# 2024-06-25 12:09:54 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.074793 -> iter 130: 0.046846
# 2024-06-25 12:09:57 INFO autoround.py L1306: quantizing 31/32, model.layers.30
# 2024-06-25 12:12:45 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.129660 -> iter 185: 0.067565
# 2024-06-25 12:12:48 INFO autoround.py L1306: quantizing 32/32, model.layers.31
# 2024-06-25 12:15:36 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.412629 -> iter 174: 0.149343
# 2024-06-25 12:15:40 INFO autoround.py L589: quantization tuning time 5512.954709529877
# 2024-06-25 12:15:40 INFO autoround.py L605: Summary: quantized 224/225 in the model,  ['lm_head'] have not been quantized
# 2024-06-25 12:15:40 INFO export_to_autogptq.py L69: Saving quantized model to autogptq format, this may take a while...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
model_name = "meta-llama/Meta-Llama-3-8B"
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.float16)
tokenizer = AutoTokenizer.from_pretrained(model_name)

from auto_round import AutoRound

bits, group_size, sym = 4, 128, True
autoround = AutoRound(model, tokenizer, bits=bits, group_size=group_size, batch_size=2, seqlen=512, sym=sym, gradient_accumulate_steps=4, device='cuda')
autoround.quantize()
output_dir = "./Llama-3-8B-4bit-Symm-AutoRound-GPTQ/"
autoround.save_quantized(output_dir) ##save_quantized(output_dir,format=="auto_round")
# Out:
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/177 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-06-26 12:54:58 INFO autoround.py L464: using torch.float16 for quantization tuning
# Downloading readme:   0%|          | 0.00/373 [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/921 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/33.3M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/10000 [00:00<?, ? examples/s]
# 2024-06-26 12:55:59 INFO autoround.py L1306: quantizing 1/32, model.layers.0
# 2024-06-26 12:58:45 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000004 -> iter 195: 0.000002
# 2024-06-26 12:58:49 INFO autoround.py L1306: quantizing 2/32, model.layers.1
# 2024-06-26 13:01:34 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000474 -> iter 40: 0.000116
# 2024-06-26 13:01:38 INFO autoround.py L1306: quantizing 3/32, model.layers.2
# 2024-06-26 13:04:23 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000137 -> iter 194: 0.000104
# 2024-06-26 13:04:26 INFO autoround.py L1306: quantizing 4/32, model.layers.3
# 2024-06-26 13:07:11 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000139 -> iter 185: 0.000101
# 2024-06-26 13:07:15 INFO autoround.py L1306: quantizing 5/32, model.layers.4
# 2024-06-26 13:09:59 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000162 -> iter 176: 0.000106
# 2024-06-26 13:10:03 INFO autoround.py L1306: quantizing 6/32, model.layers.5
# 2024-06-26 13:12:48 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000165 -> iter 189: 0.000117
# 2024-06-26 13:12:51 INFO autoround.py L1306: quantizing 7/32, model.layers.6
# 2024-06-26 13:15:36 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000189 -> iter 191: 0.000133
# 2024-06-26 13:15:40 INFO autoround.py L1306: quantizing 8/32, model.layers.7
# 2024-06-26 13:18:24 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000205 -> iter 199: 0.000149
# 2024-06-26 13:18:28 INFO autoround.py L1306: quantizing 9/32, model.layers.8
# 2024-06-26 13:21:13 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000245 -> iter 178: 0.000168
# 2024-06-26 13:21:16 INFO autoround.py L1306: quantizing 10/32, model.layers.9
# 2024-06-26 13:24:01 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000302 -> iter 139: 0.000197
# 2024-06-26 13:24:04 INFO autoround.py L1306: quantizing 11/32, model.layers.10
# 2024-06-26 13:26:49 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000315 -> iter 197: 0.000214
# 2024-06-26 13:26:53 INFO autoround.py L1306: quantizing 12/32, model.layers.11
# 2024-06-26 13:29:38 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000335 -> iter 198: 0.000241
# 2024-06-26 13:29:41 INFO autoround.py L1306: quantizing 13/32, model.layers.12
# 2024-06-26 13:32:26 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000374 -> iter 171: 0.000246
# 2024-06-26 13:32:30 INFO autoround.py L1306: quantizing 14/32, model.layers.13
# 2024-06-26 13:35:15 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000405 -> iter 185: 0.000279
# 2024-06-26 13:35:19 INFO autoround.py L1306: quantizing 15/32, model.layers.14
# 2024-06-26 13:38:03 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000448 -> iter 188: 0.000306
# 2024-06-26 13:38:07 INFO autoround.py L1306: quantizing 16/32, model.layers.15
# 2024-06-26 13:40:52 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000477 -> iter 79: 0.000340
# 2024-06-26 13:40:56 INFO autoround.py L1306: quantizing 17/32, model.layers.16
# 2024-06-26 13:43:41 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000553 -> iter 188: 0.000380
# 2024-06-26 13:43:44 INFO autoround.py L1306: quantizing 18/32, model.layers.17
# 2024-06-26 13:46:29 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000645 -> iter 158: 0.000460
# 2024-06-26 13:46:33 INFO autoround.py L1306: quantizing 19/32, model.layers.18
# 2024-06-26 13:49:18 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000713 -> iter 188: 0.000504
# 2024-06-26 13:49:21 INFO autoround.py L1306: quantizing 20/32, model.layers.19
# 2024-06-26 13:52:06 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000794 -> iter 155: 0.000573
# 2024-06-26 13:52:10 INFO autoround.py L1306: quantizing 21/32, model.layers.20
# 2024-06-26 13:54:55 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000875 -> iter 134: 0.000682
# 2024-06-26 13:54:58 INFO autoround.py L1306: quantizing 22/32, model.layers.21
# 2024-06-26 13:57:43 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.001104 -> iter 164: 0.000868
# 2024-06-26 13:57:47 INFO autoround.py L1306: quantizing 23/32, model.layers.22
# 2024-06-26 14:00:32 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.001220 -> iter 147: 0.000991
# 2024-06-26 14:00:36 INFO autoround.py L1306: quantizing 24/32, model.layers.23
# 2024-06-26 14:03:21 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.001589 -> iter 167: 0.001187
# 2024-06-26 14:03:25 INFO autoround.py L1306: quantizing 25/32, model.layers.24
# 2024-06-26 14:06:10 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.001774 -> iter 191: 0.001388
# 2024-06-26 14:06:13 INFO autoround.py L1306: quantizing 26/32, model.layers.25
# 2024-06-26 14:08:59 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.002103 -> iter 191: 0.001703
# 2024-06-26 14:09:02 INFO autoround.py L1306: quantizing 27/32, model.layers.26
# 2024-06-26 14:11:48 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.002545 -> iter 80: 0.002060
# 2024-06-26 14:11:51 INFO autoround.py L1306: quantizing 28/32, model.layers.27
# 2024-06-26 14:14:36 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.003310 -> iter 159: 0.002418
# 2024-06-26 14:14:40 INFO autoround.py L1306: quantizing 29/32, model.layers.28
# 2024-06-26 14:17:25 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.003994 -> iter 153: 0.003065
# 2024-06-26 14:17:28 INFO autoround.py L1306: quantizing 30/32, model.layers.29
# 2024-06-26 14:20:14 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.006525 -> iter 192: 0.004154
# 2024-06-26 14:20:17 INFO autoround.py L1306: quantizing 31/32, model.layers.30
# 2024-06-26 14:23:02 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.009503 -> iter 162: 0.006195
# 2024-06-26 14:23:06 INFO autoround.py L1306: quantizing 32/32, model.layers.31
# 2024-06-26 14:25:51 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.029138 -> iter 164: 0.013530
# 2024-06-26 14:25:55 INFO autoround.py L589: quantization tuning time 5456.652592420578
# 2024-06-26 14:25:55 INFO autoround.py L605: Summary: quantized 224/225 in the model,  ['lm_head'] have not been quantized
# 2024-06-26 14:25:55 INFO export_to_autogptq.py L69: Saving quantized model to autogptq format, this may take a while...
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda:CUDA extension not installed.
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda_old:CUDA extension not installed.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
model_name = "meta-llama/Meta-Llama-3-8B"
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.float16)
tokenizer = AutoTokenizer.from_pretrained(model_name)

from auto_round import AutoRound

bits, group_size, sym = 2, 128, False
autoround = AutoRound(model, tokenizer, bits=bits, group_size=group_size, iters=1000, batch_size=2, seqlen=512, sym=sym, gradient_accumulate_steps=4, device='cuda')
autoround.quantize()
output_dir = "./Llama-3-8B-2bit-iter1000-AutoRound-GPTQ/"
autoround.save_quantized(output_dir) ##save_quantized(output_dir,format=="auto_round")
# Out:
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/177 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-06-24 17:18:35 INFO autoround.py L464: using torch.float16 for quantization tuning
# Downloading readme:   0%|          | 0.00/373 [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/921 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/33.3M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/10000 [00:00<?, ? examples/s]
# 2024-06-24 17:19:37 INFO autoround.py L1306: quantizing 1/32, model.layers.0
# 2024-06-24 17:33:20 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000060 -> iter 973: 0.000013
# 2024-06-24 17:33:24 INFO autoround.py L1306: quantizing 2/32, model.layers.1
# 2024-06-24 17:47:06 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000383 -> iter 320: 0.000130
# 2024-06-24 17:47:10 INFO autoround.py L1306: quantizing 3/32, model.layers.2
# 2024-06-24 18:00:52 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000484 -> iter 941: 0.000123
# 2024-06-24 18:00:56 INFO autoround.py L1306: quantizing 4/32, model.layers.3
# 2024-06-24 18:14:38 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000844 -> iter 553: 0.000240
# 2024-06-24 18:14:42 INFO autoround.py L1306: quantizing 5/32, model.layers.4
# 2024-06-24 18:28:25 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.001133 -> iter 705: 0.000383
# 2024-06-24 18:28:28 INFO autoround.py L1306: quantizing 6/32, model.layers.5
# 2024-06-24 18:42:11 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.001587 -> iter 888: 0.000574
# 2024-06-24 18:42:15 INFO autoround.py L1306: quantizing 7/32, model.layers.6
# 2024-06-24 18:55:58 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.002068 -> iter 998: 0.000833
# 2024-06-24 18:56:01 INFO autoround.py L1306: quantizing 8/32, model.layers.7
# 2024-06-24 19:09:45 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.002490 -> iter 674: 0.001059
# 2024-06-24 19:09:48 INFO autoround.py L1306: quantizing 9/32, model.layers.8
# 2024-06-24 19:23:32 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.002735 -> iter 786: 0.001177
# 2024-06-24 19:23:35 INFO autoround.py L1306: quantizing 10/32, model.layers.9
# 2024-06-24 19:37:18 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.003407 -> iter 758: 0.001463
# 2024-06-24 19:37:22 INFO autoround.py L1306: quantizing 11/32, model.layers.10
# 2024-06-24 19:51:05 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.003561 -> iter 985: 0.001597
# 2024-06-24 19:51:08 INFO autoround.py L1306: quantizing 12/32, model.layers.11
# 2024-06-24 20:04:52 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.003958 -> iter 871: 0.001882
# 2024-06-24 20:04:55 INFO autoround.py L1306: quantizing 13/32, model.layers.12
# 2024-06-24 20:18:38 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.004467 -> iter 979: 0.002011
# 2024-06-24 20:18:42 INFO autoround.py L1306: quantizing 14/32, model.layers.13
# 2024-06-24 20:32:25 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.004878 -> iter 859: 0.002178
# 2024-06-24 20:32:29 INFO autoround.py L1306: quantizing 15/32, model.layers.14
# 2024-06-24 20:46:12 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.005667 -> iter 964: 0.002659
# 2024-06-24 20:46:15 INFO autoround.py L1306: quantizing 16/32, model.layers.15
# 2024-06-24 20:59:59 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.006053 -> iter 941: 0.002973
# 2024-06-24 21:00:02 INFO autoround.py L1306: quantizing 17/32, model.layers.16
# 2024-06-24 21:13:46 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.006808 -> iter 651: 0.003365
# 2024-06-24 21:13:49 INFO autoround.py L1306: quantizing 18/32, model.layers.17
# 2024-06-24 21:27:32 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.007900 -> iter 851: 0.003946
# 2024-06-24 21:27:36 INFO autoround.py L1306: quantizing 19/32, model.layers.18
# 2024-06-24 21:41:19 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.008745 -> iter 881: 0.004719
# 2024-06-24 21:41:22 INFO autoround.py L1306: quantizing 20/32, model.layers.19
# 2024-06-24 21:55:06 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.009536 -> iter 910: 0.005426
# 2024-06-24 21:55:10 INFO autoround.py L1306: quantizing 21/32, model.layers.20
# 2024-06-24 22:08:54 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.011536 -> iter 641: 0.006384
# 2024-06-24 22:08:57 INFO autoround.py L1306: quantizing 22/32, model.layers.21
# 2024-06-24 22:22:41 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.013725 -> iter 942: 0.008383
# 2024-06-24 22:22:44 INFO autoround.py L1306: quantizing 23/32, model.layers.22
# 2024-06-24 22:36:28 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.015881 -> iter 328: 0.009555
# 2024-06-24 22:36:31 INFO autoround.py L1306: quantizing 24/32, model.layers.23
# 2024-06-24 22:50:14 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.018597 -> iter 829: 0.012137
# 2024-06-24 22:50:18 INFO autoround.py L1306: quantizing 25/32, model.layers.24
# 2024-06-24 23:04:01 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.022018 -> iter 673: 0.014289
# 2024-06-24 23:04:05 INFO autoround.py L1306: quantizing 26/32, model.layers.25
# 2024-06-24 23:17:48 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.027024 -> iter 893: 0.016100
# 2024-06-24 23:17:52 INFO autoround.py L1306: quantizing 27/32, model.layers.26
# 2024-06-24 23:31:36 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.031472 -> iter 676: 0.020050
# 2024-06-24 23:31:40 INFO autoround.py L1306: quantizing 28/32, model.layers.27
# 2024-06-24 23:45:25 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.042923 -> iter 975: 0.024810
# 2024-06-24 23:45:28 INFO autoround.py L1306: quantizing 29/32, model.layers.28
# 2024-06-24 23:59:13 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.052135 -> iter 975: 0.029736
# 2024-06-24 23:59:16 INFO autoround.py L1306: quantizing 30/32, model.layers.29
# 2024-06-25 00:13:01 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.071970 -> iter 644: 0.037278
# 2024-06-25 00:13:05 INFO autoround.py L1306: quantizing 31/32, model.layers.30
# 2024-06-25 00:26:50 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.114876 -> iter 955: 0.054996
# 2024-06-25 00:26:53 INFO autoround.py L1306: quantizing 32/32, model.layers.31
# 2024-06-25 00:40:38 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.321284 -> iter 972: 0.121463
# 2024-06-25 00:40:42 INFO autoround.py L589: quantization tuning time 26527.443501234055
# 2024-06-25 00:40:42 INFO autoround.py L605: Summary: quantized 224/225 in the model,  ['lm_head'] have not been quantized
# 2024-06-25 00:40:42 INFO export_to_autogptq.py L69: Saving quantized model to autogptq format, this may take a while...
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda:CUDA extension not installed.
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda_old:CUDA extension not installed.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
model_name = "meta-llama/Meta-Llama-3-8B"
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.float16)
tokenizer = AutoTokenizer.from_pretrained(model_name)

from auto_round import AutoRound

bits, group_size, sym = 2, 128, False
autoround = AutoRound(model, tokenizer, bits=bits, group_size=group_size, batch_size=2, seqlen=1024, sym=sym, gradient_accumulate_steps=4, device='cuda')
autoround.quantize()
output_dir = "./Llama-3-8B-2bit-len1024-AutoRound-GPTQ/"
autoround.save_quantized(output_dir) ##save_quantized(output_dir,format=="auto_round")
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-06-25 00:48:07 INFO autoround.py L464: using torch.float16 for quantization tuning
# Map:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/10000 [00:00<?, ? examples/s]
# 2024-06-25 00:48:59 INFO autoround.py L1306: quantizing 1/32, model.layers.0
# 2024-06-25 00:52:11 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000066 -> iter 195: 0.000014
# 2024-06-25 00:52:20 INFO autoround.py L1306: quantizing 2/32, model.layers.1
# 2024-06-25 00:55:32 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000257 -> iter 51: 0.000106
# 2024-06-25 00:55:39 INFO autoround.py L1306: quantizing 3/32, model.layers.2
# 2024-06-25 00:58:51 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000470 -> iter 198: 0.000146
# 2024-06-25 00:58:58 INFO autoround.py L1306: quantizing 4/32, model.layers.3
# 2024-06-25 01:02:11 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.000855 -> iter 180: 0.000267
# 2024-06-25 01:02:18 INFO autoround.py L1306: quantizing 5/32, model.layers.4
# 2024-06-25 01:05:30 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.001239 -> iter 192: 0.000441
# 2024-06-25 01:05:37 INFO autoround.py L1306: quantizing 6/32, model.layers.5
# 2024-06-25 01:08:50 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.001646 -> iter 123: 0.000662
# 2024-06-25 01:08:56 INFO autoround.py L1306: quantizing 7/32, model.layers.6
# 2024-06-25 01:12:09 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.002257 -> iter 195: 0.000931
# 2024-06-25 01:12:16 INFO autoround.py L1306: quantizing 8/32, model.layers.7
# 2024-06-25 01:15:28 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.002740 -> iter 114: 0.001239
# 2024-06-25 01:15:35 INFO autoround.py L1306: quantizing 9/32, model.layers.8
# 2024-06-25 01:18:48 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.003237 -> iter 191: 0.001469
# 2024-06-25 01:18:54 INFO autoround.py L1306: quantizing 10/32, model.layers.9
# 2024-06-25 01:22:07 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.003734 -> iter 192: 0.001725
# 2024-06-25 01:22:14 INFO autoround.py L1306: quantizing 11/32, model.layers.10
# 2024-06-25 01:25:27 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.004115 -> iter 176: 0.002071
# 2024-06-25 01:25:33 INFO autoround.py L1306: quantizing 12/32, model.layers.11
# 2024-06-25 01:28:46 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.004410 -> iter 140: 0.002255
# 2024-06-25 01:28:53 INFO autoround.py L1306: quantizing 13/32, model.layers.12
# 2024-06-25 01:32:06 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.005112 -> iter 137: 0.002464
# 2024-06-25 01:32:12 INFO autoround.py L1306: quantizing 14/32, model.layers.13
# 2024-06-25 01:35:25 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.005359 -> iter 160: 0.002958
# 2024-06-25 01:35:32 INFO autoround.py L1306: quantizing 15/32, model.layers.14
# 2024-06-25 01:38:44 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.006452 -> iter 175: 0.003256
# 2024-06-25 01:38:51 INFO autoround.py L1306: quantizing 16/32, model.layers.15
# 2024-06-25 01:42:03 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.006878 -> iter 179: 0.003693
# 2024-06-25 01:42:10 INFO autoround.py L1306: quantizing 17/32, model.layers.16
# 2024-06-25 01:45:23 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.007809 -> iter 176: 0.004351
# 2024-06-25 01:45:29 INFO autoround.py L1306: quantizing 18/32, model.layers.17
# 2024-06-25 01:48:42 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.009284 -> iter 198: 0.005339
# 2024-06-25 01:48:49 INFO autoround.py L1306: quantizing 19/32, model.layers.18
# 2024-06-25 01:52:01 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.009954 -> iter 154: 0.005890
# 2024-06-25 01:52:08 INFO autoround.py L1306: quantizing 20/32, model.layers.19
# 2024-06-25 01:55:21 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.010937 -> iter 170: 0.007309
# 2024-06-25 01:55:28 INFO autoround.py L1306: quantizing 21/32, model.layers.20
# 2024-06-25 01:58:41 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.013410 -> iter 174: 0.008290
# 2024-06-25 01:58:48 INFO autoround.py L1306: quantizing 22/32, model.layers.21
# 2024-06-25 02:02:00 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.017663 -> iter 145: 0.010305
# 2024-06-25 02:02:07 INFO autoround.py L1306: quantizing 23/32, model.layers.22
# 2024-06-25 02:05:20 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.017952 -> iter 82: 0.013002
# 2024-06-25 02:05:27 INFO autoround.py L1306: quantizing 24/32, model.layers.23
# 2024-06-25 02:08:40 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.024646 -> iter 103: 0.015691
# 2024-06-25 02:08:46 INFO autoround.py L1306: quantizing 25/32, model.layers.24
# 2024-06-25 02:11:59 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.027153 -> iter 190: 0.019196
# 2024-06-25 02:12:06 INFO autoround.py L1306: quantizing 26/32, model.layers.25
# 2024-06-25 02:15:19 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.034352 -> iter 199: 0.022161
# 2024-06-25 02:15:26 INFO autoround.py L1306: quantizing 27/32, model.layers.26
# 2024-06-25 02:18:39 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.039576 -> iter 175: 0.026702
# 2024-06-25 02:18:45 INFO autoround.py L1306: quantizing 28/32, model.layers.27
# 2024-06-25 02:21:58 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.048016 -> iter 162: 0.031438
# 2024-06-25 02:22:05 INFO autoround.py L1306: quantizing 29/32, model.layers.28
# 2024-06-25 02:25:18 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.064614 -> iter 70: 0.040219
# 2024-06-25 02:25:25 INFO autoround.py L1306: quantizing 30/32, model.layers.29
# 2024-06-25 02:28:38 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.083872 -> iter 190: 0.047644
# 2024-06-25 02:28:45 INFO autoround.py L1306: quantizing 31/32, model.layers.30
# 2024-06-25 02:31:58 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.130978 -> iter 142: 0.071451
# 2024-06-25 02:32:05 INFO autoround.py L1306: quantizing 32/32, model.layers.31
# 2024-06-25 02:35:18 INFO autoround.py L1237: quantized 7/7 layers in the block, loss iter 0: 0.416298 -> iter 194: 0.162479
# 2024-06-25 02:35:25 INFO autoround.py L589: quantization tuning time 6437.931393623352
# 2024-06-25 02:35:25 INFO autoround.py L605: Summary: quantized 224/225 in the model,  ['lm_head'] have not been quantized
# 2024-06-25 02:35:25 INFO export_to_autogptq.py L69: Saving quantized model to autogptq format, this may take a while...

# %% [markdown]
# # Evaluation with the Evaluation Harness

# %%
# !pip install git+https://github.com/EleutherAI/lm-evaluation-harness.git
# !pip install auto-gptq optimum
# Out:
# Collecting git+https://github.com/EleutherAI/lm-evaluation-harness.git
#   Cloning https://github.com/EleutherAI/lm-evaluation-harness.git to /tmp/pip-req-build-g52qe58j
#   Running command git clone --filter=blob:none --quiet https://github.com/EleutherAI/lm-evaluation-harness.git /tmp/pip-req-build-g52qe58j
#   Resolved https://github.com/EleutherAI/lm-evaluation-harness.git to commit 6e49b1f6910931882a4b3b105794c6faf96b74e5
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: accelerate>=0.26.0 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2) (0.31.0)
# Collecting evaluate (from lm_eval==0.4.2)
#   Downloading evaluate-0.4.2-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: datasets>=2.16.0 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2) (2.20.0)
# Collecting jsonlines (from lm_eval==0.4.2)
#   Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2) (2.10.1)
# Requirement already satisfied: peft>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2) (0.11.1)
# Collecting pybind11>=2.6.2 (from lm_eval==0.4.2)
#   Downloading pybind11-2.13.0-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.7/238.7 kB 7.2 MB/s eta 0:00:00
# Collecting pytablewriter (from lm_eval==0.4.2)
#   Downloading pytablewriter-1.2.0-py3-none-any.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 6.4 MB/s eta 0:00:00
# Collecting rouge-score>=0.0.4 (from lm_eval==0.4.2)
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sacrebleu>=1.5.0 (from lm_eval==0.4.2)
#   Downloading sacrebleu-2.4.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2) (1.2.2)
# Collecting sqlitedict (from lm_eval==0.4.2)
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2) (2.3.0+cu121)
# Collecting tqdm-multiprocess (from lm_eval==0.4.2)
#   Downloading tqdm_multiprocess-0.0.11-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: transformers>=4.1 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2) (4.41.2)
# Collecting zstandard (from lm_eval==0.4.2)
#   Downloading zstandard-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 21.8 MB/s eta 0:00:00
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2) (0.3.8)
# Collecting word2number (from lm_eval==0.4.2)
#   Downloading word2number-1.1.zip (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2) (10.1.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.2) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.2) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.2) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.2) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.2) (0.23.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.2) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2) (3.15.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2) (0.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2) (2.0.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2) (4.66.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.5.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2) (3.9.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.2) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.2) (3.8.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.2) (1.16.0)
# Collecting portalocker (from sacrebleu>=1.5.0->lm_eval==0.4.2)
#   Downloading portalocker-2.10.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.2) (2024.5.15)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.2) (0.9.0)
# Collecting colorama (from sacrebleu>=1.5.0->lm_eval==0.4.2)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.2) (4.9.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.2) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.2) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8->lm_eval==0.4.2) (12.5.40)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.1->lm_eval==0.4.2) (0.19.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines->lm_eval==0.4.2) (23.2.0)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm_eval==0.4.2) (67.7.2)
# Collecting DataProperty<2,>=1.0.1 (from pytablewriter->lm_eval==0.4.2)
#   Downloading DataProperty-1.0.1-py3-none-any.whl (27 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter->lm_eval==0.4.2)
#   Downloading mbstrdecoder-1.1.3-py3-none-any.whl (7.8 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter->lm_eval==0.4.2)
#   Downloading pathvalidate-3.2.0-py3-none-any.whl (23 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter->lm_eval==0.4.2)
#   Downloading tabledata-1.3.3-py3-none-any.whl (11 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter->lm_eval==0.4.2)
#   Downloading tcolorpy-0.1.6-py3-none-any.whl (8.1 kB)
# Collecting typepy[datetime]<2,>=1.3.2 (from pytablewriter->lm_eval==0.4.2)
#   Downloading typepy-1.3.2-py3-none-any.whl (31 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.2) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.2) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.2) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.2) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.2) (4.0.3)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.10/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter->lm_eval==0.4.2) (5.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.2) (2024.6.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.2) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.2) (2023.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8->lm_eval==0.4.2) (2.1.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score>=0.0.4->lm_eval==0.4.2) (8.1.7)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->lm_eval==0.4.2) (2024.1)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8->lm_eval==0.4.2) (1.3.0)
# Building wheels for collected packages: lm_eval, rouge-score, sqlitedict, word2number
#   Building wheel for lm_eval (pyproject.toml) ... done
#   Created wheel for lm_eval: filename=lm_eval-0.4.2-py3-none-any.whl size=1653424 sha256=5743855a59cf576ccb6b9cd6a57f122085e9a3afa85963494a180468ee6ff94e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gtriijrp/wheels/ff/d5/f4/949f2b285369fc332f8dbba43f220ebd88387ee2f2c0c1174f
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=661ee395c372345052453c9c7f3fda2569abf146483b4402a20551f6bf156475
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16862 sha256=1f7f72280b8635b4de421bded175b86e91e1d12996d5c4e1cd7ade216e287bce
#   Stored in directory: /root/.cache/pip/wheels/79/d6/e7/304e0e6cb2221022c26d8161f7c23cd4f259a9e41e8bbcfabd
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5566 sha256=1577d621f8e9c5adde74954e79b379117dbaddf150534c7294f57c8318df2f5a
#   Stored in directory: /root/.cache/pip/wheels/84/ff/26/d3cfbd971e96c5aa3737ecfced81628830d7359b55fbb8ca3b
# Successfully built lm_eval rouge-score sqlitedict word2number
# Installing collected packages: word2number, sqlitedict, zstandard, tcolorpy, pybind11, portalocker, pathvalidate, mbstrdecoder, jsonlines, colorama, typepy, tqdm-multiprocess, sacrebleu, rouge-score, DataProperty, tabledata, evaluate, pytablewriter, lm_eval
# Successfully installed DataProperty-1.0.1 colorama-0.4.6 evaluate-0.4.2 jsonlines-4.0.0 lm_eval-0.4.2 mbstrdecoder-1.1.3 pathvalidate-3.2.0 portalocker-2.10.0 pybind11-2.13.0 pytablewriter-1.2.0 rouge-score-0.1.2 sacrebleu-2.4.2 sqlitedict-2.1.0 tabledata-1.3.3 tcolorpy-0.1.6 tqdm-multiprocess-0.0.11 typepy-1.3.2 word2number-1.1 zstandard-0.22.0
# Requirement already satisfied: auto-gptq in /usr/local/lib/python3.10/dist-packages (0.7.1)
# Requirement already satisfied: optimum in /usr/local/lib/python3.10/dist-packages (1.20.0)
# Requirement already satisfied: accelerate>=0.26.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.31.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (2.20.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.1.99)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (1.25.2)
# Requirement already satisfied: rouge in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (1.0.1)
# Requirement already satisfied: gekko in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (1.1.3)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (2.3.0+cu121)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.4.3)
# Requirement already satisfied: transformers>=4.31.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (4.41.2)
# Requirement already satisfied: peft>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.11.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (4.66.4)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from optimum) (15.0.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from optimum) (1.12.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from optimum) (24.1)
# Requirement already satisfied: huggingface-hub>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from optimum) (0.23.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (3.15.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->auto-gptq) (12.5.40)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->auto-gptq) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->auto-gptq) (0.19.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->auto-gptq) (3.20.3)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->optimum) (10.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (2.0.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (3.9.5)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge->auto-gptq) (1.16.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->optimum) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->auto-gptq) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-gptq) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-gptq) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-gptq) (2024.1)

# %%
# !lm_eval --model hf --model_args pretrained=./Llama-3-8B-4bit-AutoRound-GPTQ/,trust_remote_code=True --tasks winogrande,hellaswag,arc_challenge --device cuda:0 --num_fewshot 0 --batch_size 16 --output_path ./eval_gptq/4bit
# Out:
# 2024-06-24 09:37:21.769582: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-24 09:37:21.819353: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-24 09:37:21.819406: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-24 09:37:21.820733: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-24 09:37:21.828023: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-24 09:37:22.957037: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-06-24:09:37:27,121 INFO     [__main__.py:272] Verbosity set to INFO
# 2024-06-24:09:37:34,075 INFO     [__main__.py:369] Selected Tasks: ['arc_challenge', 'hellaswag', 'winogrande']
# 2024-06-24:09:37:34,077 INFO     [evaluator.py:152] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-06-24:09:37:34,077 INFO     [evaluator.py:189] Initializing hf model, with arguments: {'pretrained': './drive/MyDrive/autoround/Llama-3-8B-4bit-AutoRound-GPTQ/', 'trust_remote_code': True}
# 2024-06-24:09:37:34,100 INFO     [huggingface.py:169] Using device 'cuda:0'
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-06-24:09:37:34,682 WARNING  [qlinear_cuda.py:18] CUDA extension not installed.
# 2024-06-24:09:37:34,683 WARNING  [qlinear_cuda_old.py:17] CUDA extension not installed.
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:4481: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(
# Some weights of the model checkpoint at ./drive/MyDrive/autoround/Llama-3-8B-4bit-AutoRound-GPTQ/ were not used when initializing LlamaForCausalLM: ['model.layers.0.mlp.down_proj.bias', 'model.layers.0.mlp.gate_proj.bias', 'model.layers.0.mlp.up_proj.bias', 'model.layers.0.self_attn.k_proj.bias', 'model.layers.0.self_attn.o_proj.bias', 'model.layers.0.self_attn.q_proj.bias', 'model.layers.0.self_attn.v_proj.bias', 'model.layers.1.mlp.down_proj.bias', 'model.layers.1.mlp.gate_proj.bias', 'model.layers.1.mlp.up_proj.bias', 'model.layers.1.self_attn.k_proj.bias', 'model.layers.1.self_attn.o_proj.bias', 'model.layers.1.self_attn.q_proj.bias', 'model.layers.1.self_attn.v_proj.bias', 'model.layers.10.mlp.down_proj.bias', 'model.layers.10.mlp.gate_proj.bias', 'model.layers.10.mlp.up_proj.bias', 'model.layers.10.self_attn.k_proj.bias', 'model.layers.10.self_attn.o_proj.bias', 'model.layers.10.self_attn.q_proj.bias', 'model.layers.10.self_attn.v_proj.bias', 'model.layers.11.mlp.down_proj.bias', 'model.layers.11.mlp.gate_proj.bias', 'model.layers.11.mlp.up_proj.bias', 'model.layers.11.self_attn.k_proj.bias', 'model.layers.11.self_attn.o_proj.bias', 'model.layers.11.self_attn.q_proj.bias', 'model.layers.11.self_attn.v_proj.bias', 'model.layers.12.mlp.down_proj.bias', 'model.layers.12.mlp.gate_proj.bias', 'model.layers.12.mlp.up_proj.bias', 'model.layers.12.self_attn.k_proj.bias', 'model.layers.12.self_attn.o_proj.bias', 'model.layers.12.self_attn.q_proj.bias', 'model.layers.12.self_attn.v_proj.bias', 'model.layers.13.mlp.down_proj.bias', 'model.layers.13.mlp.gate_proj.bias', 'model.layers.13.mlp.up_proj.bias', 'model.layers.13.self_attn.k_proj.bias', 'model.layers.13.self_attn.o_proj.bias', 'model.layers.13.self_attn.q_proj.bias', 'model.layers.13.self_attn.v_proj.bias', 'model.layers.14.mlp.down_proj.bias', 'model.layers.14.mlp.gate_proj.bias', 'model.layers.14.mlp.up_proj.bias', 'model.layers.14.self_attn.k_proj.bias', 'model.layers.14.self_attn.o_proj.bias', 'model.layers.14.self_attn.q_proj.bias', 'model.layers.14.self_attn.v_proj.bias', 'model.layers.15.mlp.down_proj.bias', 'model.layers.15.mlp.gate_proj.bias', 'model.layers.15.mlp.up_proj.bias', 'model.layers.15.self_attn.k_proj.bias', 'model.layers.15.self_attn.o_proj.bias', 'model.layers.15.self_attn.q_proj.bias', 'model.layers.15.self_attn.v_proj.bias', 'model.layers.16.mlp.down_proj.bias', 'model.layers.16.mlp.gate_proj.bias', 'model.layers.16.mlp.up_proj.bias', 'model.layers.16.self_attn.k_proj.bias', 'model.layers.16.self_attn.o_proj.bias', 'model.layers.16.self_attn.q_proj.bias', 'model.layers.16.self_attn.v_proj.bias', 'model.layers.17.mlp.down_proj.bias', 'model.layers.17.mlp.gate_proj.bias', 'model.layers.17.mlp.up_proj.bias', 'model.layers.17.self_attn.k_proj.bias', 'model.layers.17.self_attn.o_proj.bias', 'model.layers.17.self_attn.q_proj.bias', 'model.layers.17.self_attn.v_proj.bias', 'model.layers.18.mlp.down_proj.bias', 'model.layers.18.mlp.gate_proj.bias', 'model.layers.18.mlp.up_proj.bias', 'model.layers.18.self_attn.k_proj.bias', 'model.layers.18.self_attn.o_proj.bias', 'model.layers.18.self_attn.q_proj.bias', 'model.layers.18.self_attn.v_proj.bias', 'model.layers.19.mlp.down_proj.bias', 'model.layers.19.mlp.gate_proj.bias', 'model.layers.19.mlp.up_proj.bias', 'model.layers.19.self_attn.k_proj.bias', 'model.layers.19.self_attn.o_proj.bias', 'model.layers.19.self_attn.q_proj.bias', 'model.layers.19.self_attn.v_proj.bias', 'model.layers.2.mlp.down_proj.bias', 'model.layers.2.mlp.gate_proj.bias', 'model.layers.2.mlp.up_proj.bias', 'model.layers.2.self_attn.k_proj.bias', 'model.layers.2.self_attn.o_proj.bias', 'model.layers.2.self_attn.q_proj.bias', 'model.layers.2.self_attn.v_proj.bias', 'model.layers.20.mlp.down_proj.bias', 'model.layers.20.mlp.gate_proj.bias', 'model.layers.20.mlp.up_proj.bias', 'model.layers.20.self_attn.k_proj.bias', 'model.layers.20.self_attn.o_proj.bias', 'model.layers.20.self_attn.q_proj.bias', 'model.layers.20.self_attn.v_proj.bias', 'model.l ...
# - This IS expected if you are initializing LlamaForCausalLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LlamaForCausalLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# The repository for winogrande contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/winogrande.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# Downloading data: 100% 3.40M/3.40M [00:00<00:00, 72.1MB/s]
# Generating train split: 100% 40398/40398 [00:01<00:00, 23656.25 examples/s]
# Generating test split: 100% 1767/1767 [00:00<00:00, 24066.06 examples/s]
# Generating validation split: 100% 1267/1267 [00:00<00:00, 22870.87 examples/s]
# 2024-06-24:09:37:57,697 WARNING  [evaluator.py:251] Overwriting default num_fewshot of winogrande from None to 0
# 2024-06-24:09:37:57,697 INFO     [evaluator.py:261] Setting fewshot random generator seed to 1234
# 2024-06-24:09:37:57,697 WARNING  [evaluator.py:251] Overwriting default num_fewshot of hellaswag from None to 0
# 2024-06-24:09:37:57,697 INFO     [evaluator.py:261] Setting fewshot random generator seed to 1234
# 2024-06-24:09:37:57,697 WARNING  [evaluator.py:251] Overwriting default num_fewshot of arc_challenge from None to 0
# 2024-06-24:09:37:57,697 INFO     [evaluator.py:261] Setting fewshot random generator seed to 1234
# 2024-06-24:09:37:57,700 INFO     [task.py:410] Building contexts for winogrande on rank 0...
# 100% 1267/1267 [00:00<00:00, 77595.18it/s]
# 2024-06-24:09:37:57,761 INFO     [task.py:410] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [00:04<00:00, 2142.94it/s]
# 2024-06-24:09:38:03,569 INFO     [task.py:410] Building contexts for arc_challenge on rank 0...
# 100% 1172/1172 [00:01<00:00, 1013.56it/s]
# 2024-06-24:09:38:04,795 INFO     [evaluator.py:432] Running loglikelihood requests
# Running loglikelihood requests: 100% 47389/47389 [44:08<00:00, 17.89it/s]
# 2024-06-24:10:22:40,673 WARNING  [huggingface.py:1335] Failed to get model SHA for ./drive/MyDrive/autoround/Llama-3-8B-4bit-AutoRound-GPTQ/ at revision main. Error: Repo id must be in the form 'repo_name' or 'namespace/repo_name': './drive/MyDrive/autoround/Llama-3-8B-4bit-AutoRound-GPTQ/'. Use `repo_type` argument if needed.
# fatal: not a git repository (or any of the parent directories): .git
# 2024-06-24:10:22:42,622 INFO     [evaluation_tracker.py:182] Saving results aggregated
# hf (pretrained=./drive/MyDrive/autoround/Llama-3-8B-4bit-AutoRound-GPTQ/,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: 0, batch_size: 16
# |    Tasks    |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |-------------|------:|------|-----:|--------|---|-----:|---|-----:|
# |arc_challenge|      1|none  |     0|acc     |↑  |0.4966|±  |0.0146|
# |             |       |none  |     0|acc_norm|↑  |0.5282|±  |0.0146|
# |hellaswag    |      1|none  |     0|acc     |↑  |0.5927|±  |0.0049|
# |             |       |none  |     0|acc_norm|↑  |0.7852|±  |0.0041|
# |winogrande   |      1|none  |     0|acc     |↑  |0.7364|±  |0.0124|

# %%
# !lm_eval --model hf --model_args pretrained=./Llama-3-8B-2bit-AutoRound-GPTQ/,trust_remote_code=True --tasks winogrande,hellaswag,arc_challenge --device cuda:0 --num_fewshot 0 --batch_size 16 --output_path ./eval_gptq/4bit
# Out:
# 2024-06-24 12:46:30.793376: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-24 12:46:30.846039: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-24 12:46:30.846090: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-24 12:46:30.847848: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-24 12:46:30.855979: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-24 12:46:32.057355: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-06-24:12:46:36,580 INFO     [__main__.py:272] Verbosity set to INFO
# 2024-06-24:12:46:43,502 INFO     [__main__.py:369] Selected Tasks: ['arc_challenge', 'hellaswag', 'winogrande']
# 2024-06-24:12:46:43,505 INFO     [evaluator.py:152] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-06-24:12:46:43,505 INFO     [evaluator.py:189] Initializing hf model, with arguments: {'pretrained': './drive/MyDrive/autoround/Llama-3-8B-2bit-AutoRound-GPTQ/', 'trust_remote_code': True}
# 2024-06-24:12:46:43,527 INFO     [huggingface.py:169] Using device 'cuda:0'
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-06-24:12:46:44,133 WARNING  [qlinear_cuda.py:18] CUDA extension not installed.
# 2024-06-24:12:46:44,134 WARNING  [qlinear_cuda_old.py:17] CUDA extension not installed.
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:4481: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(
# Some weights of the model checkpoint at ./drive/MyDrive/autoround/Llama-3-8B-2bit-AutoRound-GPTQ/ were not used when initializing LlamaForCausalLM: ['model.layers.0.mlp.down_proj.bias', 'model.layers.0.mlp.gate_proj.bias', 'model.layers.0.mlp.up_proj.bias', 'model.layers.0.self_attn.k_proj.bias', 'model.layers.0.self_attn.o_proj.bias', 'model.layers.0.self_attn.q_proj.bias', 'model.layers.0.self_attn.v_proj.bias', 'model.layers.1.mlp.down_proj.bias', 'model.layers.1.mlp.gate_proj.bias', 'model.layers.1.mlp.up_proj.bias', 'model.layers.1.self_attn.k_proj.bias', 'model.layers.1.self_attn.o_proj.bias', 'model.layers.1.self_attn.q_proj.bias', 'model.layers.1.self_attn.v_proj.bias', 'model.layers.10.mlp.down_proj.bias', 'model.layers.10.mlp.gate_proj.bias', 'model.layers.10.mlp.up_proj.bias', 'model.layers.10.self_attn.k_proj.bias', 'model.layers.10.self_attn.o_proj.bias', 'model.layers.10.self_attn.q_proj.bias', 'model.layers.10.self_attn.v_proj.bias', 'model.layers.11.mlp.down_proj.bias', 'model.layers.11.mlp.gate_proj.bias', 'model.layers.11.mlp.up_proj.bias', 'model.layers.11.self_attn.k_proj.bias', 'model.layers.11.self_attn.o_proj.bias', 'model.layers.11.self_attn.q_proj.bias', 'model.layers.11.self_attn.v_proj.bias', 'model.layers.12.mlp.down_proj.bias', 'model.layers.12.mlp.gate_proj.bias', 'model.layers.12.mlp.up_proj.bias', 'model.layers.12.self_attn.k_proj.bias', 'model.layers.12.self_attn.o_proj.bias', 'model.layers.12.self_attn.q_proj.bias', 'model.layers.12.self_attn.v_proj.bias', 'model.layers.13.mlp.down_proj.bias', 'model.layers.13.mlp.gate_proj.bias', 'model.layers.13.mlp.up_proj.bias', 'model.layers.13.self_attn.k_proj.bias', 'model.layers.13.self_attn.o_proj.bias', 'model.layers.13.self_attn.q_proj.bias', 'model.layers.13.self_attn.v_proj.bias', 'model.layers.14.mlp.down_proj.bias', 'model.layers.14.mlp.gate_proj.bias', 'model.layers.14.mlp.up_proj.bias', 'model.layers.14.self_attn.k_proj.bias', 'model.layers.14.self_attn.o_proj.bias', 'model.layers.14.self_attn.q_proj.bias', 'model.layers.14.self_attn.v_proj.bias', 'model.layers.15.mlp.down_proj.bias', 'model.layers.15.mlp.gate_proj.bias', 'model.layers.15.mlp.up_proj.bias', 'model.layers.15.self_attn.k_proj.bias', 'model.layers.15.self_attn.o_proj.bias', 'model.layers.15.self_attn.q_proj.bias', 'model.layers.15.self_attn.v_proj.bias', 'model.layers.16.mlp.down_proj.bias', 'model.layers.16.mlp.gate_proj.bias', 'model.layers.16.mlp.up_proj.bias', 'model.layers.16.self_attn.k_proj.bias', 'model.layers.16.self_attn.o_proj.bias', 'model.layers.16.self_attn.q_proj.bias', 'model.layers.16.self_attn.v_proj.bias', 'model.layers.17.mlp.down_proj.bias', 'model.layers.17.mlp.gate_proj.bias', 'model.layers.17.mlp.up_proj.bias', 'model.layers.17.self_attn.k_proj.bias', 'model.layers.17.self_attn.o_proj.bias', 'model.layers.17.self_attn.q_proj.bias', 'model.layers.17.self_attn.v_proj.bias', 'model.layers.18.mlp.down_proj.bias', 'model.layers.18.mlp.gate_proj.bias', 'model.layers.18.mlp.up_proj.bias', 'model.layers.18.self_attn.k_proj.bias', 'model.layers.18.self_attn.o_proj.bias', 'model.layers.18.self_attn.q_proj.bias', 'model.layers.18.self_attn.v_proj.bias', 'model.layers.19.mlp.down_proj.bias', 'model.layers.19.mlp.gate_proj.bias', 'model.layers.19.mlp.up_proj.bias', 'model.layers.19.self_attn.k_proj.bias', 'model.layers.19.self_attn.o_proj.bias', 'model.layers.19.self_attn.q_proj.bias', 'model.layers.19.self_attn.v_proj.bias', 'model.layers.2.mlp.down_proj.bias', 'model.layers.2.mlp.gate_proj.bias', 'model.layers.2.mlp.up_proj.bias', 'model.layers.2.self_attn.k_proj.bias', 'model.layers.2.self_attn.o_proj.bias', 'model.layers.2.self_attn.q_proj.bias', 'model.layers.2.self_attn.v_proj.bias', 'model.layers.20.mlp.down_proj.bias', 'model.layers.20.mlp.gate_proj.bias', 'model.layers.20.mlp.up_proj.bias', 'model.layers.20.self_attn.k_proj.bias', 'model.layers.20.self_attn.o_proj.bias', 'model.layers.20.self_attn.q_proj.bias', 'model.layers.20.self_attn.v_proj.bias', 'model.l ...
# - This IS expected if you are initializing LlamaForCausalLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LlamaForCausalLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2024-06-24:12:47:00,364 WARNING  [evaluator.py:251] Overwriting default num_fewshot of winogrande from None to 0
# 2024-06-24:12:47:00,364 INFO     [evaluator.py:261] Setting fewshot random generator seed to 1234
# 2024-06-24:12:47:00,364 WARNING  [evaluator.py:251] Overwriting default num_fewshot of hellaswag from None to 0
# 2024-06-24:12:47:00,364 INFO     [evaluator.py:261] Setting fewshot random generator seed to 1234
# 2024-06-24:12:47:00,364 WARNING  [evaluator.py:251] Overwriting default num_fewshot of arc_challenge from None to 0
# 2024-06-24:12:47:00,364 INFO     [evaluator.py:261] Setting fewshot random generator seed to 1234
# 2024-06-24:12:47:00,366 INFO     [task.py:410] Building contexts for winogrande on rank 0...
# 100% 1267/1267 [00:00<00:00, 81037.30it/s]
# 2024-06-24:12:47:00,427 INFO     [task.py:410] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [00:04<00:00, 2117.05it/s]
# 2024-06-24:12:47:06,311 INFO     [task.py:410] Building contexts for arc_challenge on rank 0...
# 100% 1172/1172 [00:01<00:00, 986.67it/s]
# 2024-06-24:12:47:07,569 INFO     [evaluator.py:432] Running loglikelihood requests
# Running loglikelihood requests: 100% 47389/47389 [42:20<00:00, 18.66it/s]
# 2024-06-24:13:29:54,803 WARNING  [huggingface.py:1335] Failed to get model SHA for ./drive/MyDrive/autoround/Llama-3-8B-2bit-AutoRound-GPTQ/ at revision main. Error: Repo id must be in the form 'repo_name' or 'namespace/repo_name': './drive/MyDrive/autoround/Llama-3-8B-2bit-AutoRound-GPTQ/'. Use `repo_type` argument if needed.
# fatal: not a git repository (or any of the parent directories): .git
# 2024-06-24:13:29:57,246 INFO     [evaluation_tracker.py:182] Saving results aggregated
# hf (pretrained=./drive/MyDrive/autoround/Llama-3-8B-2bit-AutoRound-GPTQ/,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: 0, batch_size: 16
# |    Tasks    |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |-------------|------:|------|-----:|--------|---|-----:|---|-----:|
# |arc_challenge|      1|none  |     0|acc     |↑  |0.2270|±  |0.0122|
# |             |       |none  |     0|acc_norm|↑  |0.2730|±  |0.0130|
# |hellaswag    |      1|none  |     0|acc     |↑  |0.2545|±  |0.0043|
# |             |       |none  |     0|acc_norm|↑  |0.2668|±  |0.0044|
# |winogrande   |      1|none  |     0|acc     |↑  |0.4878|±  |0.0140|

# %%
# !lm_eval --model hf --model_args pretrained=./Llama-3-8B-2bit-iter1000-AutoRound-GPTQ/,trust_remote_code=True --tasks winogrande,hellaswag,arc_challenge --device cuda:0 --num_fewshot 0 --batch_size 16 --output_path ./eval_gptq/4bit
# Out:
# 2024-06-25 06:46:09.311787: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-25 06:46:09.368281: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-25 06:46:09.368343: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-25 06:46:09.370370: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-25 06:46:09.379133: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-25 06:46:10.477498: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Downloading builder script: 100% 5.67k/5.67k [00:00<00:00, 18.3MB/s]
# 2024-06-25:06:46:16,986 INFO     [__main__.py:272] Verbosity set to INFO
# 2024-06-25:06:46:23,909 INFO     [__main__.py:369] Selected Tasks: ['arc_challenge', 'hellaswag', 'winogrande']
# 2024-06-25:06:46:23,916 INFO     [evaluator.py:152] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-06-25:06:46:23,916 INFO     [evaluator.py:189] Initializing hf model, with arguments: {'pretrained': './drive/MyDrive/autoround/Llama-3-8B-2bit-iter1000-AutoRound-GPTQ/', 'trust_remote_code': True}
# 2024-06-25:06:46:23,938 INFO     [huggingface.py:169] Using device 'cuda:0'
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-06-25:06:46:28,194 WARNING  [qlinear_cuda.py:18] CUDA extension not installed.
# 2024-06-25:06:46:28,195 WARNING  [qlinear_cuda_old.py:17] CUDA extension not installed.
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:4481: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(
# Some weights of the model checkpoint at ./drive/MyDrive/autoround/Llama-3-8B-2bit-iter1000-AutoRound-GPTQ/ were not used when initializing LlamaForCausalLM: ['model.layers.0.mlp.down_proj.bias', 'model.layers.0.mlp.gate_proj.bias', 'model.layers.0.mlp.up_proj.bias', 'model.layers.0.self_attn.k_proj.bias', 'model.layers.0.self_attn.o_proj.bias', 'model.layers.0.self_attn.q_proj.bias', 'model.layers.0.self_attn.v_proj.bias', 'model.layers.1.mlp.down_proj.bias', 'model.layers.1.mlp.gate_proj.bias', 'model.layers.1.mlp.up_proj.bias', 'model.layers.1.self_attn.k_proj.bias', 'model.layers.1.self_attn.o_proj.bias', 'model.layers.1.self_attn.q_proj.bias', 'model.layers.1.self_attn.v_proj.bias', 'model.layers.10.mlp.down_proj.bias', 'model.layers.10.mlp.gate_proj.bias', 'model.layers.10.mlp.up_proj.bias', 'model.layers.10.self_attn.k_proj.bias', 'model.layers.10.self_attn.o_proj.bias', 'model.layers.10.self_attn.q_proj.bias', 'model.layers.10.self_attn.v_proj.bias', 'model.layers.11.mlp.down_proj.bias', 'model.layers.11.mlp.gate_proj.bias', 'model.layers.11.mlp.up_proj.bias', 'model.layers.11.self_attn.k_proj.bias', 'model.layers.11.self_attn.o_proj.bias', 'model.layers.11.self_attn.q_proj.bias', 'model.layers.11.self_attn.v_proj.bias', 'model.layers.12.mlp.down_proj.bias', 'model.layers.12.mlp.gate_proj.bias', 'model.layers.12.mlp.up_proj.bias', 'model.layers.12.self_attn.k_proj.bias', 'model.layers.12.self_attn.o_proj.bias', 'model.layers.12.self_attn.q_proj.bias', 'model.layers.12.self_attn.v_proj.bias', 'model.layers.13.mlp.down_proj.bias', 'model.layers.13.mlp.gate_proj.bias', 'model.layers.13.mlp.up_proj.bias', 'model.layers.13.self_attn.k_proj.bias', 'model.layers.13.self_attn.o_proj.bias', 'model.layers.13.self_attn.q_proj.bias', 'model.layers.13.self_attn.v_proj.bias', 'model.layers.14.mlp.down_proj.bias', 'model.layers.14.mlp.gate_proj.bias', 'model.layers.14.mlp.up_proj.bias', 'model.layers.14.self_attn.k_proj.bias', 'model.layers.14.self_attn.o_proj.bias', 'model.layers.14.self_attn.q_proj.bias', 'model.layers.14.self_attn.v_proj.bias', 'model.layers.15.mlp.down_proj.bias', 'model.layers.15.mlp.gate_proj.bias', 'model.layers.15.mlp.up_proj.bias', 'model.layers.15.self_attn.k_proj.bias', 'model.layers.15.self_attn.o_proj.bias', 'model.layers.15.self_attn.q_proj.bias', 'model.layers.15.self_attn.v_proj.bias', 'model.layers.16.mlp.down_proj.bias', 'model.layers.16.mlp.gate_proj.bias', 'model.layers.16.mlp.up_proj.bias', 'model.layers.16.self_attn.k_proj.bias', 'model.layers.16.self_attn.o_proj.bias', 'model.layers.16.self_attn.q_proj.bias', 'model.layers.16.self_attn.v_proj.bias', 'model.layers.17.mlp.down_proj.bias', 'model.layers.17.mlp.gate_proj.bias', 'model.layers.17.mlp.up_proj.bias', 'model.layers.17.self_attn.k_proj.bias', 'model.layers.17.self_attn.o_proj.bias', 'model.layers.17.self_attn.q_proj.bias', 'model.layers.17.self_attn.v_proj.bias', 'model.layers.18.mlp.down_proj.bias', 'model.layers.18.mlp.gate_proj.bias', 'model.layers.18.mlp.up_proj.bias', 'model.layers.18.self_attn.k_proj.bias', 'model.layers.18.self_attn.o_proj.bias', 'model.layers.18.self_attn.q_proj.bias', 'model.layers.18.self_attn.v_proj.bias', 'model.layers.19.mlp.down_proj.bias', 'model.layers.19.mlp.gate_proj.bias', 'model.layers.19.mlp.up_proj.bias', 'model.layers.19.self_attn.k_proj.bias', 'model.layers.19.self_attn.o_proj.bias', 'model.layers.19.self_attn.q_proj.bias', 'model.layers.19.self_attn.v_proj.bias', 'model.layers.2.mlp.down_proj.bias', 'model.layers.2.mlp.gate_proj.bias', 'model.layers.2.mlp.up_proj.bias', 'model.layers.2.self_attn.k_proj.bias', 'model.layers.2.self_attn.o_proj.bias', 'model.layers.2.self_attn.q_proj.bias', 'model.layers.2.self_attn.v_proj.bias', 'model.layers.20.mlp.down_proj.bias', 'model.layers.20.mlp.gate_proj.bias', 'model.layers.20.mlp.up_proj.bias', 'model.layers.20.self_attn.k_proj.bias', 'model.layers.20.self_attn.o_proj.bias', 'model.layers.20.self_attn.q_proj.bias', 'model.layers.20.self_attn.v_proj.bias', ...
# - This IS expected if you are initializing LlamaForCausalLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LlamaForCausalLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading readme: 100% 9.00k/9.00k [00:00<00:00, 27.0MB/s]
# Downloading data: 100% 190k/190k [00:00<00:00, 737kB/s]
# Downloading data: 100% 204k/204k [00:00<00:00, 821kB/s]
# Downloading data: 100% 55.7k/55.7k [00:00<00:00, 234kB/s]
# Generating train split: 100% 1119/1119 [00:00<00:00, 162604.84 examples/s]
# Generating test split: 100% 1172/1172 [00:00<00:00, 261196.83 examples/s]
# Generating validation split: 100% 299/299 [00:00<00:00, 122938.62 examples/s]
# Downloading builder script: 100% 4.36k/4.36k [00:00<00:00, 19.5MB/s]
# Downloading metadata: 100% 2.53k/2.53k [00:00<00:00, 14.6MB/s]
# Downloading readme: 100% 6.84k/6.84k [00:00<00:00, 27.9MB/s]
# The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# Downloading data: 47.5MB [00:00, 70.3MB/s]
# Downloading data: 11.8MB [00:00, 70.8MB/s]
# Downloading data: 12.2MB [00:00, 75.3MB/s]
# Generating train split: 100% 39905/39905 [00:04<00:00, 9575.17 examples/s]
# Generating test split: 100% 10003/10003 [00:01<00:00, 9599.02 examples/s]
# Generating validation split: 100% 10042/10042 [00:01<00:00, 9353.52 examples/s]
# Map: 100% 39905/39905 [00:06<00:00, 6073.99 examples/s]
# Map: 100% 10042/10042 [00:01<00:00, 6565.50 examples/s]
# Downloading builder script: 100% 5.65k/5.65k [00:00<00:00, 23.4MB/s]
# Downloading readme: 100% 9.97k/9.97k [00:00<00:00, 31.6MB/s]
# The repository for winogrande contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/winogrande.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# Downloading data: 100% 3.40M/3.40M [00:01<00:00, 2.75MB/s]
# Generating train split: 100% 40398/40398 [00:01<00:00, 23841.10 examples/s]
# Generating test split: 100% 1767/1767 [00:00<00:00, 23917.72 examples/s]
# Generating validation split: 100% 1267/1267 [00:00<00:00, 23626.99 examples/s]
# 2024-06-25:06:48:17,571 WARNING  [evaluator.py:251] Overwriting default num_fewshot of winogrande from None to 0
# 2024-06-25:06:48:17,571 INFO     [evaluator.py:261] Setting fewshot random generator seed to 1234
# 2024-06-25:06:48:17,571 WARNING  [evaluator.py:251] Overwriting default num_fewshot of hellaswag from None to 0
# 2024-06-25:06:48:17,572 INFO     [evaluator.py:261] Setting fewshot random generator seed to 1234
# 2024-06-25:06:48:17,572 WARNING  [evaluator.py:251] Overwriting default num_fewshot of arc_challenge from None to 0
# 2024-06-25:06:48:17,572 INFO     [evaluator.py:261] Setting fewshot random generator seed to 1234
# 2024-06-25:06:48:17,574 INFO     [task.py:410] Building contexts for winogrande on rank 0...
# 100% 1267/1267 [00:00<00:00, 77048.41it/s]
# 2024-06-25:06:48:17,637 INFO     [task.py:410] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [00:04<00:00, 2159.03it/s]
# 2024-06-25:06:48:23,475 INFO     [task.py:410] Building contexts for arc_challenge on rank 0...
# 100% 1172/1172 [00:01<00:00, 999.50it/s]
# 2024-06-25:06:48:24,740 INFO     [evaluator.py:433] Running loglikelihood requests
# Running loglikelihood requests: 100% 47389/47389 [42:22<00:00, 18.64it/s]
# 2024-06-25:07:31:14,415 WARNING  [huggingface.py:1335] Failed to get model SHA for ./drive/MyDrive/autoround/Llama-3-8B-2bit-iter1000-AutoRound-GPTQ/ at revision main. Error: Repo id must be in the form 'repo_name' or 'namespace/repo_name': './drive/MyDrive/autoround/Llama-3-8B-2bit-iter1000-AutoRound-GPTQ/'. Use `repo_type` argument if needed.
# fatal: not a git repository (or any of the parent directories): .git
# 2024-06-25:07:31:16,517 INFO     [evaluation_tracker.py:182] Saving results aggregated
# hf (pretrained=./drive/MyDrive/autoround/Llama-3-8B-2bit-iter1000-AutoRound-GPTQ/,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: 0, batch_size: 16
# |    Tasks    |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |-------------|------:|------|-----:|--------|---|-----:|---|-----:|
# |arc_challenge|      1|none  |     0|acc     |↑  |0.2184|±  |0.0121|
# |             |       |none  |     0|acc_norm|↑  |0.2679|±  |0.0129|
# |hellaswag    |      1|none  |     0|acc     |↑  |0.2600|±  |0.0044|
# |             |       |none  |     0|acc_norm|↑  |0.2645|±  |0.0044|
# |winogrande   |      1|none  |     0|acc     |↑  |0.4791|±  |0.0140|

# %%
# !lm_eval --model hf --model_args pretrained=./Llama-3-8B-2bit-len1024-AutoRound-GPTQ/,trust_remote_code=True --tasks winogrande,hellaswag,arc_challenge --device cuda:0 --num_fewshot 0 --batch_size 16 --output_path ./eval_gptq/4bit
# Out:
# 2024-06-25 07:41:00.468812: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-25 07:41:00.521575: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-25 07:41:00.521625: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-25 07:41:00.523583: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-25 07:41:00.531925: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-25 07:41:01.615145: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-06-25:07:41:06,422 INFO     [__main__.py:272] Verbosity set to INFO
# 2024-06-25:07:41:13,286 INFO     [__main__.py:369] Selected Tasks: ['arc_challenge', 'hellaswag', 'winogrande']
# 2024-06-25:07:41:13,288 INFO     [evaluator.py:152] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-06-25:07:41:13,288 INFO     [evaluator.py:189] Initializing hf model, with arguments: {'pretrained': './drive/MyDrive/autoround/Llama-3-8B-2bit-len1024-AutoRound-GPTQ/', 'trust_remote_code': True}
# 2024-06-25:07:41:13,311 INFO     [huggingface.py:169] Using device 'cuda:0'
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-06-25:07:41:18,598 WARNING  [qlinear_cuda.py:18] CUDA extension not installed.
# 2024-06-25:07:41:18,599 WARNING  [qlinear_cuda_old.py:17] CUDA extension not installed.
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:4481: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(
# Some weights of the model checkpoint at ./drive/MyDrive/autoround/Llama-3-8B-2bit-len1024-AutoRound-GPTQ/ were not used when initializing LlamaForCausalLM: ['model.layers.0.mlp.down_proj.bias', 'model.layers.0.mlp.gate_proj.bias', 'model.layers.0.mlp.up_proj.bias', 'model.layers.0.self_attn.k_proj.bias', 'model.layers.0.self_attn.o_proj.bias', 'model.layers.0.self_attn.q_proj.bias', 'model.layers.0.self_attn.v_proj.bias', 'model.layers.1.mlp.down_proj.bias', 'model.layers.1.mlp.gate_proj.bias', 'model.layers.1.mlp.up_proj.bias', 'model.layers.1.self_attn.k_proj.bias', 'model.layers.1.self_attn.o_proj.bias', 'model.layers.1.self_attn.q_proj.bias', 'model.layers.1.self_attn.v_proj.bias', 'model.layers.10.mlp.down_proj.bias', 'model.layers.10.mlp.gate_proj.bias', 'model.layers.10.mlp.up_proj.bias', 'model.layers.10.self_attn.k_proj.bias', 'model.layers.10.self_attn.o_proj.bias', 'model.layers.10.self_attn.q_proj.bias', 'model.layers.10.self_attn.v_proj.bias', 'model.layers.11.mlp.down_proj.bias', 'model.layers.11.mlp.gate_proj.bias', 'model.layers.11.mlp.up_proj.bias', 'model.layers.11.self_attn.k_proj.bias', 'model.layers.11.self_attn.o_proj.bias', 'model.layers.11.self_attn.q_proj.bias', 'model.layers.11.self_attn.v_proj.bias', 'model.layers.12.mlp.down_proj.bias', 'model.layers.12.mlp.gate_proj.bias', 'model.layers.12.mlp.up_proj.bias', 'model.layers.12.self_attn.k_proj.bias', 'model.layers.12.self_attn.o_proj.bias', 'model.layers.12.self_attn.q_proj.bias', 'model.layers.12.self_attn.v_proj.bias', 'model.layers.13.mlp.down_proj.bias', 'model.layers.13.mlp.gate_proj.bias', 'model.layers.13.mlp.up_proj.bias', 'model.layers.13.self_attn.k_proj.bias', 'model.layers.13.self_attn.o_proj.bias', 'model.layers.13.self_attn.q_proj.bias', 'model.layers.13.self_attn.v_proj.bias', 'model.layers.14.mlp.down_proj.bias', 'model.layers.14.mlp.gate_proj.bias', 'model.layers.14.mlp.up_proj.bias', 'model.layers.14.self_attn.k_proj.bias', 'model.layers.14.self_attn.o_proj.bias', 'model.layers.14.self_attn.q_proj.bias', 'model.layers.14.self_attn.v_proj.bias', 'model.layers.15.mlp.down_proj.bias', 'model.layers.15.mlp.gate_proj.bias', 'model.layers.15.mlp.up_proj.bias', 'model.layers.15.self_attn.k_proj.bias', 'model.layers.15.self_attn.o_proj.bias', 'model.layers.15.self_attn.q_proj.bias', 'model.layers.15.self_attn.v_proj.bias', 'model.layers.16.mlp.down_proj.bias', 'model.layers.16.mlp.gate_proj.bias', 'model.layers.16.mlp.up_proj.bias', 'model.layers.16.self_attn.k_proj.bias', 'model.layers.16.self_attn.o_proj.bias', 'model.layers.16.self_attn.q_proj.bias', 'model.layers.16.self_attn.v_proj.bias', 'model.layers.17.mlp.down_proj.bias', 'model.layers.17.mlp.gate_proj.bias', 'model.layers.17.mlp.up_proj.bias', 'model.layers.17.self_attn.k_proj.bias', 'model.layers.17.self_attn.o_proj.bias', 'model.layers.17.self_attn.q_proj.bias', 'model.layers.17.self_attn.v_proj.bias', 'model.layers.18.mlp.down_proj.bias', 'model.layers.18.mlp.gate_proj.bias', 'model.layers.18.mlp.up_proj.bias', 'model.layers.18.self_attn.k_proj.bias', 'model.layers.18.self_attn.o_proj.bias', 'model.layers.18.self_attn.q_proj.bias', 'model.layers.18.self_attn.v_proj.bias', 'model.layers.19.mlp.down_proj.bias', 'model.layers.19.mlp.gate_proj.bias', 'model.layers.19.mlp.up_proj.bias', 'model.layers.19.self_attn.k_proj.bias', 'model.layers.19.self_attn.o_proj.bias', 'model.layers.19.self_attn.q_proj.bias', 'model.layers.19.self_attn.v_proj.bias', 'model.layers.2.mlp.down_proj.bias', 'model.layers.2.mlp.gate_proj.bias', 'model.layers.2.mlp.up_proj.bias', 'model.layers.2.self_attn.k_proj.bias', 'model.layers.2.self_attn.o_proj.bias', 'model.layers.2.self_attn.q_proj.bias', 'model.layers.2.self_attn.v_proj.bias', 'model.layers.20.mlp.down_proj.bias', 'model.layers.20.mlp.gate_proj.bias', 'model.layers.20.mlp.up_proj.bias', 'model.layers.20.self_attn.k_proj.bias', 'model.layers.20.self_attn.o_proj.bias', 'model.layers.20.self_attn.q_proj.bias', 'model.layers.20.self_attn.v_proj.bias',  ...
# - This IS expected if you are initializing LlamaForCausalLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LlamaForCausalLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2024-06-25:07:42:33,565 WARNING  [evaluator.py:251] Overwriting default num_fewshot of winogrande from None to 0
# 2024-06-25:07:42:33,566 INFO     [evaluator.py:261] Setting fewshot random generator seed to 1234
# 2024-06-25:07:42:33,566 WARNING  [evaluator.py:251] Overwriting default num_fewshot of hellaswag from None to 0
# 2024-06-25:07:42:33,566 INFO     [evaluator.py:261] Setting fewshot random generator seed to 1234
# 2024-06-25:07:42:33,566 WARNING  [evaluator.py:251] Overwriting default num_fewshot of arc_challenge from None to 0
# 2024-06-25:07:42:33,566 INFO     [evaluator.py:261] Setting fewshot random generator seed to 1234
# 2024-06-25:07:42:33,568 INFO     [task.py:410] Building contexts for winogrande on rank 0...
# 100% 1267/1267 [00:00<00:00, 80313.49it/s]
# 2024-06-25:07:42:33,634 INFO     [task.py:410] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [00:04<00:00, 2172.99it/s]
# 2024-06-25:07:42:39,366 INFO     [task.py:410] Building contexts for arc_challenge on rank 0...
# 100% 1172/1172 [00:01<00:00, 1008.98it/s]
# 2024-06-25:07:42:40,596 INFO     [evaluator.py:433] Running loglikelihood requests
# Running loglikelihood requests: 100% 47389/47389 [42:20<00:00, 18.65it/s]
# 2024-06-25:08:25:27,735 WARNING  [huggingface.py:1335] Failed to get model SHA for ./drive/MyDrive/autoround/Llama-3-8B-2bit-len1024-AutoRound-GPTQ/ at revision main. Error: Repo id must be in the form 'repo_name' or 'namespace/repo_name': './drive/MyDrive/autoround/Llama-3-8B-2bit-len1024-AutoRound-GPTQ/'. Use `repo_type` argument if needed.
# fatal: not a git repository (or any of the parent directories): .git
# 2024-06-25:08:25:28,981 INFO     [evaluation_tracker.py:182] Saving results aggregated
# hf (pretrained=./drive/MyDrive/autoround/Llama-3-8B-2bit-len1024-AutoRound-GPTQ/,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: 0, batch_size: 16
# |    Tasks    |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |-------------|------:|------|-----:|--------|---|-----:|---|-----:|
# |arc_challenge|      1|none  |     0|acc     |↑  |0.2287|±  |0.0123|
# |             |       |none  |     0|acc_norm|↑  |0.2628|±  |0.0129|
# |hellaswag    |      1|none  |     0|acc     |↑  |0.2572|±  |0.0044|
# |             |       |none  |     0|acc_norm|↑  |0.2675|±  |0.0044|
# |winogrande   |      1|none  |     0|acc     |↑  |0.4862|±  |0.0140|

# %%
# !lm_eval --model hf --model_args pretrained=./Llama-3-8B-4bit-Symm-AutoRound-GPTQ/ --tasks winogrande,hellaswag,arc_challenge --device cuda:0 --num_fewshot 0 --batch_size 16 --output_path ./eval_gptq/4bit
# Out:
# 2024-06-26 14:36:01.366739: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-26 14:36:01.422191: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-26 14:36:01.422242: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-26 14:36:01.424789: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-26 14:36:01.435155: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-26 14:36:02.547423: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-06-26:14:36:06,713 INFO     [__main__.py:272] Verbosity set to INFO
# 2024-06-26:14:36:13,573 INFO     [__main__.py:369] Selected Tasks: ['arc_challenge', 'hellaswag', 'winogrande']
# 2024-06-26:14:36:13,574 INFO     [evaluator.py:152] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-06-26:14:36:13,574 INFO     [evaluator.py:189] Initializing hf model, with arguments: {'pretrained': './drive/MyDrive/autoround/Llama-3-8B-4bit-Symm-AutoRound-GPTQ/'}
# 2024-06-26:14:36:13,597 INFO     [huggingface.py:169] Using device 'cuda:0'
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-06-26:14:36:14,146 WARNING  [qlinear_cuda.py:18] CUDA extension not installed.
# 2024-06-26:14:36:14,147 WARNING  [qlinear_cuda_old.py:17] CUDA extension not installed.
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:4481: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(
# Some weights of the model checkpoint at ./drive/MyDrive/autoround/Llama-3-8B-4bit-Symm-AutoRound-GPTQ/ were not used when initializing LlamaForCausalLM: ['model.layers.0.mlp.down_proj.bias', 'model.layers.0.mlp.gate_proj.bias', 'model.layers.0.mlp.up_proj.bias', 'model.layers.0.self_attn.k_proj.bias', 'model.layers.0.self_attn.o_proj.bias', 'model.layers.0.self_attn.q_proj.bias', 'model.layers.0.self_attn.v_proj.bias', 'model.layers.1.mlp.down_proj.bias', 'model.layers.1.mlp.gate_proj.bias', 'model.layers.1.mlp.up_proj.bias', 'model.layers.1.self_attn.k_proj.bias', 'model.layers.1.self_attn.o_proj.bias', 'model.layers.1.self_attn.q_proj.bias', 'model.layers.1.self_attn.v_proj.bias', 'model.layers.10.mlp.down_proj.bias', 'model.layers.10.mlp.gate_proj.bias', 'model.layers.10.mlp.up_proj.bias', 'model.layers.10.self_attn.k_proj.bias', 'model.layers.10.self_attn.o_proj.bias', 'model.layers.10.self_attn.q_proj.bias', 'model.layers.10.self_attn.v_proj.bias', 'model.layers.11.mlp.down_proj.bias', 'model.layers.11.mlp.gate_proj.bias', 'model.layers.11.mlp.up_proj.bias', 'model.layers.11.self_attn.k_proj.bias', 'model.layers.11.self_attn.o_proj.bias', 'model.layers.11.self_attn.q_proj.bias', 'model.layers.11.self_attn.v_proj.bias', 'model.layers.12.mlp.down_proj.bias', 'model.layers.12.mlp.gate_proj.bias', 'model.layers.12.mlp.up_proj.bias', 'model.layers.12.self_attn.k_proj.bias', 'model.layers.12.self_attn.o_proj.bias', 'model.layers.12.self_attn.q_proj.bias', 'model.layers.12.self_attn.v_proj.bias', 'model.layers.13.mlp.down_proj.bias', 'model.layers.13.mlp.gate_proj.bias', 'model.layers.13.mlp.up_proj.bias', 'model.layers.13.self_attn.k_proj.bias', 'model.layers.13.self_attn.o_proj.bias', 'model.layers.13.self_attn.q_proj.bias', 'model.layers.13.self_attn.v_proj.bias', 'model.layers.14.mlp.down_proj.bias', 'model.layers.14.mlp.gate_proj.bias', 'model.layers.14.mlp.up_proj.bias', 'model.layers.14.self_attn.k_proj.bias', 'model.layers.14.self_attn.o_proj.bias', 'model.layers.14.self_attn.q_proj.bias', 'model.layers.14.self_attn.v_proj.bias', 'model.layers.15.mlp.down_proj.bias', 'model.layers.15.mlp.gate_proj.bias', 'model.layers.15.mlp.up_proj.bias', 'model.layers.15.self_attn.k_proj.bias', 'model.layers.15.self_attn.o_proj.bias', 'model.layers.15.self_attn.q_proj.bias', 'model.layers.15.self_attn.v_proj.bias', 'model.layers.16.mlp.down_proj.bias', 'model.layers.16.mlp.gate_proj.bias', 'model.layers.16.mlp.up_proj.bias', 'model.layers.16.self_attn.k_proj.bias', 'model.layers.16.self_attn.o_proj.bias', 'model.layers.16.self_attn.q_proj.bias', 'model.layers.16.self_attn.v_proj.bias', 'model.layers.17.mlp.down_proj.bias', 'model.layers.17.mlp.gate_proj.bias', 'model.layers.17.mlp.up_proj.bias', 'model.layers.17.self_attn.k_proj.bias', 'model.layers.17.self_attn.o_proj.bias', 'model.layers.17.self_attn.q_proj.bias', 'model.layers.17.self_attn.v_proj.bias', 'model.layers.18.mlp.down_proj.bias', 'model.layers.18.mlp.gate_proj.bias', 'model.layers.18.mlp.up_proj.bias', 'model.layers.18.self_attn.k_proj.bias', 'model.layers.18.self_attn.o_proj.bias', 'model.layers.18.self_attn.q_proj.bias', 'model.layers.18.self_attn.v_proj.bias', 'model.layers.19.mlp.down_proj.bias', 'model.layers.19.mlp.gate_proj.bias', 'model.layers.19.mlp.up_proj.bias', 'model.layers.19.self_attn.k_proj.bias', 'model.layers.19.self_attn.o_proj.bias', 'model.layers.19.self_attn.q_proj.bias', 'model.layers.19.self_attn.v_proj.bias', 'model.layers.2.mlp.down_proj.bias', 'model.layers.2.mlp.gate_proj.bias', 'model.layers.2.mlp.up_proj.bias', 'model.layers.2.self_attn.k_proj.bias', 'model.layers.2.self_attn.o_proj.bias', 'model.layers.2.self_attn.q_proj.bias', 'model.layers.2.self_attn.v_proj.bias', 'model.layers.20.mlp.down_proj.bias', 'model.layers.20.mlp.gate_proj.bias', 'model.layers.20.mlp.up_proj.bias', 'model.layers.20.self_attn.k_proj.bias', 'model.layers.20.self_attn.o_proj.bias', 'model.layers.20.self_attn.q_proj.bias', 'model.layers.20.self_attn.v_proj.bias', 'mo ...
# - This IS expected if you are initializing LlamaForCausalLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LlamaForCausalLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# Downloading data: 47.5MB [00:00, 76.1MB/s]
# Downloading data: 11.8MB [00:00, 69.3MB/s]
# Downloading data: 12.2MB [00:00, 71.7MB/s]
# Generating train split: 100% 39905/39905 [00:04<00:00, 9594.60 examples/s]
# Generating test split: 100% 10003/10003 [00:01<00:00, 9560.68 examples/s]
# Generating validation split: 100% 10042/10042 [00:01<00:00, 9543.02 examples/s]
# Map: 100% 39905/39905 [00:06<00:00, 6483.79 examples/s]
# Map: 100% 10042/10042 [00:01<00:00, 6672.20 examples/s]
# Downloading builder script: 100% 5.65k/5.65k [00:00<00:00, 22.1MB/s]
# Downloading readme: 100% 9.97k/9.97k [00:00<00:00, 33.2MB/s]
# The repository for winogrande contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/winogrande.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# Downloading data: 100% 3.40M/3.40M [00:00<00:00, 72.1MB/s]
# Generating train split: 100% 40398/40398 [00:01<00:00, 24544.66 examples/s]
# Generating test split: 100% 1767/1767 [00:00<00:00, 24175.96 examples/s]
# Generating validation split: 100% 1267/1267 [00:00<00:00, 24101.15 examples/s]
# 2024-06-26:14:37:00,730 WARNING  [evaluator.py:251] Overwriting default num_fewshot of winogrande from None to 0
# 2024-06-26:14:37:00,730 INFO     [evaluator.py:261] Setting fewshot random generator seed to 1234
# 2024-06-26:14:37:00,730 WARNING  [evaluator.py:251] Overwriting default num_fewshot of hellaswag from None to 0
# 2024-06-26:14:37:00,730 INFO     [evaluator.py:261] Setting fewshot random generator seed to 1234
# 2024-06-26:14:37:00,730 WARNING  [evaluator.py:251] Overwriting default num_fewshot of arc_challenge from None to 0
# 2024-06-26:14:37:00,730 INFO     [evaluator.py:261] Setting fewshot random generator seed to 1234
# 2024-06-26:14:37:00,732 INFO     [task.py:411] Building contexts for winogrande on rank 0...
# 100% 1267/1267 [00:00<00:00, 78390.69it/s]
# 2024-06-26:14:37:00,791 INFO     [task.py:411] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [00:04<00:00, 2159.95it/s]
# 2024-06-26:14:37:06,534 INFO     [task.py:411] Building contexts for arc_challenge on rank 0...
# 100% 1172/1172 [00:01<00:00, 1012.04it/s]
# 2024-06-26:14:37:07,760 INFO     [evaluator.py:438] Running loglikelihood requests
# Running loglikelihood requests: 100% 47389/47389 [45:26<00:00, 17.38it/s]
# 2024-06-26:15:23:00,980 WARNING  [huggingface.py:1335] Failed to get model SHA for ./drive/MyDrive/autoround/Llama-3-8B-4bit-Symm-AutoRound-GPTQ/ at revision main. Error: Repo id must be in the form 'repo_name' or 'namespace/repo_name': './drive/MyDrive/autoround/Llama-3-8B-4bit-Symm-AutoRound-GPTQ/'. Use `repo_type` argument if needed.
# fatal: not a git repository (or any of the parent directories): .git
# 2024-06-26:15:23:03,058 INFO     [evaluation_tracker.py:182] Saving results aggregated
# hf (pretrained=./drive/MyDrive/autoround/Llama-3-8B-4bit-Symm-AutoRound-GPTQ/), gen_kwargs: (None), limit: None, num_fewshot: 0, batch_size: 16
# |    Tasks    |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |-------------|------:|------|-----:|--------|---|-----:|---|-----:|
# |arc_challenge|      1|none  |     0|acc     |↑  |0.4949|±  |0.0146|
# |             |       |none  |     0|acc_norm|↑  |0.5213|±  |0.0146|
# |hellaswag    |      1|none  |     0|acc     |↑  |0.5923|±  |0.0049|
# |             |       |none  |     0|acc_norm|↑  |0.7789|±  |0.0041|
# |winogrande   |      1|none  |     0|acc     |↑  |0.7427|±  |0.0123|

# %%
# !lm_eval --model hf --model_args pretrained=./Llama-3-8B-2bit-Sym-AutoRound-GPTQ/ --tasks winogrande,hellaswag,arc_challenge --device cuda:0 --num_fewshot 0 --batch_size 16 --output_path ./eval_gptq/4bit
# Out:
# 2024-06-25 13:06:11.428493: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-25 13:06:12.302150: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-25 13:06:12.302214: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-25 13:06:12.420607: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-25 13:06:12.648372: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-25 13:06:14.668199: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Downloading builder script: 100% 5.67k/5.67k [00:00<00:00, 20.0MB/s]
# 2024-06-25:13:06:22,614 INFO     [__main__.py:272] Verbosity set to INFO
# 2024-06-25:13:06:29,512 INFO     [__main__.py:369] Selected Tasks: ['arc_challenge', 'hellaswag', 'winogrande']
# 2024-06-25:13:06:29,518 INFO     [evaluator.py:152] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-06-25:13:06:29,518 INFO     [evaluator.py:189] Initializing hf model, with arguments: {'pretrained': './drive/MyDrive/autoround/Llama-3-8B-2bit-Sym-AutoRound-GPTQ/'}
# 2024-06-25:13:06:29,541 INFO     [huggingface.py:169] Using device 'cuda:0'
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-06-25:13:06:30,341 WARNING  [qlinear_cuda.py:18] CUDA extension not installed.
# 2024-06-25:13:06:30,342 WARNING  [qlinear_cuda_old.py:17] CUDA extension not installed.
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:4481: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(
# Some weights of the model checkpoint at ./drive/MyDrive/autoround/Llama-3-8B-2bit-Sym-AutoRound-GPTQ/ were not used when initializing LlamaForCausalLM: ['model.layers.0.mlp.down_proj.bias', 'model.layers.0.mlp.gate_proj.bias', 'model.layers.0.mlp.up_proj.bias', 'model.layers.0.self_attn.k_proj.bias', 'model.layers.0.self_attn.o_proj.bias', 'model.layers.0.self_attn.q_proj.bias', 'model.layers.0.self_attn.v_proj.bias', 'model.layers.1.mlp.down_proj.bias', 'model.layers.1.mlp.gate_proj.bias', 'model.layers.1.mlp.up_proj.bias', 'model.layers.1.self_attn.k_proj.bias', 'model.layers.1.self_attn.o_proj.bias', 'model.layers.1.self_attn.q_proj.bias', 'model.layers.1.self_attn.v_proj.bias', 'model.layers.10.mlp.down_proj.bias', 'model.layers.10.mlp.gate_proj.bias', 'model.layers.10.mlp.up_proj.bias', 'model.layers.10.self_attn.k_proj.bias', 'model.layers.10.self_attn.o_proj.bias', 'model.layers.10.self_attn.q_proj.bias', 'model.layers.10.self_attn.v_proj.bias', 'model.layers.11.mlp.down_proj.bias', 'model.layers.11.mlp.gate_proj.bias', 'model.layers.11.mlp.up_proj.bias', 'model.layers.11.self_attn.k_proj.bias', 'model.layers.11.self_attn.o_proj.bias', 'model.layers.11.self_attn.q_proj.bias', 'model.layers.11.self_attn.v_proj.bias', 'model.layers.12.mlp.down_proj.bias', 'model.layers.12.mlp.gate_proj.bias', 'model.layers.12.mlp.up_proj.bias', 'model.layers.12.self_attn.k_proj.bias', 'model.layers.12.self_attn.o_proj.bias', 'model.layers.12.self_attn.q_proj.bias', 'model.layers.12.self_attn.v_proj.bias', 'model.layers.13.mlp.down_proj.bias', 'model.layers.13.mlp.gate_proj.bias', 'model.layers.13.mlp.up_proj.bias', 'model.layers.13.self_attn.k_proj.bias', 'model.layers.13.self_attn.o_proj.bias', 'model.layers.13.self_attn.q_proj.bias', 'model.layers.13.self_attn.v_proj.bias', 'model.layers.14.mlp.down_proj.bias', 'model.layers.14.mlp.gate_proj.bias', 'model.layers.14.mlp.up_proj.bias', 'model.layers.14.self_attn.k_proj.bias', 'model.layers.14.self_attn.o_proj.bias', 'model.layers.14.self_attn.q_proj.bias', 'model.layers.14.self_attn.v_proj.bias', 'model.layers.15.mlp.down_proj.bias', 'model.layers.15.mlp.gate_proj.bias', 'model.layers.15.mlp.up_proj.bias', 'model.layers.15.self_attn.k_proj.bias', 'model.layers.15.self_attn.o_proj.bias', 'model.layers.15.self_attn.q_proj.bias', 'model.layers.15.self_attn.v_proj.bias', 'model.layers.16.mlp.down_proj.bias', 'model.layers.16.mlp.gate_proj.bias', 'model.layers.16.mlp.up_proj.bias', 'model.layers.16.self_attn.k_proj.bias', 'model.layers.16.self_attn.o_proj.bias', 'model.layers.16.self_attn.q_proj.bias', 'model.layers.16.self_attn.v_proj.bias', 'model.layers.17.mlp.down_proj.bias', 'model.layers.17.mlp.gate_proj.bias', 'model.layers.17.mlp.up_proj.bias', 'model.layers.17.self_attn.k_proj.bias', 'model.layers.17.self_attn.o_proj.bias', 'model.layers.17.self_attn.q_proj.bias', 'model.layers.17.self_attn.v_proj.bias', 'model.layers.18.mlp.down_proj.bias', 'model.layers.18.mlp.gate_proj.bias', 'model.layers.18.mlp.up_proj.bias', 'model.layers.18.self_attn.k_proj.bias', 'model.layers.18.self_attn.o_proj.bias', 'model.layers.18.self_attn.q_proj.bias', 'model.layers.18.self_attn.v_proj.bias', 'model.layers.19.mlp.down_proj.bias', 'model.layers.19.mlp.gate_proj.bias', 'model.layers.19.mlp.up_proj.bias', 'model.layers.19.self_attn.k_proj.bias', 'model.layers.19.self_attn.o_proj.bias', 'model.layers.19.self_attn.q_proj.bias', 'model.layers.19.self_attn.v_proj.bias', 'model.layers.2.mlp.down_proj.bias', 'model.layers.2.mlp.gate_proj.bias', 'model.layers.2.mlp.up_proj.bias', 'model.layers.2.self_attn.k_proj.bias', 'model.layers.2.self_attn.o_proj.bias', 'model.layers.2.self_attn.q_proj.bias', 'model.layers.2.self_attn.v_proj.bias', 'model.layers.20.mlp.down_proj.bias', 'model.layers.20.mlp.gate_proj.bias', 'model.layers.20.mlp.up_proj.bias', 'model.layers.20.self_attn.k_proj.bias', 'model.layers.20.self_attn.o_proj.bias', 'model.layers.20.self_attn.q_proj.bias', 'model.layers.20.self_attn.v_proj.bias', 'mod ...
# - This IS expected if you are initializing LlamaForCausalLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LlamaForCausalLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading readme: 100% 9.00k/9.00k [00:00<00:00, 25.5MB/s]
# Downloading data: 100% 190k/190k [00:00<00:00, 594kB/s]
# Downloading data: 100% 204k/204k [00:00<00:00, 865kB/s]
# Downloading data: 100% 55.7k/55.7k [00:00<00:00, 235kB/s]
# Generating train split: 100% 1119/1119 [00:00<00:00, 63107.44 examples/s]
# Generating test split: 100% 1172/1172 [00:00<00:00, 280545.84 examples/s]
# Generating validation split: 100% 299/299 [00:00<00:00, 135329.33 examples/s]
# Downloading builder script: 100% 4.36k/4.36k [00:00<00:00, 16.6MB/s]
# Downloading metadata: 100% 2.53k/2.53k [00:00<00:00, 15.9MB/s]
# Downloading readme: 100% 6.84k/6.84k [00:00<00:00, 25.3MB/s]
# The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# Downloading data: 47.5MB [00:00, 77.3MB/s]
# y
# Downloading data: 11.8MB [00:00, 75.5MB/s]
# Downloading data: 12.2MB [00:00, 75.5MB/s]
# Generating train split: 100% 39905/39905 [00:04<00:00, 9539.97 examples/s]
# Generating test split: 100% 10003/10003 [00:01<00:00, 9518.67 examples/s]
# Generating validation split: 100% 10042/10042 [00:01<00:00, 9524.79 examples/s]
# Map: 100% 39905/39905 [00:06<00:00, 6581.52 examples/s]
# Map: 100% 10042/10042 [00:01<00:00, 6854.55 examples/s]
# Downloading builder script: 100% 5.65k/5.65k [00:00<00:00, 23.4MB/s]
# Downloading readme: 100% 9.97k/9.97k [00:00<00:00, 31.0MB/s]
# The repository for winogrande contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/winogrande.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Downloading data: 100% 3.40M/3.40M [00:01<00:00, 2.53MB/s]
# Generating train split: 100% 40398/40398 [00:01<00:00, 24063.65 examples/s]
# Generating test split: 100% 1767/1767 [00:00<00:00, 23920.73 examples/s]
# Generating validation split: 100% 1267/1267 [00:00<00:00, 22729.90 examples/s]
# 2024-06-25:13:07:34,563 WARNING  [evaluator.py:251] Overwriting default num_fewshot of winogrande from None to 0
# 2024-06-25:13:07:34,563 INFO     [evaluator.py:261] Setting fewshot random generator seed to 1234
# 2024-06-25:13:07:34,563 WARNING  [evaluator.py:251] Overwriting default num_fewshot of hellaswag from None to 0
# 2024-06-25:13:07:34,563 INFO     [evaluator.py:261] Setting fewshot random generator seed to 1234
# 2024-06-25:13:07:34,563 WARNING  [evaluator.py:251] Overwriting default num_fewshot of arc_challenge from None to 0
# 2024-06-25:13:07:34,563 INFO     [evaluator.py:261] Setting fewshot random generator seed to 1234
# 2024-06-25:13:07:34,565 INFO     [task.py:410] Building contexts for winogrande on rank 0...
# 100% 1267/1267 [00:00<00:00, 75072.87it/s]
# 2024-06-25:13:07:34,626 INFO     [task.py:410] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [00:04<00:00, 2149.35it/s]
# 2024-06-25:13:07:40,409 INFO     [task.py:410] Building contexts for arc_challenge on rank 0...
# 100% 1172/1172 [00:01<00:00, 1001.78it/s]
# 2024-06-25:13:07:41,665 INFO     [evaluator.py:433] Running loglikelihood requests
# Running loglikelihood requests: 100% 47389/47389 [42:13<00:00, 18.71it/s]
# 2024-06-25:13:50:21,634 WARNING  [huggingface.py:1335] Failed to get model SHA for ./drive/MyDrive/autoround/Llama-3-8B-2bit-Sym-AutoRound-GPTQ/ at revision main. Error: Repo id must be in the form 'repo_name' or 'namespace/repo_name': './drive/MyDrive/autoround/Llama-3-8B-2bit-Sym-AutoRound-GPTQ/'. Use `repo_type` argument if needed.
# fatal: not a git repository (or any of the parent directories): .git
# 2024-06-25:13:50:23,806 INFO     [evaluation_tracker.py:182] Saving results aggregated
# hf (pretrained=./drive/MyDrive/autoround/Llama-3-8B-2bit-Sym-AutoRound-GPTQ/), gen_kwargs: (None), limit: None, num_fewshot: 0, batch_size: 16
# |    Tasks    |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |-------------|------:|------|-----:|--------|---|-----:|---|-----:|
# |arc_challenge|      1|none  |     0|acc     |↑  |0.2363|±  |0.0124|
# |             |       |none  |     0|acc_norm|↑  |0.2662|±  |0.0129|
# |hellaswag    |      1|none  |     0|acc     |↑  |0.2568|±  |0.0044|
# |             |       |none  |     0|acc_norm|↑  |0.2668|±  |0.0044|
# |winogrande   |      1|none  |     0|acc     |↑  |0.4996|±  |0.0141|

# %% [markdown]
# #Benchmarking Inference Throughput with vLLM

# %%
# !git clone https://github.com/vllm-project/vllm.git
# !cd vllm && pip install -e .  # This may take 5-10 minutes.
# Out:
# fatal: destination path 'vllm' already exists and is not an empty directory.
# Obtaining file:///content/vllm
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: cmake>=3.21 in /usr/local/lib/python3.10/dist-packages (from vllm==0.5.0.post1+cu122) (3.27.9)
# Collecting ninja (from vllm==0.5.0.post1+cu122)
#   Using cached ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from vllm==0.5.0.post1+cu122) (5.9.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from vllm==0.5.0.post1+cu122) (0.1.99)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from vllm==0.5.0.post1+cu122) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vllm==0.5.0.post1+cu122) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from vllm==0.5.0.post1+cu122) (4.66.4)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from vllm==0.5.0.post1+cu122) (9.0.0)
# Requirement already satisfied: transformers>=4.40.0 in /usr/local/lib/python3.10/dist-packages (from vllm==0.5.0.post1+cu122) (4.41.2)
# Requirement already satisfied: tokenizers>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from vllm==0.5.0.post1+cu122) (0.19.1)
# Collecting fastapi (from vllm==0.5.0.post1+cu122)
#   Using cached fastapi-0.111.0-py3-none-any.whl (91 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from vllm==0.5.0.post1+cu122) (3.9.5)
# Collecting openai (from vllm==0.5.0.post1+cu122)
#   Using cached openai-1.35.4-py3-none-any.whl (327 kB)
# Collecting uvicorn[standard] (from vllm==0.5.0.post1+cu122)
#   Using cached uvicorn-0.30.1-py3-none-any.whl (62 kB)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from vllm==0.5.0.post1+cu122) (2.7.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from vllm==0.5.0.post1+cu122) (9.4.0)
# Requirement already satisfied: prometheus-client>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from vllm==0.5.0.post1+cu122) (0.20.0)
# Collecting prometheus-fastapi-instrumentator>=7.0.0 (from vllm==0.5.0.post1+cu122)
#   Using cached prometheus_fastapi_instrumentator-7.0.0-py3-none-any.whl (19 kB)
# Collecting tiktoken>=0.6.0 (from vllm==0.5.0.post1+cu122)
#   Using cached tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Collecting lm-format-enforcer==0.10.1 (from vllm==0.5.0.post1+cu122)
#   Using cached lm_format_enforcer-0.10.1-py3-none-any.whl (42 kB)
# Collecting outlines>=0.0.43 (from vllm==0.5.0.post1+cu122)
#   Using cached outlines-0.0.46-py3-none-any.whl (101 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from vllm==0.5.0.post1+cu122) (4.12.2)
# Requirement already satisfied: filelock>=3.10.4 in /usr/local/lib/python3.10/dist-packages (from vllm==0.5.0.post1+cu122) (3.15.3)
# Collecting ray>=2.9 (from vllm==0.5.0.post1+cu122)
#   Using cached ray-2.30.0-cp310-cp310-manylinux2014_x86_64.whl (66.0 MB)
# Collecting nvidia-ml-py (from vllm==0.5.0.post1+cu122)
#   Using cached nvidia_ml_py-12.555.43-py3-none-any.whl (39 kB)
# Requirement already satisfied: torch==2.3.0 in /usr/local/lib/python3.10/dist-packages (from vllm==0.5.0.post1+cu122) (2.3.0+cu121)
# Requirement already satisfied: torchvision==0.18.0 in /usr/local/lib/python3.10/dist-packages (from vllm==0.5.0.post1+cu122) (0.18.0+cu121)
# Collecting xformers==0.0.26.post1 (from vllm==0.5.0.post1+cu122)
#   Using cached xformers-0.0.26.post1-cp310-cp310-manylinux2014_x86_64.whl (222.7 MB)
# Collecting vllm-flash-attn==2.5.9 (from vllm==0.5.0.post1+cu122)
#   Using cached vllm_flash_attn-2.5.9-cp310-cp310-manylinux1_x86_64.whl (37.1 MB)
# Collecting interegular>=0.3.2 (from lm-format-enforcer==0.10.1->vllm==0.5.0.post1+cu122)
#   Using cached interegular-0.3.3-py37-none-any.whl (23 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from lm-format-enforcer==0.10.1->vllm==0.5.0.post1+cu122) (24.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from lm-format-enforcer==0.10.1->vllm==0.5.0.post1+cu122) (6.0.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->vllm==0.5.0.post1+cu122) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->vllm==0.5.0.post1+cu122) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->vllm==0.5.0.post1+cu122) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->vllm==0.5.0.post1+cu122) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->vllm==0.5.0.post1+cu122) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->vllm==0.5.0.post1+cu122) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->vllm==0.5.0.post1+cu122) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->vllm==0.5.0.post1+cu122) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->vllm==0.5.0.post1+cu122) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->vllm==0.5.0.post1+cu122) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->vllm==0.5.0.post1+cu122) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->vllm==0.5.0.post1+cu122) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->vllm==0.5.0.post1+cu122) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->vllm==0.5.0.post1+cu122) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->vllm==0.5.0.post1+cu122) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->vllm==0.5.0.post1+cu122) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.0->vllm==0.5.0.post1+cu122) (12.5.40)
# Collecting lark (from outlines>=0.0.43->vllm==0.5.0.post1+cu122)
#   Using cached lark-1.1.9-py3-none-any.whl (111 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from outlines>=0.0.43->vllm==0.5.0.post1+cu122) (1.6.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from outlines>=0.0.43->vllm==0.5.0.post1+cu122) (2.2.1)
# Collecting diskcache (from outlines>=0.0.43->vllm==0.5.0.post1+cu122)
#   Using cached diskcache-5.6.3-py3-none-any.whl (45 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from outlines>=0.0.43->vllm==0.5.0.post1+cu122) (0.58.1)
# Requirement already satisfied: referencing in /usr/local/lib/python3.10/dist-packages (from outlines>=0.0.43->vllm==0.5.0.post1+cu122) (0.35.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from outlines>=0.0.43->vllm==0.5.0.post1+cu122) (4.19.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from outlines>=0.0.43->vllm==0.5.0.post1+cu122) (2.20.0)
# Collecting pycountry (from outlines>=0.0.43->vllm==0.5.0.post1+cu122)
#   Using cached pycountry-24.6.1-py3-none-any.whl (6.3 MB)
# Collecting pyairports (from outlines>=0.0.43->vllm==0.5.0.post1+cu122)
#   Using cached pyairports-2.1.1-py3-none-any.whl (371 kB)
# Collecting starlette<1.0.0,>=0.30.0 (from prometheus-fastapi-instrumentator>=7.0.0->vllm==0.5.0.post1+cu122)
#   Using cached starlette-0.37.2-py3-none-any.whl (71 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->vllm==0.5.0.post1+cu122) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->vllm==0.5.0.post1+cu122) (2.18.4)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm==0.5.0.post1+cu122) (8.1.7)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm==0.5.0.post1+cu122) (1.0.8)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm==0.5.0.post1+cu122) (3.20.3)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm==0.5.0.post1+cu122) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm==0.5.0.post1+cu122) (1.4.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken>=0.6.0->vllm==0.5.0.post1+cu122) (2024.5.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vllm==0.5.0.post1+cu122) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vllm==0.5.0.post1+cu122) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vllm==0.5.0.post1+cu122) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vllm==0.5.0.post1+cu122) (2024.6.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.19.1->vllm==0.5.0.post1+cu122) (0.23.4)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.40.0->vllm==0.5.0.post1+cu122) (0.4.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->vllm==0.5.0.post1+cu122) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->vllm==0.5.0.post1+cu122) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->vllm==0.5.0.post1+cu122) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->vllm==0.5.0.post1+cu122) (4.0.3)
# Collecting fastapi-cli>=0.0.2 (from fastapi->vllm==0.5.0.post1+cu122)
#   Using cached fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Collecting httpx>=0.23.0 (from fastapi->vllm==0.5.0.post1+cu122)
#   Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Collecting python-multipart>=0.0.7 (from fastapi->vllm==0.5.0.post1+cu122)
#   Using cached python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 (from fastapi->vllm==0.5.0.post1+cu122)
#   Using cached ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
# Collecting orjson>=3.2.1 (from fastapi->vllm==0.5.0.post1+cu122)
#   Using cached orjson-3.10.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
# Collecting email_validator>=2.0.0 (from fastapi->vllm==0.5.0.post1+cu122)
#   Using cached email_validator-2.2.0-py3-none-any.whl (33 kB)
# Collecting h11>=0.8 (from uvicorn[standard]->vllm==0.5.0.post1+cu122)
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting httptools>=0.5.0 (from uvicorn[standard]->vllm==0.5.0.post1+cu122)
#   Using cached httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]->vllm==0.5.0.post1+cu122)
#   Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]->vllm==0.5.0.post1+cu122)
#   Using cached uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]->vllm==0.5.0.post1+cu122)
#   Using cached watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Collecting websockets>=10.4 (from uvicorn[standard]->vllm==0.5.0.post1+cu122)
#   Using cached websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai->vllm==0.5.0.post1+cu122) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai->vllm==0.5.0.post1+cu122) (1.7.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai->vllm==0.5.0.post1+cu122) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai->vllm==0.5.0.post1+cu122) (1.2.1)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi->vllm==0.5.0.post1+cu122)
#   Using cached dnspython-2.6.1-py3-none-any.whl (307 kB)
# Requirement already satisfied: typer>=0.12.3 in /usr/local/lib/python3.10/dist-packages (from fastapi-cli>=0.0.2->fastapi->vllm==0.5.0.post1+cu122) (0.12.3)
# Collecting httpcore==1.* (from httpx>=0.23.0->fastapi->vllm==0.5.0.post1+cu122)
#   Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.3.0->vllm==0.5.0.post1+cu122) (2.1.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->outlines>=0.0.43->vllm==0.5.0.post1+cu122) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->outlines>=0.0.43->vllm==0.5.0.post1+cu122) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->outlines>=0.0.43->vllm==0.5.0.post1+cu122) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->outlines>=0.0.43->vllm==0.5.0.post1+cu122) (2.0.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->outlines>=0.0.43->vllm==0.5.0.post1+cu122) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->outlines>=0.0.43->vllm==0.5.0.post1+cu122) (0.70.16)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->outlines>=0.0.43->vllm==0.5.0.post1+cu122) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->outlines>=0.0.43->vllm==0.5.0.post1+cu122) (0.18.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->outlines>=0.0.43->vllm==0.5.0.post1+cu122) (0.41.1)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.3.0->vllm==0.5.0.post1+cu122) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->vllm==0.5.0.post1+cu122) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->vllm==0.5.0.post1+cu122) (13.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->outlines>=0.0.43->vllm==0.5.0.post1+cu122) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->outlines>=0.0.43->vllm==0.5.0.post1+cu122) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->outlines>=0.0.43->vllm==0.5.0.post1+cu122) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->outlines>=0.0.43->vllm==0.5.0.post1+cu122) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->vllm==0.5.0.post1+cu122) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->vllm==0.5.0.post1+cu122) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->vllm==0.5.0.post1+cu122) (0.1.2)
# Building wheels for collected packages: vllm
#   Building editable for vllm (pyproject.toml) ... done
#   Created wheel for vllm: filename=vllm-0.5.0.post1+cu122-0.editable-cp310-cp310-linux_x86_64.whl size=10419 sha256=b1a59b16803672f94f08bbbadf8ce7781147894677fc27f4cbc1cd7b2a9b842a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-miypnfvb/wheels/35/28/89/44ebc8017c7395bab306eb7218f34e5d09408126dd82c20f16
# Successfully built vllm
# Installing collected packages: pyairports, nvidia-ml-py, ninja, websockets, uvloop, ujson, python-multipart, python-dotenv, pycountry, orjson, lark, interegular, httptools, h11, dnspython, diskcache, watchfiles, uvicorn, tiktoken, starlette, httpcore, email_validator, prometheus-fastapi-instrumentator, lm-format-enforcer, httpx, xformers, vllm-flash-attn, ray, openai, fastapi-cli, outlines, fastapi, vllm
# Successfully installed diskcache-5.6.3 dnspython-2.6.1 email_validator-2.2.0 fastapi-0.111.0 fastapi-cli-0.0.4 h11-0.14.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 interegular-0.3.3 lark-1.1.9 lm-format-enforcer-0.10.1 ninja-1.11.1.1 nvidia-ml-py-12.555.43 openai-1.35.4 orjson-3.10.5 outlines-0.0.46 prometheus-fastapi-instrumentator-7.0.0 pyairports-2.1.1 pycountry-24.6.1 python-dotenv-1.0.1 python-multipart-0.0.9 ray-2.30.0 starlette-0.37.2 tiktoken-0.7.0 ujson-5.10.0 uvicorn-0.30.1 uvloop-0.19.0 vllm-0.5.0.post1+cu122 vllm-flash-attn-2.5.9 watchfiles-0.22.0 websockets-12.0 xformers-0.0.26.post1

# %%
# !wget https://huggingface.co/datasets/anon8231489123/ShareGPT_Vicuna_unfiltered/resolve/main/ShareGPT_V3_unfiltered_cleaned_split.json
# Out:
# --2024-06-26 16:00:43--  https://huggingface.co/datasets/anon8231489123/ShareGPT_Vicuna_unfiltered/resolve/main/ShareGPT_V3_unfiltered_cleaned_split.json
# Resolving huggingface.co (huggingface.co)... 18.164.174.23, 18.164.174.17, 18.164.174.118, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.23|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/58/74/5874e8234cbcd37dd31ca486e8492d9f1370bdd04829001f53991a866851e83f/35f0e213ce091ed9b9af2a1f0755e9d39f9ccec34ab281cd4ca60d70f6479ba4?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27ShareGPT_V3_unfiltered_cleaned_split.json%3B+filename%3D%22ShareGPT_V3_unfiltered_cleaned_split.json%22%3B&response-content-type=application%2Fjson&Expires=1719676844&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=m8SAws6cIBwizkZNj3CeGiX2XOkhWx15DMDEajkqyDYpT5hempMTKghG8ILKoE18u%7E-6P1yEykM35DpGda68mjI713Qm%7Eb7hCnglVGuTqCLjSIIjPWR%7EuexwgczTNTq5ohCQPVGSqMyW%7EsXRGZuIDbLSXuE3lZ71dEcL9TDf0U0kwC0IYmNWPzld99qbSrLOqczM7DJbPKknJef4ZurhP1PluaqI6CksBVqzC%7Eszrksv%7EIIRfX7h2mvxuR5U9R86ffoviJwjZzdnxPJdOUyjQVCkojoqN6O-3zz5fC8wQTIAIHz6jjUAxHqH0YDlNKIGDnWleFiTMOV4FhHqh9wxiQ__&Key-Pair-Id=K3ESJI6DHPFC7 [following]
# --2024-06-26 16:00:44--  https://cdn-lfs.huggingface.co/repos/58/74/5874e8234cbcd37dd31ca486e8492d9f1370bdd04829001f53991a866851e83f/35f0e213ce091ed9b9af2a1f0755e9d39f9ccec34ab281cd4ca60d70f6479ba4?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27ShareGPT_V3_unfiltered_cleaned_split.json%3B+filename%3D%22ShareGPT_V3_unfiltered_cleaned_split.json%22%3B&response-content-type=application%2Fjson&Expires=1719676844&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=m8SAws6cIBwizkZNj3CeGiX2XOkhWx15DMDEajkqyDYpT5hempMTKghG8ILKoE18u%7E-6P1yEykM35DpGda68mjI713Qm%7Eb7hCnglVGuTqCLjSIIjPWR%7EuexwgczTNTq5ohCQPVGSqMyW%7EsXRGZuIDbLSXuE3lZ71dEcL9TDf0U0kwC0IYmNWPzld99qbSrLOqczM7DJbPKknJef4ZurhP1PluaqI6CksBVqzC%7Eszrksv%7EIIRfX7h2mvxuR5U9R86ffoviJwjZzdnxPJdOUyjQVCkojoqN6O-3zz5fC8wQTIAIHz6jjUAxHqH0YDlNKIGDnWleFiTMOV4FhHqh9wxiQ__&Key-Pair-Id=K3ESJI6DHPFC7
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.155.173.108, 18.155.173.8, 18.155.173.61, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.155.173.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 672837942 (642M) [application/json]
# Saving to: ‘ShareGPT_V3_unfiltered_cleaned_split.json’
#
# ShareGPT_V3_unfilte 100%[===================>] 641.67M   136MB/s    in 5.2s
#
# 2024-06-26 16:00:49 (124 MB/s) - ‘ShareGPT_V3_unfiltered_cleaned_split.json’ saved [672837942/672837942]

# %%
# !python vllm/benchmarks/benchmark_throughput.py --backend vllm --dataset ShareGPT_V3_unfiltered_cleaned_split.json --model ./Llama-3-8B-4bit-AutoRound-GPTQ/
# Out:
# Namespace(backend='vllm', dataset='ShareGPT_V3_unfiltered_cleaned_split.json', input_len=None, output_len=None, model='./drive/MyDrive/autoround/Llama-3-8B-4bit-AutoRound-GPTQ/', tokenizer='./drive/MyDrive/autoround/Llama-3-8B-4bit-AutoRound-GPTQ/', quantization=None, tensor_parallel_size=1, n=1, use_beam_search=False, num_prompts=1000, seed=0, hf_max_batch_size=None, trust_remote_code=False, max_model_len=None, dtype='auto', gpu_memory_utilization=0.9, enforce_eager=False, kv_cache_dtype='auto', quantization_param_path=None, device='cuda', enable_prefix_caching=False, enable_chunked_prefill=False, max_num_batched_tokens=None, download_dir=None, output_json=None, distributed_executor_backend=None, load_format='auto')
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# WARNING 06-26 08:05:02 config.py:220] gptq quantization is not fully optimized yet. The speed can be slower than non-quantized models.
# INFO 06-26 08:05:02 llm_engine.py:164] Initializing an LLM engine (v0.5.0.post1) with config: model='./drive/MyDrive/autoround/Llama-3-8B-4bit-AutoRound-GPTQ/', speculative_config=None, tokenizer='./drive/MyDrive/autoround/Llama-3-8B-4bit-AutoRound-GPTQ/', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, rope_scaling=None, rope_theta=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=8192, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, disable_custom_all_reduce=False, quantization=gptq, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None), seed=0, served_model_name=./drive/MyDrive/autoround/Llama-3-8B-4bit-AutoRound-GPTQ/)
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-06-26 08:05:03.045926: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-26 08:05:03.092197: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-26 08:05:03.092254: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-26 08:05:03.094122: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-26 08:05:03.103060: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-26 08:05:04.301802: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO 06-26 08:07:44 model_runner.py:224] Loading model weights took 5.3472 GB
# INFO 06-26 08:07:47 gpu_executor.py:83] # GPU blocks: 6571, # CPU blocks: 2048
# INFO 06-26 08:07:49 model_runner.py:845] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 06-26 08:07:49 model_runner.py:849] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 06-26 08:08:12 model_runner.py:921] Graph capturing finished in 22 secs.
# Processed prompts: 100% 1000/1000 [05:18<00:00,  3.14it/s, est. speed input: 674.66 toks/s, output: 621.83 toks/s]
# Throughput: 3.13 requests/s, 1292.37 tokens/s

# %%
# !python vllm/benchmarks/benchmark_throughput.py --backend vllm --dataset ShareGPT_V3_unfiltered_cleaned_split.json --model ./Llama-3-8B-4bit-Symm-AutoRound-GPTQ/
# Out:
# Namespace(backend='vllm', dataset='ShareGPT_V3_unfiltered_cleaned_split.json', input_len=None, output_len=None, model='./drive/MyDrive/autoround/Llama-3-8B-4bit-Symm-AutoRound-GPTQ/', tokenizer='./drive/MyDrive/autoround/Llama-3-8B-4bit-Symm-AutoRound-GPTQ/', quantization=None, tensor_parallel_size=1, n=1, use_beam_search=False, num_prompts=1000, seed=0, hf_max_batch_size=None, trust_remote_code=False, max_model_len=None, dtype='auto', gpu_memory_utilization=0.9, enforce_eager=False, kv_cache_dtype='auto', quantization_param_path=None, device='cuda', enable_prefix_caching=False, enable_chunked_prefill=False, max_num_batched_tokens=None, download_dir=None, output_json=None, distributed_executor_backend=None, load_format='auto')
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# INFO 06-26 16:00:58 gptq_marlin.py:134] The model is convertible to gptq_marlin during runtime. Using gptq_marlin kernel.
# INFO 06-26 16:00:58 llm_engine.py:164] Initializing an LLM engine (v0.5.0.post1) with config: model='./drive/MyDrive/autoround/Llama-3-8B-4bit-Symm-AutoRound-GPTQ/', speculative_config=None, tokenizer='./drive/MyDrive/autoround/Llama-3-8B-4bit-Symm-AutoRound-GPTQ/', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, rope_scaling=None, rope_theta=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=8192, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, disable_custom_all_reduce=False, quantization=gptq_marlin, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None), seed=0, served_model_name=./drive/MyDrive/autoround/Llama-3-8B-4bit-Symm-AutoRound-GPTQ/)
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-06-26 16:01:00.607799: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-26 16:01:01.586538: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-26 16:01:01.586604: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-26 16:01:01.709385: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-26 16:01:01.967384: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-26 16:01:04.359583: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO 06-26 16:01:37 model_runner.py:224] Loading model weights took 5.3262 GB
# INFO 06-26 16:01:40 gpu_executor.py:83] # GPU blocks: 6513, # CPU blocks: 2048
# INFO 06-26 16:01:43 model_runner.py:845] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 06-26 16:01:43 model_runner.py:849] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 06-26 16:02:00 model_runner.py:921] Graph capturing finished in 17 secs.
# Processed prompts: 100% 1000/1000 [03:27<00:00,  4.82it/s, est. speed input: 1037.06 toks/s, output: 955.84 toks/s]
# Throughput: 4.80 requests/s, 1983.00 tokens/s

# %%
# !python vllm/benchmarks/benchmark_throughput.py --backend vllm --dataset ShareGPT_V3_unfiltered_cleaned_split.json --model kaitchup/Meta-Llama-3-8B-gptq-4bit
# Out:
# Namespace(backend='vllm', dataset='ShareGPT_V3_unfiltered_cleaned_split.json', input_len=None, output_len=None, model='kaitchup/Meta-Llama-3-8B-gptq-4bit', tokenizer='kaitchup/Meta-Llama-3-8B-gptq-4bit', quantization=None, tensor_parallel_size=1, n=1, use_beam_search=False, num_prompts=1000, seed=0, hf_max_batch_size=None, trust_remote_code=False, max_model_len=None, dtype='auto', gpu_memory_utilization=0.9, enforce_eager=False, kv_cache_dtype='auto', quantization_param_path=None, device='cuda', enable_prefix_caching=False, enable_chunked_prefill=False, max_num_batched_tokens=None, download_dir=None, output_json=None, distributed_executor_backend=None, load_format='auto')
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# INFO 06-26 08:13:44 gptq_marlin.py:134] The model is convertible to gptq_marlin during runtime. Using gptq_marlin kernel.
# INFO 06-26 08:13:44 llm_engine.py:164] Initializing an LLM engine (v0.5.0.post1) with config: model='kaitchup/Meta-Llama-3-8B-gptq-4bit', speculative_config=None, tokenizer='kaitchup/Meta-Llama-3-8B-gptq-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, rope_scaling=None, rope_theta=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=8192, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, disable_custom_all_reduce=False, quantization=gptq_marlin, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None), seed=0, served_model_name=kaitchup/Meta-Llama-3-8B-gptq-4bit)
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-06-26 08:13:45.339449: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-26 08:13:45.384783: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-26 08:13:45.384855: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-26 08:13:45.386755: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-26 08:13:45.395250: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-26 08:13:46.582589: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO 06-26 08:13:48 weight_utils.py:218] Using model weights format ['*.safetensors']
# INFO 06-26 08:13:51 model_runner.py:224] Loading model weights took 5.3262 GB
# INFO 06-26 08:13:55 gpu_executor.py:83] # GPU blocks: 6513, # CPU blocks: 2048
# INFO 06-26 08:13:57 model_runner.py:845] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 06-26 08:13:57 model_runner.py:849] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 06-26 08:14:14 model_runner.py:921] Graph capturing finished in 18 secs.
# Processed prompts: 100% 1000/1000 [03:27<00:00,  4.82it/s, est. speed input: 1036.23 toks/s, output: 955.07 toks/s]
# Throughput: 4.79 requests/s, 1981.39 tokens/s
