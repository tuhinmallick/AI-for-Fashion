# %% [markdown]
# <a href="https://colab.research.google.com/github/tuhinmallick/AI-for-Fashion/blob/main/Training%2C_Loading%2C_and_Merging_QDoRA%2C_QLoRA%2C_and_LoftQ_Adapters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook is organized into two sections.
#
# The first section shows how to fine-tune QLoRA, QDoRA, and LoftQ adapters for Mistral 7B using Hugging Face PEFT and TRL libraries. Then, the notebook benchmarks the adapters before and after merging them into the base model, followed by quantization with BNB NF4 and AWQ.
#
#
# First, we need all these dependencies:

# %%
# !pip install -q -U transformers peft accelerate datasets trl bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 27.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 25.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.4/297.4 kB 30.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 45.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 27.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 MB 13.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 15.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 27.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 21.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.0/102.0 kB 15.1 MB/s eta 0:00:00

# %% [markdown]
# Import all the necessary packages.

# %%
import torch
from datasets import load_dataset
from peft import LoraConfig, prepare_model_for_kbit_training, PeftModel
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    TrainingArguments,
    BitsAndBytesConfig
)
from trl import SFTTrainer

# %% [markdown]
# # Fine-tuning

# %% [markdown]
# **LoftQ**
#
# More info:
# [LoftQ: Better Initialization for a Quantization-Aware LoRA](https://kaitchup.substack.com/p/loftq-better-initialization-for-a)

# %%
# !git clone https://github.com/huggingface/peft.git

# !python peft/examples/loftq_finetuning/quantize_save_load.py \
    --model_name_or_path mistralai/Mistral-7B-v0.1 \
    --bits 4 \
    --iter 5 \
    --rank 16 \
    --save_dir "./loftq_iters/"
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): Shell()
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): Shell()
#   (act_fn): SiLU()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): Shell()
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): Shell()
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): Shell()
#   (act_fn): SiLU()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): Shell()
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): Shell()
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): Shell()
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): Shell()
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): Shell()
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): Shell()
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): Shell()
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): Shell()
#   (act_fn): SiLU()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralSdpaAttention(
#   (q_proj): Shell()
#   (k_proj): Shell()
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralMLP(
#   (gate_proj): Shell()
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralSdpaAttention(
#   (q_proj): Shell()
#   (k_proj): Shell()
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): Shell()
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): Shell()
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): Shell()
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): Shell()
#   (o_proj): Shell()
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralMLP(
#   (gate_proj): Shell()
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): Shell()
#   (act_fn): SiLU()
# )
# MistralSdpaAttention(
#   (q_proj): Shell()
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): Shell()
#   (k_proj): Shell()
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): Shell()
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): Shell()
#   (k_proj): Shell()
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): Shell()
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): Shell()
#   (down_proj): Shell()
#   (act_fn): SiLU()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): Shell()
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralMLP(
#   (gate_proj): Shell()
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): Shell()
#   (act_fn): SiLU()
# )
# MistralMLP(
#   (gate_proj): Shell()
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralMLP(
#   (gate_proj): Shell()
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralSdpaAttention(
#   (q_proj): Shell()
#   (k_proj): Shell()
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): Shell()
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): Shell()
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralMLP(
#   (gate_proj): Shell()
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): Shell()
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): Shell()
#   (down_proj): Shell()
#   (act_fn): SiLU()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): Shell()
#   (v_proj): Shell()
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.05, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralMLP(
#   (gate_proj): Shell()
# ...
# model.layers.18.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 3.776842731895158e-06 0.052478522062301636
# model.layers.18.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 4.0575153548161325e-07 0.02917599305510521
# model.layers.18.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 1.5044324754853733e-06 0.10824323445558548
# model.layers.18.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 1.6592117617619806e-06 0.08427177369594574
# model.layers.18.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.4092901185213123e-06 0.099543496966362
# model.layers.18.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 2.082257196889259e-06 0.10001786798238754
# model.layers.18.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.4567813873291016 5.96875
# model.layers.18.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.407374858856201 6.0
# model.layers.19.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 2.264550403197063e-06 0.0686311274766922
# model.layers.19.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 2.074259100481868e-06 0.0663929134607315
# model.layers.19.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 1.185344217446982e-06 0.024796558544039726
# model.layers.19.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 2.209109425166389e-06 0.08801016956567764
# model.layers.19.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.6868697204918135e-06 0.08984527736902237
# model.layers.19.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.951746182588977e-06 0.11106240004301071
# model.layers.19.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 2.561020664870739e-06 0.09330469369888306
# model.layers.19.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.518817901611328 6.0
# model.layers.19.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.5749154090881348 4.78125
# model.layers.20.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 2.973922391902306e-06 0.0572701096534729
# model.layers.20.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 8.27043731987942e-06 0.05693117156624794
# model.layers.20.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 3.5132993048136996e-07 0.022681917995214462
# model.layers.20.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 2.2592632831219817e-06 0.07891858369112015
# model.layers.20.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 1.0310110383215942e-06 0.07511454820632935
# model.layers.20.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 1.8646194348548306e-06 0.10487798601388931
# model.layers.20.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 2.3359341412287904e-06 0.07822565734386444
# model.layers.20.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.561117172241211 5.71875
# model.layers.20.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.7784910202026367 5.46875
# model.layers.21.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 1.8369184999755817e-06 0.06874597072601318
# model.layers.21.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 2.6985269414581126e-06 0.06768845021724701
# model.layers.21.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 3.3666867693682434e-06 0.02463623322546482
# model.layers.21.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 1.6979854535748018e-06 0.06146921589970589
# model.layers.21.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 1.366486685583368e-06 0.09954547137022018
# model.layers.21.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.4405965177720645e-06 0.08064983040094376
# model.layers.21.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 1.926306595123606e-06 0.19360530376434326
# model.layers.21.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.552286148071289 6.03125
# model.layers.21.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.983227491378784 4.59375
# model.layers.22.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 1.6606586541456636e-06 0.07379599660634995
# model.layers.22.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 2.2121798792795744e-06 0.06662378460168839
# model.layers.22.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 4.717314823210472e-07 0.023236047476530075
# model.layers.22.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 2.2838580662210006e-06 0.1248667985200882
# model.layers.22.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.8028152883052826e-06 0.05993702635169029
# model.layers.22.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.6359466573921964e-06 0.058993276208639145
# model.layers.22.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 2.1239004581730114e-06 0.1758839190006256
# model.layers.22.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.573479175567627 6.03125
# model.layers.22.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 3.0877535343170166 4.1875
# model.layers.23.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 2.6018451535492204e-06 0.0704914778470993
# model.layers.23.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False -3.4271414506292786e-07 0.06998441368341446
# model.layers.23.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 4.449791958904825e-06 0.027922248467803
# model.layers.23.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 2.1363862288126256e-06 0.09019135683774948
# model.layers.23.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 4.542016085906653e-06 0.1260858029127121
# model.layers.23.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 1.9767862795561086e-06 0.0544363372027874
# model.layers.23.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 1.8185302224082989e-06 0.08158762753009796
# model.layers.23.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.5992050170898438 6.125
# model.layers.23.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 3.2200865745544434 4.53125
# model.layers.24.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 1.3509544487533276e-06 0.05851111561059952
# model.layers.24.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 4.568957592709921e-06 0.06562267988920212
# model.layers.24.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 1.2008804333163425e-06 0.029653968289494514
# model.layers.24.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 2.8733272756653605e-06 0.05445827916264534
# model.layers.24.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 6.0473280427686404e-06 0.09761155396699905
# model.layers.24.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.197769845224684e-06 0.10179770737886429
# model.layers.24.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 1.8434863022775971e-06 0.18064658343791962
# model.layers.24.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.820614814758301 6.40625
# model.layers.24.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 3.352470874786377 4.9375
# model.layers.25.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 8.698717692823266e-07 0.052686817944049835
# model.layers.25.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 1.1983590866293525e-06 0.05558350309729576
# model.layers.25.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 1.227595703312545e-06 0.03916184604167938
# model.layers.25.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 1.6249090322162374e-06 0.1574246883392334
# model.layers.25.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 6.91777995598386e-06 0.08339677006006241
# model.layers.25.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.1650457711075433e-06 0.05348631739616394
# model.layers.25.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 2.0505578959273407e-06 0.07910995185375214
# model.layers.25.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.897142171859741 6.875
# model.layers.25.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 3.4562883377075195 5.1875
# model.layers.26.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 1.3628584838443203e-06 0.048510950058698654
# model.layers.26.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 1.7030606613843702e-06 0.07269557565450668
# model.layers.26.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 4.2783517528732773e-07 0.03529560565948486
# model.layers.26.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 1.932965233208961e-06 0.051401328295469284
# model.layers.26.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 4.049868039146531e-06 0.09699179977178574
# model.layers.26.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.5472425022599055e-06 0.08840193599462509
# model.layers.26.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 2.5200617983500706e-06 0.1223413422703743
# model.layers.26.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.782806396484375 6.9375
# model.layers.26.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 3.5270397663116455 5.0
# model.layers.27.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 2.9484094739018474e-06 0.05685514956712723
# model.layers.27.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 5.4238157645158935e-06 0.06961875408887863
# model.layers.27.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 3.928807473130291e-06 0.03371858224272728
# model.layers.27.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 1.734071588543884e-06 0.08460652083158493
# model.layers.27.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False -1.2717429171971162e-06 0.07926957309246063
# model.layers.27.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.979271357617108e-06 0.052260227501392365
# model.layers.27.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 1.9855394839396467e-06 0.16491913795471191
# model.layers.27.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.837923526763916 7.375
# model.layers.27.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 3.6432299613952637 5.21875
# model.layers.28.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 2.1398775515990565e-06 0.054381322115659714
# model.layers.28.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 2.6046229777421104e-06 0.05248332396149635
# model.layers.28.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 1.7832462617661804e-06 0.03275762498378754
# model.layers.28.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 2.132002919097431e-06 0.06929787248373032
# model.layers.28.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False -3.510057013045298e-06 0.08619145303964615
# model.layers.28.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 1.982363073693705e-06 0.08398338407278061
# model.layers.28.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 3.26796771332738e-06 0.0933743566274643
# model.layers.28.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.748250961303711 7.84375
# model.layers.28.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 3.7343578338623047 5.53125
# model.layers.29.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 3.7376664749899646e-06 0.05795130133628845
# model.layers.29.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 3.7094991967023816e-06 0.05710139498114586
# model.layers.29.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 4.472033651836682e-06 0.040542636066675186
# model.layers.29.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 5.90741251471627e-07 0.06138165295124054
# model.layers.29.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False -2.8791480417567072e-06 0.055247124284505844
# model.layers.29.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 1.5219138731481507e-06 0.07269863039255142
# model.layers.29.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 3.2158873182197567e-06 0.1424742192029953
# model.layers.29.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 3.032315731048584 8.75
# model.layers.29.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 3.7174072265625 5.375
# model.layers.30.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 1.2558654134409153e-06 0.06713055074214935
# model.layers.30.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 9.974811518986826e-07 0.05571644380688667
# model.layers.30.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 4.584130692819599e-06 0.0479009672999382
# model.layers.30.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 3.1162214781943476e-06 0.10569024085998535
# model.layers.30.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 1.4713245377606654e-07 0.07916683703660965
# model.layers.30.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.5486276626907056e-06 0.08038534224033356
# model.layers.30.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 2.3293603135243757e-06 0.20922721922397614
# model.layers.30.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.9241838455200195 9.0
# model.layers.30.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 3.7705609798431396 5.53125
# model.layers.31.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 4.824407255910046e-07 0.05755443125963211
# model.layers.31.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 4.108212579012616e-06 0.05775906890630722
# model.layers.31.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False -5.920560397498775e-07 0.043666768819093704
# model.layers.31.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 1.3111066436977126e-06 0.2004215121269226
# model.layers.31.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 6.419703026949719e-07 0.06114254891872406
# model.layers.31.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.9174937026255066e-06 0.05994551628828049
# model.layers.31.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 2.3148204491008073e-06 0.2717202305793762
# model.layers.31.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.921815872192383 8.75
# model.layers.31.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 3.635004997253418 5.84375
# model.norm.weight torch.Size([4096]) cpu torch.float32 False 5.2825469970703125 13.25
# lm_head.weight torch.Size([32000, 4096]) cpu torch.float32 False 1.3422666597762145e-05 0.06689453125

# %%
MODEL_DIR = "./loftq_iters/Mistral-7B-v0.1-4bit-16rank"
bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.bfloat16,
        bnb_4bit_use_double_quant=True,
)
tokenizer = AutoTokenizer.from_pretrained(MODEL_DIR, add_eos_token=True, use_fast=True)
model = AutoModelForCausalLM.from_pretrained(
          MODEL_DIR, quantization_config=bnb_config, device_map={"": 0}, torch_dtype=torch.bfloat16
)

model.save_pretrained("./loftq_base/")
tokenizer.save_pretrained("./loftq_base/")
# Out:
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]
# ('./drive/MyDrive/mergexp/loftq_base/tokenizer_config.json',
#  './drive/MyDrive/mergexp/loftq_base/special_tokens_map.json',
#  './drive/MyDrive/mergexp/loftq_base/tokenizer.model',
#  './drive/MyDrive/mergexp/loftq_base/added_tokens.json',
#  './drive/MyDrive/mergexp/loftq_base/tokenizer.json')

# %%
# !mkdir -p ./drive/MyDrive/mergexp/loftq_base/

# %%
# !cp -r ./loftq_iters/Mistral-7B-v0.1-4bit-16rank/loft_init/ ./drive/MyDrive/mergexp/loftq_base/loft_init/

# %%
MODEL_DIR = "./loftq_base/"
#Tokenizer
tokenizer = AutoTokenizer.from_pretrained(MODEL_DIR, add_eos_token=True, use_fast=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = 'left' #Necessary for FlashAttention compatibility

#Better to use bf16 if supported (Ampere GPUs or more recent)
#If bf16 is supported, the GPU is also recent enough to support FlashAttention
if torch.cuda.is_bf16_supported():
  # !pip install flash_attn
  compute_dtype = torch.bfloat16
  attn_implementation = 'flash_attention_2'
else:
  compute_dtype = torch.float16
  attn_implementation = 'sdpa'

dataset = load_dataset("timdettmers/openassistant-guanaco")

model = AutoModelForCausalLM.from_pretrained(
          MODEL_DIR,  device_map={"": 0}, torch_dtype=compute_dtype
)
model = prepare_model_for_kbit_training(model)
#Configure the pad token in the model
model.config.pad_token_id = tokenizer.pad_token_id

peft_model = PeftModel.from_pretrained(
    model,
    MODEL_DIR,
    subfolder="loft_init",
    is_trainable=True,
)



from trl import SFTConfig

training_arguments = SFTConfig(
        output_dir="./loftq_ft/",
        evaluation_strategy="steps",
        do_eval=True,
        optim="paged_adamw_8bit",
        per_device_train_batch_size=8,
        per_device_eval_batch_size=8,
        log_level="debug",
        logging_steps=50,
        learning_rate=1e-5,
        eval_steps=50,
        num_train_epochs=1,
        fp16= not torch.cuda.is_bf16_supported(),
        bf16= torch.cuda.is_bf16_supported(),
        save_strategy='epoch',
        warmup_ratio=0.1,
        lr_scheduler_type="linear",
)

trainer = SFTTrainer(
        model=peft_model,
        train_dataset=dataset['train'],
        eval_dataset=dataset['test'],
        dataset_text_field="text",
        max_seq_length=512,
        tokenizer=tokenizer,
        args=training_arguments,
)

trainer.train()
# Out:
# Collecting flash_attn
#   Downloading flash_attn-2.5.6.tar.gz (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 14.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from flash_attn) (2.2.1+cu121)
# Collecting einops (from flash_attn)
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from flash_attn) (24.0)
# Collecting ninja (from flash_attn)
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 18.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->flash_attn) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->flash_attn) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->flash_attn) (1.3.0)
# Building wheels for collected packages: flash_attn
#   Building wheel for flash_attn (setup.py) ... done
#   Created wheel for flash_attn: filename=flash_attn-2.5.6-cp310-cp310-linux_x86_64.whl size=120592258 sha256=d8cf54adda65f59820221d329d274e124972d7fdc05ab3b1130253c64eee6c8a
#   Stored in directory: /root/.cache/pip/wheels/a8/1c/88/b959d6818b98a46d61ba231683abb7523b89ac1a7ed1e0c206
# Successfully built flash_attn
# Installing collected packages: ninja, einops, flash_attn
# Successfully installed einops-0.7.0 flash_attn-2.5.6 ninja-1.11.1.1
# Downloading readme:   0%|          | 0.00/395 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Downloading data:   0%|          | 0.00/20.9M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/transformers/quantizers/auto.py:159: UserWarning: You passed `quantization_config` or equivalent parameters to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` from the model will be used.
#   warnings.warn(warning_msg)
# Map:   0%|          | 0/9846 [00:00<?, ? examples/s]
# Map:   0%|          | 0/518 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:317: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:436: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(
# Using auto half precision backend
# Currently training with a batch size of: 8
# ***** Running training *****
#   Num examples = 9,846
#   Num Epochs = 1
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1,231
#   Number of trainable parameters = 41,943,040
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# The input hidden states seems to be silently casted in float32, this might be related to the fact you have upcasted embedding or layer norm layers in float32. We will cast back the input in torch.bfloat16.
#     <div>
#
#       <progress value='788' max='1231' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 788/1231 2:46:43 < 1:33:57, 0.08 it/s, Epoch 0.64/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.347700</td>
#       <td>1.354418</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.270200</td>
#       <td>1.237236</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.185200</td>
#       <td>1.192417</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.160600</td>
#       <td>1.178373</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.139600</td>
#       <td>1.162789</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.154300</td>
#       <td>1.151754</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.130600</td>
#       <td>1.148634</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.138800</td>
#       <td>1.145539</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.123100</td>
#       <td>1.142953</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.120400</td>
#       <td>1.141005</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>1.101900</td>
#       <td>1.139638</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.095800</td>
#       <td>1.137972</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>1.111200</td>
#       <td>1.136775</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>1.101500</td>
#       <td>1.135484</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>1.089300</td>
#       <td>1.134628</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='1231' max='1231' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1231/1231 4:22:36, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.347700</td>
#       <td>1.354418</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.270200</td>
#       <td>1.237236</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.185200</td>
#       <td>1.192417</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.160600</td>
#       <td>1.178373</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.139600</td>
#       <td>1.162789</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.154300</td>
#       <td>1.151754</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.130600</td>
#       <td>1.148634</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.138800</td>
#       <td>1.145539</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.123100</td>
#       <td>1.142953</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.120400</td>
#       <td>1.141005</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>1.101900</td>
#       <td>1.139638</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.095800</td>
#       <td>1.137972</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>1.111200</td>
#       <td>1.136775</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>1.101500</td>
#       <td>1.135484</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>1.089300</td>
#       <td>1.134628</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>1.130700</td>
#       <td>1.133873</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>1.108400</td>
#       <td>1.133086</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>1.147300</td>
#       <td>1.132470</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>1.141600</td>
#       <td>1.132046</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.117400</td>
#       <td>1.131644</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>1.087500</td>
#       <td>1.131198</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>1.092800</td>
#       <td>1.131021</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>1.051500</td>
#       <td>1.130828</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>1.125900</td>
#       <td>1.130821</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# Saving model checkpoint to ./drive/MyDrive/mergexp/loftq_ft/checkpoint-1231
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:154: UserWarning: Could not find a config file in ./loftq_iters/Mistral-7B-v0.1-4bit-16rank - will assume that the vocabulary was not modified.
#   warnings.warn(
# tokenizer config file saved in ./drive/MyDrive/mergexp/loftq_ft/checkpoint-1231/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/mergexp/loftq_ft/checkpoint-1231/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=1231, training_loss=1.1346433749535914, metrics={'train_runtime': 15766.5706, 'train_samples_per_second': 0.624, 'train_steps_per_second': 0.078, 'total_flos': 2.148541273402245e+17, 'train_loss': 1.1346433749535914, 'epoch': 1.0})

# %% [markdown]
# Merge the LoftQ adapter

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from peft import PeftModel
#Better to use bf16 if supported (Ampere GPUs or more recent)
#If bf16 is supported, the GPU is also recent enough to support FlashAttention
if torch.cuda.is_bf16_supported():
  # !pip install flash_attn
  compute_dtype = torch.bfloat16
  attn_implementation = 'flash_attention_2'
else:
  compute_dtype = torch.float16
  attn_implementation = 'sdpa'


model_name = "./loftq_base/"
adapter = "./loftq_ft/checkpoint-1231"
#Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, padding_size="left",  use_fast=True)

bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)

model = AutoModelForCausalLM.from_pretrained(
          model_name, quantization_config=bnb_config, device_map={"": 0}, torch_dtype=compute_dtype,  attn_implementation=attn_implementation
)

model = dequantize_model(model, to='./dqz_model_loftq/',dtype=compute_dtype)
model = PeftModel.from_pretrained(model, adapter)
model = model.merge_and_unload()

print(f"Successfully loaded the model {model_name} into memory")

#pushed to hub
#model.push_to_hub("kaitchup/Mistral-7B-v0.1-oasstguanaco-1e-loftq-merged")
#tokenizer.push_to_hub("kaitchup/Mistral-7B-v0.1-oasstguanaco-1e-loftq-merged")
# Out:
# Requirement already satisfied: flash_attn in /usr/local/lib/python3.10/dist-packages (2.5.7)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from flash_attn) (2.2.1+cu121)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from flash_attn) (0.7.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from flash_attn) (24.0)
# Requirement already satisfied: ninja in /usr/local/lib/python3.10/dist-packages (from flash_attn) (1.11.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->flash_attn) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->flash_attn) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->flash_attn) (1.3.0)
# /usr/local/lib/python3.10/dist-packages/transformers/quantizers/auto.py:159: UserWarning: You passed `quantization_config` or equivalent parameters to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` from the model will be used.
#   warnings.warn(warning_msg)
# Dequantizing `model.layers.0.self_attn.q_proj`...
# Dequantizing `model.layers.0.self_attn.k_proj`...
# Dequantizing `model.layers.0.self_attn.v_proj`...
# Dequantizing `model.layers.0.self_attn.o_proj`...
# Dequantizing `model.layers.0.mlp.gate_proj`...
# Dequantizing `model.layers.0.mlp.up_proj`...
# Dequantizing `model.layers.0.mlp.down_proj`...
# Dequantizing `model.layers.1.self_attn.q_proj`...
# Dequantizing `model.layers.1.self_attn.k_proj`...
# Dequantizing `model.layers.1.self_attn.v_proj`...
# Dequantizing `model.layers.1.self_attn.o_proj`...
# Dequantizing `model.layers.1.mlp.gate_proj`...
# Dequantizing `model.layers.1.mlp.up_proj`...
# Dequantizing `model.layers.1.mlp.down_proj`...
# Dequantizing `model.layers.2.self_attn.q_proj`...
# Dequantizing `model.layers.2.self_attn.k_proj`...
# Dequantizing `model.layers.2.self_attn.v_proj`...
# Dequantizing `model.layers.2.self_attn.o_proj`...
# Dequantizing `model.layers.2.mlp.gate_proj`...
# Dequantizing `model.layers.2.mlp.up_proj`...
# Dequantizing `model.layers.2.mlp.down_proj`...
# Dequantizing `model.layers.3.self_attn.q_proj`...
# Dequantizing `model.layers.3.self_attn.k_proj`...
# Dequantizing `model.layers.3.self_attn.v_proj`...
# Dequantizing `model.layers.3.self_attn.o_proj`...
# Dequantizing `model.layers.3.mlp.gate_proj`...
# Dequantizing `model.layers.3.mlp.up_proj`...
# Dequantizing `model.layers.3.mlp.down_proj`...
# Dequantizing `model.layers.4.self_attn.q_proj`...
# Dequantizing `model.layers.4.self_attn.k_proj`...
# Dequantizing `model.layers.4.self_attn.v_proj`...
# Dequantizing `model.layers.4.self_attn.o_proj`...
# Dequantizing `model.layers.4.mlp.gate_proj`...
# Dequantizing `model.layers.4.mlp.up_proj`...
# Dequantizing `model.layers.4.mlp.down_proj`...
# Dequantizing `model.layers.5.self_attn.q_proj`...
# Dequantizing `model.layers.5.self_attn.k_proj`...
# Dequantizing `model.layers.5.self_attn.v_proj`...
# Dequantizing `model.layers.5.self_attn.o_proj`...
# Dequantizing `model.layers.5.mlp.gate_proj`...
# Dequantizing `model.layers.5.mlp.up_proj`...
# Dequantizing `model.layers.5.mlp.down_proj`...
# Dequantizing `model.layers.6.self_attn.q_proj`...
# Dequantizing `model.layers.6.self_attn.k_proj`...
# Dequantizing `model.layers.6.self_attn.v_proj`...
# Dequantizing `model.layers.6.self_attn.o_proj`...
# Dequantizing `model.layers.6.mlp.gate_proj`...
# Dequantizing `model.layers.6.mlp.up_proj`...
# Dequantizing `model.layers.6.mlp.down_proj`...
# Dequantizing `model.layers.7.self_attn.q_proj`...
# Dequantizing `model.layers.7.self_attn.k_proj`...
# Dequantizing `model.layers.7.self_attn.v_proj`...
# Dequantizing `model.layers.7.self_attn.o_proj`...
# Dequantizing `model.layers.7.mlp.gate_proj`...
# Dequantizing `model.layers.7.mlp.up_proj`...
# Dequantizing `model.layers.7.mlp.down_proj`...
# Dequantizing `model.layers.8.self_attn.q_proj`...
# Dequantizing `model.layers.8.self_attn.k_proj`...
# Dequantizing `model.layers.8.self_attn.v_proj`...
# Dequantizing `model.layers.8.self_attn.o_proj`...
# Dequantizing `model.layers.8.mlp.gate_proj`...
# Dequantizing `model.layers.8.mlp.up_proj`...
# Dequantizing `model.layers.8.mlp.down_proj`...
# Dequantizing `model.layers.9.self_attn.q_proj`...
# Dequantizing `model.layers.9.self_attn.k_proj`...
# Dequantizing `model.layers.9.self_attn.v_proj`...
# Dequantizing `model.layers.9.self_attn.o_proj`...
# Dequantizing `model.layers.9.mlp.gate_proj`...
# Dequantizing `model.layers.9.mlp.up_proj`...
# Dequantizing `model.layers.9.mlp.down_proj`...
# Dequantizing `model.layers.10.self_attn.q_proj`...
# Dequantizing `model.layers.10.self_attn.k_proj`...
# Dequantizing `model.layers.10.self_attn.v_proj`...
# Dequantizing `model.layers.10.self_attn.o_proj`...
# Dequantizing `model.layers.10.mlp.gate_proj`...
# Dequantizing `model.layers.10.mlp.up_proj`...
# Dequantizing `model.layers.10.mlp.down_proj`...
# Dequantizing `model.layers.11.self_attn.q_proj`...
# Dequantizing `model.layers.11.self_attn.k_proj`...
# Dequantizing `model.layers.11.self_attn.v_proj`...
# Dequantizing `model.layers.11.self_attn.o_proj`...
# Dequantizing `model.layers.11.mlp.gate_proj`...
# Dequantizing `model.layers.11.mlp.up_proj`...
# Dequantizing `model.layers.11.mlp.down_proj`...
# Dequantizing `model.layers.12.self_attn.q_proj`...
# Dequantizing `model.layers.12.self_attn.k_proj`...
# Dequantizing `model.layers.12.self_attn.v_proj`...
# Dequantizing `model.layers.12.self_attn.o_proj`...
# Dequantizing `model.layers.12.mlp.gate_proj`...
# Dequantizing `model.layers.12.mlp.up_proj`...
# Dequantizing `model.layers.12.mlp.down_proj`...
# Dequantizing `model.layers.13.self_attn.q_proj`...
# Dequantizing `model.layers.13.self_attn.k_proj`...
# Dequantizing `model.layers.13.self_attn.v_proj`...
# Dequantizing `model.layers.13.self_attn.o_proj`...
# Dequantizing `model.layers.13.mlp.gate_proj`...
# Dequantizing `model.layers.13.mlp.up_proj`...
# Dequantizing `model.layers.13.mlp.down_proj`...
# Dequantizing `model.layers.14.self_attn.q_proj`...
# Dequantizing `model.layers.14.self_attn.k_proj`...
# Dequantizing `model.layers.14.self_attn.v_proj`...
# Dequantizing `model.layers.14.self_attn.o_proj`...
# Dequantizing `model.layers.14.mlp.gate_proj`...
# Dequantizing `model.layers.14.mlp.up_proj`...
# Dequantizing `model.layers.14.mlp.down_proj`...
# Dequantizing `model.layers.15.self_attn.q_proj`...
# Dequantizing `model.layers.15.self_attn.k_proj`...
# Dequantizing `model.layers.15.self_attn.v_proj`...
# Dequantizing `model.layers.15.self_attn.o_proj`...
# Dequantizing `model.layers.15.mlp.gate_proj`...
# Dequantizing `model.layers.15.mlp.up_proj`...
# Dequantizing `model.layers.15.mlp.down_proj`...
# Dequantizing `model.layers.16.self_attn.q_proj`...
# Dequantizing `model.layers.16.self_attn.k_proj`...
# Dequantizing `model.layers.16.self_attn.v_proj`...
# Dequantizing `model.layers.16.self_attn.o_proj`...
# Dequantizing `model.layers.16.mlp.gate_proj`...
# Dequantizing `model.layers.16.mlp.up_proj`...
# Dequantizing `model.layers.16.mlp.down_proj`...
# Dequantizing `model.layers.17.self_attn.q_proj`...
# Dequantizing `model.layers.17.self_attn.k_proj`...
# Dequantizing `model.layers.17.self_attn.v_proj`...
# Dequantizing `model.layers.17.self_attn.o_proj`...
# Dequantizing `model.layers.17.mlp.gate_proj`...
# Dequantizing `model.layers.17.mlp.up_proj`...
# Dequantizing `model.layers.17.mlp.down_proj`...
# Dequantizing `model.layers.18.self_attn.q_proj`...
# Dequantizing `model.layers.18.self_attn.k_proj`...
# Dequantizing `model.layers.18.self_attn.v_proj`...
# Dequantizing `model.layers.18.self_attn.o_proj`...
# Dequantizing `model.layers.18.mlp.gate_proj`...
# Dequantizing `model.layers.18.mlp.up_proj`...
# Dequantizing `model.layers.18.mlp.down_proj`...
# Dequantizing `model.layers.19.self_attn.q_proj`...
# Dequantizing `model.layers.19.self_attn.k_proj`...
# Dequantizing `model.layers.19.self_attn.v_proj`...
# Dequantizing `model.layers.19.self_attn.o_proj`...
# Dequantizing `model.layers.19.mlp.gate_proj`...
# Dequantizing `model.layers.19.mlp.up_proj`...
# Dequantizing `model.layers.19.mlp.down_proj`...
# Dequantizing `model.layers.20.self_attn.q_proj`...
# Dequantizing `model.layers.20.self_attn.k_proj`...
# Dequantizing `model.layers.20.self_attn.v_proj`...
# Dequantizing `model.layers.20.self_attn.o_proj`...
# Dequantizing `model.layers.20.mlp.gate_proj`...
# Dequantizing `model.layers.20.mlp.up_proj`...
# Dequantizing `model.layers.20.mlp.down_proj`...
# Dequantizing `model.layers.21.self_attn.q_proj`...
# Dequantizing `model.layers.21.self_attn.k_proj`...
# Dequantizing `model.layers.21.self_attn.v_proj`...
# Dequantizing `model.layers.21.self_attn.o_proj`...
# Dequantizing `model.layers.21.mlp.gate_proj`...
# Dequantizing `model.layers.21.mlp.up_proj`...
# Dequantizing `model.layers.21.mlp.down_proj`...
# Dequantizing `model.layers.22.self_attn.q_proj`...
# Dequantizing `model.layers.22.self_attn.k_proj`...
# Dequantizing `model.layers.22.self_attn.v_proj`...
# Dequantizing `model.layers.22.self_attn.o_proj`...
# Dequantizing `model.layers.22.mlp.gate_proj`...
# Dequantizing `model.layers.22.mlp.up_proj`...
# Dequantizing `model.layers.22.mlp.down_proj`...
# Dequantizing `model.layers.23.self_attn.q_proj`...
# Dequantizing `model.layers.23.self_attn.k_proj`...
# Dequantizing `model.layers.23.self_attn.v_proj`...
# Dequantizing `model.layers.23.self_attn.o_proj`...
# Dequantizing `model.layers.23.mlp.gate_proj`...
# Dequantizing `model.layers.23.mlp.up_proj`...
# Dequantizing `model.layers.23.mlp.down_proj`...
# Dequantizing `model.layers.24.self_attn.q_proj`...
# Dequantizing `model.layers.24.self_attn.k_proj`...
# Dequantizing `model.layers.24.self_attn.v_proj`...
# Dequantizing `model.layers.24.self_attn.o_proj`...
# Dequantizing `model.layers.24.mlp.gate_proj`...
# Dequantizing `model.layers.24.mlp.up_proj`...
# Dequantizing `model.layers.24.mlp.down_proj`...
# Dequantizing `model.layers.25.self_attn.q_proj`...
# Dequantizing `model.layers.25.self_attn.k_proj`...
# Dequantizing `model.layers.25.self_attn.v_proj`...
# Dequantizing `model.layers.25.self_attn.o_proj`...
# Dequantizing `model.layers.25.mlp.gate_proj`...
# Dequantizing `model.layers.25.mlp.up_proj`...
# Dequantizing `model.layers.25.mlp.down_proj`...
# Dequantizing `model.layers.26.self_attn.q_proj`...
# Dequantizing `model.layers.26.self_attn.k_proj`...
# Dequantizing `model.layers.26.self_attn.v_proj`...
# Dequantizing `model.layers.26.self_attn.o_proj`...
# Dequantizing `model.layers.26.mlp.gate_proj`...
# Dequantizing `model.layers.26.mlp.up_proj`...
# Dequantizing `model.layers.26.mlp.down_proj`...
# Dequantizing `model.layers.27.self_attn.q_proj`...
# Dequantizing `model.layers.27.self_attn.k_proj`...
# Dequantizing `model.layers.27.self_attn.v_proj`...
# Dequantizing `model.layers.27.self_attn.o_proj`...
# Dequantizing `model.layers.27.mlp.gate_proj`...
# Dequantizing `model.layers.27.mlp.up_proj`...
# Dequantizing `model.layers.27.mlp.down_proj`...
# Dequantizing `model.layers.28.self_attn.q_proj`...
# Dequantizing `model.layers.28.self_attn.k_proj`...
# Dequantizing `model.layers.28.self_attn.v_proj`...
# Dequantizing `model.layers.28.self_attn.o_proj`...
# Dequantizing `model.layers.28.mlp.gate_proj`...
# Dequantizing `model.layers.28.mlp.up_proj`...
# Dequantizing `model.layers.28.mlp.down_proj`...
# Dequantizing `model.layers.29.self_attn.q_proj`...
# Dequantizing `model.layers.29.self_attn.k_proj`...
# Dequantizing `model.layers.29.self_attn.v_proj`...
# Dequantizing `model.layers.29.self_attn.o_proj`...
# Dequantizing `model.layers.29.mlp.gate_proj`...
# Dequantizing `model.layers.29.mlp.up_proj`...
# Dequantizing `model.layers.29.mlp.down_proj`...
# Dequantizing `model.layers.30.self_attn.q_proj`...
# Dequantizing `model.layers.30.self_attn.k_proj`...
# Dequantizing `model.layers.30.self_attn.v_proj`...
# Dequantizing `model.layers.30.self_attn.o_proj`...
# Dequantizing `model.layers.30.mlp.gate_proj`...
# Dequantizing `model.layers.30.mlp.up_proj`...
# Dequantizing `model.layers.30.mlp.down_proj`...
# Dequantizing `model.layers.31.self_attn.q_proj`...
# Dequantizing `model.layers.31.self_attn.k_proj`...
# Dequantizing `model.layers.31.self_attn.v_proj`...
# Dequantizing `model.layers.31.self_attn.o_proj`...
# Dequantizing `model.layers.31.mlp.gate_proj`...
# Dequantizing `model.layers.31.mlp.up_proj`...
# Dequantizing `model.layers.31.mlp.down_proj`...
# Saving dequantized model...
# Successfully loaded the model ./drive/MyDrive/mergexp/loftq_base/ into memory
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/5.18k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/kaitchup/Mistral-7B-v0.1-oasstguanaco-1e-loftq-merged/commit/fb41de77231ac8904d1f195cd8b28cec80a22add', commit_message='Upload tokenizer', commit_description='', oid='fb41de77231ac8904d1f195cd8b28cec80a22add', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# ---
#
# **QDoRA**
#
# More info:
# [DoRA: Better and Faster than LoRA?](https://kaitchup.substack.com/p/dora-better-and-faster-than-lora)

# %%
model_name = "mistralai/Mistral-7B-v0.1"
#Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, add_eos_token=True, use_fast=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = 'left' #Necessary for FlashAttention compatibility

#Better to use bf16 if supported (Ampere GPUs or more recent)
#If bf16 is supported, the GPU is also recent enough to support FlashAttention
if torch.cuda.is_bf16_supported():
  # !pip install flash_attn
  compute_dtype = torch.bfloat16
  attn_implementation = 'flash_attention_2'
else:
  compute_dtype = torch.float16
  attn_implementation = 'sdpa'

dataset = load_dataset("timdettmers/openassistant-guanaco")


#Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, add_eos_token=True, use_fast=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = 'left' #Necessary for FlashAttention compatibility

bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)
model = AutoModelForCausalLM.from_pretrained(
          model_name, quantization_config=bnb_config, device_map={"": 0}, torch_dtype=compute_dtype,  attn_implementation=attn_implementation
)
model = prepare_model_for_kbit_training(model)
model.gradient_checkpointing_enable({'use_reentrant':True})
#model.enable_input_require_grads()

peft_config = LoraConfig(
        lora_alpha=16,
        lora_dropout=0.05,
        r=16,
        bias="none",
        use_dora=True,
        task_type="CAUSAL_LM",
        target_modules= ['k_proj', 'q_proj', 'v_proj', 'o_proj', "gate_proj", "down_proj", "up_proj"]
)


from trl import SFTConfig

training_arguments = SFTConfig(
        output_dir="./qdora/",
        evaluation_strategy="steps",
        do_eval=True,
        optim="paged_adamw_8bit",
        per_device_train_batch_size=8,
        per_device_eval_batch_size=8,
        log_level="debug",
        logging_steps=50,
        learning_rate=1e-5,
        eval_steps=50,
        num_train_epochs=1,
        fp16= not torch.cuda.is_bf16_supported(),
        bf16= torch.cuda.is_bf16_supported(),
        save_strategy='epoch',
        warmup_ratio=0.1,
        lr_scheduler_type="linear",
)

trainer = SFTTrainer(
        model=model,
        train_dataset=dataset['train'],
        eval_dataset=dataset['test'],
        dataset_text_field="text",
        max_seq_length=512,
        peft_config=peft_config,
        tokenizer=tokenizer,
        args=training_arguments,
)

trainer.train()
# Out:
# tokenizer_config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]
# loading file tokenizer.model from cache at /root/.cache/huggingface/hub/models--mistralai--Mistral-7B-v0.1/snapshots/26bca36bde8333b5d7f72e9ed20ccda6a618af24/tokenizer.model
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--mistralai--Mistral-7B-v0.1/snapshots/26bca36bde8333b5d7f72e9ed20ccda6a618af24/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--mistralai--Mistral-7B-v0.1/snapshots/26bca36bde8333b5d7f72e9ed20ccda6a618af24/special_tokens_map.json
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--mistralai--Mistral-7B-v0.1/snapshots/26bca36bde8333b5d7f72e9ed20ccda6a618af24/tokenizer_config.json
# Requirement already satisfied: flash_attn in /usr/local/lib/python3.10/dist-packages (2.5.6)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from flash_attn) (2.2.1+cu121)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from flash_attn) (0.7.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from flash_attn) (24.0)
# Requirement already satisfied: ninja in /usr/local/lib/python3.10/dist-packages (from flash_attn) (1.11.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->flash_attn) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->flash_attn) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->flash_attn) (1.3.0)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# loading file tokenizer.model from cache at /root/.cache/huggingface/hub/models--mistralai--Mistral-7B-v0.1/snapshots/26bca36bde8333b5d7f72e9ed20ccda6a618af24/tokenizer.model
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--mistralai--Mistral-7B-v0.1/snapshots/26bca36bde8333b5d7f72e9ed20ccda6a618af24/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--mistralai--Mistral-7B-v0.1/snapshots/26bca36bde8333b5d7f72e9ed20ccda6a618af24/special_tokens_map.json
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--mistralai--Mistral-7B-v0.1/snapshots/26bca36bde8333b5d7f72e9ed20ccda6a618af24/tokenizer_config.json
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--mistralai--Mistral-7B-v0.1/snapshots/26bca36bde8333b5d7f72e9ed20ccda6a618af24/config.json
# Model config MistralConfig {
#   "_name_or_path": "mistralai/Mistral-7B-v0.1",
#   "architectures": [
#     "MistralForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 32768,
#   "model_type": "mistral",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "rms_norm_eps": 1e-05,
#   "rope_theta": 10000.0,
#   "sliding_window": 4096,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.39.3",
#   "use_cache": true,
#   "vocab_size": 32000
# }
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--mistralai--Mistral-7B-v0.1/snapshots/26bca36bde8333b5d7f72e9ed20ccda6a618af24/model.safetensors.index.json
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Instantiating MistralForCausalLM model under default dtype torch.bfloat16.
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "eos_token_id": 2
# }
#
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Detected flash_attn version: 2.5.6
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# All model checkpoint weights were used when initializing MistralForCausalLM.
#
# All the weights of MistralForCausalLM were initialized from the model checkpoint at mistralai/Mistral-7B-v0.1.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use MistralForCausalLM for predictions without further training.
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--mistralai--Mistral-7B-v0.1/snapshots/26bca36bde8333b5d7f72e9ed20ccda6a618af24/generation_config.json
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "eos_token_id": 2
# }
#
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# PyTorch: setting up devices
# Map:   0%|          | 0/9846 [00:00<?, ? examples/s]
# Map:   0%|          | 0/518 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:317: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:436: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(
# Using auto half precision backend
# Currently training with a batch size of: 8
# ***** Running training *****
#   Num examples = 9,846
#   Num Epochs = 1
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1,231
#   Number of trainable parameters = 43,319,296
#     <div>
#
#       <progress value='751' max='1231' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 751/1231 4:45:10 < 3:02:45, 0.04 it/s, Epoch 0.61/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.347300</td>
#       <td>1.353635</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.262400</td>
#       <td>1.231624</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.180400</td>
#       <td>1.188604</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.155300</td>
#       <td>1.169926</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.128800</td>
#       <td>1.153853</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.150000</td>
#       <td>1.150144</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.127900</td>
#       <td>1.147451</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.138100</td>
#       <td>1.145200</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.122600</td>
#       <td>1.143323</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.121200</td>
#       <td>1.141987</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>1.103200</td>
#       <td>1.141111</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.098100</td>
#       <td>1.139901</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>1.113400</td>
#       <td>1.139124</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>1.104400</td>
#       <td>1.138323</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='15' max='65' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [15/65 01:15 < 04:30, 0.18 it/s]
#     </div>
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8

# %% [markdown]
# Merging the adapter

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from peft import PeftModel
#Better to use bf16 if supported (Ampere GPUs or more recent)
#If bf16 is supported, the GPU is also recent enough to support FlashAttention
if torch.cuda.is_bf16_supported():
  # !pip install flash_attn
  compute_dtype = torch.bfloat16
  attn_implementation = 'flash_attention_2'
else:
  compute_dtype = torch.float16
  attn_implementation = 'sdpa'


model_name = "mistralai/Mistral-7B-v0.1"
adapter = "./qdora/checkpoint-1231"
#Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, padding_size="left",  use_fast=True)

bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)

model = AutoModelForCausalLM.from_pretrained(
          model_name, quantization_config=bnb_config, device_map={"": 0}, torch_dtype=compute_dtype,  attn_implementation=attn_implementation
)

model = dequantize_model(model, to='./dqz_model_qdora/',dtype=compute_dtype)
model = PeftModel.from_pretrained(model, adapter)
model = model.merge_and_unload()

print(f"Successfully loaded the model {model_name} into memory")
#pushed to the hub
#model.push_to_hub("kaitchup/Mistral-7B-v0.1-oasstguanaco-1e-qdora-merged")
#tokenizer.push_to_hub("kaitchup/Mistral-7B-v0.1-oasstguanaco-1e-qdora-merged")
# Out:
# Requirement already satisfied: flash_attn in /usr/local/lib/python3.10/dist-packages (2.5.7)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from flash_attn) (2.2.1+cu121)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from flash_attn) (0.7.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from flash_attn) (24.0)
# Requirement already satisfied: ninja in /usr/local/lib/python3.10/dist-packages (from flash_attn) (1.11.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->flash_attn) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->flash_attn) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->flash_attn) (1.3.0)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Dequantizing `model.layers.0.self_attn.q_proj`...
# Dequantizing `model.layers.0.self_attn.k_proj`...
# Dequantizing `model.layers.0.self_attn.v_proj`...
# Dequantizing `model.layers.0.self_attn.o_proj`...
# Dequantizing `model.layers.0.mlp.gate_proj`...
# Dequantizing `model.layers.0.mlp.up_proj`...
# Dequantizing `model.layers.0.mlp.down_proj`...
# Dequantizing `model.layers.1.self_attn.q_proj`...
# Dequantizing `model.layers.1.self_attn.k_proj`...
# Dequantizing `model.layers.1.self_attn.v_proj`...
# Dequantizing `model.layers.1.self_attn.o_proj`...
# Dequantizing `model.layers.1.mlp.gate_proj`...
# Dequantizing `model.layers.1.mlp.up_proj`...
# Dequantizing `model.layers.1.mlp.down_proj`...
# Dequantizing `model.layers.2.self_attn.q_proj`...
# Dequantizing `model.layers.2.self_attn.k_proj`...
# Dequantizing `model.layers.2.self_attn.v_proj`...
# Dequantizing `model.layers.2.self_attn.o_proj`...
# Dequantizing `model.layers.2.mlp.gate_proj`...
# Dequantizing `model.layers.2.mlp.up_proj`...
# Dequantizing `model.layers.2.mlp.down_proj`...
# Dequantizing `model.layers.3.self_attn.q_proj`...
# Dequantizing `model.layers.3.self_attn.k_proj`...
# Dequantizing `model.layers.3.self_attn.v_proj`...
# Dequantizing `model.layers.3.self_attn.o_proj`...
# Dequantizing `model.layers.3.mlp.gate_proj`...
# Dequantizing `model.layers.3.mlp.up_proj`...
# Dequantizing `model.layers.3.mlp.down_proj`...
# Dequantizing `model.layers.4.self_attn.q_proj`...
# Dequantizing `model.layers.4.self_attn.k_proj`...
# Dequantizing `model.layers.4.self_attn.v_proj`...
# Dequantizing `model.layers.4.self_attn.o_proj`...
# Dequantizing `model.layers.4.mlp.gate_proj`...
# Dequantizing `model.layers.4.mlp.up_proj`...
# Dequantizing `model.layers.4.mlp.down_proj`...
# Dequantizing `model.layers.5.self_attn.q_proj`...
# Dequantizing `model.layers.5.self_attn.k_proj`...
# Dequantizing `model.layers.5.self_attn.v_proj`...
# Dequantizing `model.layers.5.self_attn.o_proj`...
# Dequantizing `model.layers.5.mlp.gate_proj`...
# Dequantizing `model.layers.5.mlp.up_proj`...
# Dequantizing `model.layers.5.mlp.down_proj`...
# Dequantizing `model.layers.6.self_attn.q_proj`...
# Dequantizing `model.layers.6.self_attn.k_proj`...
# Dequantizing `model.layers.6.self_attn.v_proj`...
# Dequantizing `model.layers.6.self_attn.o_proj`...
# Dequantizing `model.layers.6.mlp.gate_proj`...
# Dequantizing `model.layers.6.mlp.up_proj`...
# Dequantizing `model.layers.6.mlp.down_proj`...
# Dequantizing `model.layers.7.self_attn.q_proj`...
# Dequantizing `model.layers.7.self_attn.k_proj`...
# Dequantizing `model.layers.7.self_attn.v_proj`...
# Dequantizing `model.layers.7.self_attn.o_proj`...
# Dequantizing `model.layers.7.mlp.gate_proj`...
# Dequantizing `model.layers.7.mlp.up_proj`...
# Dequantizing `model.layers.7.mlp.down_proj`...
# Dequantizing `model.layers.8.self_attn.q_proj`...
# Dequantizing `model.layers.8.self_attn.k_proj`...
# Dequantizing `model.layers.8.self_attn.v_proj`...
# Dequantizing `model.layers.8.self_attn.o_proj`...
# Dequantizing `model.layers.8.mlp.gate_proj`...
# Dequantizing `model.layers.8.mlp.up_proj`...
# Dequantizing `model.layers.8.mlp.down_proj`...
# Dequantizing `model.layers.9.self_attn.q_proj`...
# Dequantizing `model.layers.9.self_attn.k_proj`...
# Dequantizing `model.layers.9.self_attn.v_proj`...
# Dequantizing `model.layers.9.self_attn.o_proj`...
# Dequantizing `model.layers.9.mlp.gate_proj`...
# Dequantizing `model.layers.9.mlp.up_proj`...
# Dequantizing `model.layers.9.mlp.down_proj`...
# Dequantizing `model.layers.10.self_attn.q_proj`...
# Dequantizing `model.layers.10.self_attn.k_proj`...
# Dequantizing `model.layers.10.self_attn.v_proj`...
# Dequantizing `model.layers.10.self_attn.o_proj`...
# Dequantizing `model.layers.10.mlp.gate_proj`...
# Dequantizing `model.layers.10.mlp.up_proj`...
# Dequantizing `model.layers.10.mlp.down_proj`...
# Dequantizing `model.layers.11.self_attn.q_proj`...
# Dequantizing `model.layers.11.self_attn.k_proj`...
# Dequantizing `model.layers.11.self_attn.v_proj`...
# Dequantizing `model.layers.11.self_attn.o_proj`...
# Dequantizing `model.layers.11.mlp.gate_proj`...
# Dequantizing `model.layers.11.mlp.up_proj`...
# Dequantizing `model.layers.11.mlp.down_proj`...
# Dequantizing `model.layers.12.self_attn.q_proj`...
# Dequantizing `model.layers.12.self_attn.k_proj`...
# Dequantizing `model.layers.12.self_attn.v_proj`...
# Dequantizing `model.layers.12.self_attn.o_proj`...
# Dequantizing `model.layers.12.mlp.gate_proj`...
# Dequantizing `model.layers.12.mlp.up_proj`...
# Dequantizing `model.layers.12.mlp.down_proj`...
# Dequantizing `model.layers.13.self_attn.q_proj`...
# Dequantizing `model.layers.13.self_attn.k_proj`...
# Dequantizing `model.layers.13.self_attn.v_proj`...
# Dequantizing `model.layers.13.self_attn.o_proj`...
# Dequantizing `model.layers.13.mlp.gate_proj`...
# Dequantizing `model.layers.13.mlp.up_proj`...
# Dequantizing `model.layers.13.mlp.down_proj`...
# Dequantizing `model.layers.14.self_attn.q_proj`...
# Dequantizing `model.layers.14.self_attn.k_proj`...
# Dequantizing `model.layers.14.self_attn.v_proj`...
# Dequantizing `model.layers.14.self_attn.o_proj`...
# Dequantizing `model.layers.14.mlp.gate_proj`...
# Dequantizing `model.layers.14.mlp.up_proj`...
# Dequantizing `model.layers.14.mlp.down_proj`...
# Dequantizing `model.layers.15.self_attn.q_proj`...
# Dequantizing `model.layers.15.self_attn.k_proj`...
# Dequantizing `model.layers.15.self_attn.v_proj`...
# Dequantizing `model.layers.15.self_attn.o_proj`...
# Dequantizing `model.layers.15.mlp.gate_proj`...
# Dequantizing `model.layers.15.mlp.up_proj`...
# Dequantizing `model.layers.15.mlp.down_proj`...
# Dequantizing `model.layers.16.self_attn.q_proj`...
# Dequantizing `model.layers.16.self_attn.k_proj`...
# Dequantizing `model.layers.16.self_attn.v_proj`...
# Dequantizing `model.layers.16.self_attn.o_proj`...
# Dequantizing `model.layers.16.mlp.gate_proj`...
# Dequantizing `model.layers.16.mlp.up_proj`...
# Dequantizing `model.layers.16.mlp.down_proj`...
# Dequantizing `model.layers.17.self_attn.q_proj`...
# Dequantizing `model.layers.17.self_attn.k_proj`...
# Dequantizing `model.layers.17.self_attn.v_proj`...
# Dequantizing `model.layers.17.self_attn.o_proj`...
# Dequantizing `model.layers.17.mlp.gate_proj`...
# Dequantizing `model.layers.17.mlp.up_proj`...
# Dequantizing `model.layers.17.mlp.down_proj`...
# Dequantizing `model.layers.18.self_attn.q_proj`...
# Dequantizing `model.layers.18.self_attn.k_proj`...
# Dequantizing `model.layers.18.self_attn.v_proj`...
# Dequantizing `model.layers.18.self_attn.o_proj`...
# Dequantizing `model.layers.18.mlp.gate_proj`...
# Dequantizing `model.layers.18.mlp.up_proj`...
# Dequantizing `model.layers.18.mlp.down_proj`...
# Dequantizing `model.layers.19.self_attn.q_proj`...
# Dequantizing `model.layers.19.self_attn.k_proj`...
# Dequantizing `model.layers.19.self_attn.v_proj`...
# Dequantizing `model.layers.19.self_attn.o_proj`...
# Dequantizing `model.layers.19.mlp.gate_proj`...
# Dequantizing `model.layers.19.mlp.up_proj`...
# Dequantizing `model.layers.19.mlp.down_proj`...
# Dequantizing `model.layers.20.self_attn.q_proj`...
# Dequantizing `model.layers.20.self_attn.k_proj`...
# Dequantizing `model.layers.20.self_attn.v_proj`...
# Dequantizing `model.layers.20.self_attn.o_proj`...
# Dequantizing `model.layers.20.mlp.gate_proj`...
# Dequantizing `model.layers.20.mlp.up_proj`...
# Dequantizing `model.layers.20.mlp.down_proj`...
# Dequantizing `model.layers.21.self_attn.q_proj`...
# Dequantizing `model.layers.21.self_attn.k_proj`...
# Dequantizing `model.layers.21.self_attn.v_proj`...
# Dequantizing `model.layers.21.self_attn.o_proj`...
# Dequantizing `model.layers.21.mlp.gate_proj`...
# Dequantizing `model.layers.21.mlp.up_proj`...
# Dequantizing `model.layers.21.mlp.down_proj`...
# Dequantizing `model.layers.22.self_attn.q_proj`...
# Dequantizing `model.layers.22.self_attn.k_proj`...
# Dequantizing `model.layers.22.self_attn.v_proj`...
# Dequantizing `model.layers.22.self_attn.o_proj`...
# Dequantizing `model.layers.22.mlp.gate_proj`...
# Dequantizing `model.layers.22.mlp.up_proj`...
# Dequantizing `model.layers.22.mlp.down_proj`...
# Dequantizing `model.layers.23.self_attn.q_proj`...
# Dequantizing `model.layers.23.self_attn.k_proj`...
# Dequantizing `model.layers.23.self_attn.v_proj`...
# Dequantizing `model.layers.23.self_attn.o_proj`...
# Dequantizing `model.layers.23.mlp.gate_proj`...
# Dequantizing `model.layers.23.mlp.up_proj`...
# Dequantizing `model.layers.23.mlp.down_proj`...
# Dequantizing `model.layers.24.self_attn.q_proj`...
# Dequantizing `model.layers.24.self_attn.k_proj`...
# Dequantizing `model.layers.24.self_attn.v_proj`...
# Dequantizing `model.layers.24.self_attn.o_proj`...
# Dequantizing `model.layers.24.mlp.gate_proj`...
# Dequantizing `model.layers.24.mlp.up_proj`...
# Dequantizing `model.layers.24.mlp.down_proj`...
# Dequantizing `model.layers.25.self_attn.q_proj`...
# Dequantizing `model.layers.25.self_attn.k_proj`...
# Dequantizing `model.layers.25.self_attn.v_proj`...
# Dequantizing `model.layers.25.self_attn.o_proj`...
# Dequantizing `model.layers.25.mlp.gate_proj`...
# Dequantizing `model.layers.25.mlp.up_proj`...
# Dequantizing `model.layers.25.mlp.down_proj`...
# Dequantizing `model.layers.26.self_attn.q_proj`...
# Dequantizing `model.layers.26.self_attn.k_proj`...
# Dequantizing `model.layers.26.self_attn.v_proj`...
# Dequantizing `model.layers.26.self_attn.o_proj`...
# Dequantizing `model.layers.26.mlp.gate_proj`...
# Dequantizing `model.layers.26.mlp.up_proj`...
# Dequantizing `model.layers.26.mlp.down_proj`...
# Dequantizing `model.layers.27.self_attn.q_proj`...
# Dequantizing `model.layers.27.self_attn.k_proj`...
# Dequantizing `model.layers.27.self_attn.v_proj`...
# Dequantizing `model.layers.27.self_attn.o_proj`...
# Dequantizing `model.layers.27.mlp.gate_proj`...
# Dequantizing `model.layers.27.mlp.up_proj`...
# Dequantizing `model.layers.27.mlp.down_proj`...
# Dequantizing `model.layers.28.self_attn.q_proj`...
# Dequantizing `model.layers.28.self_attn.k_proj`...
# Dequantizing `model.layers.28.self_attn.v_proj`...
# Dequantizing `model.layers.28.self_attn.o_proj`...
# Dequantizing `model.layers.28.mlp.gate_proj`...
# Dequantizing `model.layers.28.mlp.up_proj`...
# Dequantizing `model.layers.28.mlp.down_proj`...
# Dequantizing `model.layers.29.self_attn.q_proj`...
# Dequantizing `model.layers.29.self_attn.k_proj`...
# Dequantizing `model.layers.29.self_attn.v_proj`...
# Dequantizing `model.layers.29.self_attn.o_proj`...
# Dequantizing `model.layers.29.mlp.gate_proj`...
# Dequantizing `model.layers.29.mlp.up_proj`...
# Dequantizing `model.layers.29.mlp.down_proj`...
# Dequantizing `model.layers.30.self_attn.q_proj`...
# Dequantizing `model.layers.30.self_attn.k_proj`...
# Dequantizing `model.layers.30.self_attn.v_proj`...
# Dequantizing `model.layers.30.self_attn.o_proj`...
# Dequantizing `model.layers.30.mlp.gate_proj`...
# Dequantizing `model.layers.30.mlp.up_proj`...
# Dequantizing `model.layers.30.mlp.down_proj`...
# Dequantizing `model.layers.31.self_attn.q_proj`...
# Dequantizing `model.layers.31.self_attn.k_proj`...
# Dequantizing `model.layers.31.self_attn.v_proj`...
# Dequantizing `model.layers.31.self_attn.o_proj`...
# Dequantizing `model.layers.31.mlp.gate_proj`...
# Dequantizing `model.layers.31.mlp.up_proj`...
# Dequantizing `model.layers.31.mlp.down_proj`...
# Saving dequantized model...
# Successfully loaded the model mistralai/Mistral-7B-v0.1 into memory
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/5.18k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/kaitchup/Mistral-7B-v0.1-oasstguanaco-1e-qdora-merged/commit/558bbd6ffcc2df825d10398546ed0566511e9653', commit_message='Upload tokenizer', commit_description='', oid='558bbd6ffcc2df825d10398546ed0566511e9653', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# ---
#
#
# **QLoRA**
#
# More info: [QLoRA: Fine-Tune a Large Language Model on Your GPU](https://kaitchup.substack.com/p/qlora-fine-tune-a-large-language-model-on-your-gpu-27bed5a03e2b)

# %%
model_name = "mistralai/Mistral-7B-v0.1"
#Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, add_eos_token=True, use_fast=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = 'left' #Necessary for FlashAttention compatibility

#Better to use bf16 if supported (Ampere GPUs or more recent)
#If bf16 is supported, the GPU is also recent enough to support FlashAttention
if torch.cuda.is_bf16_supported():
  # !pip install flash_attn
  compute_dtype = torch.bfloat16
  attn_implementation = 'flash_attention_2'
else:
  compute_dtype = torch.float16
  attn_implementation = 'sdpa'

dataset = load_dataset("timdettmers/openassistant-guanaco")


#Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, add_eos_token=True, use_fast=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = 'left' #Necessary for FlashAttention compatibility

bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)
model = AutoModelForCausalLM.from_pretrained(
          model_name, quantization_config=bnb_config, device_map={"": 0}, torch_dtype=compute_dtype,  attn_implementation=attn_implementation
)
model = prepare_model_for_kbit_training(model)
model.gradient_checkpointing_enable({'use_reentrant':True})
#model.enable_input_require_grads()

peft_config = LoraConfig(
        lora_alpha=16,
        lora_dropout=0.05,
        r=16,
        bias="none",
        task_type="CAUSAL_LM",
        target_modules= ['k_proj', 'q_proj', 'v_proj', 'o_proj', "gate_proj", "down_proj", "up_proj"]
)


from trl import SFTConfig

training_arguments = SFTConfig(
        output_dir="./qlora/",
        evaluation_strategy="steps",
        do_eval=True,
        optim="paged_adamw_8bit",
        per_device_train_batch_size=8,
        per_device_eval_batch_size=8,
        log_level="debug",
        logging_steps=50,
        learning_rate=1e-5,
        eval_steps=50,
        num_train_epochs=1,
        fp16= not torch.cuda.is_bf16_supported(),
        bf16= torch.cuda.is_bf16_supported(),
        save_strategy='epoch',
        warmup_ratio=0.1,
        lr_scheduler_type="linear",
)

trainer = SFTTrainer(
        model=model,
        train_dataset=dataset['train'],
        eval_dataset=dataset['test'],
        dataset_text_field="text",
        max_seq_length=512,
        peft_config=peft_config,
        tokenizer=tokenizer,
        args=training_arguments,
)

trainer.train()
# Out:
# tokenizer_config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]
# Collecting flash_attn
#   Downloading flash_attn-2.5.7.tar.gz (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 15.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from flash_attn) (2.2.1+cu121)
# Collecting einops (from flash_attn)
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from flash_attn) (24.0)
# Collecting ninja (from flash_attn)
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 21.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->flash_attn) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->flash_attn) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->flash_attn) (1.3.0)
# Building wheels for collected packages: flash_attn
#   Building wheel for flash_attn (setup.py) ... done
#   Created wheel for flash_attn: filename=flash_attn-2.5.7-cp310-cp310-linux_x86_64.whl size=120853563 sha256=bbe6f77fd0899f8a125a5bdcf734b660c4c88e81c9b51c7ce98ebeba44dc6fa0
#   Stored in directory: /root/.cache/pip/wheels/13/96/ed/bcac89c56b606421f99b45b16a94db5d0f2b6b4eaf8bac4d01
# Successfully built flash_attn
# Installing collected packages: ninja, einops, flash_attn
# Successfully installed einops-0.7.0 flash_attn-2.5.7 ninja-1.11.1.1
# Downloading readme:   0%|          | 0.00/395 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Downloading data:   0%|          | 0.00/20.9M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Map:   0%|          | 0/9846 [00:00<?, ? examples/s]
# Map:   0%|          | 0/518 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:317: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:436: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(
# Using auto half precision backend
# Currently training with a batch size of: 8
# ***** Running training *****
#   Num examples = 9,846
#   Num Epochs = 1
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1,231
#   Number of trainable parameters = 41,943,040
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
# The input hidden states seems to be silently casted in float32, this might be related to the fact you have upcasted embedding or layer norm layers in float32. We will cast back the input in torch.bfloat16.
#     <div>
#
#       <progress value='551' max='1231' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 551/1231 1:53:42 < 2:20:50, 0.08 it/s, Epoch 0.45/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.347300</td>
#       <td>1.353649</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.262000</td>
#       <td>1.231738</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.181200</td>
#       <td>1.189125</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.156100</td>
#       <td>1.170896</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.129900</td>
#       <td>1.154133</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.150300</td>
#       <td>1.150258</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.128000</td>
#       <td>1.147490</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.138300</td>
#       <td>1.145134</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.122700</td>
#       <td>1.143200</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.121100</td>
#       <td>1.141903</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='36' max='65' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [36/65 01:37 < 01:20, 0.36 it/s]
#     </div>
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#     <div>
#
#       <progress value='1231' max='1231' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1231/1231 4:19:24, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.347300</td>
#       <td>1.353649</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.262000</td>
#       <td>1.231738</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.181200</td>
#       <td>1.189125</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.156100</td>
#       <td>1.170896</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.129900</td>
#       <td>1.154133</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.150300</td>
#       <td>1.150258</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.128000</td>
#       <td>1.147490</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.138300</td>
#       <td>1.145134</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.122700</td>
#       <td>1.143200</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.121100</td>
#       <td>1.141903</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>1.102900</td>
#       <td>1.141026</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.098100</td>
#       <td>1.139840</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>1.113300</td>
#       <td>1.138997</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>1.104500</td>
#       <td>1.138303</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>1.091700</td>
#       <td>1.137485</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>1.134400</td>
#       <td>1.137015</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>1.111500</td>
#       <td>1.136568</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>1.150700</td>
#       <td>1.136072</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>1.145200</td>
#       <td>1.136006</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.121100</td>
#       <td>1.135761</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>1.091800</td>
#       <td>1.135398</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>1.097300</td>
#       <td>1.135290</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>1.055400</td>
#       <td>1.135303</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>1.130300</td>
#       <td>1.135274</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/mergexp/qlora/checkpoint-1231
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--mistralai--Mistral-7B-v0.1/snapshots/26bca36bde8333b5d7f72e9ed20ccda6a618af24/config.json
# Model config MistralConfig {
#   "architectures": [
#     "MistralForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 32768,
#   "model_type": "mistral",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "rms_norm_eps": 1e-05,
#   "rope_theta": 10000.0,
#   "sliding_window": 4096,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.39.3",
#   "use_cache": true,
#   "vocab_size": 32000
# }
#
# tokenizer config file saved in ./drive/MyDrive/mergexp/qlora/checkpoint-1231/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/mergexp/qlora/checkpoint-1231/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=1231, training_loss=1.1352182507611792, metrics={'train_runtime': 15574.6019, 'train_samples_per_second': 0.632, 'train_steps_per_second': 0.079, 'total_flos': 2.148541273402245e+17, 'train_loss': 1.1352182507611792, 'epoch': 1.0})

# %% [markdown]
# Merging the adapter

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from peft import PeftModel
#Better to use bf16 if supported (Ampere GPUs or more recent)
#If bf16 is supported, the GPU is also recent enough to support FlashAttention
if torch.cuda.is_bf16_supported():
  # !pip install flash_attn
  compute_dtype = torch.bfloat16
  attn_implementation = 'flash_attention_2'
else:
  compute_dtype = torch.float16
  attn_implementation = 'sdpa'


model_name = "mistralai/Mistral-7B-v0.1"
adapter = "./qlora/checkpoint-1231"
#Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, padding_size="left",  use_fast=True)

bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)

model = AutoModelForCausalLM.from_pretrained(
          model_name, quantization_config=bnb_config, device_map={"": 0}, torch_dtype=compute_dtype,  attn_implementation=attn_implementation
)

model = dequantize_model(model, to='./dqz_model_qlora/',dtype=compute_dtype)
model = PeftModel.from_pretrained(model, adapter)
model = model.merge_and_unload()

print(f"Successfully loaded the model {model_name} into memory")

#pushed to the hub
#model.push_to_hub("kaitchup/Mistral-7B-v0.1-oasstguanaco-1e-qlora-merged")
#tokenizer.push_to_hub("kaitchup/Mistral-7B-v0.1-oasstguanaco-1e-qlora-merged")
# Out:
# Requirement already satisfied: flash_attn in /usr/local/lib/python3.10/dist-packages (2.5.7)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from flash_attn) (2.2.1+cu121)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from flash_attn) (0.7.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from flash_attn) (24.0)
# Requirement already satisfied: ninja in /usr/local/lib/python3.10/dist-packages (from flash_attn) (1.11.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->flash_attn) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->flash_attn) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->flash_attn) (1.3.0)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Dequantizing `model.layers.0.self_attn.q_proj`...
# Dequantizing `model.layers.0.self_attn.k_proj`...
# Dequantizing `model.layers.0.self_attn.v_proj`...
# Dequantizing `model.layers.0.self_attn.o_proj`...
# Dequantizing `model.layers.0.mlp.gate_proj`...
# Dequantizing `model.layers.0.mlp.up_proj`...
# Dequantizing `model.layers.0.mlp.down_proj`...
# Dequantizing `model.layers.1.self_attn.q_proj`...
# Dequantizing `model.layers.1.self_attn.k_proj`...
# Dequantizing `model.layers.1.self_attn.v_proj`...
# Dequantizing `model.layers.1.self_attn.o_proj`...
# Dequantizing `model.layers.1.mlp.gate_proj`...
# Dequantizing `model.layers.1.mlp.up_proj`...
# Dequantizing `model.layers.1.mlp.down_proj`...
# Dequantizing `model.layers.2.self_attn.q_proj`...
# Dequantizing `model.layers.2.self_attn.k_proj`...
# Dequantizing `model.layers.2.self_attn.v_proj`...
# Dequantizing `model.layers.2.self_attn.o_proj`...
# Dequantizing `model.layers.2.mlp.gate_proj`...
# Dequantizing `model.layers.2.mlp.up_proj`...
# Dequantizing `model.layers.2.mlp.down_proj`...
# Dequantizing `model.layers.3.self_attn.q_proj`...
# Dequantizing `model.layers.3.self_attn.k_proj`...
# Dequantizing `model.layers.3.self_attn.v_proj`...
# Dequantizing `model.layers.3.self_attn.o_proj`...
# Dequantizing `model.layers.3.mlp.gate_proj`...
# Dequantizing `model.layers.3.mlp.up_proj`...
# Dequantizing `model.layers.3.mlp.down_proj`...
# Dequantizing `model.layers.4.self_attn.q_proj`...
# Dequantizing `model.layers.4.self_attn.k_proj`...
# Dequantizing `model.layers.4.self_attn.v_proj`...
# Dequantizing `model.layers.4.self_attn.o_proj`...
# Dequantizing `model.layers.4.mlp.gate_proj`...
# Dequantizing `model.layers.4.mlp.up_proj`...
# Dequantizing `model.layers.4.mlp.down_proj`...
# Dequantizing `model.layers.5.self_attn.q_proj`...
# Dequantizing `model.layers.5.self_attn.k_proj`...
# Dequantizing `model.layers.5.self_attn.v_proj`...
# Dequantizing `model.layers.5.self_attn.o_proj`...
# Dequantizing `model.layers.5.mlp.gate_proj`...
# Dequantizing `model.layers.5.mlp.up_proj`...
# Dequantizing `model.layers.5.mlp.down_proj`...
# Dequantizing `model.layers.6.self_attn.q_proj`...
# Dequantizing `model.layers.6.self_attn.k_proj`...
# Dequantizing `model.layers.6.self_attn.v_proj`...
# Dequantizing `model.layers.6.self_attn.o_proj`...
# Dequantizing `model.layers.6.mlp.gate_proj`...
# Dequantizing `model.layers.6.mlp.up_proj`...
# Dequantizing `model.layers.6.mlp.down_proj`...
# Dequantizing `model.layers.7.self_attn.q_proj`...
# Dequantizing `model.layers.7.self_attn.k_proj`...
# Dequantizing `model.layers.7.self_attn.v_proj`...
# Dequantizing `model.layers.7.self_attn.o_proj`...
# Dequantizing `model.layers.7.mlp.gate_proj`...
# Dequantizing `model.layers.7.mlp.up_proj`...
# Dequantizing `model.layers.7.mlp.down_proj`...
# Dequantizing `model.layers.8.self_attn.q_proj`...
# Dequantizing `model.layers.8.self_attn.k_proj`...
# Dequantizing `model.layers.8.self_attn.v_proj`...
# Dequantizing `model.layers.8.self_attn.o_proj`...
# Dequantizing `model.layers.8.mlp.gate_proj`...
# Dequantizing `model.layers.8.mlp.up_proj`...
# Dequantizing `model.layers.8.mlp.down_proj`...
# Dequantizing `model.layers.9.self_attn.q_proj`...
# Dequantizing `model.layers.9.self_attn.k_proj`...
# Dequantizing `model.layers.9.self_attn.v_proj`...
# Dequantizing `model.layers.9.self_attn.o_proj`...
# Dequantizing `model.layers.9.mlp.gate_proj`...
# Dequantizing `model.layers.9.mlp.up_proj`...
# Dequantizing `model.layers.9.mlp.down_proj`...
# Dequantizing `model.layers.10.self_attn.q_proj`...
# Dequantizing `model.layers.10.self_attn.k_proj`...
# Dequantizing `model.layers.10.self_attn.v_proj`...
# Dequantizing `model.layers.10.self_attn.o_proj`...
# Dequantizing `model.layers.10.mlp.gate_proj`...
# Dequantizing `model.layers.10.mlp.up_proj`...
# Dequantizing `model.layers.10.mlp.down_proj`...
# Dequantizing `model.layers.11.self_attn.q_proj`...
# Dequantizing `model.layers.11.self_attn.k_proj`...
# Dequantizing `model.layers.11.self_attn.v_proj`...
# Dequantizing `model.layers.11.self_attn.o_proj`...
# Dequantizing `model.layers.11.mlp.gate_proj`...
# Dequantizing `model.layers.11.mlp.up_proj`...
# Dequantizing `model.layers.11.mlp.down_proj`...
# Dequantizing `model.layers.12.self_attn.q_proj`...
# Dequantizing `model.layers.12.self_attn.k_proj`...
# Dequantizing `model.layers.12.self_attn.v_proj`...
# Dequantizing `model.layers.12.self_attn.o_proj`...
# Dequantizing `model.layers.12.mlp.gate_proj`...
# Dequantizing `model.layers.12.mlp.up_proj`...
# Dequantizing `model.layers.12.mlp.down_proj`...
# Dequantizing `model.layers.13.self_attn.q_proj`...
# Dequantizing `model.layers.13.self_attn.k_proj`...
# Dequantizing `model.layers.13.self_attn.v_proj`...
# Dequantizing `model.layers.13.self_attn.o_proj`...
# Dequantizing `model.layers.13.mlp.gate_proj`...
# Dequantizing `model.layers.13.mlp.up_proj`...
# Dequantizing `model.layers.13.mlp.down_proj`...
# Dequantizing `model.layers.14.self_attn.q_proj`...
# Dequantizing `model.layers.14.self_attn.k_proj`...
# Dequantizing `model.layers.14.self_attn.v_proj`...
# Dequantizing `model.layers.14.self_attn.o_proj`...
# Dequantizing `model.layers.14.mlp.gate_proj`...
# Dequantizing `model.layers.14.mlp.up_proj`...
# Dequantizing `model.layers.14.mlp.down_proj`...
# Dequantizing `model.layers.15.self_attn.q_proj`...
# Dequantizing `model.layers.15.self_attn.k_proj`...
# Dequantizing `model.layers.15.self_attn.v_proj`...
# Dequantizing `model.layers.15.self_attn.o_proj`...
# Dequantizing `model.layers.15.mlp.gate_proj`...
# Dequantizing `model.layers.15.mlp.up_proj`...
# Dequantizing `model.layers.15.mlp.down_proj`...
# Dequantizing `model.layers.16.self_attn.q_proj`...
# Dequantizing `model.layers.16.self_attn.k_proj`...
# Dequantizing `model.layers.16.self_attn.v_proj`...
# Dequantizing `model.layers.16.self_attn.o_proj`...
# Dequantizing `model.layers.16.mlp.gate_proj`...
# Dequantizing `model.layers.16.mlp.up_proj`...
# Dequantizing `model.layers.16.mlp.down_proj`...
# Dequantizing `model.layers.17.self_attn.q_proj`...
# Dequantizing `model.layers.17.self_attn.k_proj`...
# Dequantizing `model.layers.17.self_attn.v_proj`...
# Dequantizing `model.layers.17.self_attn.o_proj`...
# Dequantizing `model.layers.17.mlp.gate_proj`...
# Dequantizing `model.layers.17.mlp.up_proj`...
# Dequantizing `model.layers.17.mlp.down_proj`...
# Dequantizing `model.layers.18.self_attn.q_proj`...
# Dequantizing `model.layers.18.self_attn.k_proj`...
# Dequantizing `model.layers.18.self_attn.v_proj`...
# Dequantizing `model.layers.18.self_attn.o_proj`...
# Dequantizing `model.layers.18.mlp.gate_proj`...
# Dequantizing `model.layers.18.mlp.up_proj`...
# Dequantizing `model.layers.18.mlp.down_proj`...
# Dequantizing `model.layers.19.self_attn.q_proj`...
# Dequantizing `model.layers.19.self_attn.k_proj`...
# Dequantizing `model.layers.19.self_attn.v_proj`...
# Dequantizing `model.layers.19.self_attn.o_proj`...
# Dequantizing `model.layers.19.mlp.gate_proj`...
# Dequantizing `model.layers.19.mlp.up_proj`...
# Dequantizing `model.layers.19.mlp.down_proj`...
# Dequantizing `model.layers.20.self_attn.q_proj`...
# Dequantizing `model.layers.20.self_attn.k_proj`...
# Dequantizing `model.layers.20.self_attn.v_proj`...
# Dequantizing `model.layers.20.self_attn.o_proj`...
# Dequantizing `model.layers.20.mlp.gate_proj`...
# Dequantizing `model.layers.20.mlp.up_proj`...
# Dequantizing `model.layers.20.mlp.down_proj`...
# Dequantizing `model.layers.21.self_attn.q_proj`...
# Dequantizing `model.layers.21.self_attn.k_proj`...
# Dequantizing `model.layers.21.self_attn.v_proj`...
# Dequantizing `model.layers.21.self_attn.o_proj`...
# Dequantizing `model.layers.21.mlp.gate_proj`...
# Dequantizing `model.layers.21.mlp.up_proj`...
# Dequantizing `model.layers.21.mlp.down_proj`...
# Dequantizing `model.layers.22.self_attn.q_proj`...
# Dequantizing `model.layers.22.self_attn.k_proj`...
# Dequantizing `model.layers.22.self_attn.v_proj`...
# Dequantizing `model.layers.22.self_attn.o_proj`...
# Dequantizing `model.layers.22.mlp.gate_proj`...
# Dequantizing `model.layers.22.mlp.up_proj`...
# Dequantizing `model.layers.22.mlp.down_proj`...
# Dequantizing `model.layers.23.self_attn.q_proj`...
# Dequantizing `model.layers.23.self_attn.k_proj`...
# Dequantizing `model.layers.23.self_attn.v_proj`...
# Dequantizing `model.layers.23.self_attn.o_proj`...
# Dequantizing `model.layers.23.mlp.gate_proj`...
# Dequantizing `model.layers.23.mlp.up_proj`...
# Dequantizing `model.layers.23.mlp.down_proj`...
# Dequantizing `model.layers.24.self_attn.q_proj`...
# Dequantizing `model.layers.24.self_attn.k_proj`...
# Dequantizing `model.layers.24.self_attn.v_proj`...
# Dequantizing `model.layers.24.self_attn.o_proj`...
# Dequantizing `model.layers.24.mlp.gate_proj`...
# Dequantizing `model.layers.24.mlp.up_proj`...
# Dequantizing `model.layers.24.mlp.down_proj`...
# Dequantizing `model.layers.25.self_attn.q_proj`...
# Dequantizing `model.layers.25.self_attn.k_proj`...
# Dequantizing `model.layers.25.self_attn.v_proj`...
# Dequantizing `model.layers.25.self_attn.o_proj`...
# Dequantizing `model.layers.25.mlp.gate_proj`...
# Dequantizing `model.layers.25.mlp.up_proj`...
# Dequantizing `model.layers.25.mlp.down_proj`...
# Dequantizing `model.layers.26.self_attn.q_proj`...
# Dequantizing `model.layers.26.self_attn.k_proj`...
# Dequantizing `model.layers.26.self_attn.v_proj`...
# Dequantizing `model.layers.26.self_attn.o_proj`...
# Dequantizing `model.layers.26.mlp.gate_proj`...
# Dequantizing `model.layers.26.mlp.up_proj`...
# Dequantizing `model.layers.26.mlp.down_proj`...
# Dequantizing `model.layers.27.self_attn.q_proj`...
# Dequantizing `model.layers.27.self_attn.k_proj`...
# Dequantizing `model.layers.27.self_attn.v_proj`...
# Dequantizing `model.layers.27.self_attn.o_proj`...
# Dequantizing `model.layers.27.mlp.gate_proj`...
# Dequantizing `model.layers.27.mlp.up_proj`...
# Dequantizing `model.layers.27.mlp.down_proj`...
# Dequantizing `model.layers.28.self_attn.q_proj`...
# Dequantizing `model.layers.28.self_attn.k_proj`...
# Dequantizing `model.layers.28.self_attn.v_proj`...
# Dequantizing `model.layers.28.self_attn.o_proj`...
# Dequantizing `model.layers.28.mlp.gate_proj`...
# Dequantizing `model.layers.28.mlp.up_proj`...
# Dequantizing `model.layers.28.mlp.down_proj`...
# Dequantizing `model.layers.29.self_attn.q_proj`...
# Dequantizing `model.layers.29.self_attn.k_proj`...
# Dequantizing `model.layers.29.self_attn.v_proj`...
# Dequantizing `model.layers.29.self_attn.o_proj`...
# Dequantizing `model.layers.29.mlp.gate_proj`...
# Dequantizing `model.layers.29.mlp.up_proj`...
# Dequantizing `model.layers.29.mlp.down_proj`...
# Dequantizing `model.layers.30.self_attn.q_proj`...
# Dequantizing `model.layers.30.self_attn.k_proj`...
# Dequantizing `model.layers.30.self_attn.v_proj`...
# Dequantizing `model.layers.30.self_attn.o_proj`...
# Dequantizing `model.layers.30.mlp.gate_proj`...
# Dequantizing `model.layers.30.mlp.up_proj`...
# Dequantizing `model.layers.30.mlp.down_proj`...
# Dequantizing `model.layers.31.self_attn.q_proj`...
# Dequantizing `model.layers.31.self_attn.k_proj`...
# Dequantizing `model.layers.31.self_attn.v_proj`...
# Dequantizing `model.layers.31.self_attn.o_proj`...
# Dequantizing `model.layers.31.mlp.gate_proj`...
# Dequantizing `model.layers.31.mlp.up_proj`...
# Dequantizing `model.layers.31.mlp.down_proj`...
# Saving dequantized model...
# Successfully loaded the model mistralai/Mistral-7B-v0.1 into memory

# %% [markdown]
# # Benchmarking: Inference throughtput and accuracy

# %% [markdown]
# Some utilities to dequantize a model and benchmark perplexity and inference speed.
#
# The dequantization is done before merging the adapter. More info here:
# [LoRA Adapters: When a Naive Merge Leads to Poor Performance](https://kaitchup.substack.com/p/lora-adapters-when-a-naive-merge)

# %%
import torch
from tqdm import tqdm
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from peft import PeftModel
from datasets import load_dataset
from peft.utils import _get_submodules
import os,json, copy
import bitsandbytes as bnb
from bitsandbytes.functional import dequantize_4bit
import time
#Better to use bf16 if supported (Ampere GPUs or more recent)
#If bf16 is supported, the GPU is also recent enough to support FlashAttention
if torch.cuda.is_bf16_supported():
  # !pip install flash_attn
  compute_dtype = torch.bfloat16
  attn_implementation = 'flash_attention_2'
else:
  compute_dtype = torch.float16
  attn_implementation = 'sdpa'


def dequantize_model(model, to='./dequantized_model', dtype=torch.float16, device="cuda"):
    """
    'model': the peftmodel you loaded with qlora.
    'tokenizer': the model's corresponding hf's tokenizer.
    'to': directory to save the dequantized model
    'dtype': dtype that the model was trained using
    'device': device to load the model to
    """


    os.makedirs(to, exist_ok=True)

    cls = bnb.nn.Linear4bit

    with torch.no_grad():
        for name, module in model.named_modules():
            if isinstance(module, cls):
                print(f"Dequantizing `{name}`...")
                quant_state = copy.deepcopy(module.weight.quant_state)
                quant_state.dtype = dtype

                weights = dequantize_4bit(module.weight.data, quant_state=quant_state, quant_type="nf4").to(dtype)

                new_module = torch.nn.Linear(module.in_features, module.out_features, bias=None, dtype=dtype)
                new_module.weight = torch.nn.Parameter(weights)
                new_module.to(device=device, dtype=dtype)

                parent, target, target_name = _get_submodules(model, name)
                setattr(parent, target_name, new_module)

        # a hack, setting this to avoid hf's saving error because hf
        # itself does not support saving a model that is registered to be loaded in 4bit.
        model.is_loaded_in_4bit = False

        print("Saving dequantized model...")
        model.save_pretrained(to)
        #tokenizer.save_pretrained(to)
        config_data = json.loads(open(os.path.join(to, 'config.json'), 'r').read())
        config_data.pop("quantization_config", None)
        config_data.pop("pretraining_tp", None)
        with open(os.path.join(to, 'config.json'), 'w') as config:
            config.write(json.dumps(config_data, indent=2))

        return model


#compute the perplexity on a dataset given a tokenizer and a model
def ppl_model(model, tokenizer, dataset):
  nlls= []
  max_length = 2048
  stride = 512
  for s in tqdm(range(len(dataset['text']))):
      encodings = tokenizer(dataset['text'][s], return_tensors="pt")
      seq_len = encodings.input_ids.size(1)
      prev_end_loc = 0
      for begin_loc in range(0, seq_len, stride):
          end_loc = min(begin_loc + max_length, seq_len)
          trg_len = end_loc - prev_end_loc
          input_ids = encodings.input_ids[:, begin_loc:end_loc].to("cuda")
          target_ids = input_ids.clone()
          target_ids[:, :-trg_len] = -100
          with torch.no_grad():
              outputs = model(input_ids, labels=target_ids)
              neg_log_likelihood = outputs.loss
          nlls.append(neg_log_likelihood)
          prev_end_loc = end_loc
          if end_loc == seq_len:
              break
  ppl = torch.exp(torch.stack(nlls).mean())
  return ppl.item()

model_name = "mistralai/Mistral-7B-v0.1"

#Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, padding_size="left",  use_fast=True)
tokenizer.pad_token = tokenizer.eos_token
p = "You are a helpful, respectful and honest assistant. Always answer as helpfully as possible, while being safe. Your answers should not include any harmful, unethical, racist, sexist, toxic, dangerous, or illegal content. Please ensure that your responses are socially unbiased and positive in nature.\n\nIf a question does not make any sense, or is not factually coherent, explain why instead of answering something not correct. If you don't know the answer to a question, please don't share false information. \n\n Tell me about gravity."


def eval_model(model):
  total_tokens = 0
  total_duration = 0
  for b in range(5):


    inputs = tokenizer(p, return_tensors="pt").to("cuda")
    generation_time = time.time()
    outputs = model.generate(**inputs, pad_token_id=tokenizer.eos_token_id, max_new_tokens=300)
    duration = time.time() - generation_time
    total_duration += duration

    for output in outputs:
      result = tokenizer.decode(output)
      nb_tokens = len(result)
      total_tokens += nb_tokens
    print("--- Speed: %s tokens/second ---" % (round(nb_tokens/duration,2)))
  print("--- Average speed: %s tokens/second ---" % (round(total_tokens/total_duration,2)))

  ds = load_dataset("timdettmers/openassistant-guanaco", split='test')
  ppl = ppl_model(model, tokenizer, ds)
  print("Perplexity: "+str(ppl))
# Out:
# Collecting flash_attn
#   Downloading flash_attn-2.5.7.tar.gz (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 15.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from flash_attn) (2.2.1+cu121)
# Collecting einops (from flash_attn)
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from flash_attn) (24.0)
# Collecting ninja (from flash_attn)
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash_attn) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->flash_attn) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->flash_attn) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->flash_attn) (1.3.0)
# Building wheels for collected packages: flash_attn
#   Building wheel for flash_attn (setup.py) ... done
#   Created wheel for flash_attn: filename=flash_attn-2.5.7-cp310-cp310-linux_x86_64.whl size=120853563 sha256=bbe6f77fd0899f8a125a5bdcf734b660c4c88e81c9b51c7ce98ebeba44dc6fa0
#   Stored in directory: /root/.cache/pip/wheels/13/96/ed/bcac89c56b606421f99b45b16a94db5d0f2b6b4eaf8bac4d01
# Successfully built flash_attn
# Installing collected packages: ninja, einops, flash_attn
# Successfully installed einops-0.7.0 flash_attn-2.5.7 ninja-1.11.1.1
# tokenizer_config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]

# %% [markdown]
# # Baseline: Mistral 7B Quantized with bitsandbytes NF4

# %%
model_name = "mistralai/Mistral-7B-v0.1"
bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)
loading_start = time.time()
model = AutoModelForCausalLM.from_pretrained(
          model_name, quantization_config=bnb_config, device_map={"": 0}, torch_dtype=compute_dtype,  attn_implementation=attn_implementation
)
print("--- Loading model time: %s seconds ---" % (time.time() - loading_start))
eval_model(model)
# Out:
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# --- Loading model time: 63.12954354286194 seconds ---
# --- Speed: 30.5 tokens/second ---
# --- Speed: 35.92 tokens/second ---
# --- Speed: 35.9 tokens/second ---
# --- Speed: 35.94 tokens/second ---
# --- Speed: 36.06 tokens/second ---
# --- Average speed: 34.71 tokens/second ---
# Downloading readme:   0%|          | 0.00/395 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Downloading data:   0%|          | 0.00/20.9M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# 100%|██████████| 518/518 [02:18<00:00,  3.73it/s]
# Perplexity: 4.720216751098633

# %% [markdown]
# # QLoRA
#
# With a loaded adapter

# %%
model_name = "mistralai/Mistral-7B-v0.1"
adapter = "../qlora/checkpoint-1231"
bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)
loading_start = time.time()
model = AutoModelForCausalLM.from_pretrained(
          model_name, quantization_config=bnb_config, device_map={"": 0}, torch_dtype=compute_dtype,  attn_implementation=attn_implementation
)
print("--- Loading model time: %s seconds ---" % (time.time() - loading_start))
loading_adapter_start = time.time()
model = PeftModel.from_pretrained(model, adapter)
print("--- Loading adapter time: %s seconds ---" % (time.time() - loading_adapter_start))

eval_model(model)
# Out:
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# --- Loading model time: 64.71461462974548 seconds ---
# --- Loading adapter time: 6.66745662689209 seconds ---
# --- Speed: 43.31 tokens/second ---
# --- Speed: 45.56 tokens/second ---
# --- Speed: 45.41 tokens/second ---
# --- Speed: 45.01 tokens/second ---
# --- Speed: 45.22 tokens/second ---
# --- Average speed: 44.89 tokens/second ---
# Downloading readme:   0%|          | 0.00/395 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Downloading data:   0%|          | 0.00/20.9M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# 100%|██████████| 518/518 [02:52<00:00,  3.01it/s]
# Perplexity: 3.379533052444458

# %% [markdown]
# with a merged adapter

# %%
model_name = "kaitchup/Mistral-7B-v0.1-oasstguanaco-1e-qlora-merged"
loading_start = time.time()
model = AutoModelForCausalLM.from_pretrained(
          model_name, device_map={"": 0}, torch_dtype=compute_dtype,  attn_implementation=attn_implementation
)
print("--- Loading model time: %s seconds ---" % (time.time() - loading_start))
eval_model(model)
# Out:
# config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# --- Loading model time: 7.132479667663574 seconds ---
# --- Speed: 76.58 tokens/second ---
# --- Speed: 76.71 tokens/second ---
# --- Speed: 76.79 tokens/second ---
# --- Speed: 76.68 tokens/second ---
# --- Speed: 76.64 tokens/second ---
# --- Average speed: 76.68 tokens/second ---
# 100%|██████████| 518/518 [01:36<00:00,  5.35it/s]
# Perplexity: 3.3805997371673584

# %% [markdown]
# With merged adapter and BNB NF4 quantization

# %%
model_name = "kaitchup/Mistral-7B-v0.1-oasstguanaco-1e-qlora-merged"
loading_start = time.time()
bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)
model = AutoModelForCausalLM.from_pretrained(
          model_name, quantization_config=bnb_config, device_map={"": 0}, torch_dtype=compute_dtype,  attn_implementation=attn_implementation
)
print("--- Loading model time: %s seconds ---" % (time.time() - loading_start))
eval_model(model)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# --- Loading model time: 7.103466033935547 seconds ---
# --- Speed: 34.68 tokens/second ---
# --- Speed: 34.67 tokens/second ---
# --- Speed: 34.91 tokens/second ---
# --- Speed: 35.11 tokens/second ---
# --- Speed: 35.0 tokens/second ---
# --- Average speed: 34.87 tokens/second ---
# 100%|██████████| 518/518 [02:18<00:00,  3.74it/s]
# Perplexity: 4.590646266937256

# %% [markdown]
# With merged adapter and AWQ quantization

# %%
from awq import AutoAWQForCausalLM
from transformers import AutoTokenizer

model_path = 'kaitchup/Mistral-7B-v0.1-oasstguanaco-1e-qlora-merged'
quant_path = 'Mistral-7B-v0.1-oasstguanaco-1e-qlora-merged-awq-4bit'
quant_config = { "zero_point": True, "q_group_size": 128, "w_bit": 4, "version": "GEMM" }

# Load model and tokenizer
model = AutoAWQForCausalLM.from_pretrained(model_path, safetensors=True)
tokenizer = AutoTokenizer.from_pretrained(model_path, use_fast=True)

# Quantize
model.quantize(tokenizer, quant_config=quant_config)

# Save quantized model with safetensors
model.save_quantized("./"+quant_path, safetensors=True)
tokenizer.save_pretrained("./"+quant_path)
# Out:
# config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/5.18k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/993 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# AWQ: 100%|██████████| 32/32 [28:30<00:00, 53.45s/it]
# ('./Mistral-7B-v0.1-oasstguanaco-1e-qlora-merged-awq-4bit/tokenizer_config.json',
#  './Mistral-7B-v0.1-oasstguanaco-1e-qlora-merged-awq-4bit/special_tokens_map.json',
#  './Mistral-7B-v0.1-oasstguanaco-1e-qlora-merged-awq-4bit/tokenizer.model',
#  './Mistral-7B-v0.1-oasstguanaco-1e-qlora-merged-awq-4bit/added_tokens.json',
#  './Mistral-7B-v0.1-oasstguanaco-1e-qlora-merged-awq-4bit/tokenizer.json')

# %%
model_name = "Mistral-7B-v0.1-oasstguanaco-1e-qlora-merged-awq-4bit"
loading_start = time.time()
model = AutoModelForCausalLM.from_pretrained(
          model_name, device_map={"": 0}, torch_dtype=torch.float16
)
print("--- Loading model time: %s seconds ---" % (time.time() - loading_start))
eval_model(model)
# Out:
# --- Loading model time: 2.4577279090881348 seconds ---
# --- Speed: 278.74 tokens/second ---
# --- Speed: 876.4 tokens/second ---
# --- Speed: 113.87 tokens/second ---
# --- Speed: 108.53 tokens/second ---
# --- Speed: 435.08 tokens/second ---
# --- Average speed: 152.05 tokens/second ---
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# 100%|██████████| 518/518 [02:57<00:00,  2.92it/s]
# Perplexity: 3.4783289432525635

# %% [markdown]
# # QDoRA
# With a loaded adapter

# %%
model_name = "mistralai/Mistral-7B-v0.1"
adapter = "./qdora/checkpoint-1231"
bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)
loading_start = time.time()
model = AutoModelForCausalLM.from_pretrained(
          model_name, quantization_config=bnb_config, device_map={"": 0}, torch_dtype=compute_dtype,  attn_implementation=attn_implementation
)
print("--- Loading model time: %s seconds ---" % (time.time() - loading_start))
loading_adapter_start = time.time()
model = PeftModel.from_pretrained(model, adapter)
print("--- Loading adapter time: %s seconds ---" % (time.time() - loading_adapter_start))

eval_model(model)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# --- Loading model time: 57.367106676101685 seconds ---
# --- Loading adapter time: 6.7472243309021 seconds ---
# --- Speed: 5.0 tokens/second ---
# --- Speed: 5.01 tokens/second ---
# --- Speed: 5.01 tokens/second ---
# --- Speed: 5.01 tokens/second ---
# --- Speed: 5.01 tokens/second ---
# --- Average speed: 5.01 tokens/second ---
# 100%|██████████| 518/518 [18:27<00:00,  2.14s/it]
# Perplexity: 3.3790879249572754

# %% [markdown]
# with a merged adapter

# %%
model_name = "kaitchup/Mistral-7B-v0.1-oasstguanaco-1e-qdora-merged"
loading_start = time.time()
model = AutoModelForCausalLM.from_pretrained(
          model_name, device_map={"": 0}, torch_dtype=compute_dtype,  attn_implementation=attn_implementation
)
print("--- Loading model time: %s seconds ---" % (time.time() - loading_start))
eval_model(model)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# --- Loading model time: 5.826384544372559 seconds ---
# --- Speed: 74.77 tokens/second ---
# --- Speed: 77.26 tokens/second ---
# --- Speed: 77.34 tokens/second ---
# --- Speed: 77.63 tokens/second ---
# --- Speed: 77.64 tokens/second ---
# --- Average speed: 76.91 tokens/second ---
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# 100%|██████████| 518/518 [01:37<00:00,  5.33it/s]
# Perplexity: 3.3809475898742676

# %% [markdown]
# With merged adapter and BNB NF4 quantization

# %%
model_name = "kaitchup/Mistral-7B-v0.1-oasstguanaco-1e-qdora-merged"
loading_start = time.time()
bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)
model = AutoModelForCausalLM.from_pretrained(
          model_name, quantization_config=bnb_config, device_map={"": 0}, torch_dtype=compute_dtype,  attn_implementation=attn_implementation
)
print("--- Loading model time: %s seconds ---" % (time.time() - loading_start))
eval_model(model)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# --- Loading model time: 6.595882892608643 seconds ---
# --- Speed: 35.01 tokens/second ---
# --- Speed: 35.06 tokens/second ---
# --- Speed: 35.07 tokens/second ---
# --- Speed: 35.14 tokens/second ---
# --- Speed: 35.1 tokens/second ---
# --- Average speed: 35.08 tokens/second ---
# 100%|██████████| 518/518 [02:18<00:00,  3.74it/s]
# Perplexity: 4.622631072998047

# %% [markdown]
# With merged adapter and AWQ quantization

# %%
# !pip install autoawq
# Out:
# Collecting autoawq
#   Downloading autoawq-0.2.4-cp310-cp310-manylinux2014_x86_64.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.8/80.8 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: torch>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from autoawq) (2.2.1+cu121)
# Collecting transformers<=4.38.2,>=4.35.0 (from autoawq)
#   Downloading transformers-4.38.2-py3-none-any.whl (8.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 26.7 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from autoawq) (0.15.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from autoawq) (4.10.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (from autoawq) (0.29.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from autoawq) (2.18.0)
# Collecting zstandard (from autoawq)
#   Downloading zstandard-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 60.6 MB/s eta 0:00:00
# Collecting autoawq-kernels (from autoawq)
#   Downloading autoawq_kernels-0.0.6-cp310-cp310-manylinux2014_x86_64.whl (33.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.4/33.4 MB 50.4 MB/s eta 0:00:00
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.12.1->autoawq) (0.20.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (3.13.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.0.1->autoawq) (12.4.127)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.38.2,>=4.35.0->autoawq) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.38.2,>=4.35.0->autoawq) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.38.2,>=4.35.0->autoawq) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.38.2,>=4.35.0->autoawq) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers<=4.38.2,>=4.35.0->autoawq) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.38.2,>=4.35.0->autoawq) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.38.2,>=4.35.0->autoawq) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->autoawq) (5.9.5)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (2.0.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (3.9.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<=4.38.2,>=4.35.0->autoawq) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<=4.38.2,>=4.35.0->autoawq) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<=4.38.2,>=4.35.0->autoawq) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<=4.38.2,>=4.35.0->autoawq) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.1->autoawq) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.0.1->autoawq) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->autoawq) (1.16.0)
# Installing collected packages: zstandard, transformers, autoawq-kernels, autoawq
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.39.3
#     Uninstalling transformers-4.39.3:
#       Successfully uninstalled transformers-4.39.3
# Successfully installed autoawq-0.2.4 autoawq-kernels-0.0.6 transformers-4.38.2 zstandard-0.22.0

# %%
from awq import AutoAWQForCausalLM
from transformers import AutoTokenizer

model_path = 'kaitchup/Mistral-7B-v0.1-oasstguanaco-1e-qdora-merged'
quant_path = 'Mistral-7B-v0.1-oasstguanaco-1e-qdora-merged-awq-4bit'
quant_config = { "zero_point": True, "q_group_size": 128, "w_bit": 4, "version": "GEMM" }

# Load model and tokenizer
model = AutoAWQForCausalLM.from_pretrained(model_path, safetensors=True)
tokenizer = AutoTokenizer.from_pretrained(model_path, use_fast=True)

# Quantize
model.quantize(tokenizer, quant_config=quant_config)

# Save quantized model with safetensors
model.save_quantized("./"+quant_path, safetensors=True)
tokenizer.save_pretrained("./"+quant_path)

# %%
model_name = "Mistral-7B-v0.1-oasstguanaco-1e-qdora-merged-awq-4bit"
loading_start = time.time()
model = AutoModelForCausalLM.from_pretrained(
          model_name, device_map={"": 0}, torch_dtype=torch.float16
)
print("--- Loading model time: %s seconds ---" % (time.time() - loading_start))
eval_model(model)
# Out:
# --- Loading model time: 2.804798126220703 seconds ---
# --- Speed: 96.55 tokens/second ---
# --- Speed: 118.2 tokens/second ---
# --- Speed: 114.38 tokens/second ---
# --- Speed: 1568.48 tokens/second ---
# --- Speed: 6009.32 tokens/second ---
# --- Average speed: 132.51 tokens/second ---
# Downloading readme:   0%|          | 0.00/395 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Downloading data:   0%|          | 0.00/20.9M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# 100%|██████████| 518/518 [02:57<00:00,  2.92it/s]
# Perplexity: 3.477247714996338

# %% [markdown]
# # LoftQ

# %%
model_name = "./loftq_base/"
adapter = "./loftq_ft/checkpoint-1231"

loading_start = time.time()
model = AutoModelForCausalLM.from_pretrained(
          model_name, device_map={"": 0}, torch_dtype=compute_dtype,  attn_implementation=attn_implementation
)
print("--- Loading model time: %s seconds ---" % (time.time() - loading_start))
loading_adapter_start = time.time()
model = PeftModel.from_pretrained(model, adapter)
print("--- Loading adapter time: %s seconds ---" % (time.time() - loading_adapter_start))

eval_model(model)
# Out:
# --- Loading model time: 51.703083515167236 seconds ---
# --- Loading adapter time: 9.962267637252808 seconds ---
# --- Speed: 40.67 tokens/second ---
# --- Speed: 43.75 tokens/second ---
# --- Speed: 43.7 tokens/second ---
# --- Speed: 43.75 tokens/second ---
# --- Speed: 43.64 tokens/second ---
# --- Average speed: 43.07 tokens/second ---
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# 100%|██████████| 518/518 [02:51<00:00,  3.01it/s]
# Perplexity: 3.355402946472168

# %% [markdown]
# With merged adapter

# %%
model_name = "kaitchup/Mistral-7B-v0.1-oasstguanaco-1e-loftq-merged"
loading_start = time.time()
model = AutoModelForCausalLM.from_pretrained(
          model_name, device_map={"": 0}, torch_dtype=compute_dtype,  attn_implementation=attn_implementation
)
print("--- Loading model time: %s seconds ---" % (time.time() - loading_start))
eval_model(model)
# Out:
# config.json:   0%|          | 0.00/652 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# --- Loading model time: 345.3683784008026 seconds ---
# --- Speed: 73.65 tokens/second ---
# --- Speed: 75.74 tokens/second ---
# --- Speed: 75.76 tokens/second ---
# --- Speed: 75.65 tokens/second ---
# --- Speed: 75.77 tokens/second ---
# --- Average speed: 75.3 tokens/second ---
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# 100%|██████████| 518/518 [01:35<00:00,  5.45it/s]
# Perplexity: 3.3551559448242188

# %% [markdown]
# With merged adapter and BNB NF4 quantization

# %%
model_name = "kaitchup/Mistral-7B-v0.1-oasstguanaco-1e-loftq-merged"
loading_start = time.time()
bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)
model = AutoModelForCausalLM.from_pretrained(
          model_name, quantization_config=bnb_config, device_map={"": 0}, torch_dtype=compute_dtype,  attn_implementation=attn_implementation
)
print("--- Loading model time: %s seconds ---" % (time.time() - loading_start))
eval_model(model)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# --- Loading model time: 7.500432014465332 seconds ---
# --- Speed: 30.09 tokens/second ---
# --- Speed: 34.83 tokens/second ---
# --- Speed: 35.02 tokens/second ---
# --- Speed: 35.15 tokens/second ---
# --- Speed: 35.07 tokens/second ---
# --- Average speed: 33.91 tokens/second ---
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# 100%|██████████| 518/518 [02:17<00:00,  3.76it/s]
# Perplexity: 4.526394844055176

# %% [markdown]
# With merged adapter and GPTQ quantization

# %%
# !pip install --upgrade transformers auto-gptq accelerate datasets auto-gptq optimum
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Collecting transformers
#   Downloading transformers-4.39.3-py3-none-any.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 71.1 MB/s eta 0:00:00
# Collecting auto-gptq
#   Downloading auto_gptq-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 72.5 MB/s eta 0:00:00
# Collecting accelerate
#   Downloading accelerate-0.29.2-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.4/297.4 kB 40.3 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 55.5 MB/s eta 0:00:00
# Collecting optimum
#   Downloading optimum-1.18.1-py3-none-any.whl (410 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.0/410.0 kB 50.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.1.99)
# Collecting rouge (from auto-gptq)
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Collecting gekko (from auto-gptq)
#   Downloading gekko-1.1.0-py3-none-any.whl (13.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 101.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (2.2.1+cu121)
# Collecting peft>=0.5.0 (from auto-gptq)
#   Downloading peft-0.10.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 28.1 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 18.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 26.8 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.8 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Collecting coloredlogs (from optimum)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from optimum) (1.12)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.13.0->auto-gptq)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.13.0->auto-gptq)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.13.0->auto-gptq)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.13.0->auto-gptq)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.13.0->auto-gptq)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.13.0->auto-gptq)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.13.0->auto-gptq)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.13.0->auto-gptq)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.13.0->auto-gptq)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.13.0->auto-gptq)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.13.0->auto-gptq)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->auto-gptq)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers) (3.20.3)
# Collecting humanfriendly>=9.1 (from coloredlogs->optimum)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge->auto-gptq) (1.16.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->optimum) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->auto-gptq) (2.1.5)
# Installing collected packages: xxhash, rouge, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, humanfriendly, gekko, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, coloredlogs, nvidia-cusolver-cu12, transformers, datasets, accelerate, peft, optimum, auto-gptq
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.38.2
#     Uninstalling transformers-4.38.2:
#       Successfully uninstalled transformers-4.38.2
# Successfully installed accelerate-0.29.2 auto-gptq-0.7.1 coloredlogs-15.0.1 datasets-2.18.0 dill-0.3.8 gekko-1.1.0 humanfriendly-10.0 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 optimum-1.18.1 peft-0.10.0 rouge-1.0.1 transformers-4.39.3 xxhash-3.4.1

# %%
from transformers import  GPTQConfig

model_path = 'kaitchup/Mistral-7B-v0.1-oasstguanaco-1e-loftq-merged'
tokenizer = AutoTokenizer.from_pretrained(model_path, use_fast=True)

quantization_config = GPTQConfig(bits=4, dataset = "c4", tokenizer=tokenizer)

model = AutoModelForCausalLM.from_pretrained(model_path, device_map={"": 0}, quantization_config=quantization_config)
# Out:
# tokenizer_config.json:   0%|          | 0.00/992 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/652 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/41.1k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/319M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Quantizing model.layers blocks :   0%|          | 0/32 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:4225: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(

# %%
eval_model(model)
# Out:
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# --- Speed: 65.54 tokens/second ---
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# --- Speed: 72.3 tokens/second ---
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# --- Speed: 72.1 tokens/second ---
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# --- Speed: 72.95 tokens/second ---
# --- Speed: 73.04 tokens/second ---
# --- Average speed: 71.07 tokens/second ---
# Downloading readme:   0%|          | 0.00/395 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Downloading data:   0%|          | 0.00/20.9M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# 100%|██████████| 518/518 [00:35<00:00, 14.44it/s]
# Perplexity: 3.671870470046997

# %% [markdown]
# With merged adapter and AWQ quantization

# %%
# !pip install autoawq
# Out:
# Collecting autoawq
#   Downloading autoawq-0.2.4-cp310-cp310-manylinux2014_x86_64.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.8/80.8 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: torch>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from autoawq) (2.2.1+cu121)
# Collecting transformers<=4.38.2,>=4.35.0 (from autoawq)
#   Downloading transformers-4.38.2-py3-none-any.whl (8.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 26.0 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from autoawq) (0.15.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from autoawq) (4.10.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (from autoawq) (0.29.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from autoawq) (2.18.0)
# Collecting zstandard (from autoawq)
#   Downloading zstandard-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 57.2 MB/s eta 0:00:00
# Collecting autoawq-kernels (from autoawq)
#   Downloading autoawq_kernels-0.0.6-cp310-cp310-manylinux2014_x86_64.whl (33.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.4/33.4 MB 50.8 MB/s eta 0:00:00
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.12.1->autoawq) (0.20.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (3.13.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.0.1->autoawq) (12.4.127)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.38.2,>=4.35.0->autoawq) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.38.2,>=4.35.0->autoawq) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.38.2,>=4.35.0->autoawq) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.38.2,>=4.35.0->autoawq) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers<=4.38.2,>=4.35.0->autoawq) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.38.2,>=4.35.0->autoawq) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.38.2,>=4.35.0->autoawq) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->autoawq) (5.9.5)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (2.0.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (3.9.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<=4.38.2,>=4.35.0->autoawq) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<=4.38.2,>=4.35.0->autoawq) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<=4.38.2,>=4.35.0->autoawq) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<=4.38.2,>=4.35.0->autoawq) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.1->autoawq) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.0.1->autoawq) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->autoawq) (1.16.0)
# Installing collected packages: zstandard, transformers, autoawq-kernels, autoawq
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.39.3
#     Uninstalling transformers-4.39.3:
#       Successfully uninstalled transformers-4.39.3
# Successfully installed autoawq-0.2.4 autoawq-kernels-0.0.6 transformers-4.38.2 zstandard-0.22.0

# %%
from awq import AutoAWQForCausalLM
from transformers import AutoTokenizer

model_path = 'kaitchup/Mistral-7B-v0.1-oasstguanaco-1e-loftq-merged'
quant_path = 'Mistral-7B-v0.1-oasstguanaco-1e-loftq-merged-awq-4bit'
quant_config = { "zero_point": True, "q_group_size": 128, "w_bit": 4, "version": "GEMM" }

# Load model and tokenizer
model = AutoAWQForCausalLM.from_pretrained(model_path, safetensors=True)
tokenizer = AutoTokenizer.from_pretrained(model_path, use_fast=True)

# Quantize
model.quantize(tokenizer, quant_config=quant_config)

# Save quantized model with safetensors
model.save_quantized("./"+quant_path, safetensors=True)
tokenizer.save_pretrained("./"+quant_path)
# Out:
# config.json:   0%|          | 0.00/652 [00:00<?, ?B/s]
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# README.md:   0%|          | 0.00/5.18k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/992 [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading readme:   0%|          | 0.00/167 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Downloading data:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# AWQ: 100%|██████████| 32/32 [28:31<00:00, 53.48s/it]
# ('./Mistral-7B-v0.1-oasstguanaco-1e-loftq-merged-awq-4bit/tokenizer_config.json',
#  './Mistral-7B-v0.1-oasstguanaco-1e-loftq-merged-awq-4bit/special_tokens_map.json',
#  './Mistral-7B-v0.1-oasstguanaco-1e-loftq-merged-awq-4bit/tokenizer.model',
#  './Mistral-7B-v0.1-oasstguanaco-1e-loftq-merged-awq-4bit/added_tokens.json',
#  './Mistral-7B-v0.1-oasstguanaco-1e-loftq-merged-awq-4bit/tokenizer.json')

# %%
model_name = "Mistral-7B-v0.1-oasstguanaco-1e-loftq-merged-awq-4bit"
loading_start = time.time()
model = AutoModelForCausalLM.from_pretrained(
          model_name, device_map={"": 0}, torch_dtype=torch.float16
)
print("--- Loading model time: %s seconds ---" % (time.time() - loading_start))
eval_model(model)
# Out:
# --- Loading model time: 2.324984312057495 seconds ---
# --- Speed: 109.81 tokens/second ---
# --- Speed: 156.0 tokens/second ---
# --- Speed: 154.99 tokens/second ---
# --- Speed: 158.94 tokens/second ---
# --- Speed: 153.41 tokens/second ---
# --- Average speed: 140.26 tokens/second ---
# Downloading readme:   0%|          | 0.00/395 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Downloading data:   0%|          | 0.00/20.9M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# 100%|██████████| 518/518 [02:58<00:00,  2.90it/s]
# Perplexity: 3.4350991249084473
