# %% [markdown]
# <a href="https://colab.research.google.com/github/tuhinmallick/AI-for-Fashion/blob/main/LoftQ_A_Better_LoRA_Adapter_for_Quantized_LLMs_Example_with_Mistral_7B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook shows how to fine-tune an LLM, here Mistral 7B, with loftq.
#
#
# First, we need all these dependencies:

# %%
# !pip install -q -U bitsandbytes
# !pip install --upgrade -q -U transformers
# !pip install -q -U peft
# !pip install -q -U accelerate
# !pip install -q -U datasets
# !pip install -q -U trl
# !pip install -q -U flash_attn
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 MB 15.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 62.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 45.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 82.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 14.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 29.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 12.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 27.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 10.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 10.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 4.3 MB/s eta 0:00:00
#   Building wheel for flash_attn (setup.py) ... done

# %% [markdown]
# Import the following packages. Not all these imports are necessary depending on the method (#1 or #2) you use to apply loftq.

# %%
import torch
from datasets import load_dataset
from peft import LoraConfig, PeftModel, prepare_model_for_kbit_training, get_peft_model, replace_lora_weights_loftq
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
)
from trl import SFTTrainer

# %% [markdown]
# #Method #1: Replace LoRA with LoftQ
#
#
# Load the tokenizer, configure padding, and detect if the GPU support bfloat16 and FlashAttention (not necessary but better).

# %%
model_name = "mistralai/Mistral-7B-v0.1"
#Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, add_eos_token=True, use_fast=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = 'left' #Necessary for FlashAttention compatibility

#Better to use bf16 if supported (Ampere GPUs or more recent)
#If bf16 is supported, the GPU is also recent enough to support FlashAttention
if torch.cuda.is_bf16_supported():
  compute_dtype = torch.bfloat16
  attn_implementation = 'flash_attention_2'
else:
  compute_dtype = torch.float16
  attn_implementation = 'sdpa'

# %% [markdown]
# Load the dataset that we will use for fine-tuning.

# %%
dataset = load_dataset("timdettmers/openassistant-guanaco")
# Out:
# Downloading readme:   0%|          | 0.00/395 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Downloading data:   0%|          | 0.00/20.9M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %% [markdown]
# Load the model and prepare it for QLoRA

# %%
bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)
model = AutoModelForCausalLM.from_pretrained(
          model_name, quantization_config=bnb_config, device_map={"": 0},  attn_implementation=attn_implementation
)
model = prepare_model_for_kbit_training(model)
#Configure the pad token in the model
model.config.pad_token_id = tokenizer.pad_token_id
# Out:
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]

# %% [markdown]
# Define the configuration of LoRA

# %%
peft_config = LoraConfig(
        lora_alpha=16,
        lora_dropout=0.05,
        r=16,
        bias="none",
        task_type="CAUSAL_LM",
        target_modules= ['k_proj', 'q_proj', 'v_proj', 'o_proj', "gate_proj", "down_proj", "up_proj"]
)

# %% [markdown]
# The following cell is the only code specific to LoftQ fine-tuning.
# We first make a peft model with the LoraConfig, and then replace LoRA's weights with LoftQ's weights.

# %%
peft_model = get_peft_model(model, peft_config)
print(peft_model)
replace_lora_weights_loftq(peft_model)
print(peft_model)
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): MistralForCausalLM(
#       (model): MistralModel(
#         (embed_tokens): Embedding(32000, 4096)
#         (layers): ModuleList(
#           (0-31): 32 x MistralDecoderLayer(
#             (self_attn): MistralSdpaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (rotary_emb): MistralRotaryEmbedding()
#             )
#             (mlp): MistralMLP(
#               (gate_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=14336, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (up_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=14336, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (down_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=14336, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (act_fn): SiLU()
#             )
#             (input_layernorm): MistralRMSNorm()
#             (post_attention_layernorm): MistralRMSNorm()
#           )
#         )
#         (norm): MistralRMSNorm()
#       )
#       (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
#     )
#   )
# )
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): MistralForCausalLM(
#       (model): MistralModel(
#         (embed_tokens): Embedding(32000, 4096)
#         (layers): ModuleList(
#           (0-31): 32 x MistralDecoderLayer(
#             (self_attn): MistralSdpaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (rotary_emb): MistralRotaryEmbedding()
#             )
#             (mlp): MistralMLP(
#               (gate_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=14336, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (up_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=14336, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (down_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=14336, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (act_fn): SiLU()
#             )
#             (input_layernorm): MistralRMSNorm()
#             (post_attention_layernorm): MistralRMSNorm()
#           )
#         )
#         (norm): MistralRMSNorm()
#       )
#       (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
#     )
#   )
# )

# %% [markdown]
# For this tutorial, I fine-tuned the adapter for one epoch.

# %%
training_arguments = TrainingArguments(
        output_dir="./results/",
        evaluation_strategy="steps",
        do_eval=True,
        optim="paged_adamw_8bit",
        per_device_train_batch_size=12,
        gradient_accumulation_steps=2,
        per_device_eval_batch_size=12,
        log_level="debug",
        logging_steps=50,
        learning_rate=1e-4,
        eval_steps=50,
        num_train_epochs=1,
        save_strategy='epoch',
        warmup_ratio=0.1,
        lr_scheduler_type="linear",
)

# %% [markdown]
# SFTTrainer configuration and start training:

# %%
trainer = SFTTrainer(
        model=peft_model,
        train_dataset=dataset['train'],
        eval_dataset=dataset['test'],
        dataset_text_field="text",
        max_seq_length=512,
        tokenizer=tokenizer,
        args=training_arguments,
)

trainer.train()
# Out:
# Map:   0%|          | 0/9846 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:317: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(
# Currently training with a batch size of: 12
# ***** Running training *****
#   Num examples = 9,846
#   Num Epochs = 1
#   Instantaneous batch size per device = 12
#   Total train batch size (w. parallel, distributed & accumulation) = 24
#   Gradient Accumulation steps = 2
#   Total optimization steps = 410
#   Number of trainable parameters = 41,943,040
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='410' max='410' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [410/410 5:28:21, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.214700</td>
#       <td>1.144708</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.114000</td>
#       <td>1.127303</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.109100</td>
#       <td>1.122229</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.087900</td>
#       <td>1.118388</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.079300</td>
#       <td>1.115253</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.111600</td>
#       <td>1.112868</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.098400</td>
#       <td>1.111607</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.072500</td>
#       <td>1.111051</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# Saving model checkpoint to ./results/checkpoint-410
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--mistralai--Mistral-7B-v0.1/snapshots/26bca36bde8333b5d7f72e9ed20ccda6a618af24/config.json
# Model config MistralConfig {
#   "architectures": [
#     "MistralForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 32768,
#   "model_type": "mistral",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "rms_norm_eps": 1e-05,
#   "rope_theta": 10000.0,
#   "sliding_window": 4096,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.39.3",
#   "use_cache": true,
#   "vocab_size": 32000
# }
#
# tokenizer config file saved in ./results/checkpoint-410/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-410/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=410, training_loss=1.109550892434469, metrics={'train_runtime': 19745.2716, 'train_samples_per_second': 0.499, 'train_steps_per_second': 0.021, 'total_flos': 2.1604031504429875e+17, 'train_loss': 1.109550892434469, 'epoch': 1.0})

# %% [markdown]
# #Method #2: Jointly search for better LLM quantization and LoRA initliazation.
#
# We are going to use a script from PEFT. I cloned the repository to have everything locally.
#
# Then, we run the script which performs 5 iterations of LoftQ to find a better quantization and initialization of LoRA.

# %%
# !git clone https://github.com/huggingface/peft.git

# !python peft/examples/loftq_finetuning/quantize_save_load.py \
    --model_name_or_path mistralai/Mistral-7B-v0.1 \
    --bits 4 \
    --iter 5 \
    --rank 16 \
    --save_dir "./loftq_iters/"
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): Shell()
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): Shell()
#   (act_fn): SiLU()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): Shell()
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): Shell()
#   (act_fn): SiLU()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): Shell()
#   (down_proj): Shell()
#   (act_fn): SiLU()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): Shell()
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): Shell()
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): Shell()
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralMLP(
#   (gate_proj): Shell()
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): Shell()
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): Shell()
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): Shell()
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): Shell()
#   (k_proj): Shell()
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): Shell()
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): Shell()
#   (k_proj): Shell()
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): Shell()
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralMLP(
#   (gate_proj): Shell()
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): Shell()
#   (v_proj): Shell()
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralMLP(
#   (gate_proj): Shell()
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralMLP(
#   (gate_proj): Shell()
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): Shell()
#   (act_fn): SiLU()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): Shell()
#   (v_proj): Shell()
#   (o_proj): Shell()
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): Shell()
#   (act_fn): SiLU()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): Shell()
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): Shell()
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): Shell()
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): Shell()
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): Shell()
#   (act_fn): SiLU()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): Shell()
#   (v_proj): Shell()
#   (o_proj): Shell()
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): Shell()
#   (down_proj): Shell()
#   (act_fn): SiLU()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralMLP(
#   (gate_proj): Shell()
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralMLP(
#   (gate_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralSdpaAttention(
#   (q_proj): Shell()
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): Shell()
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): Shell()
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): Shell()
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): Shell()
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (k_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralMLP(
#   (gate_proj): Shell()
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): lora.Linear(
#     (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=14336, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (act_fn): SiLU()
# )
# MistralSdpaAttention(
#   (q_proj): Shell()
#   (k_proj): Shell()
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=4096, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralSdpaAttention(
#   (q_proj): Shell()
#   (k_proj): Shell()
#   (v_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=1024, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (o_proj): Shell()
#   (rotary_emb): MistralRotaryEmbedding()
# )
# MistralMLP(
#   (gate_proj): Shell()
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
#   (down_proj): Shell()
#   (act_fn): SiLU()
# )
# MistralMLP(
#   (gate_proj): Shell()
#   (up_proj): lora.Linear(
#     (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.1, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=4096, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=14336, bias=False)
# ...
# model.layers.18.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 3.7968475226080045e-06 0.05246831849217415
# model.layers.18.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 3.5037828638451174e-07 0.029179025441408157
# model.layers.18.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 1.5044324754853733e-06 0.10824323445558548
# model.layers.18.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 1.6532342215214157e-06 0.08427742123603821
# model.layers.18.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.406773319307831e-06 0.09952303767204285
# model.layers.18.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 2.0937952740496257e-06 0.10003058612346649
# model.layers.18.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.4567813873291016 5.96875
# model.layers.18.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.407374858856201 6.0
# model.layers.19.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 2.2645501758233877e-06 0.0686311274766922
# model.layers.19.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 2.122721298292163e-06 0.06637533009052277
# model.layers.19.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 1.208468006552721e-06 0.024796122685074806
# model.layers.19.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 2.209109425166389e-06 0.08801016956567764
# model.layers.19.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.6838949906959897e-06 0.08984062820672989
# model.layers.19.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.9353057016123785e-06 0.1110566034913063
# model.layers.19.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 2.5531630853947718e-06 0.09330163151025772
# model.layers.19.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.518817901611328 6.0
# model.layers.19.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.5749154090881348 4.78125
# model.layers.20.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 2.9739226192759816e-06 0.0572701096534729
# model.layers.20.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 8.322873327415437e-06 0.056973446160554886
# model.layers.20.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 3.45907210430596e-07 0.022668616846203804
# model.layers.20.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 2.2592632831219817e-06 0.07891858369112015
# model.layers.20.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 1.018874854707974e-06 0.07512858510017395
# model.layers.20.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 1.8675455066841096e-06 0.1048654317855835
# model.layers.20.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 2.3335512651101453e-06 0.07824002206325531
# model.layers.20.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.561117172241211 5.71875
# model.layers.20.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.7784910202026367 5.46875
# model.layers.21.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 1.8369182726019062e-06 0.06874597072601318
# model.layers.21.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 2.686307652766118e-06 0.06768792867660522
# model.layers.21.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 3.3707167403917992e-06 0.024637524038553238
# model.layers.21.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 1.6979856809484772e-06 0.06146921589970589
# model.layers.21.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 1.3770413715974428e-06 0.09955395758152008
# model.layers.21.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.4392970772169065e-06 0.08065174520015717
# model.layers.21.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 1.9361377781024203e-06 0.19359049201011658
# model.layers.21.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.552286148071289 6.03125
# model.layers.21.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.983227491378784 4.59375
# model.layers.22.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 1.6606584267719882e-06 0.07379599660634995
# model.layers.22.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 2.209240847150795e-06 0.06662126630544662
# model.layers.22.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 4.792725576407975e-07 0.023226935416460037
# model.layers.22.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 2.2838580662210006e-06 0.1248667985200882
# model.layers.22.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.8012495931761805e-06 0.05992332473397255
# model.layers.22.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.6556660941423615e-06 0.058987151831388474
# model.layers.22.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 2.1250157260510605e-06 0.1758631318807602
# model.layers.22.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.573479175567627 6.03125
# model.layers.22.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 3.0877535343170166 4.1875
# model.layers.23.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 2.6018451535492204e-06 0.0704914778470993
# model.layers.23.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False -3.305717655166518e-07 0.06997507810592651
# model.layers.23.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 4.403796992846765e-06 0.027920972555875778
# model.layers.23.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 2.1363862288126256e-06 0.09019135683774948
# model.layers.23.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 4.544730018096743e-06 0.12608501315116882
# model.layers.23.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 1.9840506411128445e-06 0.054437171667814255
# model.layers.23.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 1.8130018588635721e-06 0.08152732253074646
# model.layers.23.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.5992050170898438 6.125
# model.layers.23.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 3.2200865745544434 4.53125
# model.layers.24.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 1.3509542213796522e-06 0.05851111561059952
# model.layers.24.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 4.586150680552237e-06 0.06562822312116623
# model.layers.24.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 1.1939039268327178e-06 0.029651615768671036
# model.layers.24.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 2.8733277304127114e-06 0.05445827916264534
# model.layers.24.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 6.055785888747778e-06 0.09759733080863953
# model.layers.24.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.1928790374659e-06 0.10180869698524475
# model.layers.24.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 1.8519298237151816e-06 0.18064995110034943
# model.layers.24.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.820614814758301 6.40625
# model.layers.24.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 3.352470874786377 4.9375
# model.layers.25.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 8.698718829691643e-07 0.052686817944049835
# model.layers.25.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 1.2286564015084878e-06 0.05557328462600708
# model.layers.25.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 1.286884184992232e-06 0.0391434021294117
# model.layers.25.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 1.6249090322162374e-06 0.1574246883392334
# model.layers.25.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 6.924101853655884e-06 0.08339735120534897
# model.layers.25.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.1698838281736244e-06 0.05348646268248558
# model.layers.25.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 2.040620984189445e-06 0.07910362631082535
# model.layers.25.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.897142171859741 6.875
# model.layers.25.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 3.4562883377075195 5.1875
# model.layers.26.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 1.3628584838443203e-06 0.048510950058698654
# model.layers.26.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 1.6805078075776692e-06 0.07267642766237259
# model.layers.26.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 4.7677599468443077e-07 0.03529985249042511
# model.layers.26.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 1.9329650058352854e-06 0.051401328295469284
# model.layers.26.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 4.039658506371779e-06 0.09698830544948578
# model.layers.26.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.5451940928178374e-06 0.08840601146221161
# model.layers.26.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 2.5224030650861096e-06 0.12235291302204132
# model.layers.26.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.782806396484375 6.9375
# model.layers.26.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 3.5270397663116455 5.0
# model.layers.27.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 2.9484094739018474e-06 0.05685514956712723
# model.layers.27.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 5.387018063629512e-06 0.0696144849061966
# model.layers.27.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 3.918338279618183e-06 0.03372291475534439
# model.layers.27.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 1.734071588543884e-06 0.08460652083158493
# model.layers.27.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False -1.2731608194371802e-06 0.07926996797323227
# model.layers.27.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.9918280688434606e-06 0.052260734140872955
# model.layers.27.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 1.9892725049430737e-06 0.16492429375648499
# model.layers.27.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.837923526763916 7.375
# model.layers.27.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 3.6432299613952637 5.21875
# model.layers.28.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 2.139877778972732e-06 0.054381322115659714
# model.layers.28.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 2.6050340693473117e-06 0.0524749793112278
# model.layers.28.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 1.7680985138213146e-06 0.032784353941679
# model.layers.28.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 2.132002919097431e-06 0.06929787248373032
# model.layers.28.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False -3.5287193895783275e-06 0.08618655800819397
# model.layers.28.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 1.973468442884041e-06 0.08398433774709702
# model.layers.28.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 3.2710383948142407e-06 0.09336832910776138
# model.layers.28.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.748250961303711 7.84375
# model.layers.28.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 3.7343578338623047 5.53125
# model.layers.29.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 3.737666247616289e-06 0.05795130133628845
# model.layers.29.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 3.719464302776032e-06 0.0571075864136219
# model.layers.29.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 4.490783339861082e-06 0.040538180619478226
# model.layers.29.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 5.907411377847893e-07 0.06138165295124054
# model.layers.29.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False -2.8879501314804656e-06 0.05524864047765732
# model.layers.29.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 1.5157201005422394e-06 0.07264211773872375
# model.layers.29.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 3.208803491361323e-06 0.142495259642601
# model.layers.29.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 3.032315731048584 8.75
# model.layers.29.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 3.7174072265625 5.375
# model.layers.30.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 1.2558651860672398e-06 0.06713055074214935
# model.layers.30.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 9.925065569404978e-07 0.05572083964943886
# model.layers.30.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 4.5771275836159475e-06 0.0479198656976223
# model.layers.30.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 3.116221250820672e-06 0.10569024085998535
# model.layers.30.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 1.3678608468126185e-07 0.0792294442653656
# model.layers.30.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.5439076125621796e-06 0.08039778470993042
# model.layers.30.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 2.329038807147299e-06 0.2092239260673523
# model.layers.30.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.9241838455200195 9.0
# model.layers.30.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 3.7705609798431396 5.53125
# model.layers.31.self_attn.q_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 4.824406687475857e-07 0.05755443125963211
# model.layers.31.self_attn.k_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False 4.1731354940566234e-06 0.05776270851492882
# model.layers.31.self_attn.v_proj.weight torch.Size([1024, 4096]) cpu torch.float32 False -6.129407665866893e-07 0.043652839958667755
# model.layers.31.self_attn.o_proj.weight torch.Size([4096, 4096]) cpu torch.float32 False 1.311106871071388e-06 0.2004215121269226
# model.layers.31.mlp.gate_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 6.489997872449749e-07 0.06114400550723076
# model.layers.31.mlp.up_proj.weight torch.Size([14336, 4096]) cpu torch.float32 False 2.9264888325997163e-06 0.05997253954410553
# model.layers.31.mlp.down_proj.weight torch.Size([4096, 14336]) cpu torch.float32 False 2.3125689949665684e-06 0.2717234194278717
# model.layers.31.input_layernorm.weight torch.Size([4096]) cpu torch.float32 False 2.921815872192383 8.75
# model.layers.31.post_attention_layernorm.weight torch.Size([4096]) cpu torch.float32 False 3.635004997253418 5.84375
# model.norm.weight torch.Size([4096]) cpu torch.float32 False 5.2825469970703125 13.25
# lm_head.weight torch.Size([32000, 4096]) cpu torch.float32 False 1.3422666597762145e-05 0.06689453125

# %% [markdown]
# The following code is a standard LoRA fine-tuning but using the new base model and adapter found by the script.

# %%
import torch
from datasets import load_dataset
from peft import LoraConfig, PeftModel, prepare_model_for_kbit_training
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
)
from trl import SFTTrainer

MODEL_DIR = "./loftq_iters/Mistral-7B-v0.1-4bit-16rank"
#Tokenizer
tokenizer = AutoTokenizer.from_pretrained(MODEL_DIR, add_eos_token=True, use_fast=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = 'left' #Necessary for FlashAttention compatibility

#Better to use bf16 if supported (Ampere GPUs or more recent)
#If bf16 is supported, the GPU is also recent enough to support FlashAttention
if torch.cuda.is_bf16_supported():
  compute_dtype = torch.bfloat16
  attn_implementation = 'flash_attention_2'
else:
  compute_dtype = torch.float16
  attn_implementation = 'sdpa'

dataset = load_dataset("timdettmers/openassistant-guanaco")
bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)
model = AutoModelForCausalLM.from_pretrained(
          MODEL_DIR, quantization_config=bnb_config, device_map={"": 0}, torch_dtype=compute_dtype,  attn_implementation=attn_implementation
)
model = prepare_model_for_kbit_training(model)
#Configure the pad token in the model
model.config.pad_token_id = tokenizer.pad_token_id

peft_model = PeftModel.from_pretrained(
    model,
    MODEL_DIR,
    subfolder="loft_init",
    is_trainable=True,
)



training_arguments = TrainingArguments(
        output_dir="./results_loftq/",
        evaluation_strategy="steps",
        do_eval=True,
        optim="paged_adamw_8bit",
        per_device_train_batch_size=12,
        gradient_accumulation_steps=2,
        per_device_eval_batch_size=12,
        log_level="debug",
        logging_steps=50,
        learning_rate=1e-4,
        eval_steps=50,
        num_train_epochs=1,
        save_strategy='epoch',
        warmup_ratio=0.1,
        lr_scheduler_type="linear",
)

trainer = SFTTrainer(
        model=peft_model,
        train_dataset=dataset['train'],
        eval_dataset=dataset['test'],
        dataset_text_field="text",
        max_seq_length=512,
        tokenizer=tokenizer,
        args=training_arguments,
)

trainer.train()
# Out:
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]
# Map:   0%|          | 0/9846 [00:00<?, ? examples/s]
# Map:   0%|          | 0/518 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:317: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(
# Currently training with a batch size of: 12
# ***** Running training *****
#   Num examples = 9,846
#   Num Epochs = 1
#   Instantaneous batch size per device = 12
#   Total train batch size (w. parallel, distributed & accumulation) = 24
#   Gradient Accumulation steps = 2
#   Total optimization steps = 410
#   Number of trainable parameters = 41,943,040
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='160' max='410' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [160/410 2:07:51 < 3:22:17, 0.02 it/s, Epoch 0.39/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.210800</td>
#       <td>1.144687</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.114300</td>
#       <td>1.127882</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.109900</td>
#       <td>1.123113</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
#     <div>
#
#       <progress value='410' max='410' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [410/410 5:31:59, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.210800</td>
#       <td>1.144687</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.114300</td>
#       <td>1.127882</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.109900</td>
#       <td>1.123113</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.088600</td>
#       <td>1.118970</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.079500</td>
#       <td>1.115887</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.111700</td>
#       <td>1.113478</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.098700</td>
#       <td>1.112291</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.073100</td>
#       <td>1.111724</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# Saving model checkpoint to ./results_loftq/checkpoint-410
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:154: UserWarning: Could not find a config file in ./loftq_iters/Mistral-7B-v0.1-4bit-16rank - will assume that the vocabulary was not modified.
#   warnings.warn(
# tokenizer config file saved in ./results_loftq/checkpoint-410/tokenizer_config.json
# Special tokens file saved in ./results_loftq/checkpoint-410/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=410, training_loss=1.1094729190919457, metrics={'train_runtime': 19963.3802, 'train_samples_per_second': 0.493, 'train_steps_per_second': 0.021, 'total_flos': 2.1604031504429875e+17, 'train_loss': 1.1094729190919457, 'epoch': 1.0})

# %% [markdown]
# #LoRA (for reference)
#
# The following code runs LoRA fine-tuning for comparison with LoftQ.

# %%
import torch
from datasets import load_dataset
from peft import LoraConfig, PeftModel, prepare_model_for_kbit_training, get_peft_model
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
)
from trl import SFTTrainer

model_name = "mistralai/Mistral-7B-v0.1"
#Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, add_eos_token=True, use_fast=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = 'left' #Necessary for FlashAttention compatibility

#Better to use bf16 if supported (Ampere GPUs or more recent)
#If bf16 is supported, the GPU is also recent enough to support FlashAttention
if torch.cuda.is_bf16_supported():
  compute_dtype = torch.bfloat16
  attn_implementation = 'flash_attention_2'
else:
  compute_dtype = torch.float16
  attn_implementation = 'sdpa'

dataset = load_dataset("timdettmers/openassistant-guanaco")
bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)
model = AutoModelForCausalLM.from_pretrained(
          model_name, quantization_config=bnb_config, device_map={"": 0},  attn_implementation=attn_implementation
)
model = prepare_model_for_kbit_training(model)
#Configure the pad token in the model
model.config.pad_token_id = tokenizer.pad_token_id

peft_config = LoraConfig(
        lora_alpha=16,
        lora_dropout=0.05,
        r=16,
        bias="none",
        task_type="CAUSAL_LM",
        target_modules= ['k_proj', 'q_proj', 'v_proj', 'o_proj', "gate_proj", "down_proj", "up_proj"]
)

peft_model = get_peft_model(model, peft_config)


training_arguments = TrainingArguments(
        output_dir="./results/",
        evaluation_strategy="steps",
        do_eval=True,
        optim="paged_adamw_8bit",
        per_device_train_batch_size=12,
        gradient_accumulation_steps=2,
        per_device_eval_batch_size=12,
        log_level="debug",
        logging_steps=50,
        learning_rate=1e-4,
        eval_steps=50,
        num_train_epochs=1,
        save_strategy='epoch',
        warmup_ratio=0.1,
        lr_scheduler_type="linear",
)

trainer = SFTTrainer(
        model=peft_model,
        train_dataset=dataset['train'],
        eval_dataset=dataset['test'],
        dataset_text_field="text",
        max_seq_length=512,
        tokenizer=tokenizer,
        args=training_arguments,
)

trainer.train()
# Out:
# tokenizer_config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/395 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Downloading data:   0%|          | 0.00/20.9M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Map:   0%|          | 0/9846 [00:00<?, ? examples/s]
# Map:   0%|          | 0/518 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:317: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(
# Currently training with a batch size of: 12
# ***** Running training *****
#   Num examples = 9,846
#   Num Epochs = 1
#   Instantaneous batch size per device = 12
#   Total train batch size (w. parallel, distributed & accumulation) = 24
#   Gradient Accumulation steps = 2
#   Total optimization steps = 410
#   Number of trainable parameters = 41,943,040
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='410' max='410' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [410/410 5:30:07, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.199000</td>
#       <td>1.141348</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.112300</td>
#       <td>1.125894</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.108000</td>
#       <td>1.121279</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.086700</td>
#       <td>1.117162</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.077800</td>
#       <td>1.114128</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.110000</td>
#       <td>1.111743</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.097100</td>
#       <td>1.110371</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.071100</td>
#       <td>1.109758</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 12
# Saving model checkpoint to ./results/checkpoint-410
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--mistralai--Mistral-7B-v0.1/snapshots/26bca36bde8333b5d7f72e9ed20ccda6a618af24/config.json
# Model config MistralConfig {
#   "architectures": [
#     "MistralForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 32768,
#   "model_type": "mistral",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "rms_norm_eps": 1e-05,
#   "rope_theta": 10000.0,
#   "sliding_window": 4096,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.39.3",
#   "use_cache": true,
#   "vocab_size": 32000
# }
#
# tokenizer config file saved in ./results/checkpoint-410/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-410/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=410, training_loss=1.1064177047915575, metrics={'train_runtime': 19850.6029, 'train_samples_per_second': 0.496, 'train_steps_per_second': 0.021, 'total_flos': 2.1604031504429875e+17, 'train_loss': 1.1064177047915575, 'epoch': 1.0})
