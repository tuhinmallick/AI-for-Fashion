# %% [markdown]
# <a href="https://colab.research.google.com/github/tuhinmallick/AI-for-Fashion/blob/main/Fine_tuning_Phi_3_5_MoE_and_Mini_With_Code_for_AutoRound_and_Bitsandbytes_Quantization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *All the details in article: [Fine-tuning Phi-3.5 MoE and Mini on Your Computer](https://newsletter.kaitchup.com/p/fine-tuning-phi-35-moe-and-mini-on)*
#
# This notebook shows how to quantize Phi-3.5 Mini with AutoRound, and how to fine-tune it with QLoRA. QLoRA fine-tuning with bitsandbytes, and LoRA code, are also provided. There is also an evaluation section comparing bitsandbytes and AutoRound quantization.
#
# For Phi-3.5 MoE, you will find the QLoRA fine-tuning, using bitsandbytes, at the end of the notebook.

# %% [markdown]
# #Quantization
# ##AutoRound

# %%
# !pip install --upgrade transformers auto-round flash_attn optimum auto-gptq
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Collecting transformers
#   Downloading transformers-4.44.1-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 3.6 MB/s eta 0:00:00
# Collecting auto-round
#   Downloading auto_round-0.3-py3-none-any.whl.metadata (18 kB)
# Collecting flash_attn
#   Downloading flash_attn-2.6.3.tar.gz (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 90.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting optimum
#   Downloading optimum-1.21.4-py3-none-any.whl.metadata (19 kB)
# Collecting auto-gptq
#   Downloading auto_gptq-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (from auto-round) (0.32.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from auto-round) (2.21.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from auto-round) (9.0.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from auto-round) (0.1.99)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from auto-round) (2.3.1+cu121)
# Requirement already satisfied: triton in /usr/local/lib/python3.10/dist-packages (from auto-round) (2.3.1)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.10/dist-packages (from auto-round) (3.5.0)
# Collecting intel-extension-for-transformers (from auto-round)
#   Downloading intel_extension_for_transformers-1.4.2-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from flash_attn) (0.8.0)
# Collecting coloredlogs (from optimum)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from optimum) (1.13.2)
# Collecting transformers
#   Downloading transformers-4.43.4-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 4.0 MB/s eta 0:00:00
# Collecting rouge (from auto-gptq)
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting gekko (from auto-gptq)
#   Downloading gekko-1.2.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: peft>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.12.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->auto-round) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->auto-round) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->auto-round) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->auto-round) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->auto-round) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->auto-round) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->auto-round) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->auto-round) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->auto-round) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->auto-round) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->auto-round) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->auto-round) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->auto-round) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->auto-round) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->auto-round) (12.6.20)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]<4.44.0,>=4.29.0->optimum) (3.20.3)
# Collecting humanfriendly>=9.1 (from coloredlogs->optimum)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->auto-round) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->auto-round) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->auto-round) (2.1.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->auto-round) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->auto-round) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->auto-round) (3.10.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)
# Collecting schema (from intel-extension-for-transformers->auto-round)
#   Downloading schema-0.7.7-py2.py3-none-any.whl.metadata (34 kB)
# Collecting neural-compressor (from intel-extension-for-transformers->auto-round)
#   Downloading neural_compressor-3.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge->auto-gptq) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->optimum) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-round) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-round) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-round) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-round) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-round) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-round) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-round) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->auto-round) (2.1.5)
# Collecting deprecated>=1.2.13 (from neural-compressor->intel-extension-for-transformers->auto-round)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from neural-compressor->intel-extension-for-transformers->auto-round) (4.10.0.84)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from neural-compressor->intel-extension-for-transformers->auto-round) (9.4.0)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from neural-compressor->intel-extension-for-transformers->auto-round) (3.11.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from neural-compressor->intel-extension-for-transformers->auto-round) (1.3.2)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from neural-compressor->intel-extension-for-transformers->auto-round) (2.0.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-round) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-round) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-round) (2024.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.13->neural-compressor->intel-extension-for-transformers->auto-round) (1.16.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->neural-compressor->intel-extension-for-transformers->auto-round) (0.2.13)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools->neural-compressor->intel-extension-for-transformers->auto-round) (3.7.1)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->neural-compressor->intel-extension-for-transformers->auto-round) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->neural-compressor->intel-extension-for-transformers->auto-round) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools->neural-compressor->intel-extension-for-transformers->auto-round) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools->neural-compressor->intel-extension-for-transformers->auto-round) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools->neural-compressor->intel-extension-for-transformers->auto-round) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools->neural-compressor->intel-extension-for-transformers->auto-round) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools->neural-compressor->intel-extension-for-transformers->auto-round) (3.1.2)
# Downloading auto_round-0.3-py3-none-any.whl (136 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.4/136.4 kB 13.5 MB/s eta 0:00:00
# Downloading optimum-1.21.4-py3-none-any.whl (421 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 34.4 MB/s eta 0:00:00
# Downloading transformers-4.43.4-py3-none-any.whl (9.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 106.2 MB/s eta 0:00:00
# Downloading auto_gptq-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 76.7 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.6 MB/s eta 0:00:00
# Downloading gekko-1.2.1-py3-none-any.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 109.9 MB/s eta 0:00:00
# Downloading intel_extension_for_transformers-1.4.2-cp310-cp310-manylinux_2_28_x86_64.whl (45.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 MB 44.6 MB/s eta 0:00:00
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.4 MB/s eta 0:00:00
# Downloading neural_compressor-3.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 73.7 MB/s eta 0:00:00
# Downloading schema-0.7.7-py2.py3-none-any.whl (18 kB)
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Building wheels for collected packages: flash_attn
#   Building wheel for flash_attn (setup.py) ... done
#   Created wheel for flash_attn: filename=flash_attn-2.6.3-cp310-cp310-linux_x86_64.whl size=187290390 sha256=c50f5de67a8b75bcfcf4a34257622475f9b56d59da58a539476a21db9d5b9867
#   Stored in directory: /root/.cache/pip/wheels/7e/e3/c3/89c7a2f3c4adc07cd1c675f8bb7b9ad4d18f64a72bccdfe826
# Successfully built flash_attn
# Installing collected packages: schema, rouge, humanfriendly, gekko, deprecated, coloredlogs, transformers, neural-compressor, flash_attn, intel-extension-for-transformers, optimum, auto-round, auto-gptq
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.42.4
#     Uninstalling transformers-4.42.4:
#       Successfully uninstalled transformers-4.42.4
# Successfully installed auto-gptq-0.7.1 auto-round-0.3 coloredlogs-15.0.1 deprecated-1.2.14 flash_attn-2.6.3 gekko-1.2.1 humanfriendly-10.0 intel-extension-for-transformers-1.4.2 neural-compressor-3.0 optimum-1.21.4 rouge-1.0.1 schema-0.7.7 transformers-4.43.4

# %% [markdown]
# * Requirements:
#  * CPU RAM: 13.1 GB
#  * GPU: 10.3 GB

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
model_name = "microsoft/Phi-3.5-Mini-instruct"
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.float16, trust_remote_code=True)
tokenizer = AutoTokenizer.from_pretrained(model_name)

from auto_round import AutoRound

bits, group_size, sym = 4, 128, True
autoround = AutoRound(model, tokenizer, bits=bits, group_size=group_size, batch_size=2, seqlen=512, sym=sym, gradient_accumulate_steps=4, device='cuda')
autoround.quantize()
output_dir = "./AutoRound/GPTQ-sym/"
autoround.save_quantized(output_dir)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# 2024-08-21 10:03:14 INFO autoround.py L209: using torch.float16 for quantization tuning
# Downloading readme:   0%|          | 0.00/373 [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/921 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/33.3M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/10000 [00:00<?, ? examples/s]
# 2024-08-21 10:04:09 INFO autoround.py L1039: quantizing 1/32, model.layers.0
# WARNING:transformers_modules.microsoft.Phi-3.5-Mini-instruct.64963004ad95869fa73a30279371c8778509ac84.modeling_phi3:You are not running the flash-attention implementation, expect numerical differences.
# 2024-08-21 10:05:37 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.000037 -> iter 196: 0.000004
# 2024-08-21 10:05:38 INFO autoround.py L1039: quantizing 2/32, model.layers.1
# 2024-08-21 10:07:05 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.000220 -> iter 191: 0.000035
# 2024-08-21 10:07:05 INFO autoround.py L1039: quantizing 3/32, model.layers.2
# 2024-08-21 10:08:32 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.020320 -> iter 21: 0.002543
# 2024-08-21 10:08:33 INFO autoround.py L1039: quantizing 4/32, model.layers.3
# 2024-08-21 10:09:59 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.003458 -> iter 109: 0.002240
# 2024-08-21 10:10:00 INFO autoround.py L1039: quantizing 5/32, model.layers.4
# 2024-08-21 10:11:27 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.041033 -> iter 86: 0.005105
# 2024-08-21 10:11:28 INFO autoround.py L1039: quantizing 6/32, model.layers.5
# 2024-08-21 10:12:55 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.011642 -> iter 107: 0.004887
# 2024-08-21 10:12:56 INFO autoround.py L1039: quantizing 7/32, model.layers.6
# 2024-08-21 10:14:22 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.013911 -> iter 99: 0.005268
# 2024-08-21 10:14:23 INFO autoround.py L1039: quantizing 8/32, model.layers.7
# 2024-08-21 10:15:50 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.014019 -> iter 179: 0.003665
# 2024-08-21 10:15:51 INFO autoround.py L1039: quantizing 9/32, model.layers.8
# 2024-08-21 10:17:17 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.008479 -> iter 88: 0.004399
# 2024-08-21 10:17:18 INFO autoround.py L1039: quantizing 10/32, model.layers.9
# 2024-08-21 10:18:45 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.009774 -> iter 179: 0.005524
# 2024-08-21 10:18:46 INFO autoround.py L1039: quantizing 11/32, model.layers.10
# 2024-08-21 10:20:13 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.017493 -> iter 149: 0.006066
# 2024-08-21 10:20:13 INFO autoround.py L1039: quantizing 12/32, model.layers.11
# 2024-08-21 10:21:40 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.014427 -> iter 186: 0.007015
# 2024-08-21 10:21:41 INFO autoround.py L1039: quantizing 13/32, model.layers.12
# 2024-08-21 10:23:08 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.021935 -> iter 162: 0.007938
# 2024-08-21 10:23:09 INFO autoround.py L1039: quantizing 14/32, model.layers.13
# 2024-08-21 10:24:35 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.038169 -> iter 160: 0.010246
# 2024-08-21 10:24:36 INFO autoround.py L1039: quantizing 15/32, model.layers.14
# 2024-08-21 10:26:03 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.038212 -> iter 182: 0.012551
# 2024-08-21 10:26:04 INFO autoround.py L1039: quantizing 16/32, model.layers.15
# 2024-08-21 10:27:31 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.031908 -> iter 144: 0.013749
# 2024-08-21 10:27:31 INFO autoround.py L1039: quantizing 17/32, model.layers.16
# 2024-08-21 10:28:58 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.037367 -> iter 197: 0.017923
# 2024-08-21 10:28:59 INFO autoround.py L1039: quantizing 18/32, model.layers.17
# 2024-08-21 10:30:26 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.042876 -> iter 107: 0.018880
# 2024-08-21 10:30:27 INFO autoround.py L1039: quantizing 19/32, model.layers.18
# 2024-08-21 10:31:54 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.060563 -> iter 151: 0.023445
# 2024-08-21 10:31:54 INFO autoround.py L1039: quantizing 20/32, model.layers.19
# 2024-08-21 10:33:21 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.057493 -> iter 193: 0.028911
# 2024-08-21 10:33:22 INFO autoround.py L1039: quantizing 21/32, model.layers.20
# 2024-08-21 10:34:49 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.058960 -> iter 109: 0.036320
# 2024-08-21 10:34:50 INFO autoround.py L1039: quantizing 22/32, model.layers.21
# 2024-08-21 10:36:17 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.092210 -> iter 182: 0.047063
# 2024-08-21 10:36:17 INFO autoround.py L1039: quantizing 23/32, model.layers.22
# 2024-08-21 10:37:44 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.107898 -> iter 186: 0.060324
# 2024-08-21 10:37:45 INFO autoround.py L1039: quantizing 24/32, model.layers.23
# 2024-08-21 10:39:12 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.139002 -> iter 190: 0.071832
# 2024-08-21 10:39:13 INFO autoround.py L1039: quantizing 25/32, model.layers.24
# 2024-08-21 10:40:40 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.188125 -> iter 177: 0.093124
# 2024-08-21 10:40:40 INFO autoround.py L1039: quantizing 26/32, model.layers.25
# 2024-08-21 10:42:07 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.203077 -> iter 150: 0.121553
# 2024-08-21 10:42:08 INFO autoround.py L1039: quantizing 27/32, model.layers.26
# 2024-08-21 10:43:35 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.261067 -> iter 149: 0.140465
# 2024-08-21 10:43:36 INFO autoround.py L1039: quantizing 28/32, model.layers.27
# 2024-08-21 10:45:03 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.283703 -> iter 182: 0.168503
# 2024-08-21 10:45:03 INFO autoround.py L1039: quantizing 29/32, model.layers.28
# 2024-08-21 10:46:30 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.341364 -> iter 159: 0.212061
# 2024-08-21 10:46:31 INFO autoround.py L1039: quantizing 30/32, model.layers.29
# 2024-08-21 10:47:58 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.572062 -> iter 197: 0.288508
# 2024-08-21 10:47:59 INFO autoround.py L1039: quantizing 31/32, model.layers.30
# 2024-08-21 10:49:26 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 0.636919 -> iter 165: 0.325628
# 2024-08-21 10:49:27 INFO autoround.py L1039: quantizing 32/32, model.layers.31
# 2024-08-21 10:50:54 INFO autoround.py L966: quantized 4/4 layers in the block, loss iter 0: 2.182157 -> iter 195: 0.599882
# 2024-08-21 10:50:54 INFO autoround.py L288: quantization tuning time 2860.0398161411285
# 2024-08-21 10:50:54 INFO autoround.py L304: Summary: quantized 128/129 in the model,  ['lm_head'] have not been quantized
# 2024-08-21 10:50:54 INFO export.py L112: Saving quantized model to autogptq format, this may take a while...
# 2024-08-21 10:50:54 INFO export.py L152: packing model.layers.0.self_attn.o_proj
# 2024-08-21 10:50:55 INFO export.py L152: packing model.layers.0.self_attn.qkv_proj
# 2024-08-21 10:50:56 INFO export.py L152: packing model.layers.0.mlp.gate_up_proj
# 2024-08-21 10:50:59 INFO export.py L152: packing model.layers.0.mlp.down_proj
# 2024-08-21 10:51:00 INFO export.py L152: packing model.layers.1.self_attn.o_proj
# 2024-08-21 10:51:01 INFO export.py L152: packing model.layers.1.self_attn.qkv_proj
# 2024-08-21 10:51:02 INFO export.py L152: packing model.layers.1.mlp.gate_up_proj
# 2024-08-21 10:51:04 INFO export.py L152: packing model.layers.1.mlp.down_proj
# 2024-08-21 10:51:06 INFO export.py L152: packing model.layers.2.self_attn.o_proj
# 2024-08-21 10:51:06 INFO export.py L152: packing model.layers.2.self_attn.qkv_proj
# 2024-08-21 10:51:07 INFO export.py L152: packing model.layers.2.mlp.gate_up_proj
# 2024-08-21 10:51:10 INFO export.py L152: packing model.layers.2.mlp.down_proj
# 2024-08-21 10:51:12 INFO export.py L152: packing model.layers.3.self_attn.o_proj
# 2024-08-21 10:51:12 INFO export.py L152: packing model.layers.3.self_attn.qkv_proj
# 2024-08-21 10:51:13 INFO export.py L152: packing model.layers.3.mlp.gate_up_proj
# 2024-08-21 10:51:16 INFO export.py L152: packing model.layers.3.mlp.down_proj
# 2024-08-21 10:51:17 INFO export.py L152: packing model.layers.4.self_attn.o_proj
# 2024-08-21 10:51:18 INFO export.py L152: packing model.layers.4.self_attn.qkv_proj
# 2024-08-21 10:51:19 INFO export.py L152: packing model.layers.4.mlp.gate_up_proj
# 2024-08-21 10:51:21 INFO export.py L152: packing model.layers.4.mlp.down_proj
# 2024-08-21 10:51:23 INFO export.py L152: packing model.layers.5.self_attn.o_proj
# 2024-08-21 10:51:23 INFO export.py L152: packing model.layers.5.self_attn.qkv_proj
# 2024-08-21 10:51:25 INFO export.py L152: packing model.layers.5.mlp.gate_up_proj
# 2024-08-21 10:51:27 INFO export.py L152: packing model.layers.5.mlp.down_proj
# 2024-08-21 10:51:28 INFO export.py L152: packing model.layers.6.self_attn.o_proj
# 2024-08-21 10:51:29 INFO export.py L152: packing model.layers.6.self_attn.qkv_proj
# 2024-08-21 10:51:30 INFO export.py L152: packing model.layers.6.mlp.gate_up_proj
# 2024-08-21 10:51:32 INFO export.py L152: packing model.layers.6.mlp.down_proj
# 2024-08-21 10:51:34 INFO export.py L152: packing model.layers.7.self_attn.o_proj
# 2024-08-21 10:51:35 INFO export.py L152: packing model.layers.7.self_attn.qkv_proj
# 2024-08-21 10:51:36 INFO export.py L152: packing model.layers.7.mlp.gate_up_proj
# 2024-08-21 10:51:38 INFO export.py L152: packing model.layers.7.mlp.down_proj
# 2024-08-21 10:51:40 INFO export.py L152: packing model.layers.8.self_attn.o_proj
# 2024-08-21 10:51:40 INFO export.py L152: packing model.layers.8.self_attn.qkv_proj
# 2024-08-21 10:51:41 INFO export.py L152: packing model.layers.8.mlp.gate_up_proj
# 2024-08-21 10:51:44 INFO export.py L152: packing model.layers.8.mlp.down_proj
# 2024-08-21 10:51:45 INFO export.py L152: packing model.layers.9.self_attn.o_proj
# 2024-08-21 10:51:46 INFO export.py L152: packing model.layers.9.self_attn.qkv_proj
# 2024-08-21 10:51:47 INFO export.py L152: packing model.layers.9.mlp.gate_up_proj
# 2024-08-21 10:51:49 INFO export.py L152: packing model.layers.9.mlp.down_proj
# 2024-08-21 10:51:51 INFO export.py L152: packing model.layers.10.self_attn.o_proj
# 2024-08-21 10:51:52 INFO export.py L152: packing model.layers.10.self_attn.qkv_proj
# 2024-08-21 10:51:53 INFO export.py L152: packing model.layers.10.mlp.gate_up_proj
# 2024-08-21 10:51:55 INFO export.py L152: packing model.layers.10.mlp.down_proj
# 2024-08-21 10:51:57 INFO export.py L152: packing model.layers.11.self_attn.o_proj
# 2024-08-21 10:51:57 INFO export.py L152: packing model.layers.11.self_attn.qkv_proj
# 2024-08-21 10:51:59 INFO export.py L152: packing model.layers.11.mlp.gate_up_proj
# 2024-08-21 10:52:01 INFO export.py L152: packing model.layers.11.mlp.down_proj
# 2024-08-21 10:52:03 INFO export.py L152: packing model.layers.12.self_attn.o_proj
# 2024-08-21 10:52:03 INFO export.py L152: packing model.layers.12.self_attn.qkv_proj
# 2024-08-21 10:52:05 INFO export.py L152: packing model.layers.12.mlp.gate_up_proj
# 2024-08-21 10:52:07 INFO export.py L152: packing model.layers.12.mlp.down_proj
# 2024-08-21 10:52:09 INFO export.py L152: packing model.layers.13.self_attn.o_proj
# 2024-08-21 10:52:09 INFO export.py L152: packing model.layers.13.self_attn.qkv_proj
# 2024-08-21 10:52:10 INFO export.py L152: packing model.layers.13.mlp.gate_up_proj
# 2024-08-21 10:52:13 INFO export.py L152: packing model.layers.13.mlp.down_proj
# 2024-08-21 10:52:14 INFO export.py L152: packing model.layers.14.self_attn.o_proj
# 2024-08-21 10:52:15 INFO export.py L152: packing model.layers.14.self_attn.qkv_proj
# 2024-08-21 10:52:16 INFO export.py L152: packing model.layers.14.mlp.gate_up_proj
# 2024-08-21 10:52:18 INFO export.py L152: packing model.layers.14.mlp.down_proj
# 2024-08-21 10:52:20 INFO export.py L152: packing model.layers.15.self_attn.o_proj
# 2024-08-21 10:52:21 INFO export.py L152: packing model.layers.15.self_attn.qkv_proj
# 2024-08-21 10:52:22 INFO export.py L152: packing model.layers.15.mlp.gate_up_proj
# 2024-08-21 10:52:24 INFO export.py L152: packing model.layers.15.mlp.down_proj
# 2024-08-21 10:52:26 INFO export.py L152: packing model.layers.16.self_attn.o_proj
# 2024-08-21 10:52:26 INFO export.py L152: packing model.layers.16.self_attn.qkv_proj
# 2024-08-21 10:52:28 INFO export.py L152: packing model.layers.16.mlp.gate_up_proj
# 2024-08-21 10:52:30 INFO export.py L152: packing model.layers.16.mlp.down_proj
# 2024-08-21 10:52:31 INFO export.py L152: packing model.layers.17.self_attn.o_proj
# 2024-08-21 10:52:32 INFO export.py L152: packing model.layers.17.self_attn.qkv_proj
# 2024-08-21 10:52:33 INFO export.py L152: packing model.layers.17.mlp.gate_up_proj
# 2024-08-21 10:52:36 INFO export.py L152: packing model.layers.17.mlp.down_proj
# 2024-08-21 10:52:37 INFO export.py L152: packing model.layers.18.self_attn.o_proj
# 2024-08-21 10:52:38 INFO export.py L152: packing model.layers.18.self_attn.qkv_proj
# 2024-08-21 10:52:39 INFO export.py L152: packing model.layers.18.mlp.gate_up_proj
# 2024-08-21 10:52:41 INFO export.py L152: packing model.layers.18.mlp.down_proj
# 2024-08-21 10:52:43 INFO export.py L152: packing model.layers.19.self_attn.o_proj
# 2024-08-21 10:52:44 INFO export.py L152: packing model.layers.19.self_attn.qkv_proj
# 2024-08-21 10:52:45 INFO export.py L152: packing model.layers.19.mlp.gate_up_proj
# 2024-08-21 10:52:47 INFO export.py L152: packing model.layers.19.mlp.down_proj
# 2024-08-21 10:52:49 INFO export.py L152: packing model.layers.20.self_attn.o_proj
# 2024-08-21 10:52:49 INFO export.py L152: packing model.layers.20.self_attn.qkv_proj
# 2024-08-21 10:52:51 INFO export.py L152: packing model.layers.20.mlp.gate_up_proj
# 2024-08-21 10:52:53 INFO export.py L152: packing model.layers.20.mlp.down_proj
# 2024-08-21 10:52:54 INFO export.py L152: packing model.layers.21.self_attn.o_proj
# 2024-08-21 10:52:55 INFO export.py L152: packing model.layers.21.self_attn.qkv_proj
# 2024-08-21 10:52:57 INFO export.py L152: packing model.layers.21.mlp.gate_up_proj
# 2024-08-21 10:52:59 INFO export.py L152: packing model.layers.21.mlp.down_proj
# 2024-08-21 10:53:00 INFO export.py L152: packing model.layers.22.self_attn.o_proj
# 2024-08-21 10:53:01 INFO export.py L152: packing model.layers.22.self_attn.qkv_proj
# 2024-08-21 10:53:02 INFO export.py L152: packing model.layers.22.mlp.gate_up_proj
# 2024-08-21 10:53:05 INFO export.py L152: packing model.layers.22.mlp.down_proj
# 2024-08-21 10:53:06 INFO export.py L152: packing model.layers.23.self_attn.o_proj
# 2024-08-21 10:53:07 INFO export.py L152: packing model.layers.23.self_attn.qkv_proj
# 2024-08-21 10:53:08 INFO export.py L152: packing model.layers.23.mlp.gate_up_proj
# 2024-08-21 10:53:10 INFO export.py L152: packing model.layers.23.mlp.down_proj
# 2024-08-21 10:53:12 INFO export.py L152: packing model.layers.24.self_attn.o_proj
# 2024-08-21 10:53:12 INFO export.py L152: packing model.layers.24.self_attn.qkv_proj
# 2024-08-21 10:53:14 INFO export.py L152: packing model.layers.24.mlp.gate_up_proj
# 2024-08-21 10:53:16 INFO export.py L152: packing model.layers.24.mlp.down_proj
# 2024-08-21 10:53:18 INFO export.py L152: packing model.layers.25.self_attn.o_proj
# 2024-08-21 10:53:18 INFO export.py L152: packing model.layers.25.self_attn.qkv_proj
# 2024-08-21 10:53:20 INFO export.py L152: packing model.layers.25.mlp.gate_up_proj
# 2024-08-21 10:53:22 INFO export.py L152: packing model.layers.25.mlp.down_proj
# 2024-08-21 10:53:23 INFO export.py L152: packing model.layers.26.self_attn.o_proj
# 2024-08-21 10:53:24 INFO export.py L152: packing model.layers.26.self_attn.qkv_proj
# 2024-08-21 10:53:25 INFO export.py L152: packing model.layers.26.mlp.gate_up_proj
# 2024-08-21 10:53:28 INFO export.py L152: packing model.layers.26.mlp.down_proj
# 2024-08-21 10:53:29 INFO export.py L152: packing model.layers.27.self_attn.o_proj
# 2024-08-21 10:53:30 INFO export.py L152: packing model.layers.27.self_attn.qkv_proj
# 2024-08-21 10:53:31 INFO export.py L152: packing model.layers.27.mlp.gate_up_proj
# 2024-08-21 10:53:33 INFO export.py L152: packing model.layers.27.mlp.down_proj
# 2024-08-21 10:53:35 INFO export.py L152: packing model.layers.28.self_attn.o_proj
# 2024-08-21 10:53:35 INFO export.py L152: packing model.layers.28.self_attn.qkv_proj
# 2024-08-21 10:53:37 INFO export.py L152: packing model.layers.28.mlp.gate_up_proj
# 2024-08-21 10:53:39 INFO export.py L152: packing model.layers.28.mlp.down_proj
# 2024-08-21 10:53:41 INFO export.py L152: packing model.layers.29.self_attn.o_proj
# 2024-08-21 10:53:41 INFO export.py L152: packing model.layers.29.self_attn.qkv_proj
# 2024-08-21 10:53:43 INFO export.py L152: packing model.layers.29.mlp.gate_up_proj
# 2024-08-21 10:53:45 INFO export.py L152: packing model.layers.29.mlp.down_proj
# 2024-08-21 10:53:46 INFO export.py L152: packing model.layers.30.self_attn.o_proj
# 2024-08-21 10:53:47 INFO export.py L152: packing model.layers.30.self_attn.qkv_proj
# 2024-08-21 10:53:48 INFO export.py L152: packing model.layers.30.mlp.gate_up_proj
# 2024-08-21 10:53:51 INFO export.py L152: packing model.layers.30.mlp.down_proj
# 2024-08-21 10:53:52 INFO export.py L152: packing model.layers.31.self_attn.o_proj
# 2024-08-21 10:53:53 INFO export.py L152: packing model.layers.31.self_attn.qkv_proj
# 2024-08-21 10:53:54 INFO export.py L152: packing model.layers.31.mlp.gate_up_proj
# 2024-08-21 10:53:57 INFO export.py L152: packing model.layers.31.mlp.down_proj

# %% [markdown]
# #Evaluation: Zero-shot MMLU, MMLU-PRO, Arc Challenge

# %%
# !pip install git+https://github.com/EleutherAI/lm-evaluation-harness.git
# Out:
# Collecting git+https://github.com/EleutherAI/lm-evaluation-harness.git
#   Cloning https://github.com/EleutherAI/lm-evaluation-harness.git to /tmp/pip-req-build-_cpj6cgn
#   Running command git clone --filter=blob:none --quiet https://github.com/EleutherAI/lm-evaluation-harness.git /tmp/pip-req-build-_cpj6cgn
#   Resolved https://github.com/EleutherAI/lm-evaluation-harness.git to commit a4987bba6e9e9b3f22bd3a6c1ecf0abd04fd5622
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: accelerate>=0.26.0 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.3) (0.32.1)
# Collecting evaluate (from lm_eval==0.4.3)
#   Downloading evaluate-0.4.2-py3-none-any.whl.metadata (9.3 kB)
# Collecting datasets>=2.16.0 (from lm_eval==0.4.3)
#   Downloading datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Collecting jsonlines (from lm_eval==0.4.3)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.3) (2.10.1)
# Collecting peft>=0.2.0 (from lm_eval==0.4.3)
#   Downloading peft-0.12.0-py3-none-any.whl.metadata (13 kB)
# Collecting pybind11>=2.6.2 (from lm_eval==0.4.3)
#   Downloading pybind11-2.13.4-py3-none-any.whl.metadata (9.5 kB)
# Collecting pytablewriter (from lm_eval==0.4.3)
#   Downloading pytablewriter-1.2.0-py3-none-any.whl.metadata (37 kB)
# Collecting rouge-score>=0.0.4 (from lm_eval==0.4.3)
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sacrebleu>=1.5.0 (from lm_eval==0.4.3)
#   Downloading sacrebleu-2.4.3-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.3) (1.3.2)
# Collecting sqlitedict (from lm_eval==0.4.3)
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.3) (2.3.1+cu121)
# Collecting tqdm-multiprocess (from lm_eval==0.4.3)
#   Downloading tqdm_multiprocess-0.0.11-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: transformers>=4.1 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.3) (4.42.4)
# Collecting zstandard (from lm_eval==0.4.3)
#   Downloading zstandard-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting dill (from lm_eval==0.4.3)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting word2number (from lm_eval==0.4.3)
#   Downloading word2number-1.1.zip (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.3) (10.3.0)
# Requirement already satisfied: numpy<2.0.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.3) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.3) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.3) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.3) (6.0.2)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.3) (0.23.5)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.3) (0.4.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.3) (3.15.4)
# Collecting pyarrow>=15.0.0 (from datasets>=2.16.0->lm_eval==0.4.3)
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.3) (2.1.4)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.3) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.3) (4.66.5)
# Collecting xxhash (from datasets>=2.16.0->lm_eval==0.4.3)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets>=2.16.0->lm_eval==0.4.3)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets>=2.16.0->lm_eval==0.4.3) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.3) (3.10.3)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.3) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.3) (3.8.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.3) (1.16.0)
# Collecting portalocker (from sacrebleu>=1.5.0->lm_eval==0.4.3)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.3) (2024.5.15)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.3) (0.9.0)
# Collecting colorama (from sacrebleu>=1.5.0->lm_eval==0.4.3)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.3) (4.9.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.3) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.3) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.3) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.3) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.3) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.3) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.3) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.8->lm_eval==0.4.3)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.8->lm_eval==0.4.3)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.8->lm_eval==0.4.3)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.8->lm_eval==0.4.3)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.8->lm_eval==0.4.3)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.8->lm_eval==0.4.3)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.8->lm_eval==0.4.3)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.8->lm_eval==0.4.3)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.8->lm_eval==0.4.3)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.8->lm_eval==0.4.3)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.8->lm_eval==0.4.3)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.3) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8->lm_eval==0.4.3)
#   Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.1->lm_eval==0.4.3) (0.19.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines->lm_eval==0.4.3) (24.2.0)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm_eval==0.4.3) (71.0.4)
# Collecting DataProperty<2,>=1.0.1 (from pytablewriter->lm_eval==0.4.3)
#   Downloading DataProperty-1.0.1-py3-none-any.whl.metadata (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter->lm_eval==0.4.3)
#   Downloading mbstrdecoder-1.1.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter->lm_eval==0.4.3)
#   Downloading pathvalidate-3.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter->lm_eval==0.4.3)
#   Downloading tabledata-1.3.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter->lm_eval==0.4.3)
#   Downloading tcolorpy-0.1.6-py3-none-any.whl.metadata (6.4 kB)
# Collecting typepy<2,>=1.3.2 (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.3)
#   Downloading typepy-1.3.2-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.3) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.3) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.3) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.3) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.3) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.3) (4.0.3)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.10/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter->lm_eval==0.4.3) (5.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.3) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.3) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.3) (2024.7.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.3) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.3) (2024.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8->lm_eval==0.4.3) (2.1.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score>=0.0.4->lm_eval==0.4.3) (8.1.7)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->lm_eval==0.4.3) (2024.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8->lm_eval==0.4.3) (1.3.0)
# Downloading datasets-2.21.0-py3-none-any.whl (527 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 30.9 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.5 MB/s eta 0:00:00
# Downloading evaluate-0.4.2-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.1 MB/s eta 0:00:00
# Downloading peft-0.12.0-py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.4/296.4 kB 25.6 MB/s eta 0:00:00
# Downloading pybind11-2.13.4-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.9/240.9 kB 22.9 MB/s eta 0:00:00
# Downloading sacrebleu-2.4.3-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 10.3 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading pytablewriter-1.2.0-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 9.3 MB/s eta 0:00:00
# Downloading tqdm_multiprocess-0.0.11-py3-none-any.whl (9.8 kB)
# Downloading zstandard-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 105.3 MB/s eta 0:00:00
# Downloading DataProperty-1.0.1-py3-none-any.whl (27 kB)
# Downloading mbstrdecoder-1.1.3-py3-none-any.whl (7.8 kB)
# Downloading pathvalidate-3.2.0-py3-none-any.whl (23 kB)
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 55.6 MB/s eta 0:00:00
# Downloading tabledata-1.3.3-py3-none-any.whl (11 kB)
# Downloading tcolorpy-0.1.6-py3-none-any.whl (8.1 kB)
# Downloading typepy-1.3.2-py3-none-any.whl (31 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.7 MB/s eta 0:00:00
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.7 MB/s eta 0:00:00
# Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl (19.7 MB)
# Building wheels for collected packages: lm_eval, rouge-score, sqlitedict, word2number
#   Building wheel for lm_eval (pyproject.toml) ... done
#   Created wheel for lm_eval: filename=lm_eval-0.4.3-py3-none-any.whl size=1998189 sha256=c70dd7abe26d45d40f4a8739d7c8f2988261950cd83a13cee104e18b5689f033
#   Stored in directory: /tmp/pip-ephem-wheel-cache-snq7lxn_/wheels/ff/d5/f4/949f2b285369fc332f8dbba43f220ebd88387ee2f2c0c1174f
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=954bc680d42bab61dd39df92922274a7bc8284f7f3dcae53e059d5df9a89692b
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16863 sha256=8c4d006e2fbf156f2704e653d716abf0915c900c5d277bac7c8fc789f513d676
#   Stored in directory: /root/.cache/pip/wheels/79/d6/e7/304e0e6cb2221022c26d8161f7c23cd4f259a9e41e8bbcfabd
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5570 sha256=589e7f9d90e0bb22fe5c80ceeaa1dfb0de56046a85d8b0acd0d8eebcd01961a7
#   Stored in directory: /root/.cache/pip/wheels/84/ff/26/d3cfbd971e96c5aa3737ecfced81628830d7359b55fbb8ca3b
# Successfully built lm_eval rouge-score sqlitedict word2number
# Installing collected packages: word2number, sqlitedict, zstandard, xxhash, tcolorpy, pybind11, pyarrow, portalocker, pathvalidate, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mbstrdecoder, jsonlines, dill, colorama, typepy, tqdm-multiprocess, sacrebleu, rouge-score, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, nvidia-cusolver-cu12, datasets, DataProperty, tabledata, evaluate, pytablewriter, peft, lm_eval
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed DataProperty-1.0.1 colorama-0.4.6 datasets-2.21.0 dill-0.3.8 evaluate-0.4.2 jsonlines-4.0.0 lm_eval-0.4.3 mbstrdecoder-1.1.3 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.20 nvidia-nvtx-cu12-12.1.105 pathvalidate-3.2.0 peft-0.12.0 portalocker-2.10.1 pyarrow-17.0.0 pybind11-2.13.4 pytablewriter-1.2.0 rouge-score-0.1.2 sacrebleu-2.4.3 sqlitedict-2.1.0 tabledata-1.3.3 tcolorpy-0.1.6 tqdm-multiprocess-0.0.11 typepy-1.3.2 word2number-1.1 xxhash-3.5.0 zstandard-0.23.0

# %% [markdown]
# ###Phi-3 Mini

# %%
# !lm_eval --model hf --model_args pretrained=microsoft/Phi-3-mini-128k-instruct,dtype=float16 --tasks mmlu,arc_challenge,leaderboard_mmlu_pro --device cuda:0 --num_fewshot 0 --batch_size 4 --output_path ./eval/
# Out:
# 2024-08-22 10:35:42.387358: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-22 10:35:42.404869: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-22 10:35:42.426572: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-22 10:35:42.433268: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-22 10:35:42.449306: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-22 10:35:43.657910: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-08-22:10:35:45,704 INFO     [__main__.py:279] Verbosity set to INFO
# 2024-08-22:10:35:45,710 INFO     [__init__.py:491] `group` and `group_alias` keys in tasks' configs will no longer be used in the next release of lm-eval. `tag` will be used to allow to call a collection of tasks just like `group`. `group` will be removed in order to not cause confusion with the new ConfigurableGroup which will be the offical way to create groups with addition of group-wide configuations.
# 2024-08-22:10:35:54,233 INFO     [__main__.py:383] Selected Tasks: ['arc_challenge', 'leaderboard_mmlu_pro', 'mmlu']
# 2024-08-22:10:35:54,235 INFO     [evaluator.py:161] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-08-22:10:35:54,235 INFO     [evaluator.py:198] Initializing hf model, with arguments: {'pretrained': 'microsoft/Phi-3-mini-128k-instruct', 'dtype': 'float16'}
# 2024-08-22:10:35:54,274 INFO     [huggingface.py:130] Using device 'cuda:0'
# tokenizer_config.json: 100% 3.44k/3.44k [00:00<00:00, 22.7MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 68.7MB/s]
# tokenizer.json: 100% 1.94M/1.94M [00:01<00:00, 1.37MB/s]
# added_tokens.json: 100% 306/306 [00:00<00:00, 2.18MB/s]
# special_tokens_map.json: 100% 599/599 [00:00<00:00, 4.58MB/s]
# 2024-08-22:10:35:58,241 INFO     [huggingface.py:366] Model parallel was set to False, max memory was not set, and device map was set to {'': 'cuda:0'}
# model.safetensors.index.json: 100% 16.3k/16.3k [00:00<00:00, 51.5MB/s]
# Downloading shards:   0% 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0% 0.00/4.97G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   1% 31.5M/4.97G [00:00<00:16, 292MB/s]
# model-00001-of-00002.safetensors:   1% 73.4M/4.97G [00:00<00:13, 361MB/s]
# model-00001-of-00002.safetensors:   3% 126M/4.97G [00:00<00:12, 390MB/s]
# model-00001-of-00002.safetensors:   4% 178M/4.97G [00:00<00:11, 423MB/s]
# model-00001-of-00002.safetensors:   5% 231M/4.97G [00:00<00:10, 445MB/s]
# model-00001-of-00002.safetensors:   6% 283M/4.97G [00:00<00:10, 454MB/s]
# model-00001-of-00002.safetensors:   7% 336M/4.97G [00:00<00:12, 382MB/s]
# model-00001-of-00002.safetensors:   8% 377M/4.97G [00:01<00:13, 339MB/s]
# model-00001-of-00002.safetensors:   9% 430M/4.97G [00:01<00:12, 362MB/s]
# model-00001-of-00002.safetensors:   9% 472M/4.97G [00:01<00:12, 361MB/s]
# model-00001-of-00002.safetensors:  10% 514M/4.97G [00:01<00:12, 356MB/s]
# model-00001-of-00002.safetensors:  11% 556M/4.97G [00:01<00:12, 357MB/s]
# model-00001-of-00002.safetensors:  12% 598M/4.97G [00:01<00:13, 329MB/s]
# model-00001-of-00002.safetensors:  13% 640M/4.97G [00:01<00:12, 337MB/s]
# model-00001-of-00002.safetensors:  14% 682M/4.97G [00:01<00:12, 339MB/s]
# model-00001-of-00002.safetensors:  15% 724M/4.97G [00:02<00:13, 317MB/s]
# model-00001-of-00002.safetensors:  15% 765M/4.97G [00:02<00:12, 332MB/s]
# model-00001-of-00002.safetensors:  16% 807M/4.97G [00:02<00:12, 340MB/s]
# model-00001-of-00002.safetensors:  17% 860M/4.97G [00:02<00:11, 367MB/s]
# model-00001-of-00002.safetensors:  18% 912M/4.97G [00:02<00:10, 392MB/s]
# model-00001-of-00002.safetensors:  19% 954M/4.97G [00:02<00:11, 365MB/s]
# model-00001-of-00002.safetensors:  20% 1.01G/4.97G [00:02<00:10, 381MB/s]
# model-00001-of-00002.safetensors:  21% 1.05G/4.97G [00:02<00:10, 389MB/s]
# model-00001-of-00002.safetensors:  22% 1.09G/4.97G [00:02<00:10, 379MB/s]
# model-00001-of-00002.safetensors:  23% 1.13G/4.97G [00:03<00:10, 364MB/s]
# model-00001-of-00002.safetensors:  24% 1.17G/4.97G [00:03<00:10, 363MB/s]
# model-00001-of-00002.safetensors:  24% 1.22G/4.97G [00:03<00:11, 336MB/s]
# model-00001-of-00002.safetensors:  26% 1.27G/4.97G [00:03<00:09, 371MB/s]
# model-00001-of-00002.safetensors:  27% 1.32G/4.97G [00:03<00:09, 390MB/s]
# model-00001-of-00002.safetensors:  27% 1.36G/4.97G [00:03<00:09, 393MB/s]
# model-00001-of-00002.safetensors:  28% 1.42G/4.97G [00:03<00:08, 406MB/s]
# model-00001-of-00002.safetensors:  29% 1.46G/4.97G [00:03<00:08, 409MB/s]
# model-00001-of-00002.safetensors:  30% 1.50G/4.97G [00:04<00:08, 392MB/s]
# model-00001-of-00002.safetensors:  31% 1.54G/4.97G [00:04<00:08, 383MB/s]
# model-00001-of-00002.safetensors:  32% 1.58G/4.97G [00:04<00:10, 332MB/s]
# model-00001-of-00002.safetensors:  33% 1.63G/4.97G [00:04<00:09, 343MB/s]
# model-00001-of-00002.safetensors:  34% 1.67G/4.97G [00:04<00:09, 339MB/s]
# model-00001-of-00002.safetensors:  34% 1.71G/4.97G [00:04<00:10, 299MB/s]
# model-00001-of-00002.safetensors:  35% 1.74G/4.97G [00:04<00:11, 291MB/s]
# model-00001-of-00002.safetensors:  36% 1.77G/4.97G [00:04<00:11, 284MB/s]
# model-00001-of-00002.safetensors:  37% 1.82G/4.97G [00:05<00:09, 326MB/s]
# model-00001-of-00002.safetensors:  38% 1.87G/4.97G [00:05<00:09, 344MB/s]
# model-00001-of-00002.safetensors:  38% 1.91G/4.97G [00:05<00:08, 360MB/s]
# model-00001-of-00002.safetensors:  39% 1.95G/4.97G [00:05<00:08, 359MB/s]
# model-00001-of-00002.safetensors:  40% 1.99G/4.97G [00:05<00:08, 372MB/s]
# model-00001-of-00002.safetensors:  41% 2.03G/4.97G [00:05<00:07, 375MB/s]
# model-00001-of-00002.safetensors:  42% 2.08G/4.97G [00:05<00:07, 363MB/s]
# model-00001-of-00002.safetensors:  43% 2.12G/4.97G [00:05<00:07, 368MB/s]
# model-00001-of-00002.safetensors:  44% 2.17G/4.97G [00:06<00:07, 382MB/s]
# model-00001-of-00002.safetensors:  45% 2.22G/4.97G [00:06<00:06, 398MB/s]
# model-00001-of-00002.safetensors:  46% 2.26G/4.97G [00:06<00:06, 390MB/s]
# model-00001-of-00002.safetensors:  46% 2.31G/4.97G [00:06<00:06, 390MB/s]
# model-00001-of-00002.safetensors:  47% 2.36G/4.97G [00:06<00:06, 401MB/s]
# model-00001-of-00002.safetensors:  49% 2.41G/4.97G [00:06<00:06, 416MB/s]
# model-00001-of-00002.safetensors:  49% 2.45G/4.97G [00:06<00:06, 371MB/s]
# model-00001-of-00002.safetensors:  50% 2.50G/4.97G [00:06<00:06, 372MB/s]
# model-00001-of-00002.safetensors:  51% 2.54G/4.97G [00:06<00:06, 354MB/s]
# model-00001-of-00002.safetensors:  52% 2.58G/4.97G [00:07<00:06, 343MB/s]
# model-00001-of-00002.safetensors:  53% 2.62G/4.97G [00:07<00:06, 348MB/s]
# model-00001-of-00002.safetensors:  54% 2.66G/4.97G [00:07<00:06, 364MB/s]
# model-00001-of-00002.safetensors:  55% 2.72G/4.97G [00:07<00:05, 392MB/s]
# model-00001-of-00002.safetensors:  56% 2.77G/4.97G [00:07<00:05, 419MB/s]
# model-00001-of-00002.safetensors:  57% 2.82G/4.97G [00:07<00:05, 416MB/s]
# model-00001-of-00002.safetensors:  58% 2.86G/4.97G [00:07<00:05, 398MB/s]
# model-00001-of-00002.safetensors:  58% 2.90G/4.97G [00:07<00:05, 390MB/s]
# model-00001-of-00002.safetensors:  59% 2.95G/4.97G [00:08<00:05, 365MB/s]
# model-00001-of-00002.safetensors:  60% 2.99G/4.97G [00:08<00:05, 346MB/s]
# model-00001-of-00002.safetensors:  61% 3.03G/4.97G [00:08<00:05, 349MB/s]
# model-00001-of-00002.safetensors:  62% 3.07G/4.97G [00:08<00:05, 353MB/s]
# model-00001-of-00002.safetensors:  63% 3.12G/4.97G [00:08<00:04, 389MB/s]
# model-00001-of-00002.safetensors:  64% 3.18G/4.97G [00:08<00:04, 410MB/s]
# model-00001-of-00002.safetensors:  65% 3.23G/4.97G [00:08<00:04, 423MB/s]
# model-00001-of-00002.safetensors:  66% 3.28G/4.97G [00:08<00:04, 397MB/s]
# model-00001-of-00002.safetensors:  67% 3.32G/4.97G [00:09<00:04, 394MB/s]
# model-00001-of-00002.safetensors:  68% 3.38G/4.97G [00:09<00:03, 415MB/s]
# model-00001-of-00002.safetensors:  69% 3.43G/4.97G [00:09<00:03, 432MB/s]
# model-00001-of-00002.safetensors:  70% 3.48G/4.97G [00:09<00:03, 414MB/s]
# model-00001-of-00002.safetensors:  71% 3.53G/4.97G [00:09<00:03, 432MB/s]
# model-00001-of-00002.safetensors:  72% 3.59G/4.97G [00:09<00:03, 447MB/s]
# model-00001-of-00002.safetensors:  73% 3.64G/4.97G [00:09<00:02, 449MB/s]
# model-00001-of-00002.safetensors:  74% 3.69G/4.97G [00:09<00:02, 467MB/s]
# model-00001-of-00002.safetensors:  75% 3.74G/4.97G [00:09<00:02, 427MB/s]
# model-00001-of-00002.safetensors:  76% 3.80G/4.97G [00:10<00:02, 417MB/s]
# model-00001-of-00002.safetensors:  77% 3.85G/4.97G [00:10<00:04, 273MB/s]
# model-00001-of-00002.safetensors:  78% 3.90G/4.97G [00:10<00:03, 313MB/s]
# model-00001-of-00002.safetensors:  80% 3.95G/4.97G [00:10<00:02, 349MB/s]
# model-00001-of-00002.safetensors:  81% 4.01G/4.97G [00:10<00:02, 379MB/s]
# model-00001-of-00002.safetensors:  82% 4.06G/4.97G [00:10<00:02, 409MB/s]
# model-00001-of-00002.safetensors:  83% 4.11G/4.97G [00:11<00:02, 394MB/s]
# model-00001-of-00002.safetensors:  84% 4.16G/4.97G [00:11<00:02, 393MB/s]
# model-00001-of-00002.safetensors:  85% 4.20G/4.97G [00:11<00:02, 379MB/s]
# model-00001-of-00002.safetensors:  85% 4.25G/4.97G [00:11<00:01, 379MB/s]
# model-00001-of-00002.safetensors:  86% 4.29G/4.97G [00:11<00:01, 355MB/s]
# model-00001-of-00002.safetensors:  87% 4.33G/4.97G [00:11<00:01, 347MB/s]
# model-00001-of-00002.safetensors:  88% 4.37G/4.97G [00:11<00:01, 340MB/s]
# model-00001-of-00002.safetensors:  89% 4.42G/4.97G [00:11<00:01, 369MB/s]
# model-00001-of-00002.safetensors:  90% 4.47G/4.97G [00:12<00:01, 372MB/s]
# model-00001-of-00002.safetensors:  91% 4.51G/4.97G [00:17<00:18, 25.7MB/s]
# model-00001-of-00002.safetensors:  92% 4.56G/4.97G [00:17<00:10, 37.7MB/s]
# model-00001-of-00002.safetensors:  93% 4.61G/4.97G [00:17<00:06, 53.6MB/s]
# model-00001-of-00002.safetensors:  94% 4.67G/4.97G [00:17<00:04, 74.4MB/s]
# model-00001-of-00002.safetensors:  95% 4.72G/4.97G [00:17<00:02, 99.4MB/s]
# model-00001-of-00002.safetensors:  96% 4.76G/4.97G [00:18<00:01, 124MB/s]
# model-00001-of-00002.safetensors:  97% 4.80G/4.97G [00:18<00:01, 152MB/s]
# model-00001-of-00002.safetensors:  98% 4.85G/4.97G [00:18<00:00, 198MB/s]
# model-00001-of-00002.safetensors:  99% 4.91G/4.97G [00:18<00:00, 233MB/s]
# model-00001-of-00002.safetensors: 100% 4.97G/4.97G [00:18<00:00, 268MB/s]
# Downloading shards:  50% 1/2 [00:19<00:19, 19.29s/it]
# model-00002-of-00002.safetensors:   0% 0.00/2.67G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   1% 31.5M/2.67G [00:00<00:09, 264MB/s]
# model-00002-of-00002.safetensors:   3% 73.4M/2.67G [00:00<00:08, 311MB/s]
# model-00002-of-00002.safetensors:   5% 126M/2.67G [00:00<00:07, 359MB/s]
# model-00002-of-00002.safetensors:   7% 178M/2.67G [00:00<00:06, 398MB/s]
# model-00002-of-00002.safetensors:   9% 231M/2.67G [00:00<00:06, 377MB/s]
# model-00002-of-00002.safetensors:  10% 273M/2.67G [00:00<00:06, 370MB/s]
# model-00002-of-00002.safetensors:  12% 325M/2.67G [00:00<00:05, 401MB/s]
# model-00002-of-00002.safetensors:  14% 367M/2.67G [00:00<00:05, 403MB/s]
# model-00002-of-00002.safetensors:  15% 409M/2.67G [00:01<00:06, 376MB/s]
# model-00002-of-00002.safetensors:  17% 451M/2.67G [00:01<00:06, 369MB/s]
# model-00002-of-00002.safetensors:  18% 493M/2.67G [00:01<00:06, 361MB/s]
# model-00002-of-00002.safetensors:  20% 535M/2.67G [00:01<00:06, 353MB/s]
# model-00002-of-00002.safetensors:  22% 577M/2.67G [00:01<00:08, 235MB/s]
# model-00002-of-00002.safetensors:  23% 608M/2.67G [00:01<00:08, 246MB/s]
# model-00002-of-00002.safetensors:  24% 640M/2.67G [00:02<00:10, 185MB/s]
# model-00002-of-00002.safetensors:  25% 671M/2.67G [00:02<00:11, 181MB/s]
# model-00002-of-00002.safetensors:  27% 724M/2.67G [00:02<00:08, 238MB/s]
# model-00002-of-00002.safetensors:  29% 776M/2.67G [00:02<00:06, 289MB/s]
# model-00002-of-00002.safetensors:  31% 818M/2.67G [00:02<00:05, 317MB/s]
# model-00002-of-00002.safetensors:  32% 860M/2.67G [00:02<00:07, 257MB/s]
# model-00002-of-00002.safetensors:  34% 912M/2.67G [00:03<00:05, 302MB/s]
# model-00002-of-00002.safetensors:  36% 965M/2.67G [00:03<00:04, 344MB/s]
# model-00002-of-00002.safetensors:  38% 1.02G/2.67G [00:03<00:04, 386MB/s]
# model-00002-of-00002.safetensors:  40% 1.07G/2.67G [00:03<00:03, 419MB/s]
# model-00002-of-00002.safetensors:  42% 1.12G/2.67G [00:03<00:03, 412MB/s]
# model-00002-of-00002.safetensors:  44% 1.18G/2.67G [00:03<00:03, 449MB/s]
# model-00002-of-00002.safetensors:  46% 1.24G/2.67G [00:03<00:03, 413MB/s]
# model-00002-of-00002.safetensors:  48% 1.29G/2.67G [00:03<00:03, 416MB/s]
# model-00002-of-00002.safetensors:  50% 1.34G/2.67G [00:03<00:03, 424MB/s]
# model-00002-of-00002.safetensors:  52% 1.39G/2.67G [00:04<00:02, 431MB/s]
# model-00002-of-00002.safetensors:  54% 1.45G/2.67G [00:04<00:02, 429MB/s]
# model-00002-of-00002.safetensors:  56% 1.50G/2.67G [00:04<00:02, 404MB/s]
# model-00002-of-00002.safetensors:  58% 1.54G/2.67G [00:04<00:02, 378MB/s]
# model-00002-of-00002.safetensors:  60% 1.59G/2.67G [00:04<00:02, 399MB/s]
# model-00002-of-00002.safetensors:  62% 1.65G/2.67G [00:04<00:02, 408MB/s]
# model-00002-of-00002.safetensors:  63% 1.69G/2.67G [00:04<00:02, 347MB/s]
# model-00002-of-00002.safetensors:  65% 1.73G/2.67G [00:05<00:02, 330MB/s]
# model-00002-of-00002.safetensors:  66% 1.77G/2.67G [00:05<00:02, 335MB/s]
# model-00002-of-00002.safetensors:  68% 1.81G/2.67G [00:05<00:02, 325MB/s]
# model-00002-of-00002.safetensors:  70% 1.86G/2.67G [00:05<00:02, 326MB/s]
# model-00002-of-00002.safetensors:  71% 1.90G/2.67G [00:05<00:02, 305MB/s]
# model-00002-of-00002.safetensors:  73% 1.94G/2.67G [00:05<00:02, 318MB/s]
# model-00002-of-00002.safetensors:  74% 1.98G/2.67G [00:05<00:02, 338MB/s]
# model-00002-of-00002.safetensors:  76% 2.03G/2.67G [00:05<00:01, 374MB/s]
# model-00002-of-00002.safetensors:  78% 2.08G/2.67G [00:06<00:01, 381MB/s]
# model-00002-of-00002.safetensors:  80% 2.13G/2.67G [00:06<00:01, 401MB/s]
# model-00002-of-00002.safetensors:  81% 2.17G/2.67G [00:06<00:01, 392MB/s]
# model-00002-of-00002.safetensors:  83% 2.22G/2.67G [00:06<00:01, 408MB/s]
# model-00002-of-00002.safetensors:  85% 2.28G/2.67G [00:06<00:00, 418MB/s]
# model-00002-of-00002.safetensors:  87% 2.32G/2.67G [00:06<00:00, 418MB/s]
# model-00002-of-00002.safetensors:  88% 2.36G/2.67G [00:06<00:00, 402MB/s]
# model-00002-of-00002.safetensors:  90% 2.41G/2.67G [00:06<00:00, 394MB/s]
# model-00002-of-00002.safetensors:  92% 2.45G/2.67G [00:07<00:00, 371MB/s]
# model-00002-of-00002.safetensors:  93% 2.50G/2.67G [00:07<00:00, 371MB/s]
# model-00002-of-00002.safetensors:  95% 2.54G/2.67G [00:07<00:00, 377MB/s]
# model-00002-of-00002.safetensors:  97% 2.58G/2.67G [00:07<00:00, 383MB/s]
# model-00002-of-00002.safetensors: 100% 2.67G/2.67G [00:07<00:00, 354MB/s]
# Downloading shards: 100% 2/2 [00:27<00:00, 13.54s/it]
# Loading checkpoint shards: 100% 2/2 [00:04<00:00,  2.43s/it]
# generation_config.json: 100% 181/181 [00:00<00:00, 811kB/s]
# Downloading readme: 100% 9.00k/9.00k [00:00<00:00, 28.1kB/s]
# Downloading data: 100% 190k/190k [00:00<00:00, 700kB/s]
# Downloading data: 100% 204k/204k [00:00<00:00, 692kB/s]
# Downloading data: 100% 55.7k/55.7k [00:00<00:00, 217kB/s]
# Generating train split: 100% 1119/1119 [00:00<00:00, 161647.19 examples/s]
# Generating test split: 100% 1172/1172 [00:00<00:00, 292794.35 examples/s]
# Generating validation split: 100% 299/299 [00:00<00:00, 141753.92 examples/s]
# Downloading readme: 100% 10.5k/10.5k [00:00<00:00, 45.0kB/s]
# Downloading data: 100% 4.15M/4.15M [00:00<00:00, 6.20MB/s]
# Downloading data: 100% 45.3k/45.3k [00:00<00:00, 95.0kB/s]
# Generating test split: 100% 12032/12032 [00:00<00:00, 296847.56 examples/s]
# Generating validation split: 100% 70/70 [00:00<00:00, 30637.72 examples/s]
# Downloading builder script: 100% 5.86k/5.86k [00:00<00:00, 23.6kB/s]
# Downloading readme: 100% 1.11k/1.11k [00:00<00:00, 4.51kB/s]
# Downloading data: 100% 166M/166M [00:00<00:00, 178MB/s]
# Generating test split: 163 examples [00:00, 1763.87 examples/s]
# Generating validation split: 18 examples [00:00, 3299.86 examples/s]
# Generating dev split: 5 examples [00:00, 51.67 examples/s]
# Generating test split: 237 examples [00:00, 2284.12 examples/s]
# Generating validation split: 26 examples [00:00, 3693.92 examples/s]
# Generating dev split: 5 examples [00:00, 57.81 examples/s]
# Generating test split: 108 examples [00:00, 1239.71 examples/s]
# Generating validation split: 11 examples [00:00, 1942.22 examples/s]
# Generating dev split: 5 examples [00:00, 57.41 examples/s]
# Generating test split: 324 examples [00:00, 3103.02 examples/s]
# Generating validation split: 35 examples [00:00, 5773.19 examples/s]
# Generating dev split: 5 examples [00:00, 57.90 examples/s]
# Generating test split: 1534 examples [00:00, 8187.85 examples/s]
# Generating validation split: 170 examples [00:00, 10775.27 examples/s]
# Generating dev split: 5 examples [00:00, 57.09 examples/s]
# Generating test split: 311 examples [00:00, 3186.83 examples/s]
# Generating validation split: 34 examples [00:00, 7279.92 examples/s]
# Generating dev split: 5 examples [00:00, 58.24 examples/s]
# Generating test split: 204 examples [00:00, 2101.89 examples/s]
# Generating validation split: 22 examples [00:00, 3316.25 examples/s]
# Generating dev split: 5 examples [00:00, 59.20 examples/s]
# Generating test split: 895 examples [00:00, 6592.84 examples/s]
# Generating validation split: 100 examples [00:00, 10455.70 examples/s]
# Generating dev split: 5 examples [00:00, 58.49 examples/s]
# Generating test split: 126 examples [00:00, 1373.01 examples/s]
# Generating validation split: 14 examples [00:00, 3222.67 examples/s]
# Generating dev split: 5 examples [00:00, 58.97 examples/s]
# Generating test split: 121 examples [00:00, 1343.23 examples/s]
# Generating validation split: 13 examples [00:00, 2982.33 examples/s]
# Generating dev split: 5 examples [00:00, 58.02 examples/s]
# Generating test split: 171 examples [00:00, 1864.73 examples/s]
# Generating validation split: 19 examples [00:00, 4294.43 examples/s]
# Generating dev split: 5 examples [00:00, 56.96 examples/s]
# Generating test split: 165 examples [00:00, 1784.14 examples/s]
# Generating validation split: 18 examples [00:00, 2842.85 examples/s]
# Generating dev split: 5 examples [00:00, 57.97 examples/s]
# Generating test split: 346 examples [00:00, 3316.99 examples/s]
# Generating validation split: 38 examples [00:00, 5187.76 examples/s]
# Generating dev split: 5 examples [00:00, 57.36 examples/s]
# Generating test split: 545 examples [00:00, 4914.76 examples/s]
# Generating validation split: 60 examples [00:00, 7317.14 examples/s]
# Generating dev split: 5 examples [00:00, 57.36 examples/s]
# Generating test split: 245 examples [00:00, 2593.60 examples/s]
# Generating validation split: 27 examples [00:00, 3892.83 examples/s]
# Generating dev split: 5 examples [00:00, 58.42 examples/s]
# Generating test split: 100 examples [00:00, 1089.44 examples/s]
# Generating validation split: 11 examples [00:00, 2735.20 examples/s]
# Generating dev split: 5 examples [00:00, 56.81 examples/s]
# Generating test split: 612 examples [00:00, 5238.91 examples/s]
# Generating validation split: 69 examples [00:00, 6977.02 examples/s]
# Generating dev split: 5 examples [00:00, 54.71 examples/s]
# Generating test split: 110 examples [00:00, 1240.53 examples/s]
# Generating validation split: 12 examples [00:00, 2414.34 examples/s]
# Generating dev split: 5 examples [00:00, 58.36 examples/s]
# Generating test split: 198 examples [00:00, 2059.28 examples/s]
# Generating validation split: 22 examples [00:00, 6007.86 examples/s]
# Generating dev split: 5 examples [00:00, 57.23 examples/s]
# Generating test split: 114 examples [00:00, 1309.98 examples/s]
# Generating validation split: 12 examples [00:00, 3018.21 examples/s]
# Generating dev split: 5 examples [00:00, 58.23 examples/s]
# Generating test split: 193 examples [00:00, 2150.41 examples/s]
# Generating validation split: 21 examples [00:00, 5336.26 examples/s]
# Generating dev split: 5 examples [00:00, 58.85 examples/s]
# Generating test split: 201 examples [00:00, 2197.72 examples/s]
# Generating validation split: 22 examples [00:00, 3610.83 examples/s]
# Generating dev split: 5 examples [00:00, 58.63 examples/s]
# Generating test split: 390 examples [00:00, 3815.38 examples/s]
# Generating validation split: 43 examples [00:00, 7323.77 examples/s]
# Generating dev split: 5 examples [00:00, 59.27 examples/s]
# Generating test split: 131 examples [00:00, 1528.40 examples/s]
# Generating validation split: 12 examples [00:00, 2688.37 examples/s]
# Generating dev split: 5 examples [00:00, 58.68 examples/s]
# Generating test split: 238 examples [00:00, 2474.71 examples/s]
# Generating validation split: 26 examples [00:00, 4306.27 examples/s]
# Generating dev split: 5 examples [00:00, 58.21 examples/s]
# Generating test split: 234 examples [00:00, 2476.21 examples/s]
# Generating validation split: 25 examples [00:00, 4386.98 examples/s]
# Generating dev split: 5 examples [00:00, 59.38 examples/s]
# Generating test split: 100 examples [00:00, 1128.53 examples/s]
# Generating validation split: 11 examples [00:00, 3431.31 examples/s]
# Generating dev split: 5 examples [00:00, 58.30 examples/s]
# Generating test split: 100 examples [00:00, 1204.19 examples/s]
# Generating validation split: 10 examples [00:00, 3045.97 examples/s]
# Generating dev split: 5 examples [00:00, 56.77 examples/s]
# Generating test split: 783 examples [00:00, 6188.69 examples/s]
# Generating validation split: 86 examples [00:00, 11151.96 examples/s]
# Generating dev split: 5 examples [00:00, 58.15 examples/s]
# Generating test split: 100 examples [00:00, 1147.29 examples/s]
# Generating validation split: 11 examples [00:00, 3384.74 examples/s]
# Generating dev split: 5 examples [00:00, 58.19 examples/s]
# Generating test split: 265 examples [00:00, 2628.18 examples/s]
# Generating validation split: 29 examples [00:00, 4980.75 examples/s]
# Generating dev split: 5 examples [00:00, 58.37 examples/s]
# Generating test split: 103 examples [00:00, 1207.68 examples/s]
# Generating validation split: 11 examples [00:00, 2463.55 examples/s]
# Generating dev split: 5 examples [00:00, 59.35 examples/s]
# Generating test split: 306 examples [00:00, 3152.70 examples/s]
# Generating validation split: 33 examples [00:00, 5757.57 examples/s]
# Generating dev split: 5 examples [00:00, 57.73 examples/s]
# Generating test split: 166 examples [00:00, 1890.12 examples/s]
# Generating validation split: 18 examples [00:00, 3558.85 examples/s]
# Generating dev split: 5 examples [00:00, 58.50 examples/s]
# Generating test split: 282 examples [00:00, 2724.94 examples/s]
# Generating validation split: 31 examples [00:00, 4352.25 examples/s]
# Generating dev split: 5 examples [00:00, 59.39 examples/s]
# Generating test split: 223 examples [00:00, 2429.15 examples/s]
# Generating validation split: 23 examples [00:00, 4477.14 examples/s]
# Generating dev split: 5 examples [00:00, 59.71 examples/s]
# Generating test split: 173 examples [00:00, 1924.05 examples/s]
# Generating validation split: 22 examples [00:00, 4906.66 examples/s]
# Generating dev split: 5 examples [00:00, 59.55 examples/s]
# Generating test split: 272 examples [00:00, 2757.04 examples/s]
# Generating validation split: 31 examples [00:00, 4992.07 examples/s]
# Generating dev split: 5 examples [00:00, 58.35 examples/s]
# Generating test split: 203 examples [00:00, 2220.45 examples/s]
# Generating validation split: 22 examples [00:00, 3889.02 examples/s]
# Generating dev split: 5 examples [00:00, 60.10 examples/s]
# Generating test split: 100 examples [00:00, 1130.28 examples/s]
# Generating validation split: 11 examples [00:00, 2622.18 examples/s]
# Generating dev split: 5 examples [00:00, 59.87 examples/s]
# Generating test split: 151 examples [00:00, 1680.45 examples/s]
# Generating validation split: 17 examples [00:00, 3695.04 examples/s]
# Generating dev split: 5 examples [00:00, 58.19 examples/s]
# Generating test split: 102 examples [00:00, 1162.34 examples/s]
# Generating validation split: 11 examples [00:00, 3027.38 examples/s]
# Generating dev split: 5 examples [00:00, 58.99 examples/s]
# Generating test split: 310 examples [00:00, 3247.50 examples/s]
# Generating validation split: 32 examples [00:00, 6711.22 examples/s]
# Generating dev split: 5 examples [00:00, 60.00 examples/s]
# Generating test split: 235 examples [00:00, 2550.19 examples/s]
# Generating validation split: 26 examples [00:00, 6662.10 examples/s]
# Generating dev split: 5 examples [00:00, 58.99 examples/s]
# Generating test split: 145 examples [00:00, 1656.23 examples/s]
# Generating validation split: 16 examples [00:00, 3885.86 examples/s]
# Generating dev split: 5 examples [00:00, 58.70 examples/s]
# Generating test split: 100 examples [00:00, 1179.81 examples/s]
# Generating validation split: 8 examples [00:00, 1547.71 examples/s]
# Generating dev split: 5 examples [00:00, 58.34 examples/s]
# Generating test split: 378 examples [00:00, 3648.89 examples/s]
# Generating validation split: 41 examples [00:00, 6223.68 examples/s]
# Generating dev split: 5 examples [00:00, 59.51 examples/s]
# Generating test split: 100 examples [00:00, 1164.57 examples/s]
# Generating validation split: 11 examples [00:00, 2538.51 examples/s]
# Generating dev split: 5 examples [00:00, 58.67 examples/s]
# Generating test split: 216 examples [00:00, 2223.40 examples/s]
# Generating validation split: 23 examples [00:00, 4591.79 examples/s]
# Generating dev split: 5 examples [00:00, 57.08 examples/s]
# Generating test split: 270 examples [00:00, 2869.94 examples/s]
# Generating validation split: 29 examples [00:00, 6284.09 examples/s]
# Generating dev split: 5 examples [00:00, 59.17 examples/s]
# Generating test split: 100 examples [00:00, 1175.74 examples/s]
# Generating validation split: 11 examples [00:00, 3008.24 examples/s]
# Generating dev split: 5 examples [00:00, 59.49 examples/s]
# Generating test split: 152 examples [00:00, 1738.62 examples/s]
# Generating validation split: 16 examples [00:00, 4779.83 examples/s]
# Generating dev split: 5 examples [00:00, 56.94 examples/s]
# Generating test split: 144 examples [00:00, 1673.64 examples/s]
# Generating validation split: 16 examples [00:00, 2902.76 examples/s]
# Generating dev split: 5 examples [00:00, 59.09 examples/s]
# Generating test split: 100 examples [00:00, 1128.06 examples/s]
# Generating validation split: 11 examples [00:00, 2240.11 examples/s]
# Generating dev split: 5 examples [00:00, 59.16 examples/s]
# Generating test split: 112 examples [00:00, 1316.69 examples/s]
# Generating validation split: 11 examples [00:00, 3140.09 examples/s]
# Generating dev split: 5 examples [00:00, 58.72 examples/s]
# Generating test split: 135 examples [00:00, 1550.26 examples/s]
# Generating validation split: 14 examples [00:00, 4092.29 examples/s]
# Generating dev split: 5 examples [00:00, 59.36 examples/s]
# Generating test split: 100 examples [00:00, 1161.73 examples/s]
# Generating validation split: 9 examples [00:00, 2836.54 examples/s]
# Generating dev split: 5 examples [00:00, 59.67 examples/s]
# 2024-08-22:10:39:24,130 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_computer_science from None to 0
# 2024-08-22:10:39:24,131 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,131 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_anatomy from None to 0
# 2024-08-22:10:39:24,131 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,131 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_machine_learning from None to 0
# 2024-08-22:10:39:24,131 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,131 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_computer_science from None to 0
# 2024-08-22:10:39:24,131 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,131 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_biology from None to 0
# 2024-08-22:10:39:24,131 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,131 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_astronomy from None to 0
# 2024-08-22:10:39:24,131 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,131 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_abstract_algebra from None to 0
# 2024-08-22:10:39:24,131 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,131 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_mathematics from None to 0
# 2024-08-22:10:39:24,131 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,131 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_statistics from None to 0
# 2024-08-22:10:39:24,131 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,131 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_computer_security from None to 0
# 2024-08-22:10:39:24,131 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,131 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_elementary_mathematics from None to 0
# 2024-08-22:10:39:24,131 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,131 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_chemistry from None to 0
# 2024-08-22:10:39:24,131 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,131 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_electrical_engineering from None to 0
# 2024-08-22:10:39:24,131 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,131 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_conceptual_physics from None to 0
# 2024-08-22:10:39:24,131 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,131 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_biology from None to 0
# 2024-08-22:10:39:24,132 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,132 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_physics from None to 0
# 2024-08-22:10:39:24,132 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,132 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_physics from None to 0
# 2024-08-22:10:39:24,132 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,132 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_mathematics from None to 0
# 2024-08-22:10:39:24,132 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,132 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_chemistry from None to 0
# 2024-08-22:10:39:24,132 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,132 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_professional_medicine from None to 0
# 2024-08-22:10:39:24,132 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,132 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_medicine from None to 0
# 2024-08-22:10:39:24,132 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,132 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_human_aging from None to 0
# 2024-08-22:10:39:24,132 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,132 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_professional_accounting from None to 0
# 2024-08-22:10:39:24,132 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,132 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_virology from None to 0
# 2024-08-22:10:39:24,132 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,132 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_nutrition from None to 0
# 2024-08-22:10:39:24,132 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,132 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_management from None to 0
# 2024-08-22:10:39:24,132 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,132 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_clinical_knowledge from None to 0
# 2024-08-22:10:39:24,132 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,132 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_medical_genetics from None to 0
# 2024-08-22:10:39:24,132 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,132 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_miscellaneous from None to 0
# 2024-08-22:10:39:24,132 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,132 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_global_facts from None to 0
# 2024-08-22:10:39:24,133 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,133 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_business_ethics from None to 0
# 2024-08-22:10:39:24,133 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,133 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_marketing from None to 0
# 2024-08-22:10:39:24,133 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,133 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_microeconomics from None to 0
# 2024-08-22:10:39:24,133 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,133 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_human_sexuality from None to 0
# 2024-08-22:10:39:24,133 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,133 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_macroeconomics from None to 0
# 2024-08-22:10:39:24,133 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,133 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_sociology from None to 0
# 2024-08-22:10:39:24,133 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,133 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_government_and_politics from None to 0
# 2024-08-22:10:39:24,133 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,133 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_econometrics from None to 0
# 2024-08-22:10:39:24,133 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,133 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_geography from None to 0
# 2024-08-22:10:39:24,133 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,133 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_public_relations from None to 0
# 2024-08-22:10:39:24,133 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,133 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_professional_psychology from None to 0
# 2024-08-22:10:39:24,133 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,133 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_us_foreign_policy from None to 0
# 2024-08-22:10:39:24,133 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,133 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_security_studies from None to 0
# 2024-08-22:10:39:24,133 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,133 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_psychology from None to 0
# 2024-08-22:10:39:24,133 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,134 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_moral_disputes from None to 0
# 2024-08-22:10:39:24,134 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,134 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_european_history from None to 0
# 2024-08-22:10:39:24,134 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,134 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_world_religions from None to 0
# 2024-08-22:10:39:24,134 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,134 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_international_law from None to 0
# 2024-08-22:10:39:24,134 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,134 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_formal_logic from None to 0
# 2024-08-22:10:39:24,134 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,134 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_moral_scenarios from None to 0
# 2024-08-22:10:39:24,134 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,134 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_us_history from None to 0
# 2024-08-22:10:39:24,134 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,134 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_philosophy from None to 0
# 2024-08-22:10:39:24,134 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,134 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_professional_law from None to 0
# 2024-08-22:10:39:24,134 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,134 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_prehistory from None to 0
# 2024-08-22:10:39:24,134 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,134 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_jurisprudence from None to 0
# 2024-08-22:10:39:24,134 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,134 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_world_history from None to 0
# 2024-08-22:10:39:24,134 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,134 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_logical_fallacies from None to 0
# 2024-08-22:10:39:24,134 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,134 WARNING  [evaluator.py:265] Overwriting default num_fewshot of leaderboard_mmlu_pro from 5 to 0
# 2024-08-22:10:39:24,134 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,134 WARNING  [evaluator.py:265] Overwriting default num_fewshot of arc_challenge from None to 0
# 2024-08-22:10:39:24,135 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-22:10:39:24,135 WARNING  [huggingface.py:469] model.chat_template was called with the chat_template set to False or None. Therefore no chat template will be applied. Make sure this is an intended behavior.
# 2024-08-22:10:39:24,141 INFO     [task.py:423] Building contexts for mmlu_high_school_computer_science on rank 0...
# 100% 100/100 [00:00<00:00, 581.42it/s]
# 2024-08-22:10:39:24,318 INFO     [task.py:423] Building contexts for mmlu_anatomy on rank 0...
# 100% 135/135 [00:00<00:00, 581.93it/s]
# 2024-08-22:10:39:24,557 INFO     [task.py:423] Building contexts for mmlu_machine_learning on rank 0...
# 100% 112/112 [00:00<00:00, 576.21it/s]
# 2024-08-22:10:39:24,758 INFO     [task.py:423] Building contexts for mmlu_college_computer_science on rank 0...
# 100% 100/100 [00:00<00:00, 582.60it/s]
# 2024-08-22:10:39:24,935 INFO     [task.py:423] Building contexts for mmlu_college_biology on rank 0...
# 100% 144/144 [00:00<00:00, 590.33it/s]
# 2024-08-22:10:39:25,186 INFO     [task.py:423] Building contexts for mmlu_astronomy on rank 0...
# 100% 152/152 [00:00<00:00, 591.71it/s]
# 2024-08-22:10:39:25,451 INFO     [task.py:423] Building contexts for mmlu_abstract_algebra on rank 0...
# 100% 100/100 [00:00<00:00, 591.93it/s]
# 2024-08-22:10:39:25,626 INFO     [task.py:423] Building contexts for mmlu_high_school_mathematics on rank 0...
# 100% 270/270 [00:00<00:00, 584.25it/s]
# 2024-08-22:10:39:26,101 INFO     [task.py:423] Building contexts for mmlu_high_school_statistics on rank 0...
# 100% 216/216 [00:00<00:00, 592.48it/s]
# 2024-08-22:10:39:26,477 INFO     [task.py:423] Building contexts for mmlu_computer_security on rank 0...
# 100% 100/100 [00:00<00:00, 585.79it/s]
# 2024-08-22:10:39:26,653 INFO     [task.py:423] Building contexts for mmlu_elementary_mathematics on rank 0...
# 100% 378/378 [00:00<00:00, 587.98it/s]
# 2024-08-22:10:39:27,315 INFO     [task.py:423] Building contexts for mmlu_college_chemistry on rank 0...
# 100% 100/100 [00:00<00:00, 589.26it/s]
# 2024-08-22:10:39:27,490 INFO     [task.py:423] Building contexts for mmlu_electrical_engineering on rank 0...
# 100% 145/145 [00:00<00:00, 588.06it/s]
# 2024-08-22:10:39:27,744 INFO     [task.py:423] Building contexts for mmlu_conceptual_physics on rank 0...
# 100% 235/235 [00:00<00:00, 587.52it/s]
# 2024-08-22:10:39:28,156 INFO     [task.py:423] Building contexts for mmlu_high_school_biology on rank 0...
# 100% 310/310 [00:00<00:00, 594.01it/s]
# 2024-08-22:10:39:28,693 INFO     [task.py:423] Building contexts for mmlu_college_physics on rank 0...
# 100% 102/102 [00:00<00:00, 593.58it/s]
# 2024-08-22:10:39:28,870 INFO     [task.py:423] Building contexts for mmlu_high_school_physics on rank 0...
# 100% 151/151 [00:00<00:00, 590.81it/s]
# 2024-08-22:10:39:29,134 INFO     [task.py:423] Building contexts for mmlu_college_mathematics on rank 0...
# 100% 100/100 [00:00<00:00, 580.51it/s]
# 2024-08-22:10:39:29,311 INFO     [task.py:423] Building contexts for mmlu_high_school_chemistry on rank 0...
# 100% 203/203 [00:00<00:00, 593.02it/s]
# 2024-08-22:10:39:29,664 INFO     [task.py:423] Building contexts for mmlu_professional_medicine on rank 0...
# 100% 272/272 [00:00<00:00, 592.57it/s]
# 2024-08-22:10:39:30,137 INFO     [task.py:423] Building contexts for mmlu_college_medicine on rank 0...
# 100% 173/173 [00:00<00:00, 596.09it/s]
# 2024-08-22:10:39:30,436 INFO     [task.py:423] Building contexts for mmlu_human_aging on rank 0...
# 100% 223/223 [00:00<00:00, 586.25it/s]
# 2024-08-22:10:39:30,828 INFO     [task.py:423] Building contexts for mmlu_professional_accounting on rank 0...
# 100% 282/282 [00:00<00:00, 591.84it/s]
# 2024-08-22:10:39:31,319 INFO     [task.py:423] Building contexts for mmlu_virology on rank 0...
# 100% 166/166 [00:00<00:00, 596.05it/s]
# 2024-08-22:10:39:31,606 INFO     [task.py:423] Building contexts for mmlu_nutrition on rank 0...
# 100% 306/306 [00:00<00:00, 591.74it/s]
# 2024-08-22:10:39:32,138 INFO     [task.py:423] Building contexts for mmlu_management on rank 0...
# 100% 103/103 [00:00<00:00, 587.61it/s]
# 2024-08-22:10:39:32,319 INFO     [task.py:423] Building contexts for mmlu_clinical_knowledge on rank 0...
# 100% 265/265 [00:00<00:00, 591.78it/s]
# 2024-08-22:10:39:32,780 INFO     [task.py:423] Building contexts for mmlu_medical_genetics on rank 0...
# 100% 100/100 [00:00<00:00, 595.95it/s]
# 2024-08-22:10:39:32,953 INFO     [task.py:423] Building contexts for mmlu_miscellaneous on rank 0...
# 100% 783/783 [00:01<00:00, 593.50it/s]
# 2024-08-22:10:39:34,309 INFO     [task.py:423] Building contexts for mmlu_global_facts on rank 0...
# 100% 100/100 [00:00<00:00, 464.42it/s]
# 2024-08-22:10:39:34,530 INFO     [task.py:423] Building contexts for mmlu_business_ethics on rank 0...
# 100% 100/100 [00:00<00:00, 591.26it/s]
# 2024-08-22:10:39:34,704 INFO     [task.py:423] Building contexts for mmlu_marketing on rank 0...
# 100% 234/234 [00:00<00:00, 586.55it/s]
# 2024-08-22:10:39:35,115 INFO     [task.py:423] Building contexts for mmlu_high_school_microeconomics on rank 0...
# 100% 238/238 [00:00<00:00, 595.57it/s]
# 2024-08-22:10:39:35,526 INFO     [task.py:423] Building contexts for mmlu_human_sexuality on rank 0...
# 100% 131/131 [00:00<00:00, 588.99it/s]
# 2024-08-22:10:39:35,756 INFO     [task.py:423] Building contexts for mmlu_high_school_macroeconomics on rank 0...
# 100% 390/390 [00:00<00:00, 591.71it/s]
# 2024-08-22:10:39:36,433 INFO     [task.py:423] Building contexts for mmlu_sociology on rank 0...
# 100% 201/201 [00:00<00:00, 593.49it/s]
# 2024-08-22:10:39:36,782 INFO     [task.py:423] Building contexts for mmlu_high_school_government_and_politics on rank 0...
# 100% 193/193 [00:00<00:00, 591.13it/s]
# 2024-08-22:10:39:37,119 INFO     [task.py:423] Building contexts for mmlu_econometrics on rank 0...
# 100% 114/114 [00:00<00:00, 596.65it/s]
# 2024-08-22:10:39:37,316 INFO     [task.py:423] Building contexts for mmlu_high_school_geography on rank 0...
# 100% 198/198 [00:00<00:00, 597.19it/s]
# 2024-08-22:10:39:37,657 INFO     [task.py:423] Building contexts for mmlu_public_relations on rank 0...
# 100% 110/110 [00:00<00:00, 592.43it/s]
# 2024-08-22:10:39:37,849 INFO     [task.py:423] Building contexts for mmlu_professional_psychology on rank 0...
# 100% 612/612 [00:01<00:00, 588.50it/s]
# 2024-08-22:10:39:38,918 INFO     [task.py:423] Building contexts for mmlu_us_foreign_policy on rank 0...
# 100% 100/100 [00:00<00:00, 586.79it/s]
# 2024-08-22:10:39:39,094 INFO     [task.py:423] Building contexts for mmlu_security_studies on rank 0...
# 100% 245/245 [00:00<00:00, 589.76it/s]
# 2024-08-22:10:39:39,521 INFO     [task.py:423] Building contexts for mmlu_high_school_psychology on rank 0...
# 100% 545/545 [00:01<00:00, 438.68it/s]
# 2024-08-22:10:39:40,790 INFO     [task.py:423] Building contexts for mmlu_moral_disputes on rank 0...
# 100% 346/346 [00:00<00:00, 591.29it/s]
# 2024-08-22:10:39:41,392 INFO     [task.py:423] Building contexts for mmlu_high_school_european_history on rank 0...
# 100% 165/165 [00:00<00:00, 585.16it/s]
# 2024-08-22:10:39:41,683 INFO     [task.py:423] Building contexts for mmlu_world_religions on rank 0...
# 100% 171/171 [00:00<00:00, 588.74it/s]
# 2024-08-22:10:39:41,982 INFO     [task.py:423] Building contexts for mmlu_international_law on rank 0...
# 100% 121/121 [00:00<00:00, 586.10it/s]
# 2024-08-22:10:39:42,195 INFO     [task.py:423] Building contexts for mmlu_formal_logic on rank 0...
# 100% 126/126 [00:00<00:00, 578.09it/s]
# 2024-08-22:10:39:42,420 INFO     [task.py:423] Building contexts for mmlu_moral_scenarios on rank 0...
# 100% 895/895 [00:01<00:00, 581.53it/s]
# 2024-08-22:10:39:44,004 INFO     [task.py:423] Building contexts for mmlu_high_school_us_history on rank 0...
# 100% 204/204 [00:00<00:00, 581.05it/s]
# 2024-08-22:10:39:44,366 INFO     [task.py:423] Building contexts for mmlu_philosophy on rank 0...
# 100% 311/311 [00:00<00:00, 582.66it/s]
# 2024-08-22:10:39:44,916 INFO     [task.py:423] Building contexts for mmlu_professional_law on rank 0...
# 100% 1534/1534 [00:02<00:00, 577.54it/s]
# 2024-08-22:10:39:47,646 INFO     [task.py:423] Building contexts for mmlu_prehistory on rank 0...
# 100% 324/324 [00:00<00:00, 588.51it/s]
# 2024-08-22:10:39:48,212 INFO     [task.py:423] Building contexts for mmlu_jurisprudence on rank 0...
# 100% 108/108 [00:00<00:00, 588.15it/s]
# 2024-08-22:10:39:48,401 INFO     [task.py:423] Building contexts for mmlu_high_school_world_history on rank 0...
# 100% 237/237 [00:00<00:00, 592.14it/s]
# 2024-08-22:10:39:48,814 INFO     [task.py:423] Building contexts for mmlu_logical_fallacies on rank 0...
# 100% 163/163 [00:00<00:00, 589.06it/s]
# 2024-08-22:10:39:49,099 INFO     [task.py:423] Building contexts for leaderboard_mmlu_pro on rank 0...
# 100% 12032/12032 [00:01<00:00, 11003.21it/s]
# 2024-08-22:10:39:51,172 INFO     [task.py:423] Building contexts for arc_challenge on rank 0...
# 100% 1172/1172 [00:01<00:00, 1011.32it/s]
# 2024-08-22:10:39:52,408 INFO     [evaluator.py:463] Running loglikelihood requests
# Running loglikelihood requests:   0% 0/174850 [00:00<?, ?it/s]We detected that you are passing `past_key_values` as a tuple and this is deprecated and will be removed in v4.43. Please use an appropriate `Cache` class (https://huggingface.co/docs/transformers/v4.41.3/en/internal/generation_utils#transformers.Cache)
# You are not running the flash-attention implementation, expect numerical differences.
# Running loglikelihood requests: 100% 174850/174850 [20:13<00:00, 144.13it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2024-08-22:11:02:36,672 INFO     [evaluation_tracker.py:206] Saving results aggregated
# hf (pretrained=microsoft/Phi-3-mini-128k-instruct,dtype=float16), gen_kwargs: (None), limit: None, num_fewshot: 0, batch_size: 4
# |                 Tasks                 |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |---------------------------------------|------:|------|-----:|--------|---|-----:|---|-----:|
# |arc_challenge                          |    1.0|none  |     0|acc     |↑  |0.5802|±  |0.0144|
# |                                       |       |none  |     0|acc_norm|↑  |0.5998|±  |0.0143|
# |leaderboard_mmlu_pro                   |    0.1|none  |     0|acc     |↑  |0.3591|±  |0.0044|
# |mmlu                                   |    2.0|none  |      |acc     |↑  |0.6909|±  |0.0037|
# | - humanities                          |    2.0|none  |      |acc     |↑  |0.6508|±  |0.0067|
# |  - formal_logic                       |    1.0|none  |     0|acc     |↑  |0.6111|±  |0.0436|
# |  - high_school_european_history       |    1.0|none  |     0|acc     |↑  |0.8000|±  |0.0312|
# |  - high_school_us_history             |    1.0|none  |     0|acc     |↑  |0.8676|±  |0.0238|
# |  - high_school_world_history          |    1.0|none  |     0|acc     |↑  |0.8143|±  |0.0253|
# |  - international_law                  |    1.0|none  |     0|acc     |↑  |0.8264|±  |0.0346|
# |  - jurisprudence                      |    1.0|none  |     0|acc     |↑  |0.8241|±  |0.0368|
# |  - logical_fallacies                  |    1.0|none  |     0|acc     |↑  |0.8221|±  |0.0300|
# |  - moral_disputes                     |    1.0|none  |     0|acc     |↑  |0.7543|±  |0.0232|
# |  - moral_scenarios                    |    1.0|none  |     0|acc     |↑  |0.5676|±  |0.0166|
# |  - philosophy                         |    1.0|none  |     0|acc     |↑  |0.7138|±  |0.0257|
# |  - prehistory                         |    1.0|none  |     0|acc     |↑  |0.7747|±  |0.0232|
# |  - professional_law                   |    1.0|none  |     0|acc     |↑  |0.5117|±  |0.0128|
# |  - world_religions                    |    1.0|none  |     0|acc     |↑  |0.7778|±  |0.0319|
# | - other                               |    2.0|none  |      |acc     |↑  |0.7290|±  |0.0077|
# |  - business_ethics                    |    1.0|none  |     0|acc     |↑  |0.7400|±  |0.0441|
# |  - clinical_knowledge                 |    1.0|none  |     0|acc     |↑  |0.7811|±  |0.0254|
# |  - college_medicine                   |    1.0|none  |     0|acc     |↑  |0.6705|±  |0.0358|
# |  - global_facts                       |    1.0|none  |     0|acc     |↑  |0.3900|±  |0.0490|
# |  - human_aging                        |    1.0|none  |     0|acc     |↑  |0.6637|±  |0.0317|
# |  - management                         |    1.0|none  |     0|acc     |↑  |0.8641|±  |0.0339|
# |  - marketing                          |    1.0|none  |     0|acc     |↑  |0.8974|±  |0.0199|
# |  - medical_genetics                   |    1.0|none  |     0|acc     |↑  |0.7500|±  |0.0435|
# |  - miscellaneous                      |    1.0|none  |     0|acc     |↑  |0.8263|±  |0.0135|
# |  - nutrition                          |    1.0|none  |     0|acc     |↑  |0.7288|±  |0.0255|
# |  - professional_accounting            |    1.0|none  |     0|acc     |↑  |0.5674|±  |0.0296|
# |  - professional_medicine              |    1.0|none  |     0|acc     |↑  |0.7206|±  |0.0273|
# |  - virology                           |    1.0|none  |     0|acc     |↑  |0.4880|±  |0.0389|
# | - social sciences                     |    2.0|none  |      |acc     |↑  |0.7946|±  |0.0072|
# |  - econometrics                       |    1.0|none  |     0|acc     |↑  |0.6053|±  |0.0460|
# |  - high_school_geography              |    1.0|none  |     0|acc     |↑  |0.8232|±  |0.0272|
# |  - high_school_government_and_politics|    1.0|none  |     0|acc     |↑  |0.8860|±  |0.0229|
# |  - high_school_macroeconomics         |    1.0|none  |     0|acc     |↑  |0.7308|±  |0.0225|
# |  - high_school_microeconomics         |    1.0|none  |     0|acc     |↑  |0.8487|±  |0.0233|
# |  - high_school_psychology             |    1.0|none  |     0|acc     |↑  |0.8789|±  |0.0140|
# |  - human_sexuality                    |    1.0|none  |     0|acc     |↑  |0.7786|±  |0.0364|
# |  - professional_psychology            |    1.0|none  |     0|acc     |↑  |0.7353|±  |0.0178|
# |  - public_relations                   |    1.0|none  |     0|acc     |↑  |0.7000|±  |0.0439|
# |  - security_studies                   |    1.0|none  |     0|acc     |↑  |0.7918|±  |0.0260|
# |  - sociology                          |    1.0|none  |     0|acc     |↑  |0.8507|±  |0.0252|
# |  - us_foreign_policy                  |    1.0|none  |     0|acc     |↑  |0.8200|±  |0.0386|
# | - stem                                |    2.0|none  |      |acc     |↑  |0.6118|±  |0.0083|
# |  - abstract_algebra                   |    1.0|none  |     0|acc     |↑  |0.3900|±  |0.0490|
# |  - anatomy                            |    1.0|none  |     0|acc     |↑  |0.6296|±  |0.0417|
# |  - astronomy                          |    1.0|none  |     0|acc     |↑  |0.7961|±  |0.0328|
# |  - college_biology                    |    1.0|none  |     0|acc     |↑  |0.8472|±  |0.0301|
# |  - college_chemistry                  |    1.0|none  |     0|acc     |↑  |0.5200|±  |0.0502|
# |  - college_computer_science           |    1.0|none  |     0|acc     |↑  |0.5400|±  |0.0501|
# |  - college_mathematics                |    1.0|none  |     0|acc     |↑  |0.4100|±  |0.0494|
# |  - college_physics                    |    1.0|none  |     0|acc     |↑  |0.4706|±  |0.0497|
# |  - computer_security                  |    1.0|none  |     0|acc     |↑  |0.8100|±  |0.0394|
# |  - conceptual_physics                 |    1.0|none  |     0|acc     |↑  |0.7064|±  |0.0298|
# |  - electrical_engineering             |    1.0|none  |     0|acc     |↑  |0.6345|±  |0.0401|
# |  - elementary_mathematics             |    1.0|none  |     0|acc     |↑  |0.4894|±  |0.0257|
# |  - high_school_biology                |    1.0|none  |     0|acc     |↑  |0.8452|±  |0.0206|
# |  - high_school_chemistry              |    1.0|none  |     0|acc     |↑  |0.6502|±  |0.0336|
# |  - high_school_computer_science       |    1.0|none  |     0|acc     |↑  |0.7100|±  |0.0456|
# |  - high_school_mathematics            |    1.0|none  |     0|acc     |↑  |0.3926|±  |0.0298|
# |  - high_school_physics                |    1.0|none  |     0|acc     |↑  |0.5099|±  |0.0408|
# |  - high_school_statistics             |    1.0|none  |     0|acc     |↑  |0.6250|±  |0.0330|
# |  - machine_learning                   |    1.0|none  |     0|acc     |↑  |0.5357|±  |0.0473|
#
# |      Groups      |Version|Filter|n-shot|Metric|   |Value |   |Stderr|
# |------------------|------:|------|------|------|---|-----:|---|-----:|
# |mmlu              |      2|none  |      |acc   |↑  |0.6909|±  |0.0037|
# | - humanities     |      2|none  |      |acc   |↑  |0.6508|±  |0.0067|
# | - other          |      2|none  |      |acc   |↑  |0.7290|±  |0.0077|
# | - social sciences|      2|none  |      |acc   |↑  |0.7946|±  |0.0072|
# | - stem           |      2|none  |      |acc   |↑  |0.6118|±  |0.0083|

# %% [markdown]
# ###Original Phi-3.5 Mini

# %%
# !lm_eval --model hf --model_args pretrained=microsoft/Phi-3.5-mini-instruct,dtype=float16 --tasks mmlu,arc_challenge,leaderboard_mmlu_pro --device cuda:0 --num_fewshot 0 --batch_size 4 --output_path ./eval/
# Out:
# 2024-08-21 11:19:06.837008: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-21 11:19:06.854233: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-21 11:19:06.875632: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-21 11:19:06.882257: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-21 11:19:06.897697: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-21 11:19:08.088706: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-08-21:11:19:10,063 INFO     [__main__.py:279] Verbosity set to INFO
# 2024-08-21:11:19:11,909 INFO     [__init__.py:491] `group` and `group_alias` keys in tasks' configs will no longer be used in the next release of lm-eval. `tag` will be used to allow to call a collection of tasks just like `group`. `group` will be removed in order to not cause confusion with the new ConfigurableGroup which will be the offical way to create groups with addition of group-wide configuations.
# 2024-08-21:11:19:18,695 INFO     [__main__.py:383] Selected Tasks: ['arc_challenge', 'leaderboard_mmlu_pro', 'mmlu']
# 2024-08-21:11:19:18,696 INFO     [evaluator.py:161] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-08-21:11:19:18,697 INFO     [evaluator.py:198] Initializing hf model, with arguments: {'pretrained': 'microsoft/Phi-3.5-mini-instruct', 'dtype': 'float16'}
# 2024-08-21:11:19:18,739 INFO     [huggingface.py:130] Using device 'cuda:0'
# config.json: 100% 3.45k/3.45k [00:00<00:00, 22.7MB/s]
# tokenizer_config.json: 100% 3.98k/3.98k [00:00<00:00, 25.1MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 65.7MB/s]
# tokenizer.json: 100% 1.84M/1.84M [00:00<00:00, 1.99MB/s]
# added_tokens.json: 100% 306/306 [00:00<00:00, 1.73MB/s]
# special_tokens_map.json: 100% 665/665 [00:00<00:00, 4.71MB/s]
# 2024-08-21:11:19:22,513 INFO     [huggingface.py:366] Model parallel was set to False, max memory was not set, and device map was set to {'': 'cuda:0'}
# model.safetensors.index.json: 100% 16.3k/16.3k [00:00<00:00, 61.3MB/s]
# Downloading shards:   0% 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0% 0.00/4.97G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   1% 31.5M/4.97G [00:00<00:16, 298MB/s]
# model-00001-of-00002.safetensors:   1% 62.9M/4.97G [00:00<00:16, 298MB/s]
# model-00001-of-00002.safetensors:   2% 105M/4.97G [00:00<00:16, 296MB/s]
# model-00001-of-00002.safetensors:   3% 136M/4.97G [00:00<00:18, 266MB/s]
# model-00001-of-00002.safetensors:   4% 178M/4.97G [00:00<00:16, 295MB/s]
# model-00001-of-00002.safetensors:   4% 220M/4.97G [00:00<00:15, 312MB/s]
# model-00001-of-00002.safetensors:   5% 262M/4.97G [00:00<00:14, 328MB/s]
# model-00001-of-00002.safetensors:   6% 304M/4.97G [00:00<00:13, 338MB/s]
# model-00001-of-00002.safetensors:   7% 346M/4.97G [00:01<00:13, 346MB/s]
# model-00001-of-00002.safetensors:   8% 388M/4.97G [00:01<00:16, 278MB/s]
# model-00001-of-00002.safetensors:   8% 419M/4.97G [00:01<00:19, 239MB/s]
# model-00001-of-00002.safetensors:   9% 451M/4.97G [00:01<00:18, 251MB/s]
# model-00001-of-00002.safetensors:  10% 482M/4.97G [00:01<00:17, 263MB/s]
# model-00001-of-00002.safetensors:  11% 524M/4.97G [00:01<00:14, 299MB/s]
# model-00001-of-00002.safetensors:  11% 566M/4.97G [00:01<00:15, 291MB/s]
# model-00001-of-00002.safetensors:  12% 608M/4.97G [00:02<00:14, 306MB/s]
# model-00001-of-00002.safetensors:  13% 650M/4.97G [00:02<00:12, 334MB/s]
# model-00001-of-00002.safetensors:  14% 692M/4.97G [00:02<00:12, 342MB/s]
# model-00001-of-00002.safetensors:  15% 734M/4.97G [00:02<00:12, 352MB/s]
# model-00001-of-00002.safetensors:  16% 776M/4.97G [00:02<00:12, 337MB/s]
# model-00001-of-00002.safetensors:  16% 818M/4.97G [00:02<00:11, 348MB/s]
# model-00001-of-00002.safetensors:  17% 860M/4.97G [00:02<00:12, 327MB/s]
# model-00001-of-00002.safetensors:  18% 902M/4.97G [00:02<00:12, 327MB/s]
# model-00001-of-00002.safetensors:  19% 944M/4.97G [00:03<00:12, 319MB/s]
# model-00001-of-00002.safetensors:  20% 986M/4.97G [00:03<00:12, 310MB/s]
# model-00001-of-00002.safetensors:  21% 1.03G/4.97G [00:03<00:12, 316MB/s]
# model-00001-of-00002.safetensors:  22% 1.07G/4.97G [00:03<00:12, 307MB/s]
# model-00001-of-00002.safetensors:  23% 1.12G/4.97G [00:03<00:11, 341MB/s]
# model-00001-of-00002.safetensors:  23% 1.16G/4.97G [00:03<00:11, 340MB/s]
# model-00001-of-00002.safetensors:  24% 1.21G/4.97G [00:03<00:11, 329MB/s]
# model-00001-of-00002.safetensors:  25% 1.25G/4.97G [00:03<00:10, 339MB/s]
# model-00001-of-00002.safetensors:  26% 1.29G/4.97G [00:04<00:14, 246MB/s]
# model-00001-of-00002.safetensors:  27% 1.32G/4.97G [00:04<00:14, 246MB/s]
# model-00001-of-00002.safetensors:  27% 1.35G/4.97G [00:04<00:13, 260MB/s]
# model-00001-of-00002.safetensors:  28% 1.38G/4.97G [00:04<00:13, 264MB/s]
# model-00001-of-00002.safetensors:  29% 1.43G/4.97G [00:04<00:12, 295MB/s]
# model-00001-of-00002.safetensors:  30% 1.47G/4.97G [00:04<00:11, 307MB/s]
# model-00001-of-00002.safetensors:  30% 1.51G/4.97G [00:04<00:10, 317MB/s]
# model-00001-of-00002.safetensors:  31% 1.55G/4.97G [00:05<00:10, 329MB/s]
# model-00001-of-00002.safetensors:  32% 1.59G/4.97G [00:05<00:09, 341MB/s]
# model-00001-of-00002.safetensors:  33% 1.64G/4.97G [00:05<00:11, 299MB/s]
# model-00001-of-00002.safetensors:  34% 1.68G/4.97G [00:05<00:10, 308MB/s]
# model-00001-of-00002.safetensors:  35% 1.72G/4.97G [00:05<00:10, 305MB/s]
# model-00001-of-00002.safetensors:  35% 1.76G/4.97G [00:05<00:09, 325MB/s]
# model-00001-of-00002.safetensors:  36% 1.80G/4.97G [00:05<00:09, 318MB/s]
# model-00001-of-00002.safetensors:  37% 1.85G/4.97G [00:06<00:09, 319MB/s]
# model-00001-of-00002.safetensors:  38% 1.89G/4.97G [00:06<00:09, 322MB/s]
# model-00001-of-00002.safetensors:  39% 1.93G/4.97G [00:06<00:10, 290MB/s]
# model-00001-of-00002.safetensors:  40% 1.97G/4.97G [00:06<00:09, 311MB/s]
# model-00001-of-00002.safetensors:  40% 2.01G/4.97G [00:06<00:11, 267MB/s]
# model-00001-of-00002.safetensors:  41% 2.06G/4.97G [00:06<00:09, 296MB/s]
# model-00001-of-00002.safetensors:  42% 2.10G/4.97G [00:06<00:09, 309MB/s]
# model-00001-of-00002.safetensors:  43% 2.14G/4.97G [00:07<00:09, 306MB/s]
# model-00001-of-00002.safetensors:  44% 2.18G/4.97G [00:07<00:08, 317MB/s]
# model-00001-of-00002.safetensors:  45% 2.22G/4.97G [00:07<00:08, 319MB/s]
# model-00001-of-00002.safetensors:  46% 2.26G/4.97G [00:07<00:08, 316MB/s]
# model-00001-of-00002.safetensors:  46% 2.31G/4.97G [00:07<00:08, 315MB/s]
# model-00001-of-00002.safetensors:  47% 2.35G/4.97G [00:07<00:08, 327MB/s]
# model-00001-of-00002.safetensors:  48% 2.40G/4.97G [00:07<00:07, 361MB/s]
# model-00001-of-00002.safetensors:  49% 2.45G/4.97G [00:07<00:06, 376MB/s]
# model-00001-of-00002.safetensors:  50% 2.50G/4.97G [00:07<00:06, 382MB/s]
# model-00001-of-00002.safetensors:  51% 2.54G/4.97G [00:08<00:06, 391MB/s]
# model-00001-of-00002.safetensors:  52% 2.58G/4.97G [00:08<00:06, 376MB/s]
# model-00001-of-00002.safetensors:  53% 2.62G/4.97G [00:08<00:06, 381MB/s]
# model-00001-of-00002.safetensors:  54% 2.66G/4.97G [00:08<00:06, 380MB/s]
# model-00001-of-00002.safetensors:  54% 2.71G/4.97G [00:08<00:06, 341MB/s]
# model-00001-of-00002.safetensors:  55% 2.75G/4.97G [00:08<00:06, 336MB/s]
# model-00001-of-00002.safetensors:  56% 2.79G/4.97G [00:08<00:06, 343MB/s]
# model-00001-of-00002.safetensors:  57% 2.83G/4.97G [00:08<00:05, 357MB/s]
# model-00001-of-00002.safetensors:  58% 2.87G/4.97G [00:09<00:06, 347MB/s]
# model-00001-of-00002.safetensors:  59% 2.92G/4.97G [00:09<00:05, 347MB/s]
# model-00001-of-00002.safetensors:  59% 2.96G/4.97G [00:09<00:06, 335MB/s]
# model-00001-of-00002.safetensors:  60% 3.00G/4.97G [00:09<00:05, 349MB/s]
# model-00001-of-00002.safetensors:  61% 3.04G/4.97G [00:09<00:05, 361MB/s]
# model-00001-of-00002.safetensors:  62% 3.08G/4.97G [00:09<00:05, 372MB/s]
# model-00001-of-00002.safetensors:  63% 3.12G/4.97G [00:09<00:05, 352MB/s]
# model-00001-of-00002.safetensors:  64% 3.17G/4.97G [00:09<00:04, 363MB/s]
# model-00001-of-00002.safetensors:  65% 3.21G/4.97G [00:10<00:04, 366MB/s]
# model-00001-of-00002.safetensors:  66% 3.26G/4.97G [00:10<00:06, 256MB/s]
# model-00001-of-00002.safetensors:  66% 3.30G/4.97G [00:10<00:05, 281MB/s]
# model-00001-of-00002.safetensors:  67% 3.34G/4.97G [00:10<00:05, 298MB/s]
# model-00001-of-00002.safetensors:  68% 3.40G/4.97G [00:10<00:04, 325MB/s]
# model-00001-of-00002.safetensors:  69% 3.44G/4.97G [00:10<00:04, 310MB/s]
# model-00001-of-00002.safetensors:  70% 3.48G/4.97G [00:10<00:04, 332MB/s]
# model-00001-of-00002.safetensors:  71% 3.53G/4.97G [00:11<00:03, 368MB/s]
# model-00001-of-00002.safetensors:  72% 3.58G/4.97G [00:11<00:03, 372MB/s]
# model-00001-of-00002.safetensors:  73% 3.63G/4.97G [00:11<00:03, 386MB/s]
# model-00001-of-00002.safetensors:  74% 3.67G/4.97G [00:11<00:03, 394MB/s]
# model-00001-of-00002.safetensors:  75% 3.71G/4.97G [00:11<00:03, 367MB/s]
# model-00001-of-00002.safetensors:  75% 3.75G/4.97G [00:11<00:03, 373MB/s]
# model-00001-of-00002.safetensors:  76% 3.80G/4.97G [00:11<00:03, 356MB/s]
# model-00001-of-00002.safetensors:  77% 3.84G/4.97G [00:11<00:03, 365MB/s]
# model-00001-of-00002.safetensors:  78% 3.88G/4.97G [00:11<00:02, 373MB/s]
# model-00001-of-00002.safetensors:  79% 3.92G/4.97G [00:12<00:03, 318MB/s]
# model-00001-of-00002.safetensors:  80% 3.96G/4.97G [00:12<00:03, 330MB/s]
# model-00001-of-00002.safetensors:  81% 4.01G/4.97G [00:12<00:02, 341MB/s]
# model-00001-of-00002.safetensors:  81% 4.05G/4.97G [00:12<00:02, 341MB/s]
# model-00001-of-00002.safetensors:  82% 4.10G/4.97G [00:12<00:02, 366MB/s]
# model-00001-of-00002.safetensors:  83% 4.14G/4.97G [00:12<00:02, 378MB/s]
# model-00001-of-00002.safetensors:  84% 4.18G/4.97G [00:12<00:02, 365MB/s]
# model-00001-of-00002.safetensors:  85% 4.23G/4.97G [00:12<00:01, 379MB/s]
# model-00001-of-00002.safetensors:  86% 4.27G/4.97G [00:13<00:01, 372MB/s]
# model-00001-of-00002.safetensors:  87% 4.31G/4.97G [00:13<00:01, 370MB/s]
# model-00001-of-00002.safetensors:  88% 4.35G/4.97G [00:13<00:01, 360MB/s]
# model-00001-of-00002.safetensors:  88% 4.39G/4.97G [00:13<00:01, 361MB/s]
# model-00001-of-00002.safetensors:  89% 4.44G/4.97G [00:13<00:01, 372MB/s]
# model-00001-of-00002.safetensors:  90% 4.48G/4.97G [00:13<00:01, 362MB/s]
# model-00001-of-00002.safetensors:  91% 4.52G/4.97G [00:13<00:01, 354MB/s]
# model-00001-of-00002.safetensors:  92% 4.56G/4.97G [00:13<00:01, 360MB/s]
# model-00001-of-00002.safetensors:  93% 4.60G/4.97G [00:14<00:01, 337MB/s]
# model-00001-of-00002.safetensors:  93% 4.65G/4.97G [00:14<00:00, 355MB/s]
# model-00001-of-00002.safetensors:  94% 4.69G/4.97G [00:14<00:00, 369MB/s]
# model-00001-of-00002.safetensors:  95% 4.73G/4.97G [00:14<00:00, 381MB/s]
# model-00001-of-00002.safetensors:  96% 4.77G/4.97G [00:14<00:00, 390MB/s]
# model-00001-of-00002.safetensors:  97% 4.81G/4.97G [00:14<00:00, 388MB/s]
# model-00001-of-00002.safetensors:  98% 4.85G/4.97G [00:14<00:00, 386MB/s]
# model-00001-of-00002.safetensors:  98% 4.90G/4.97G [00:14<00:00, 361MB/s]
# model-00001-of-00002.safetensors: 100% 4.97G/4.97G [00:15<00:00, 330MB/s]
# Downloading shards:  50% 1/2 [00:15<00:15, 15.57s/it]
# model-00002-of-00002.safetensors:   0% 0.00/2.67G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   2% 41.9M/2.67G [00:00<00:07, 369MB/s]
# model-00002-of-00002.safetensors:   3% 83.9M/2.67G [00:00<00:07, 341MB/s]
# model-00002-of-00002.safetensors:   5% 126M/2.67G [00:00<00:07, 335MB/s]
# model-00002-of-00002.safetensors:   6% 168M/2.67G [00:00<00:07, 356MB/s]
# model-00002-of-00002.safetensors:   8% 210M/2.67G [00:00<00:06, 372MB/s]
# model-00002-of-00002.safetensors:  10% 262M/2.67G [00:00<00:05, 411MB/s]
# model-00002-of-00002.safetensors:  12% 315M/2.67G [00:00<00:05, 393MB/s]
# model-00002-of-00002.safetensors:  13% 357M/2.67G [00:00<00:05, 388MB/s]
# model-00002-of-00002.safetensors:  15% 398M/2.67G [00:01<00:05, 394MB/s]
# model-00002-of-00002.safetensors:  17% 451M/2.67G [00:01<00:05, 412MB/s]
# model-00002-of-00002.safetensors:  18% 493M/2.67G [00:01<00:05, 394MB/s]
# model-00002-of-00002.safetensors:  20% 535M/2.67G [00:01<00:05, 388MB/s]
# model-00002-of-00002.safetensors:  22% 577M/2.67G [00:01<00:05, 373MB/s]
# model-00002-of-00002.safetensors:  23% 619M/2.67G [00:01<00:05, 384MB/s]
# model-00002-of-00002.safetensors:  25% 661M/2.67G [00:01<00:05, 363MB/s]
# model-00002-of-00002.safetensors:  26% 703M/2.67G [00:01<00:05, 361MB/s]
# model-00002-of-00002.safetensors:  28% 755M/2.67G [00:01<00:04, 391MB/s]
# model-00002-of-00002.safetensors:  30% 807M/2.67G [00:02<00:04, 395MB/s]
# model-00002-of-00002.safetensors:  32% 849M/2.67G [00:02<00:05, 364MB/s]
# model-00002-of-00002.safetensors:  33% 891M/2.67G [00:02<00:05, 354MB/s]
# model-00002-of-00002.safetensors:  35% 933M/2.67G [00:02<00:05, 293MB/s]
# model-00002-of-00002.safetensors:  37% 975M/2.67G [00:02<00:05, 310MB/s]
# model-00002-of-00002.safetensors:  38% 1.03G/2.67G [00:02<00:04, 349MB/s]
# model-00002-of-00002.safetensors:  40% 1.08G/2.67G [00:02<00:04, 379MB/s]
# model-00002-of-00002.safetensors:  42% 1.13G/2.67G [00:03<00:03, 396MB/s]
# model-00002-of-00002.safetensors:  44% 1.17G/2.67G [00:03<00:03, 392MB/s]
# model-00002-of-00002.safetensors:  46% 1.22G/2.67G [00:03<00:03, 399MB/s]
# model-00002-of-00002.safetensors:  47% 1.26G/2.67G [00:03<00:03, 404MB/s]
# model-00002-of-00002.safetensors:  49% 1.30G/2.67G [00:03<00:03, 407MB/s]
# model-00002-of-00002.safetensors:  51% 1.35G/2.67G [00:03<00:03, 419MB/s]
# model-00002-of-00002.safetensors:  53% 1.41G/2.67G [00:03<00:02, 425MB/s]
# model-00002-of-00002.safetensors:  55% 1.46G/2.67G [00:03<00:03, 399MB/s]
# model-00002-of-00002.safetensors:  56% 1.50G/2.67G [00:03<00:03, 385MB/s]
# model-00002-of-00002.safetensors:  58% 1.54G/2.67G [00:04<00:02, 378MB/s]
# model-00002-of-00002.safetensors:  59% 1.58G/2.67G [00:04<00:02, 384MB/s]
# model-00002-of-00002.safetensors:  61% 1.64G/2.67G [00:04<00:02, 379MB/s]
# model-00002-of-00002.safetensors:  63% 1.68G/2.67G [00:04<00:02, 353MB/s]
# model-00002-of-00002.safetensors:  64% 1.72G/2.67G [00:04<00:02, 355MB/s]
# model-00002-of-00002.safetensors:  66% 1.76G/2.67G [00:04<00:02, 345MB/s]
# model-00002-of-00002.safetensors:  68% 1.80G/2.67G [00:04<00:02, 343MB/s]
# model-00002-of-00002.safetensors:  69% 1.85G/2.67G [00:04<00:02, 326MB/s]
# model-00002-of-00002.safetensors:  71% 1.89G/2.67G [00:05<00:02, 327MB/s]
# model-00002-of-00002.safetensors:  72% 1.93G/2.67G [00:05<00:02, 339MB/s]
# model-00002-of-00002.safetensors:  74% 1.97G/2.67G [00:05<00:02, 347MB/s]
# model-00002-of-00002.safetensors:  75% 2.01G/2.67G [00:05<00:01, 360MB/s]
# model-00002-of-00002.safetensors:  77% 2.06G/2.67G [00:05<00:01, 313MB/s]
# model-00002-of-00002.safetensors:  79% 2.10G/2.67G [00:05<00:01, 321MB/s]
# model-00002-of-00002.safetensors:  80% 2.14G/2.67G [00:05<00:01, 289MB/s]
# model-00002-of-00002.safetensors:  81% 2.17G/2.67G [00:06<00:01, 281MB/s]
# model-00002-of-00002.safetensors:  83% 2.21G/2.67G [00:06<00:01, 310MB/s]
# model-00002-of-00002.safetensors:  85% 2.26G/2.67G [00:06<00:01, 344MB/s]
# model-00002-of-00002.safetensors:  86% 2.31G/2.67G [00:06<00:01, 342MB/s]
# model-00002-of-00002.safetensors:  88% 2.35G/2.67G [00:06<00:00, 327MB/s]
# model-00002-of-00002.safetensors:  90% 2.39G/2.67G [00:06<00:00, 304MB/s]
# model-00002-of-00002.safetensors:  91% 2.43G/2.67G [00:06<00:00, 328MB/s]
# model-00002-of-00002.safetensors:  93% 2.47G/2.67G [00:06<00:00, 329MB/s]
# model-00002-of-00002.safetensors:  94% 2.52G/2.67G [00:07<00:00, 316MB/s]
# model-00002-of-00002.safetensors:  96% 2.56G/2.67G [00:07<00:00, 316MB/s]
# model-00002-of-00002.safetensors:  97% 2.60G/2.67G [00:07<00:00, 290MB/s]
# model-00002-of-00002.safetensors: 100% 2.67G/2.67G [00:07<00:00, 353MB/s]
# Downloading shards: 100% 2/2 [00:23<00:00, 11.81s/it]
# Loading checkpoint shards: 100% 2/2 [00:04<00:00,  2.23s/it]
# generation_config.json: 100% 195/195 [00:00<00:00, 1.34MB/s]
# 2024-08-21:11:22:38,434 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_astronomy from None to 0
# 2024-08-21:11:22:38,434 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,434 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_elementary_mathematics from None to 0
# 2024-08-21:11:22:38,434 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,434 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_computer_science from None to 0
# 2024-08-21:11:22:38,435 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,435 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_biology from None to 0
# 2024-08-21:11:22:38,435 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,435 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_chemistry from None to 0
# 2024-08-21:11:22:38,435 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,435 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_computer_security from None to 0
# 2024-08-21:11:22:38,435 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,435 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_conceptual_physics from None to 0
# 2024-08-21:11:22:38,435 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,435 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_electrical_engineering from None to 0
# 2024-08-21:11:22:38,435 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,435 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_physics from None to 0
# 2024-08-21:11:22:38,435 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,435 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_biology from None to 0
# 2024-08-21:11:22:38,435 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,435 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_abstract_algebra from None to 0
# 2024-08-21:11:22:38,435 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,435 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_chemistry from None to 0
# 2024-08-21:11:22:38,435 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,435 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_mathematics from None to 0
# 2024-08-21:11:22:38,435 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,435 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_statistics from None to 0
# 2024-08-21:11:22:38,435 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,435 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_physics from None to 0
# 2024-08-21:11:22:38,435 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,435 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_anatomy from None to 0
# 2024-08-21:11:22:38,435 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,435 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_machine_learning from None to 0
# 2024-08-21:11:22:38,435 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,435 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_mathematics from None to 0
# 2024-08-21:11:22:38,436 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,436 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_computer_science from None to 0
# 2024-08-21:11:22:38,436 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,436 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_medicine from None to 0
# 2024-08-21:11:22:38,436 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,436 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_global_facts from None to 0
# 2024-08-21:11:22:38,436 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,436 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_medical_genetics from None to 0
# 2024-08-21:11:22:38,436 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,436 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_human_aging from None to 0
# 2024-08-21:11:22:38,436 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,436 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_virology from None to 0
# 2024-08-21:11:22:38,436 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,436 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_professional_medicine from None to 0
# 2024-08-21:11:22:38,436 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,436 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_professional_accounting from None to 0
# 2024-08-21:11:22:38,436 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,436 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_business_ethics from None to 0
# 2024-08-21:11:22:38,436 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,436 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_management from None to 0
# 2024-08-21:11:22:38,436 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,436 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_nutrition from None to 0
# 2024-08-21:11:22:38,436 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,436 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_clinical_knowledge from None to 0
# 2024-08-21:11:22:38,436 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,436 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_miscellaneous from None to 0
# 2024-08-21:11:22:38,436 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,436 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_marketing from None to 0
# 2024-08-21:11:22:38,436 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,437 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_microeconomics from None to 0
# 2024-08-21:11:22:38,437 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,437 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_geography from None to 0
# 2024-08-21:11:22:38,437 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,437 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_security_studies from None to 0
# 2024-08-21:11:22:38,437 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,437 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_us_foreign_policy from None to 0
# 2024-08-21:11:22:38,437 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,437 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_sociology from None to 0
# 2024-08-21:11:22:38,437 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,437 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_econometrics from None to 0
# 2024-08-21:11:22:38,437 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,437 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_psychology from None to 0
# 2024-08-21:11:22:38,437 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,437 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_public_relations from None to 0
# 2024-08-21:11:22:38,437 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,437 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_government_and_politics from None to 0
# 2024-08-21:11:22:38,437 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,437 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_professional_psychology from None to 0
# 2024-08-21:11:22:38,437 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,437 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_human_sexuality from None to 0
# 2024-08-21:11:22:38,437 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,437 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_macroeconomics from None to 0
# 2024-08-21:11:22:38,437 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,437 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_european_history from None to 0
# 2024-08-21:11:22:38,437 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,437 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_international_law from None to 0
# 2024-08-21:11:22:38,437 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,437 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_prehistory from None to 0
# 2024-08-21:11:22:38,438 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,438 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_world_religions from None to 0
# 2024-08-21:11:22:38,438 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,438 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_formal_logic from None to 0
# 2024-08-21:11:22:38,438 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,438 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_world_history from None to 0
# 2024-08-21:11:22:38,438 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,438 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_philosophy from None to 0
# 2024-08-21:11:22:38,438 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,438 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_professional_law from None to 0
# 2024-08-21:11:22:38,438 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,438 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_jurisprudence from None to 0
# 2024-08-21:11:22:38,438 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,438 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_logical_fallacies from None to 0
# 2024-08-21:11:22:38,438 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,438 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_moral_disputes from None to 0
# 2024-08-21:11:22:38,438 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,438 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_moral_scenarios from None to 0
# 2024-08-21:11:22:38,438 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,438 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_us_history from None to 0
# 2024-08-21:11:22:38,438 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,438 WARNING  [evaluator.py:265] Overwriting default num_fewshot of leaderboard_mmlu_pro from 5 to 0
# 2024-08-21:11:22:38,438 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,438 WARNING  [evaluator.py:265] Overwriting default num_fewshot of arc_challenge from None to 0
# 2024-08-21:11:22:38,438 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:22:38,438 WARNING  [huggingface.py:469] model.chat_template was called with the chat_template set to False or None. Therefore no chat template will be applied. Make sure this is an intended behavior.
# 2024-08-21:11:22:38,445 INFO     [task.py:423] Building contexts for mmlu_astronomy on rank 0...
# 100% 152/152 [00:00<00:00, 588.66it/s]
# 2024-08-21:11:22:38,710 INFO     [task.py:423] Building contexts for mmlu_elementary_mathematics on rank 0...
# 100% 378/378 [00:00<00:00, 593.83it/s]
# 2024-08-21:11:22:39,364 INFO     [task.py:423] Building contexts for mmlu_high_school_computer_science on rank 0...
# 100% 100/100 [00:00<00:00, 592.05it/s]
# 2024-08-21:11:22:39,538 INFO     [task.py:423] Building contexts for mmlu_college_biology on rank 0...
# 100% 144/144 [00:00<00:00, 595.86it/s]
# 2024-08-21:11:22:39,787 INFO     [task.py:423] Building contexts for mmlu_high_school_chemistry on rank 0...
# 100% 203/203 [00:00<00:00, 594.29it/s]
# 2024-08-21:11:22:40,139 INFO     [task.py:423] Building contexts for mmlu_computer_security on rank 0...
# 100% 100/100 [00:00<00:00, 598.62it/s]
# 2024-08-21:11:22:40,311 INFO     [task.py:423] Building contexts for mmlu_conceptual_physics on rank 0...
# 100% 235/235 [00:00<00:00, 595.53it/s]
# 2024-08-21:11:22:40,717 INFO     [task.py:423] Building contexts for mmlu_electrical_engineering on rank 0...
# 100% 145/145 [00:00<00:00, 599.55it/s]
# 2024-08-21:11:22:40,966 INFO     [task.py:423] Building contexts for mmlu_high_school_physics on rank 0...
# 100% 151/151 [00:00<00:00, 595.23it/s]
# 2024-08-21:11:22:41,227 INFO     [task.py:423] Building contexts for mmlu_high_school_biology on rank 0...
# 100% 310/310 [00:00<00:00, 597.76it/s]
# 2024-08-21:11:22:41,760 INFO     [task.py:423] Building contexts for mmlu_abstract_algebra on rank 0...
# 100% 100/100 [00:00<00:00, 599.12it/s]
# 2024-08-21:11:22:41,933 INFO     [task.py:423] Building contexts for mmlu_college_chemistry on rank 0...
# 100% 100/100 [00:00<00:00, 598.66it/s]
# 2024-08-21:11:22:42,105 INFO     [task.py:423] Building contexts for mmlu_high_school_mathematics on rank 0...
# 100% 270/270 [00:00<00:00, 599.37it/s]
# 2024-08-21:11:22:42,568 INFO     [task.py:423] Building contexts for mmlu_high_school_statistics on rank 0...
# 100% 216/216 [00:00<00:00, 598.96it/s]
# 2024-08-21:11:22:42,939 INFO     [task.py:423] Building contexts for mmlu_college_physics on rank 0...
# 100% 102/102 [00:00<00:00, 596.30it/s]
# 2024-08-21:11:22:43,116 INFO     [task.py:423] Building contexts for mmlu_anatomy on rank 0...
# 100% 135/135 [00:00<00:00, 599.89it/s]
# 2024-08-21:11:22:43,348 INFO     [task.py:423] Building contexts for mmlu_machine_learning on rank 0...
# 100% 112/112 [00:00<00:00, 595.51it/s]
# 2024-08-21:11:22:43,541 INFO     [task.py:423] Building contexts for mmlu_college_mathematics on rank 0...
# 100% 100/100 [00:00<00:00, 589.41it/s]
# 2024-08-21:11:22:43,716 INFO     [task.py:423] Building contexts for mmlu_college_computer_science on rank 0...
# 100% 100/100 [00:00<00:00, 597.90it/s]
# 2024-08-21:11:22:43,889 INFO     [task.py:423] Building contexts for mmlu_college_medicine on rank 0...
# 100% 173/173 [00:00<00:00, 595.16it/s]
# 2024-08-21:11:22:44,188 INFO     [task.py:423] Building contexts for mmlu_global_facts on rank 0...
# 100% 100/100 [00:00<00:00, 595.92it/s]
# 2024-08-21:11:22:44,362 INFO     [task.py:423] Building contexts for mmlu_medical_genetics on rank 0...
# 100% 100/100 [00:00<00:00, 589.58it/s]
# 2024-08-21:11:22:44,536 INFO     [task.py:423] Building contexts for mmlu_human_aging on rank 0...
# 100% 223/223 [00:00<00:00, 595.49it/s]
# 2024-08-21:11:22:44,922 INFO     [task.py:423] Building contexts for mmlu_virology on rank 0...
# 100% 166/166 [00:00<00:00, 592.78it/s]
# 2024-08-21:11:22:45,210 INFO     [task.py:423] Building contexts for mmlu_professional_medicine on rank 0...
# 100% 272/272 [00:00<00:00, 592.13it/s]
# 2024-08-21:11:22:45,683 INFO     [task.py:423] Building contexts for mmlu_professional_accounting on rank 0...
# 100% 282/282 [00:00<00:00, 594.08it/s]
# 2024-08-21:11:22:46,171 INFO     [task.py:423] Building contexts for mmlu_business_ethics on rank 0...
# 100% 100/100 [00:00<00:00, 601.05it/s]
# 2024-08-21:11:22:46,343 INFO     [task.py:423] Building contexts for mmlu_management on rank 0...
# 100% 103/103 [00:00<00:00, 590.27it/s]
# 2024-08-21:11:22:46,523 INFO     [task.py:423] Building contexts for mmlu_nutrition on rank 0...
# 100% 306/306 [00:00<00:00, 598.35it/s]
# 2024-08-21:11:22:47,049 INFO     [task.py:423] Building contexts for mmlu_clinical_knowledge on rank 0...
# 100% 265/265 [00:00<00:00, 594.44it/s]
# 2024-08-21:11:22:47,507 INFO     [task.py:423] Building contexts for mmlu_miscellaneous on rank 0...
# 100% 783/783 [00:01<00:00, 598.20it/s]
# 2024-08-21:11:22:48,852 INFO     [task.py:423] Building contexts for mmlu_marketing on rank 0...
# 100% 234/234 [00:00<00:00, 598.63it/s]
# 2024-08-21:11:22:49,254 INFO     [task.py:423] Building contexts for mmlu_high_school_microeconomics on rank 0...
# 100% 238/238 [00:00<00:00, 595.23it/s]
# 2024-08-21:11:22:49,665 INFO     [task.py:423] Building contexts for mmlu_high_school_geography on rank 0...
# 100% 198/198 [00:00<00:00, 593.22it/s]
# 2024-08-21:11:22:50,008 INFO     [task.py:423] Building contexts for mmlu_security_studies on rank 0...
# 100% 245/245 [00:00<00:00, 594.10it/s]
# 2024-08-21:11:22:50,433 INFO     [task.py:423] Building contexts for mmlu_us_foreign_policy on rank 0...
# 100% 100/100 [00:00<00:00, 583.89it/s]
# 2024-08-21:11:22:50,610 INFO     [task.py:423] Building contexts for mmlu_sociology on rank 0...
# 100% 201/201 [00:00<00:00, 591.24it/s]
# 2024-08-21:11:22:50,960 INFO     [task.py:423] Building contexts for mmlu_econometrics on rank 0...
# 100% 114/114 [00:00<00:00, 593.57it/s]
# 2024-08-21:11:22:51,159 INFO     [task.py:423] Building contexts for mmlu_high_school_psychology on rank 0...
# 100% 545/545 [00:00<00:00, 591.45it/s]
# 2024-08-21:11:22:52,106 INFO     [task.py:423] Building contexts for mmlu_public_relations on rank 0...
# 100% 110/110 [00:00<00:00, 595.55it/s]
# 2024-08-21:11:22:52,296 INFO     [task.py:423] Building contexts for mmlu_high_school_government_and_politics on rank 0...
# 100% 193/193 [00:00<00:00, 593.34it/s]
# 2024-08-21:11:22:52,631 INFO     [task.py:423] Building contexts for mmlu_professional_psychology on rank 0...
# 100% 612/612 [00:01<00:00, 593.31it/s]
# 2024-08-21:11:22:53,692 INFO     [task.py:423] Building contexts for mmlu_human_sexuality on rank 0...
# 100% 131/131 [00:00<00:00, 591.06it/s]
# 2024-08-21:11:22:53,921 INFO     [task.py:423] Building contexts for mmlu_high_school_macroeconomics on rank 0...
# 100% 390/390 [00:00<00:00, 407.03it/s]
# 2024-08-21:11:22:54,898 INFO     [task.py:423] Building contexts for mmlu_high_school_european_history on rank 0...
# 100% 165/165 [00:00<00:00, 588.69it/s]
# 2024-08-21:11:22:55,187 INFO     [task.py:423] Building contexts for mmlu_international_law on rank 0...
# 100% 121/121 [00:00<00:00, 594.49it/s]
# 2024-08-21:11:22:55,397 INFO     [task.py:423] Building contexts for mmlu_prehistory on rank 0...
# 100% 324/324 [00:00<00:00, 597.65it/s]
# 2024-08-21:11:22:55,958 INFO     [task.py:423] Building contexts for mmlu_world_religions on rank 0...
# 100% 171/171 [00:00<00:00, 600.56it/s]
# 2024-08-21:11:22:56,251 INFO     [task.py:423] Building contexts for mmlu_formal_logic on rank 0...
# 100% 126/126 [00:00<00:00, 599.47it/s]
# 2024-08-21:11:22:56,468 INFO     [task.py:423] Building contexts for mmlu_high_school_world_history on rank 0...
# 100% 237/237 [00:00<00:00, 594.76it/s]
# 2024-08-21:11:22:56,878 INFO     [task.py:423] Building contexts for mmlu_philosophy on rank 0...
# 100% 311/311 [00:00<00:00, 595.63it/s]
# 2024-08-21:11:22:57,415 INFO     [task.py:423] Building contexts for mmlu_professional_law on rank 0...
# 100% 1534/1534 [00:02<00:00, 593.39it/s]
# 2024-08-21:11:23:00,072 INFO     [task.py:423] Building contexts for mmlu_jurisprudence on rank 0...
# 100% 108/108 [00:00<00:00, 601.17it/s]
# 2024-08-21:11:23:00,257 INFO     [task.py:423] Building contexts for mmlu_logical_fallacies on rank 0...
# 100% 163/163 [00:00<00:00, 596.29it/s]
# 2024-08-21:11:23:00,538 INFO     [task.py:423] Building contexts for mmlu_moral_disputes on rank 0...
# 100% 346/346 [00:00<00:00, 595.31it/s]
# 2024-08-21:11:23:01,136 INFO     [task.py:423] Building contexts for mmlu_moral_scenarios on rank 0...
# 100% 895/895 [00:01<00:00, 596.51it/s]
# 2024-08-21:11:23:02,677 INFO     [task.py:423] Building contexts for mmlu_high_school_us_history on rank 0...
# 100% 204/204 [00:00<00:00, 596.90it/s]
# 2024-08-21:11:23:03,029 INFO     [task.py:423] Building contexts for leaderboard_mmlu_pro on rank 0...
# 100% 12032/12032 [00:01<00:00, 10856.47it/s]
# 2024-08-21:11:23:05,099 INFO     [task.py:423] Building contexts for arc_challenge on rank 0...
# 100% 1172/1172 [00:01<00:00, 1009.28it/s]
# 2024-08-21:11:23:06,336 INFO     [evaluator.py:463] Running loglikelihood requests
# Running loglikelihood requests:   0% 0/174850 [00:00<?, ?it/s]We detected that you are passing `past_key_values` as a tuple and this is deprecated and will be removed in v4.43. Please use an appropriate `Cache` class (https://huggingface.co/docs/transformers/v4.41.3/en/internal/generation_utils#transformers.Cache)
# You are not running the flash-attention implementation, expect numerical differences.
# Running loglikelihood requests: 100% 174850/174850 [19:58<00:00, 145.91it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2024-08-21:11:45:35,423 INFO     [evaluation_tracker.py:206] Saving results aggregated
# hf (pretrained=microsoft/Phi-3.5-mini-instruct,dtype=float16), gen_kwargs: (None), limit: None, num_fewshot: 0, batch_size: 4
# |                 Tasks                 |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |---------------------------------------|------:|------|-----:|--------|---|-----:|---|-----:|
# |arc_challenge                          |    1.0|none  |     0|acc     |↑  |0.5922|±  |0.0144|
# |                                       |       |none  |     0|acc_norm|↑  |0.6092|±  |0.0143|
# |leaderboard_mmlu_pro                   |    0.1|none  |     0|acc     |↑  |0.3616|±  |0.0044|
# |mmlu                                   |    2.0|none  |      |acc     |↑  |0.6876|±  |0.0037|
# | - humanities                          |    2.0|none  |      |acc     |↑  |0.6476|±  |0.0067|
# |  - formal_logic                       |    1.0|none  |     0|acc     |↑  |0.6111|±  |0.0436|
# |  - high_school_european_history       |    1.0|none  |     0|acc     |↑  |0.7939|±  |0.0316|
# |  - high_school_us_history             |    1.0|none  |     0|acc     |↑  |0.8480|±  |0.0252|
# |  - high_school_world_history          |    1.0|none  |     0|acc     |↑  |0.8186|±  |0.0251|
# |  - international_law                  |    1.0|none  |     0|acc     |↑  |0.8347|±  |0.0339|
# |  - jurisprudence                      |    1.0|none  |     0|acc     |↑  |0.8241|±  |0.0368|
# |  - logical_fallacies                  |    1.0|none  |     0|acc     |↑  |0.8528|±  |0.0278|
# |  - moral_disputes                     |    1.0|none  |     0|acc     |↑  |0.7486|±  |0.0234|
# |  - moral_scenarios                    |    1.0|none  |     0|acc     |↑  |0.5508|±  |0.0166|
# |  - philosophy                         |    1.0|none  |     0|acc     |↑  |0.7235|±  |0.0254|
# |  - prehistory                         |    1.0|none  |     0|acc     |↑  |0.7562|±  |0.0239|
# |  - professional_law                   |    1.0|none  |     0|acc     |↑  |0.5130|±  |0.0128|
# |  - world_religions                    |    1.0|none  |     0|acc     |↑  |0.7836|±  |0.0316|
# | - other                               |    2.0|none  |      |acc     |↑  |0.7264|±  |0.0077|
# |  - business_ethics                    |    1.0|none  |     0|acc     |↑  |0.7400|±  |0.0441|
# |  - clinical_knowledge                 |    1.0|none  |     0|acc     |↑  |0.7736|±  |0.0258|
# |  - college_medicine                   |    1.0|none  |     0|acc     |↑  |0.6590|±  |0.0361|
# |  - global_facts                       |    1.0|none  |     0|acc     |↑  |0.3600|±  |0.0482|
# |  - human_aging                        |    1.0|none  |     0|acc     |↑  |0.6726|±  |0.0315|
# |  - management                         |    1.0|none  |     0|acc     |↑  |0.8058|±  |0.0392|
# |  - marketing                          |    1.0|none  |     0|acc     |↑  |0.8590|±  |0.0228|
# |  - medical_genetics                   |    1.0|none  |     0|acc     |↑  |0.7500|±  |0.0435|
# |  - miscellaneous                      |    1.0|none  |     0|acc     |↑  |0.8429|±  |0.0130|
# |  - nutrition                          |    1.0|none  |     0|acc     |↑  |0.7549|±  |0.0246|
# |  - professional_accounting            |    1.0|none  |     0|acc     |↑  |0.5567|±  |0.0296|
# |  - professional_medicine              |    1.0|none  |     0|acc     |↑  |0.6985|±  |0.0279|
# |  - virology                           |    1.0|none  |     0|acc     |↑  |0.4880|±  |0.0389|
# | - social sciences                     |    2.0|none  |      |acc     |↑  |0.7917|±  |0.0072|
# |  - econometrics                       |    1.0|none  |     0|acc     |↑  |0.5702|±  |0.0466|
# |  - high_school_geography              |    1.0|none  |     0|acc     |↑  |0.8232|±  |0.0272|
# |  - high_school_government_and_politics|    1.0|none  |     0|acc     |↑  |0.8860|±  |0.0229|
# |  - high_school_macroeconomics         |    1.0|none  |     0|acc     |↑  |0.7436|±  |0.0221|
# |  - high_school_microeconomics         |    1.0|none  |     0|acc     |↑  |0.8697|±  |0.0219|
# |  - high_school_psychology             |    1.0|none  |     0|acc     |↑  |0.8917|±  |0.0133|
# |  - human_sexuality                    |    1.0|none  |     0|acc     |↑  |0.7481|±  |0.0381|
# |  - professional_psychology            |    1.0|none  |     0|acc     |↑  |0.7271|±  |0.0180|
# |  - public_relations                   |    1.0|none  |     0|acc     |↑  |0.6455|±  |0.0458|
# |  - security_studies                   |    1.0|none  |     0|acc     |↑  |0.7878|±  |0.0262|
# |  - sociology                          |    1.0|none  |     0|acc     |↑  |0.8259|±  |0.0268|
# |  - us_foreign_policy                  |    1.0|none  |     0|acc     |↑  |0.8100|±  |0.0394|
# | - stem                                |    2.0|none  |      |acc     |↑  |0.6074|±  |0.0083|
# |  - abstract_algebra                   |    1.0|none  |     0|acc     |↑  |0.4600|±  |0.0501|
# |  - anatomy                            |    1.0|none  |     0|acc     |↑  |0.6519|±  |0.0412|
# |  - astronomy                          |    1.0|none  |     0|acc     |↑  |0.7763|±  |0.0339|
# |  - college_biology                    |    1.0|none  |     0|acc     |↑  |0.8403|±  |0.0306|
# |  - college_chemistry                  |    1.0|none  |     0|acc     |↑  |0.5300|±  |0.0502|
# |  - college_computer_science           |    1.0|none  |     0|acc     |↑  |0.5800|±  |0.0496|
# |  - college_mathematics                |    1.0|none  |     0|acc     |↑  |0.4000|±  |0.0492|
# |  - college_physics                    |    1.0|none  |     0|acc     |↑  |0.4314|±  |0.0493|
# |  - computer_security                  |    1.0|none  |     0|acc     |↑  |0.8100|±  |0.0394|
# |  - conceptual_physics                 |    1.0|none  |     0|acc     |↑  |0.6809|±  |0.0305|
# |  - electrical_engineering             |    1.0|none  |     0|acc     |↑  |0.5931|±  |0.0409|
# |  - elementary_mathematics             |    1.0|none  |     0|acc     |↑  |0.5238|±  |0.0257|
# |  - high_school_biology                |    1.0|none  |     0|acc     |↑  |0.8387|±  |0.0209|
# |  - high_school_chemistry              |    1.0|none  |     0|acc     |↑  |0.5862|±  |0.0347|
# |  - high_school_computer_science       |    1.0|none  |     0|acc     |↑  |0.6600|±  |0.0476|
# |  - high_school_mathematics            |    1.0|none  |     0|acc     |↑  |0.3778|±  |0.0296|
# |  - high_school_physics                |    1.0|none  |     0|acc     |↑  |0.5430|±  |0.0407|
# |  - high_school_statistics             |    1.0|none  |     0|acc     |↑  |0.6389|±  |0.0328|
# |  - machine_learning                   |    1.0|none  |     0|acc     |↑  |0.4911|±  |0.0475|
#
# |      Groups      |Version|Filter|n-shot|Metric|   |Value |   |Stderr|
# |------------------|------:|------|------|------|---|-----:|---|-----:|
# |mmlu              |      2|none  |      |acc   |↑  |0.6876|±  |0.0037|
# | - humanities     |      2|none  |      |acc   |↑  |0.6476|±  |0.0067|
# | - other          |      2|none  |      |acc   |↑  |0.7264|±  |0.0077|
# | - social sciences|      2|none  |      |acc   |↑  |0.7917|±  |0.0072|
# | - stem           |      2|none  |      |acc   |↑  |0.6074|±  |0.0083|

# %% [markdown]
# ###Phi-3.5 Mini Quantized to 4-bit with AutoRound

# %%
# !lm_eval --model hf --model_args pretrained=kaitchup/Phi-3.5-Mini-instruct-AutoRound-4bit,dtype=float16 --tasks mmlu,arc_challenge,leaderboard_mmlu_pro --device cuda:0 --num_fewshot 0 --batch_size 4 --output_path ./eval/
# Out:
# 2024-08-21 11:45:46.772098: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-21 11:45:46.788982: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-21 11:45:46.810504: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-21 11:45:46.816977: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-21 11:45:46.831932: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-21 11:45:48.039175: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-08-21:11:45:50,054 INFO     [__main__.py:279] Verbosity set to INFO
# 2024-08-21:11:45:51,906 INFO     [__init__.py:491] `group` and `group_alias` keys in tasks' configs will no longer be used in the next release of lm-eval. `tag` will be used to allow to call a collection of tasks just like `group`. `group` will be removed in order to not cause confusion with the new ConfigurableGroup which will be the offical way to create groups with addition of group-wide configuations.
# 2024-08-21:11:45:58,665 INFO     [__main__.py:383] Selected Tasks: ['arc_challenge', 'leaderboard_mmlu_pro', 'mmlu']
# 2024-08-21:11:45:58,667 INFO     [evaluator.py:161] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-08-21:11:45:58,667 INFO     [evaluator.py:198] Initializing hf model, with arguments: {'pretrained': 'kaitchup/Phi-3.5-Mini-instruct-AutoRound-4bit', 'dtype': 'float16'}
# 2024-08-21:11:45:58,716 INFO     [huggingface.py:130] Using device 'cuda:0'
# 2024-08-21:11:45:59,296 INFO     [huggingface.py:366] Model parallel was set to False, max memory was not set, and device map was set to {'': 'cuda:0'}
# 2024-08-21:11:45:59,725 WARNING  [qlinear_cuda.py:18] CUDA extension not installed.
# 2024-08-21:11:45:59,726 WARNING  [qlinear_cuda_old.py:17] CUDA extension not installed.
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:4674: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(
# 2024-08-21:11:48:47,365 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_astronomy from None to 0
# 2024-08-21:11:48:47,365 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,365 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_elementary_mathematics from None to 0
# 2024-08-21:11:48:47,366 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,366 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_computer_science from None to 0
# 2024-08-21:11:48:47,366 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,366 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_biology from None to 0
# 2024-08-21:11:48:47,366 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,366 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_chemistry from None to 0
# 2024-08-21:11:48:47,366 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,366 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_computer_security from None to 0
# 2024-08-21:11:48:47,366 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,366 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_conceptual_physics from None to 0
# 2024-08-21:11:48:47,366 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,366 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_electrical_engineering from None to 0
# 2024-08-21:11:48:47,366 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,366 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_physics from None to 0
# 2024-08-21:11:48:47,366 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,366 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_biology from None to 0
# 2024-08-21:11:48:47,366 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,366 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_abstract_algebra from None to 0
# 2024-08-21:11:48:47,366 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,366 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_chemistry from None to 0
# 2024-08-21:11:48:47,366 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,366 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_mathematics from None to 0
# 2024-08-21:11:48:47,366 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,366 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_statistics from None to 0
# 2024-08-21:11:48:47,366 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,366 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_physics from None to 0
# 2024-08-21:11:48:47,366 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,366 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_anatomy from None to 0
# 2024-08-21:11:48:47,367 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,367 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_machine_learning from None to 0
# 2024-08-21:11:48:47,367 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,367 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_mathematics from None to 0
# 2024-08-21:11:48:47,367 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,367 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_computer_science from None to 0
# 2024-08-21:11:48:47,367 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,367 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_medicine from None to 0
# 2024-08-21:11:48:47,367 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,367 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_global_facts from None to 0
# 2024-08-21:11:48:47,367 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,367 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_medical_genetics from None to 0
# 2024-08-21:11:48:47,367 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,367 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_human_aging from None to 0
# 2024-08-21:11:48:47,367 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,367 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_virology from None to 0
# 2024-08-21:11:48:47,367 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,367 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_professional_medicine from None to 0
# 2024-08-21:11:48:47,367 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,367 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_professional_accounting from None to 0
# 2024-08-21:11:48:47,367 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,367 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_business_ethics from None to 0
# 2024-08-21:11:48:47,367 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,367 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_management from None to 0
# 2024-08-21:11:48:47,367 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,367 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_nutrition from None to 0
# 2024-08-21:11:48:47,367 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,367 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_clinical_knowledge from None to 0
# 2024-08-21:11:48:47,368 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,368 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_miscellaneous from None to 0
# 2024-08-21:11:48:47,368 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,368 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_marketing from None to 0
# 2024-08-21:11:48:47,368 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,368 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_microeconomics from None to 0
# 2024-08-21:11:48:47,368 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,368 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_geography from None to 0
# 2024-08-21:11:48:47,368 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,368 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_security_studies from None to 0
# 2024-08-21:11:48:47,368 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,368 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_us_foreign_policy from None to 0
# 2024-08-21:11:48:47,368 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,368 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_sociology from None to 0
# 2024-08-21:11:48:47,368 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,368 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_econometrics from None to 0
# 2024-08-21:11:48:47,368 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,368 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_psychology from None to 0
# 2024-08-21:11:48:47,368 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,368 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_public_relations from None to 0
# 2024-08-21:11:48:47,368 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,368 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_government_and_politics from None to 0
# 2024-08-21:11:48:47,368 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,368 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_professional_psychology from None to 0
# 2024-08-21:11:48:47,368 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,368 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_human_sexuality from None to 0
# 2024-08-21:11:48:47,368 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,368 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_macroeconomics from None to 0
# 2024-08-21:11:48:47,368 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,368 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_european_history from None to 0
# 2024-08-21:11:48:47,369 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,369 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_international_law from None to 0
# 2024-08-21:11:48:47,369 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,369 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_prehistory from None to 0
# 2024-08-21:11:48:47,369 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,369 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_world_religions from None to 0
# 2024-08-21:11:48:47,369 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,369 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_formal_logic from None to 0
# 2024-08-21:11:48:47,369 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,369 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_world_history from None to 0
# 2024-08-21:11:48:47,369 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,369 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_philosophy from None to 0
# 2024-08-21:11:48:47,369 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,369 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_professional_law from None to 0
# 2024-08-21:11:48:47,369 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,369 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_jurisprudence from None to 0
# 2024-08-21:11:48:47,369 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,369 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_logical_fallacies from None to 0
# 2024-08-21:11:48:47,369 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,369 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_moral_disputes from None to 0
# 2024-08-21:11:48:47,369 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,369 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_moral_scenarios from None to 0
# 2024-08-21:11:48:47,369 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,369 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_us_history from None to 0
# 2024-08-21:11:48:47,369 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,369 WARNING  [evaluator.py:265] Overwriting default num_fewshot of leaderboard_mmlu_pro from 5 to 0
# 2024-08-21:11:48:47,369 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,369 WARNING  [evaluator.py:265] Overwriting default num_fewshot of arc_challenge from None to 0
# 2024-08-21:11:48:47,369 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:11:48:47,369 WARNING  [huggingface.py:469] model.chat_template was called with the chat_template set to False or None. Therefore no chat template will be applied. Make sure this is an intended behavior.
# 2024-08-21:11:48:47,376 INFO     [task.py:423] Building contexts for mmlu_astronomy on rank 0...
# 100% 152/152 [00:00<00:00, 580.04it/s]
# 2024-08-21:11:48:47,646 INFO     [task.py:423] Building contexts for mmlu_elementary_mathematics on rank 0...
# 100% 378/378 [00:00<00:00, 585.40it/s]
# 2024-08-21:11:48:48,309 INFO     [task.py:423] Building contexts for mmlu_high_school_computer_science on rank 0...
# 100% 100/100 [00:00<00:00, 583.93it/s]
# 2024-08-21:11:48:48,486 INFO     [task.py:423] Building contexts for mmlu_college_biology on rank 0...
# 100% 144/144 [00:00<00:00, 589.91it/s]
# 2024-08-21:11:48:48,738 INFO     [task.py:423] Building contexts for mmlu_high_school_chemistry on rank 0...
# 100% 203/203 [00:00<00:00, 588.62it/s]
# 2024-08-21:11:48:49,092 INFO     [task.py:423] Building contexts for mmlu_computer_security on rank 0...
# 100% 100/100 [00:00<00:00, 588.46it/s]
# 2024-08-21:11:48:49,267 INFO     [task.py:423] Building contexts for mmlu_conceptual_physics on rank 0...
# 100% 235/235 [00:00<00:00, 587.82it/s]
# 2024-08-21:11:48:49,678 INFO     [task.py:423] Building contexts for mmlu_electrical_engineering on rank 0...
# 100% 145/145 [00:00<00:00, 589.71it/s]
# 2024-08-21:11:48:49,931 INFO     [task.py:423] Building contexts for mmlu_high_school_physics on rank 0...
# 100% 151/151 [00:00<00:00, 588.79it/s]
# 2024-08-21:11:48:50,195 INFO     [task.py:423] Building contexts for mmlu_high_school_biology on rank 0...
# 100% 310/310 [00:00<00:00, 587.35it/s]
# 2024-08-21:11:48:50,738 INFO     [task.py:423] Building contexts for mmlu_abstract_algebra on rank 0...
# 100% 100/100 [00:00<00:00, 587.16it/s]
# 2024-08-21:11:48:50,913 INFO     [task.py:423] Building contexts for mmlu_college_chemistry on rank 0...
# 100% 100/100 [00:00<00:00, 588.72it/s]
# 2024-08-21:11:48:51,088 INFO     [task.py:423] Building contexts for mmlu_high_school_mathematics on rank 0...
# 100% 270/270 [00:00<00:00, 585.49it/s]
# 2024-08-21:11:48:51,562 INFO     [task.py:423] Building contexts for mmlu_high_school_statistics on rank 0...
# 100% 216/216 [00:00<00:00, 588.96it/s]
# 2024-08-21:11:48:51,942 INFO     [task.py:423] Building contexts for mmlu_college_physics on rank 0...
# 100% 102/102 [00:00<00:00, 589.94it/s]
# 2024-08-21:11:48:52,120 INFO     [task.py:423] Building contexts for mmlu_anatomy on rank 0...
# 100% 135/135 [00:00<00:00, 589.66it/s]
# 2024-08-21:11:48:52,356 INFO     [task.py:423] Building contexts for mmlu_machine_learning on rank 0...
# 100% 112/112 [00:00<00:00, 586.32it/s]
# 2024-08-21:11:48:52,553 INFO     [task.py:423] Building contexts for mmlu_college_mathematics on rank 0...
# 100% 100/100 [00:00<00:00, 592.57it/s]
# 2024-08-21:11:48:52,727 INFO     [task.py:423] Building contexts for mmlu_college_computer_science on rank 0...
# 100% 100/100 [00:00<00:00, 590.29it/s]
# 2024-08-21:11:48:52,902 INFO     [task.py:423] Building contexts for mmlu_college_medicine on rank 0...
# 100% 173/173 [00:00<00:00, 585.94it/s]
# 2024-08-21:11:48:53,206 INFO     [task.py:423] Building contexts for mmlu_global_facts on rank 0...
# 100% 100/100 [00:00<00:00, 578.88it/s]
# 2024-08-21:11:48:53,384 INFO     [task.py:423] Building contexts for mmlu_medical_genetics on rank 0...
# 100% 100/100 [00:00<00:00, 583.46it/s]
# 2024-08-21:11:48:53,560 INFO     [task.py:423] Building contexts for mmlu_human_aging on rank 0...
# 100% 223/223 [00:00<00:00, 591.26it/s]
# 2024-08-21:11:48:53,951 INFO     [task.py:423] Building contexts for mmlu_virology on rank 0...
# 100% 166/166 [00:00<00:00, 586.78it/s]
# 2024-08-21:11:48:54,243 INFO     [task.py:423] Building contexts for mmlu_professional_medicine on rank 0...
# 100% 272/272 [00:00<00:00, 585.96it/s]
# 2024-08-21:11:48:54,721 INFO     [task.py:423] Building contexts for mmlu_professional_accounting on rank 0...
# 100% 282/282 [00:00<00:00, 579.07it/s]
# 2024-08-21:11:48:55,222 INFO     [task.py:423] Building contexts for mmlu_business_ethics on rank 0...
# 100% 100/100 [00:00<00:00, 579.13it/s]
# 2024-08-21:11:48:55,401 INFO     [task.py:423] Building contexts for mmlu_management on rank 0...
# 100% 103/103 [00:00<00:00, 574.65it/s]
# 2024-08-21:11:48:55,586 INFO     [task.py:423] Building contexts for mmlu_nutrition on rank 0...
# 100% 306/306 [00:00<00:00, 589.23it/s]
# 2024-08-21:11:48:56,121 INFO     [task.py:423] Building contexts for mmlu_clinical_knowledge on rank 0...
# 100% 265/265 [00:00<00:00, 586.90it/s]
# 2024-08-21:11:48:56,585 INFO     [task.py:423] Building contexts for mmlu_miscellaneous on rank 0...
# 100% 783/783 [00:01<00:00, 585.72it/s]
# 2024-08-21:11:48:57,957 INFO     [task.py:423] Building contexts for mmlu_marketing on rank 0...
# 100% 234/234 [00:00<00:00, 588.92it/s]
# 2024-08-21:11:48:58,366 INFO     [task.py:423] Building contexts for mmlu_high_school_microeconomics on rank 0...
# 100% 238/238 [00:00<00:00, 586.56it/s]
# 2024-08-21:11:48:58,783 INFO     [task.py:423] Building contexts for mmlu_high_school_geography on rank 0...
# 100% 198/198 [00:00<00:00, 591.55it/s]
# 2024-08-21:11:48:59,127 INFO     [task.py:423] Building contexts for mmlu_security_studies on rank 0...
# 100% 245/245 [00:00<00:00, 587.36it/s]
# 2024-08-21:11:48:59,557 INFO     [task.py:423] Building contexts for mmlu_us_foreign_policy on rank 0...
# 100% 100/100 [00:00<00:00, 588.18it/s]
# 2024-08-21:11:48:59,732 INFO     [task.py:423] Building contexts for mmlu_sociology on rank 0...
# 100% 201/201 [00:00<00:00, 590.94it/s]
# 2024-08-21:11:49:00,082 INFO     [task.py:423] Building contexts for mmlu_econometrics on rank 0...
# 100% 114/114 [00:00<00:00, 593.29it/s]
# 2024-08-21:11:49:00,280 INFO     [task.py:423] Building contexts for mmlu_high_school_psychology on rank 0...
# 100% 545/545 [00:00<00:00, 591.79it/s]
# 2024-08-21:11:49:01,226 INFO     [task.py:423] Building contexts for mmlu_public_relations on rank 0...
# 100% 110/110 [00:00<00:00, 591.14it/s]
# 2024-08-21:11:49:01,417 INFO     [task.py:423] Building contexts for mmlu_high_school_government_and_politics on rank 0...
# 100% 193/193 [00:00<00:00, 587.47it/s]
# 2024-08-21:11:49:01,755 INFO     [task.py:423] Building contexts for mmlu_professional_psychology on rank 0...
# 100% 612/612 [00:01<00:00, 590.68it/s]
# 2024-08-21:11:49:02,820 INFO     [task.py:423] Building contexts for mmlu_human_sexuality on rank 0...
# 100% 131/131 [00:00<00:00, 592.07it/s]
# 2024-08-21:11:49:03,048 INFO     [task.py:423] Building contexts for mmlu_high_school_macroeconomics on rank 0...
# 100% 390/390 [00:00<00:00, 406.42it/s]
# 2024-08-21:11:49:04,026 INFO     [task.py:423] Building contexts for mmlu_high_school_european_history on rank 0...
# 100% 165/165 [00:00<00:00, 587.77it/s]
# 2024-08-21:11:49:04,316 INFO     [task.py:423] Building contexts for mmlu_international_law on rank 0...
# 100% 121/121 [00:00<00:00, 587.20it/s]
# 2024-08-21:11:49:04,528 INFO     [task.py:423] Building contexts for mmlu_prehistory on rank 0...
# 100% 324/324 [00:00<00:00, 588.68it/s]
# 2024-08-21:11:49:05,094 INFO     [task.py:423] Building contexts for mmlu_world_religions on rank 0...
# 100% 171/171 [00:00<00:00, 592.07it/s]
# 2024-08-21:11:49:05,391 INFO     [task.py:423] Building contexts for mmlu_formal_logic on rank 0...
# 100% 126/126 [00:00<00:00, 567.63it/s]
# 2024-08-21:11:49:05,620 INFO     [task.py:423] Building contexts for mmlu_high_school_world_history on rank 0...
# 100% 237/237 [00:00<00:00, 587.91it/s]
# 2024-08-21:11:49:06,035 INFO     [task.py:423] Building contexts for mmlu_philosophy on rank 0...
# 100% 311/311 [00:00<00:00, 590.14it/s]
# 2024-08-21:11:49:06,577 INFO     [task.py:423] Building contexts for mmlu_professional_law on rank 0...
# 100% 1534/1534 [00:02<00:00, 590.44it/s]
# 2024-08-21:11:49:09,247 INFO     [task.py:423] Building contexts for mmlu_jurisprudence on rank 0...
# 100% 108/108 [00:00<00:00, 590.15it/s]
# 2024-08-21:11:49:09,436 INFO     [task.py:423] Building contexts for mmlu_logical_fallacies on rank 0...
# 100% 163/163 [00:00<00:00, 587.48it/s]
# 2024-08-21:11:49:09,721 INFO     [task.py:423] Building contexts for mmlu_moral_disputes on rank 0...
# 100% 346/346 [00:00<00:00, 591.08it/s]
# 2024-08-21:11:49:10,323 INFO     [task.py:423] Building contexts for mmlu_moral_scenarios on rank 0...
# 100% 895/895 [00:01<00:00, 570.34it/s]
# 2024-08-21:11:49:11,933 INFO     [task.py:423] Building contexts for mmlu_high_school_us_history on rank 0...
# 100% 204/204 [00:00<00:00, 590.15it/s]
# 2024-08-21:11:49:12,290 INFO     [task.py:423] Building contexts for leaderboard_mmlu_pro on rank 0...
# 100% 12032/12032 [00:01<00:00, 10877.59it/s]
# 2024-08-21:11:49:14,364 INFO     [task.py:423] Building contexts for arc_challenge on rank 0...
# 100% 1172/1172 [00:01<00:00, 1009.06it/s]
# 2024-08-21:11:49:15,599 INFO     [evaluator.py:463] Running loglikelihood requests
# Running loglikelihood requests:   0% 0/174850 [00:00<?, ?it/s]We detected that you are passing `past_key_values` as a tuple and this is deprecated and will be removed in v4.43. Please use an appropriate `Cache` class (https://huggingface.co/docs/transformers/v4.41.3/en/internal/generation_utils#transformers.Cache)
# You are not running the flash-attention implementation, expect numerical differences.
# Running loglikelihood requests: 100% 174850/174850 [52:12<00:00, 55.81it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2024-08-21:12:43:58,303 INFO     [evaluation_tracker.py:206] Saving results aggregated
# hf (pretrained=kaitchup/Phi-3.5-Mini-instruct-AutoRound-4bit,dtype=float16), gen_kwargs: (None), limit: None, num_fewshot: 0, batch_size: 4
# |                 Tasks                 |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |---------------------------------------|------:|------|-----:|--------|---|-----:|---|-----:|
# |arc_challenge                          |    1.0|none  |     0|acc     |↑  |0.5930|±  |0.0144|
# |                                       |       |none  |     0|acc_norm|↑  |0.6024|±  |0.0143|
# |leaderboard_mmlu_pro                   |    0.1|none  |     0|acc     |↑  |0.3437|±  |0.0043|
# |mmlu                                   |    2.0|none  |      |acc     |↑  |0.6690|±  |0.0038|
# | - humanities                          |    2.0|none  |      |acc     |↑  |0.6249|±  |0.0068|
# |  - formal_logic                       |    1.0|none  |     0|acc     |↑  |0.5317|±  |0.0446|
# |  - high_school_european_history       |    1.0|none  |     0|acc     |↑  |0.7758|±  |0.0326|
# |  - high_school_us_history             |    1.0|none  |     0|acc     |↑  |0.8137|±  |0.0273|
# |  - high_school_world_history          |    1.0|none  |     0|acc     |↑  |0.7890|±  |0.0266|
# |  - international_law                  |    1.0|none  |     0|acc     |↑  |0.8099|±  |0.0358|
# |  - jurisprudence                      |    1.0|none  |     0|acc     |↑  |0.8056|±  |0.0383|
# |  - logical_fallacies                  |    1.0|none  |     0|acc     |↑  |0.8160|±  |0.0304|
# |  - moral_disputes                     |    1.0|none  |     0|acc     |↑  |0.7283|±  |0.0239|
# |  - moral_scenarios                    |    1.0|none  |     0|acc     |↑  |0.5341|±  |0.0167|
# |  - philosophy                         |    1.0|none  |     0|acc     |↑  |0.7010|±  |0.0260|
# |  - prehistory                         |    1.0|none  |     0|acc     |↑  |0.7099|±  |0.0253|
# |  - professional_law                   |    1.0|none  |     0|acc     |↑  |0.5000|±  |0.0128|
# |  - world_religions                    |    1.0|none  |     0|acc     |↑  |0.7544|±  |0.0330|
# | - other                               |    2.0|none  |      |acc     |↑  |0.7097|±  |0.0079|
# |  - business_ethics                    |    1.0|none  |     0|acc     |↑  |0.7200|±  |0.0451|
# |  - clinical_knowledge                 |    1.0|none  |     0|acc     |↑  |0.7623|±  |0.0262|
# |  - college_medicine                   |    1.0|none  |     0|acc     |↑  |0.6532|±  |0.0363|
# |  - global_facts                       |    1.0|none  |     0|acc     |↑  |0.3600|±  |0.0482|
# |  - human_aging                        |    1.0|none  |     0|acc     |↑  |0.6547|±  |0.0319|
# |  - management                         |    1.0|none  |     0|acc     |↑  |0.7961|±  |0.0399|
# |  - marketing                          |    1.0|none  |     0|acc     |↑  |0.8547|±  |0.0231|
# |  - medical_genetics                   |    1.0|none  |     0|acc     |↑  |0.7000|±  |0.0461|
# |  - miscellaneous                      |    1.0|none  |     0|acc     |↑  |0.8135|±  |0.0139|
# |  - nutrition                          |    1.0|none  |     0|acc     |↑  |0.7157|±  |0.0258|
# |  - professional_accounting            |    1.0|none  |     0|acc     |↑  |0.5532|±  |0.0297|
# |  - professional_medicine              |    1.0|none  |     0|acc     |↑  |0.6985|±  |0.0279|
# |  - virology                           |    1.0|none  |     0|acc     |↑  |0.4940|±  |0.0389|
# | - social sciences                     |    2.0|none  |      |acc     |↑  |0.7738|±  |0.0074|
# |  - econometrics                       |    1.0|none  |     0|acc     |↑  |0.5088|±  |0.0470|
# |  - high_school_geography              |    1.0|none  |     0|acc     |↑  |0.8333|±  |0.0266|
# |  - high_school_government_and_politics|    1.0|none  |     0|acc     |↑  |0.8808|±  |0.0234|
# |  - high_school_macroeconomics         |    1.0|none  |     0|acc     |↑  |0.7128|±  |0.0229|
# |  - high_school_microeconomics         |    1.0|none  |     0|acc     |↑  |0.8487|±  |0.0233|
# |  - high_school_psychology             |    1.0|none  |     0|acc     |↑  |0.8606|±  |0.0149|
# |  - human_sexuality                    |    1.0|none  |     0|acc     |↑  |0.7252|±  |0.0392|
# |  - professional_psychology            |    1.0|none  |     0|acc     |↑  |0.7026|±  |0.0185|
# |  - public_relations                   |    1.0|none  |     0|acc     |↑  |0.6909|±  |0.0443|
# |  - security_studies                   |    1.0|none  |     0|acc     |↑  |0.7796|±  |0.0265|
# |  - sociology                          |    1.0|none  |     0|acc     |↑  |0.8259|±  |0.0268|
# |  - us_foreign_policy                  |    1.0|none  |     0|acc     |↑  |0.8100|±  |0.0394|
# | - stem                                |    2.0|none  |      |acc     |↑  |0.5925|±  |0.0084|
# |  - abstract_algebra                   |    1.0|none  |     0|acc     |↑  |0.4100|±  |0.0494|
# |  - anatomy                            |    1.0|none  |     0|acc     |↑  |0.6593|±  |0.0409|
# |  - astronomy                          |    1.0|none  |     0|acc     |↑  |0.7632|±  |0.0346|
# |  - college_biology                    |    1.0|none  |     0|acc     |↑  |0.8194|±  |0.0322|
# |  - college_chemistry                  |    1.0|none  |     0|acc     |↑  |0.4900|±  |0.0502|
# |  - college_computer_science           |    1.0|none  |     0|acc     |↑  |0.5400|±  |0.0501|
# |  - college_mathematics                |    1.0|none  |     0|acc     |↑  |0.4100|±  |0.0494|
# |  - college_physics                    |    1.0|none  |     0|acc     |↑  |0.4510|±  |0.0495|
# |  - computer_security                  |    1.0|none  |     0|acc     |↑  |0.7700|±  |0.0423|
# |  - conceptual_physics                 |    1.0|none  |     0|acc     |↑  |0.6553|±  |0.0311|
# |  - electrical_engineering             |    1.0|none  |     0|acc     |↑  |0.6069|±  |0.0407|
# |  - elementary_mathematics             |    1.0|none  |     0|acc     |↑  |0.5079|±  |0.0257|
# |  - high_school_biology                |    1.0|none  |     0|acc     |↑  |0.8226|±  |0.0217|
# |  - high_school_chemistry              |    1.0|none  |     0|acc     |↑  |0.5714|±  |0.0348|
# |  - high_school_computer_science       |    1.0|none  |     0|acc     |↑  |0.7000|±  |0.0461|
# |  - high_school_mathematics            |    1.0|none  |     0|acc     |↑  |0.3296|±  |0.0287|
# |  - high_school_physics                |    1.0|none  |     0|acc     |↑  |0.5563|±  |0.0406|
# |  - high_school_statistics             |    1.0|none  |     0|acc     |↑  |0.6111|±  |0.0332|
# |  - machine_learning                   |    1.0|none  |     0|acc     |↑  |0.5089|±  |0.0475|
#
# |      Groups      |Version|Filter|n-shot|Metric|   |Value |   |Stderr|
# |------------------|------:|------|------|------|---|-----:|---|-----:|
# |mmlu              |      2|none  |      |acc   |↑  |0.6690|±  |0.0038|
# | - humanities     |      2|none  |      |acc   |↑  |0.6249|±  |0.0068|
# | - other          |      2|none  |      |acc   |↑  |0.7097|±  |0.0079|
# | - social sciences|      2|none  |      |acc   |↑  |0.7738|±  |0.0074|
# | - stem           |      2|none  |      |acc   |↑  |0.5925|±  |0.0084|

# %% [markdown]
# ###Phi-3.5 Mini Quantized to 4-bit with bitsandbytes

# %%
# !lm_eval --model hf --model_args pretrained=microsoft/Phi-3.5-Mini-instruct,load_in_4bit=True --tasks mmlu,arc_challenge,leaderboard_mmlu_pro --device cuda:0 --num_fewshot 0 --batch_size 4 --output_path ./eval/
# Out:
# 2024-08-21 12:48:05.133766: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-21 12:48:05.151289: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-21 12:48:05.172697: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-21 12:48:05.179227: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-21 12:48:05.194696: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-21 12:48:06.368254: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-08-21:12:48:08,255 INFO     [__main__.py:279] Verbosity set to INFO
# 2024-08-21:12:48:10,064 INFO     [__init__.py:491] `group` and `group_alias` keys in tasks' configs will no longer be used in the next release of lm-eval. `tag` will be used to allow to call a collection of tasks just like `group`. `group` will be removed in order to not cause confusion with the new ConfigurableGroup which will be the offical way to create groups with addition of group-wide configuations.
# 2024-08-21:12:48:16,849 INFO     [__main__.py:383] Selected Tasks: ['arc_challenge', 'leaderboard_mmlu_pro', 'mmlu']
# 2024-08-21:12:48:16,851 INFO     [evaluator.py:161] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-08-21:12:48:16,851 INFO     [evaluator.py:198] Initializing hf model, with arguments: {'pretrained': 'microsoft/Phi-3.5-Mini-instruct', 'load_in_4bit': True}
# 2024-08-21:12:48:16,898 INFO     [huggingface.py:130] Using device 'cuda:0'
# 2024-08-21:12:48:17,943 INFO     [huggingface.py:366] Model parallel was set to False, max memory was not set, and device map was set to {'': 'cuda:0'}
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards: 100% 2/2 [00:02<00:00,  1.47s/it]
# 2024-08-21:12:48:22,403 WARNING  [big_modeling.py:451] You shouldn't move a model that is dispatched using accelerate hooks.
# 2024-08-21:12:51:16,952 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_astronomy from None to 0
# 2024-08-21:12:51:16,952 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,952 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_elementary_mathematics from None to 0
# 2024-08-21:12:51:16,952 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,952 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_computer_science from None to 0
# 2024-08-21:12:51:16,952 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,952 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_biology from None to 0
# 2024-08-21:12:51:16,952 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,952 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_chemistry from None to 0
# 2024-08-21:12:51:16,953 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,953 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_computer_security from None to 0
# 2024-08-21:12:51:16,953 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,953 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_conceptual_physics from None to 0
# 2024-08-21:12:51:16,953 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,953 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_electrical_engineering from None to 0
# 2024-08-21:12:51:16,953 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,953 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_physics from None to 0
# 2024-08-21:12:51:16,953 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,953 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_biology from None to 0
# 2024-08-21:12:51:16,953 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,953 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_abstract_algebra from None to 0
# 2024-08-21:12:51:16,953 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,953 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_chemistry from None to 0
# 2024-08-21:12:51:16,953 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,953 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_mathematics from None to 0
# 2024-08-21:12:51:16,953 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,953 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_statistics from None to 0
# 2024-08-21:12:51:16,953 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,953 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_physics from None to 0
# 2024-08-21:12:51:16,953 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,953 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_anatomy from None to 0
# 2024-08-21:12:51:16,953 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,953 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_machine_learning from None to 0
# 2024-08-21:12:51:16,953 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,953 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_mathematics from None to 0
# 2024-08-21:12:51:16,953 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,953 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_computer_science from None to 0
# 2024-08-21:12:51:16,953 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,953 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_college_medicine from None to 0
# 2024-08-21:12:51:16,954 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,954 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_global_facts from None to 0
# 2024-08-21:12:51:16,954 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,954 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_medical_genetics from None to 0
# 2024-08-21:12:51:16,954 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,954 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_human_aging from None to 0
# 2024-08-21:12:51:16,954 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,954 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_virology from None to 0
# 2024-08-21:12:51:16,954 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,954 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_professional_medicine from None to 0
# 2024-08-21:12:51:16,954 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,954 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_professional_accounting from None to 0
# 2024-08-21:12:51:16,954 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,954 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_business_ethics from None to 0
# 2024-08-21:12:51:16,954 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,954 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_management from None to 0
# 2024-08-21:12:51:16,954 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,954 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_nutrition from None to 0
# 2024-08-21:12:51:16,954 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,954 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_clinical_knowledge from None to 0
# 2024-08-21:12:51:16,954 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,954 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_miscellaneous from None to 0
# 2024-08-21:12:51:16,954 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,954 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_marketing from None to 0
# 2024-08-21:12:51:16,954 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,954 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_microeconomics from None to 0
# 2024-08-21:12:51:16,954 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,954 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_geography from None to 0
# 2024-08-21:12:51:16,954 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,955 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_security_studies from None to 0
# 2024-08-21:12:51:16,955 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,955 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_us_foreign_policy from None to 0
# 2024-08-21:12:51:16,955 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,955 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_sociology from None to 0
# 2024-08-21:12:51:16,955 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,955 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_econometrics from None to 0
# 2024-08-21:12:51:16,955 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,955 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_psychology from None to 0
# 2024-08-21:12:51:16,955 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,955 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_public_relations from None to 0
# 2024-08-21:12:51:16,955 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,955 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_government_and_politics from None to 0
# 2024-08-21:12:51:16,955 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,955 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_professional_psychology from None to 0
# 2024-08-21:12:51:16,955 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,955 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_human_sexuality from None to 0
# 2024-08-21:12:51:16,955 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,955 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_macroeconomics from None to 0
# 2024-08-21:12:51:16,955 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,955 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_european_history from None to 0
# 2024-08-21:12:51:16,955 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,955 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_international_law from None to 0
# 2024-08-21:12:51:16,955 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,955 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_prehistory from None to 0
# 2024-08-21:12:51:16,955 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,955 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_world_religions from None to 0
# 2024-08-21:12:51:16,955 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,955 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_formal_logic from None to 0
# 2024-08-21:12:51:16,955 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,956 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_world_history from None to 0
# 2024-08-21:12:51:16,956 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,956 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_philosophy from None to 0
# 2024-08-21:12:51:16,956 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,956 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_professional_law from None to 0
# 2024-08-21:12:51:16,956 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,956 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_jurisprudence from None to 0
# 2024-08-21:12:51:16,956 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,956 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_logical_fallacies from None to 0
# 2024-08-21:12:51:16,956 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,956 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_moral_disputes from None to 0
# 2024-08-21:12:51:16,956 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,956 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_moral_scenarios from None to 0
# 2024-08-21:12:51:16,956 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,956 WARNING  [evaluator.py:265] Overwriting default num_fewshot of mmlu_high_school_us_history from None to 0
# 2024-08-21:12:51:16,956 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,956 WARNING  [evaluator.py:265] Overwriting default num_fewshot of leaderboard_mmlu_pro from 5 to 0
# 2024-08-21:12:51:16,956 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,956 WARNING  [evaluator.py:265] Overwriting default num_fewshot of arc_challenge from None to 0
# 2024-08-21:12:51:16,956 INFO     [evaluator.py:277] Setting fewshot random generator seed to 1234
# 2024-08-21:12:51:16,956 WARNING  [huggingface.py:469] model.chat_template was called with the chat_template set to False or None. Therefore no chat template will be applied. Make sure this is an intended behavior.
# 2024-08-21:12:51:16,963 INFO     [task.py:423] Building contexts for mmlu_astronomy on rank 0...
# 100% 152/152 [00:00<00:00, 584.16it/s]
# 2024-08-21:12:51:17,230 INFO     [task.py:423] Building contexts for mmlu_elementary_mathematics on rank 0...
# 100% 378/378 [00:00<00:00, 578.93it/s]
# 2024-08-21:12:51:17,901 INFO     [task.py:423] Building contexts for mmlu_high_school_computer_science on rank 0...
# 100% 100/100 [00:00<00:00, 587.27it/s]
# 2024-08-21:12:51:18,077 INFO     [task.py:423] Building contexts for mmlu_college_biology on rank 0...
# 100% 144/144 [00:00<00:00, 582.98it/s]
# 2024-08-21:12:51:18,331 INFO     [task.py:423] Building contexts for mmlu_high_school_chemistry on rank 0...
# 100% 203/203 [00:00<00:00, 584.63it/s]
# 2024-08-21:12:51:18,688 INFO     [task.py:423] Building contexts for mmlu_computer_security on rank 0...
# 100% 100/100 [00:00<00:00, 588.72it/s]
# 2024-08-21:12:51:18,863 INFO     [task.py:423] Building contexts for mmlu_conceptual_physics on rank 0...
# 100% 235/235 [00:00<00:00, 586.07it/s]
# 2024-08-21:12:51:19,276 INFO     [task.py:423] Building contexts for mmlu_electrical_engineering on rank 0...
# 100% 145/145 [00:00<00:00, 587.65it/s]
# 2024-08-21:12:51:19,530 INFO     [task.py:423] Building contexts for mmlu_high_school_physics on rank 0...
# 100% 151/151 [00:00<00:00, 589.02it/s]
# 2024-08-21:12:51:19,795 INFO     [task.py:423] Building contexts for mmlu_high_school_biology on rank 0...
# 100% 310/310 [00:00<00:00, 588.59it/s]
# 2024-08-21:12:51:20,336 INFO     [task.py:423] Building contexts for mmlu_abstract_algebra on rank 0...
# 100% 100/100 [00:00<00:00, 590.13it/s]
# 2024-08-21:12:51:20,511 INFO     [task.py:423] Building contexts for mmlu_college_chemistry on rank 0...
# 100% 100/100 [00:00<00:00, 583.80it/s]
# 2024-08-21:12:51:20,687 INFO     [task.py:423] Building contexts for mmlu_high_school_mathematics on rank 0...
# 100% 270/270 [00:00<00:00, 587.45it/s]
# 2024-08-21:12:51:21,160 INFO     [task.py:423] Building contexts for mmlu_high_school_statistics on rank 0...
# 100% 216/216 [00:00<00:00, 586.10it/s]
# 2024-08-21:12:51:21,539 INFO     [task.py:423] Building contexts for mmlu_college_physics on rank 0...
# 100% 102/102 [00:00<00:00, 585.14it/s]
# 2024-08-21:12:51:21,719 INFO     [task.py:423] Building contexts for mmlu_anatomy on rank 0...
# 100% 135/135 [00:00<00:00, 589.73it/s]
# 2024-08-21:12:51:21,955 INFO     [task.py:423] Building contexts for mmlu_machine_learning on rank 0...
# 100% 112/112 [00:00<00:00, 587.48it/s]
# 2024-08-21:12:51:22,152 INFO     [task.py:423] Building contexts for mmlu_college_mathematics on rank 0...
# 100% 100/100 [00:00<00:00, 588.52it/s]
# 2024-08-21:12:51:22,327 INFO     [task.py:423] Building contexts for mmlu_college_computer_science on rank 0...
# 100% 100/100 [00:00<00:00, 589.01it/s]
# 2024-08-21:12:51:22,503 INFO     [task.py:423] Building contexts for mmlu_college_medicine on rank 0...
# 100% 173/173 [00:00<00:00, 591.17it/s]
# 2024-08-21:12:51:22,804 INFO     [task.py:423] Building contexts for mmlu_global_facts on rank 0...
# 100% 100/100 [00:00<00:00, 590.70it/s]
# 2024-08-21:12:51:22,978 INFO     [task.py:423] Building contexts for mmlu_medical_genetics on rank 0...
# 100% 100/100 [00:00<00:00, 588.75it/s]
# 2024-08-21:12:51:23,153 INFO     [task.py:423] Building contexts for mmlu_human_aging on rank 0...
# 100% 223/223 [00:00<00:00, 591.50it/s]
# 2024-08-21:12:51:23,541 INFO     [task.py:423] Building contexts for mmlu_virology on rank 0...
# 100% 166/166 [00:00<00:00, 587.77it/s]
# 2024-08-21:12:51:23,832 INFO     [task.py:423] Building contexts for mmlu_professional_medicine on rank 0...
# 100% 272/272 [00:00<00:00, 587.87it/s]
# 2024-08-21:12:51:24,308 INFO     [task.py:423] Building contexts for mmlu_professional_accounting on rank 0...
# 100% 282/282 [00:00<00:00, 588.83it/s]
# 2024-08-21:12:51:24,801 INFO     [task.py:423] Building contexts for mmlu_business_ethics on rank 0...
# 100% 100/100 [00:00<00:00, 591.84it/s]
# 2024-08-21:12:51:24,975 INFO     [task.py:423] Building contexts for mmlu_management on rank 0...
# 100% 103/103 [00:00<00:00, 586.17it/s]
# 2024-08-21:12:51:25,156 INFO     [task.py:423] Building contexts for mmlu_nutrition on rank 0...
# 100% 306/306 [00:00<00:00, 589.64it/s]
# 2024-08-21:12:51:25,689 INFO     [task.py:423] Building contexts for mmlu_clinical_knowledge on rank 0...
# 100% 265/265 [00:00<00:00, 591.96it/s]
# 2024-08-21:12:51:26,150 INFO     [task.py:423] Building contexts for mmlu_miscellaneous on rank 0...
# 100% 783/783 [00:01<00:00, 590.11it/s]
# 2024-08-21:12:51:27,513 INFO     [task.py:423] Building contexts for mmlu_marketing on rank 0...
# 100% 234/234 [00:00<00:00, 588.41it/s]
# 2024-08-21:12:51:27,923 INFO     [task.py:423] Building contexts for mmlu_high_school_microeconomics on rank 0...
# 100% 238/238 [00:00<00:00, 587.24it/s]
# 2024-08-21:12:51:28,340 INFO     [task.py:423] Building contexts for mmlu_high_school_geography on rank 0...
# 100% 198/198 [00:00<00:00, 587.25it/s]
# 2024-08-21:12:51:28,687 INFO     [task.py:423] Building contexts for mmlu_security_studies on rank 0...
# 100% 245/245 [00:00<00:00, 589.55it/s]
# 2024-08-21:12:51:29,115 INFO     [task.py:423] Building contexts for mmlu_us_foreign_policy on rank 0...
# 100% 100/100 [00:00<00:00, 590.73it/s]
# 2024-08-21:12:51:29,289 INFO     [task.py:423] Building contexts for mmlu_sociology on rank 0...
# 100% 201/201 [00:00<00:00, 584.33it/s]
# 2024-08-21:12:51:29,643 INFO     [task.py:423] Building contexts for mmlu_econometrics on rank 0...
# 100% 114/114 [00:00<00:00, 586.81it/s]
# 2024-08-21:12:51:29,843 INFO     [task.py:423] Building contexts for mmlu_high_school_psychology on rank 0...
# 100% 545/545 [00:00<00:00, 586.55it/s]
# 2024-08-21:12:51:30,798 INFO     [task.py:423] Building contexts for mmlu_public_relations on rank 0...
# 100% 110/110 [00:00<00:00, 587.00it/s]
# 2024-08-21:12:51:30,991 INFO     [task.py:423] Building contexts for mmlu_high_school_government_and_politics on rank 0...
# 100% 193/193 [00:00<00:00, 583.89it/s]
# 2024-08-21:12:51:31,332 INFO     [task.py:423] Building contexts for mmlu_professional_psychology on rank 0...
# 100% 612/612 [00:01<00:00, 584.96it/s]
# 2024-08-21:12:51:32,408 INFO     [task.py:423] Building contexts for mmlu_human_sexuality on rank 0...
# 100% 131/131 [00:00<00:00, 590.11it/s]
# 2024-08-21:12:51:32,637 INFO     [task.py:423] Building contexts for mmlu_high_school_macroeconomics on rank 0...
# 100% 390/390 [00:00<00:00, 402.17it/s]
# 2024-08-21:12:51:33,625 INFO     [task.py:423] Building contexts for mmlu_high_school_european_history on rank 0...
# 100% 165/165 [00:00<00:00, 582.59it/s]
# 2024-08-21:12:51:33,917 INFO     [task.py:423] Building contexts for mmlu_international_law on rank 0...
# 100% 121/121 [00:00<00:00, 581.88it/s]
# 2024-08-21:12:51:34,131 INFO     [task.py:423] Building contexts for mmlu_prehistory on rank 0...
# 100% 324/324 [00:00<00:00, 589.41it/s]
# 2024-08-21:12:51:34,697 INFO     [task.py:423] Building contexts for mmlu_world_religions on rank 0...
# 100% 171/171 [00:00<00:00, 589.88it/s]
# 2024-08-21:12:51:34,995 INFO     [task.py:423] Building contexts for mmlu_formal_logic on rank 0...
# 100% 126/126 [00:00<00:00, 586.01it/s]
# 2024-08-21:12:51:35,218 INFO     [task.py:423] Building contexts for mmlu_high_school_world_history on rank 0...
# 100% 237/237 [00:00<00:00, 585.11it/s]
# 2024-08-21:12:51:35,635 INFO     [task.py:423] Building contexts for mmlu_philosophy on rank 0...
# 100% 311/311 [00:00<00:00, 594.11it/s]
# 2024-08-21:12:51:36,174 INFO     [task.py:423] Building contexts for mmlu_professional_law on rank 0...
# 100% 1534/1534 [00:02<00:00, 576.96it/s]
# 2024-08-21:12:51:38,906 INFO     [task.py:423] Building contexts for mmlu_jurisprudence on rank 0...
# 100% 108/108 [00:00<00:00, 588.16it/s]
# 2024-08-21:12:51:39,095 INFO     [task.py:423] Building contexts for mmlu_logical_fallacies on rank 0...
# 100% 163/163 [00:00<00:00, 589.11it/s]
# 2024-08-21:12:51:39,380 INFO     [task.py:423] Building contexts for mmlu_moral_disputes on rank 0...
# 100% 346/346 [00:00<00:00, 584.32it/s]
# 2024-08-21:12:51:39,989 INFO     [task.py:423] Building contexts for mmlu_moral_scenarios on rank 0...
# 100% 895/895 [00:01<00:00, 589.55it/s]
# 2024-08-21:12:51:41,549 INFO     [task.py:423] Building contexts for mmlu_high_school_us_history on rank 0...
# 100% 204/204 [00:00<00:00, 577.98it/s]
# 2024-08-21:12:51:41,913 INFO     [task.py:423] Building contexts for leaderboard_mmlu_pro on rank 0...
# 100% 12032/12032 [00:01<00:00, 10724.24it/s]
# 2024-08-21:12:51:44,034 INFO     [task.py:423] Building contexts for arc_challenge on rank 0...
# 100% 1172/1172 [00:01<00:00, 1006.48it/s]
# 2024-08-21:12:51:45,271 INFO     [evaluator.py:463] Running loglikelihood requests
# Running loglikelihood requests:   0% 0/174850 [00:00<?, ?it/s]We detected that you are passing `past_key_values` as a tuple and this is deprecated and will be removed in v4.43. Please use an appropriate `Cache` class (https://huggingface.co/docs/transformers/v4.41.3/en/internal/generation_utils#transformers.Cache)
# You are not running the flash-attention implementation, expect numerical differences.
# Running loglikelihood requests: 100% 174850/174850 [25:21<00:00, 114.94it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2024-08-21:13:19:38,377 INFO     [evaluation_tracker.py:206] Saving results aggregated
# hf (pretrained=microsoft/Phi-3.5-Mini-instruct,load_in_4bit=True), gen_kwargs: (None), limit: None, num_fewshot: 0, batch_size: 4
# |                 Tasks                 |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |---------------------------------------|------:|------|-----:|--------|---|-----:|---|-----:|
# |arc_challenge                          |    1.0|none  |     0|acc     |↑  |0.5819|±  |0.0144|
# |                                       |       |none  |     0|acc_norm|↑  |0.6092|±  |0.0143|
# |leaderboard_mmlu_pro                   |    0.1|none  |     0|acc     |↑  |0.3009|±  |0.0042|
# |mmlu                                   |    2.0|none  |      |acc     |↑  |0.6611|±  |0.0038|
# | - humanities                          |    2.0|none  |      |acc     |↑  |0.6176|±  |0.0068|
# |  - formal_logic                       |    1.0|none  |     0|acc     |↑  |0.4762|±  |0.0447|
# |  - high_school_european_history       |    1.0|none  |     0|acc     |↑  |0.7939|±  |0.0316|
# |  - high_school_us_history             |    1.0|none  |     0|acc     |↑  |0.7892|±  |0.0286|
# |  - high_school_world_history          |    1.0|none  |     0|acc     |↑  |0.8059|±  |0.0257|
# |  - international_law                  |    1.0|none  |     0|acc     |↑  |0.8099|±  |0.0358|
# |  - jurisprudence                      |    1.0|none  |     0|acc     |↑  |0.7778|±  |0.0402|
# |  - logical_fallacies                  |    1.0|none  |     0|acc     |↑  |0.7975|±  |0.0316|
# |  - moral_disputes                     |    1.0|none  |     0|acc     |↑  |0.7341|±  |0.0238|
# |  - moral_scenarios                    |    1.0|none  |     0|acc     |↑  |0.5218|±  |0.0167|
# |  - philosophy                         |    1.0|none  |     0|acc     |↑  |0.7170|±  |0.0256|
# |  - prehistory                         |    1.0|none  |     0|acc     |↑  |0.7438|±  |0.0243|
# |  - professional_law                   |    1.0|none  |     0|acc     |↑  |0.4765|±  |0.0128|
# |  - world_religions                    |    1.0|none  |     0|acc     |↑  |0.7895|±  |0.0313|
# | - other                               |    2.0|none  |      |acc     |↑  |0.7020|±  |0.0079|
# |  - business_ethics                    |    1.0|none  |     0|acc     |↑  |0.7100|±  |0.0456|
# |  - clinical_knowledge                 |    1.0|none  |     0|acc     |↑  |0.7509|±  |0.0266|
# |  - college_medicine                   |    1.0|none  |     0|acc     |↑  |0.6358|±  |0.0367|
# |  - global_facts                       |    1.0|none  |     0|acc     |↑  |0.3100|±  |0.0465|
# |  - human_aging                        |    1.0|none  |     0|acc     |↑  |0.6592|±  |0.0318|
# |  - management                         |    1.0|none  |     0|acc     |↑  |0.7864|±  |0.0406|
# |  - marketing                          |    1.0|none  |     0|acc     |↑  |0.8547|±  |0.0231|
# |  - medical_genetics                   |    1.0|none  |     0|acc     |↑  |0.6800|±  |0.0469|
# |  - miscellaneous                      |    1.0|none  |     0|acc     |↑  |0.8084|±  |0.0141|
# |  - nutrition                          |    1.0|none  |     0|acc     |↑  |0.7516|±  |0.0247|
# |  - professional_accounting            |    1.0|none  |     0|acc     |↑  |0.5461|±  |0.0297|
# |  - professional_medicine              |    1.0|none  |     0|acc     |↑  |0.6581|±  |0.0288|
# |  - virology                           |    1.0|none  |     0|acc     |↑  |0.4699|±  |0.0389|
# | - social sciences                     |    2.0|none  |      |acc     |↑  |0.7654|±  |0.0075|
# |  - econometrics                       |    1.0|none  |     0|acc     |↑  |0.4912|±  |0.0470|
# |  - high_school_geography              |    1.0|none  |     0|acc     |↑  |0.8131|±  |0.0278|
# |  - high_school_government_and_politics|    1.0|none  |     0|acc     |↑  |0.8549|±  |0.0254|
# |  - high_school_macroeconomics         |    1.0|none  |     0|acc     |↑  |0.7179|±  |0.0228|
# |  - high_school_microeconomics         |    1.0|none  |     0|acc     |↑  |0.8361|±  |0.0240|
# |  - high_school_psychology             |    1.0|none  |     0|acc     |↑  |0.8642|±  |0.0147|
# |  - human_sexuality                    |    1.0|none  |     0|acc     |↑  |0.7023|±  |0.0401|
# |  - professional_psychology            |    1.0|none  |     0|acc     |↑  |0.6928|±  |0.0187|
# |  - public_relations                   |    1.0|none  |     0|acc     |↑  |0.6364|±  |0.0461|
# |  - security_studies                   |    1.0|none  |     0|acc     |↑  |0.7551|±  |0.0275|
# |  - sociology                          |    1.0|none  |     0|acc     |↑  |0.8308|±  |0.0265|
# |  - us_foreign_policy                  |    1.0|none  |     0|acc     |↑  |0.8500|±  |0.0359|
# | - stem                                |    2.0|none  |      |acc     |↑  |0.5839|±  |0.0084|
# |  - abstract_algebra                   |    1.0|none  |     0|acc     |↑  |0.3900|±  |0.0490|
# |  - anatomy                            |    1.0|none  |     0|acc     |↑  |0.6593|±  |0.0409|
# |  - astronomy                          |    1.0|none  |     0|acc     |↑  |0.7632|±  |0.0346|
# |  - college_biology                    |    1.0|none  |     0|acc     |↑  |0.8264|±  |0.0317|
# |  - college_chemistry                  |    1.0|none  |     0|acc     |↑  |0.5300|±  |0.0502|
# |  - college_computer_science           |    1.0|none  |     0|acc     |↑  |0.5800|±  |0.0496|
# |  - college_mathematics                |    1.0|none  |     0|acc     |↑  |0.3700|±  |0.0485|
# |  - college_physics                    |    1.0|none  |     0|acc     |↑  |0.4412|±  |0.0494|
# |  - computer_security                  |    1.0|none  |     0|acc     |↑  |0.7400|±  |0.0441|
# |  - conceptual_physics                 |    1.0|none  |     0|acc     |↑  |0.6383|±  |0.0314|
# |  - electrical_engineering             |    1.0|none  |     0|acc     |↑  |0.6207|±  |0.0404|
# |  - elementary_mathematics             |    1.0|none  |     0|acc     |↑  |0.5265|±  |0.0257|
# |  - high_school_biology                |    1.0|none  |     0|acc     |↑  |0.8161|±  |0.0220|
# |  - high_school_chemistry              |    1.0|none  |     0|acc     |↑  |0.5665|±  |0.0349|
# |  - high_school_computer_science       |    1.0|none  |     0|acc     |↑  |0.6500|±  |0.0479|
# |  - high_school_mathematics            |    1.0|none  |     0|acc     |↑  |0.3519|±  |0.0291|
# |  - high_school_physics                |    1.0|none  |     0|acc     |↑  |0.4305|±  |0.0404|
# |  - high_school_statistics             |    1.0|none  |     0|acc     |↑  |0.5926|±  |0.0335|
# |  - machine_learning                   |    1.0|none  |     0|acc     |↑  |0.4554|±  |0.0473|
#
# |      Groups      |Version|Filter|n-shot|Metric|   |Value |   |Stderr|
# |------------------|------:|------|------|------|---|-----:|---|-----:|
# |mmlu              |      2|none  |      |acc   |↑  |0.6611|±  |0.0038|
# | - humanities     |      2|none  |      |acc   |↑  |0.6176|±  |0.0068|
# | - other          |      2|none  |      |acc   |↑  |0.7020|±  |0.0079|
# | - social sciences|      2|none  |      |acc   |↑  |0.7654|±  |0.0075|
# | - stem           |      2|none  |      |acc   |↑  |0.5839|±  |0.0084|

# %% [markdown]
# #Fine-tuning Phi-3.5 Mini

# %%
# !pip install -qqq --upgrade bitsandbytes transformers peft accelerate datasets trl flash_attn
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 MB 16.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.4/296.4 kB 25.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.1/315.1 kB 30.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.8/245.8 kB 24.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.6/104.6 kB 11.8 MB/s eta 0:00:00

# %% [markdown]
# ##QLoRA with bitsandbytes

# %% [markdown]
# * Batch size of 1 with a sequence of 512 tokens requires 6 GB of CPU and 8 GB of GPU RAM
# * Batch size of 8 (in the code bewlo) with sequences of 512 tokens requires 6 GB of CPU and 13 GB of GPU RAM

# %%
import torch
from datasets import load_dataset
from peft import LoraConfig, prepare_model_for_kbit_training
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
)
from trl import SFTTrainer, SFTConfig

#use bf16 and FlashAttention if supported
if torch.cuda.is_bf16_supported():
  compute_dtype = torch.bfloat16
  attn_implementation = 'flash_attention_2'
else:
  compute_dtype = torch.float16
  attn_implementation = 'sdpa'

model_name = "microsoft/Phi-3.5-Mini-instruct"

tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True, add_eos_token=True, use_fast=True)
tokenizer.pad_token = tokenizer.unk_token
tokenizer.pad_token_id = tokenizer.convert_tokens_to_ids(tokenizer.pad_token)
tokenizer.padding_side = 'left'

ds = load_dataset("timdettmers/openassistant-guanaco")

bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)
model = AutoModelForCausalLM.from_pretrained(
          model_name, torch_dtype=compute_dtype, trust_remote_code=True, quantization_config=bnb_config, device_map={"": 0}, attn_implementation=attn_implementation
)

model = prepare_model_for_kbit_training(model,gradient_checkpointing_kwargs={'use_reentrant':True})

peft_config = LoraConfig(
        lora_alpha=16,
        lora_dropout=0.05,
        r=16,
        bias="none",
        task_type="CAUSAL_LM",
        target_modules= ['k_proj', 'q_proj', 'v_proj', 'o_proj', "gate_proj", "down_proj", "up_proj"]
)


training_arguments = SFTConfig(
        output_dir="./Phi-3.5/Phi-3.5-Mini_QLoRA",
        eval_strategy="steps",
        do_eval=True,
        optim="paged_adamw_8bit",
        per_device_train_batch_size=8,
        gradient_accumulation_steps=4,
        per_device_eval_batch_size=8,
        log_level="debug",
        save_strategy="epoch",
        logging_steps=25,
        learning_rate=1e-4,
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        eval_steps=25,
        num_train_epochs=1,
        warmup_ratio=0.1,
        lr_scheduler_type="linear",
        dataset_text_field="text",
        max_seq_length=512
)

trainer = SFTTrainer(
        model=model,
        train_dataset=ds['train'],
        eval_dataset=ds['test'],
        peft_config=peft_config,
        tokenizer=tokenizer,
        args=training_arguments,
)

trainer.train()
# Out:
# tokenizer_config.json:   0%|          | 0.00/3.98k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/306 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/395 [00:00<?, ?B/s]
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# Downloading data:   0%|          | 0.00/20.9M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/9846 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/518 [00:00<?, ? examples/s]
# config.json:   0%|          | 0.00/3.45k [00:00<?, ?B/s]
# configuration_phi3.py:   0%|          | 0.00/11.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3.5-Mini-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_phi3.py:   0%|          | 0.00/73.8k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3.5-Mini-instruct:
# - modeling_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors.index.json:   0%|          | 0.00/16.3k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.67G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/195 [00:00<?, ?B/s]
# Map:   0%|          | 0/9846 [00:00<?, ? examples/s]
# Map:   0%|          | 0/518 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:408: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(
# Using auto half precision backend
# Currently training with a batch size of: 8
# ***** Running training *****
#   Num examples = 9,846
#   Num Epochs = 1
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 4
#   Total optimization steps = 307
#   Number of trainable parameters = 8,912,896
# WARNING:transformers_modules.microsoft.Phi-3.5-Mini-instruct.64963004ad95869fa73a30279371c8778509ac84.modeling_phi3:`use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
# WARNING:transformers_modules.microsoft.Phi-3.5-Mini-instruct.64963004ad95869fa73a30279371c8778509ac84.modeling_phi3:The input hidden states seems to be silently casted in float32, this might be related to the fact you have upcasted embedding or layer norm layers in float32. We will cast back the input in torch.bfloat16.
#     <div>
#
#       <progress value='307' max='307' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [307/307 1:53:01, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>1.607100</td>
#       <td>1.484774</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.316900</td>
#       <td>1.296879</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.244200</td>
#       <td>1.264040</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.217100</td>
#       <td>1.250713</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>1.194600</td>
#       <td>1.243362</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.158600</td>
#       <td>1.238708</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>1.181500</td>
#       <td>1.235508</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.182400</td>
#       <td>1.232928</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>1.180200</td>
#       <td>1.231119</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.197000</td>
#       <td>1.230293</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>1.152800</td>
#       <td>1.229196</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.147700</td>
#       <td>1.229024</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# Saving model checkpoint to ./Phi-3.5/Phi-3.5-Mini_QLoRA/checkpoint-307
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--microsoft--Phi-3.5-Mini-instruct/snapshots/64963004ad95869fa73a30279371c8778509ac84/config.json
# Model config Phi3Config {
#   "_name_or_path": "Phi-3.5-mini-instruct",
#   "architectures": [
#     "Phi3ForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "auto_map": {
#     "AutoConfig": "microsoft/Phi-3.5-Mini-instruct--configuration_phi3.Phi3Config",
#     "AutoModelForCausalLM": "microsoft/Phi-3.5-Mini-instruct--modeling_phi3.Phi3ForCausalLM"
#   },
#   "bos_token_id": 1,
#   "embd_pdrop": 0.0,
#   "eos_token_id": 32000,
#   "hidden_act": "silu",
#   "hidden_size": 3072,
#   "initializer_range": 0.02,
#   "intermediate_size": 8192,
#   "max_position_embeddings": 131072,
#   "model_type": "phi3",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 32,
#   "original_max_position_embeddings": 4096,
#   "pad_token_id": 32000,
#   "resid_pdrop": 0.0,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": {
#     "long_factor": [
#       1.0800000429153442,
#       1.1100000143051147,
#       1.1399999856948853,
#       1.340000033378601,
#       1.5899999141693115,
#       1.600000023841858,
#       1.6200000047683716,
#       2.620000123977661,
#       3.2300000190734863,
#       3.2300000190734863,
#       4.789999961853027,
#       7.400000095367432,
#       7.700000286102295,
#       9.09000015258789,
#       12.199999809265137,
#       17.670000076293945,
#       24.46000099182129,
#       28.57000160217285,
#       30.420001983642578,
#       30.840002059936523,
#       32.590003967285156,
#       32.93000411987305,
#       42.320003509521484,
#       44.96000289916992,
#       50.340003967285156,
#       50.45000457763672,
#       57.55000305175781,
#       57.93000411987305,
#       58.21000289916992,
#       60.1400032043457,
#       62.61000442504883,
#       62.62000274658203,
#       62.71000289916992,
#       63.1400032043457,
#       63.1400032043457,
#       63.77000427246094,
#       63.93000411987305,
#       63.96000289916992,
#       63.970001220703125,
#       64.02999877929688,
#       64.06999969482422,
#       64.08000183105469,
#       64.12000274658203,
#       64.41000366210938,
#       64.4800033569336,
#       64.51000213623047,
#       64.52999877929688,
#       64.83999633789062
#     ],
#     "short_factor": [
#       1.0,
#       1.0199999809265137,
#       1.0299999713897705,
#       1.0299999713897705,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0699999332427979,
#       1.0999999046325684,
#       1.1099998950958252,
#       1.1599998474121094,
#       1.1599998474121094,
#       1.1699998378753662,
#       1.2899998426437378,
#       1.339999794960022,
#       1.679999828338623,
#       1.7899998426437378,
#       1.8199998140335083,
#       1.8499997854232788,
#       1.8799997568130493,
#       1.9099997282028198,
#       1.9399996995925903,
#       1.9899996519088745,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0799996852874756,
#       2.0899996757507324,
#       2.189999580383301,
#       2.2199995517730713,
#       2.5899994373321533,
#       2.729999542236328,
#       2.749999523162842,
#       2.8399994373321533
#     ],
#     "type": "longrope"
#   },
#   "rope_theta": 10000.0,
#   "sliding_window": 262144,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.44.1",
#   "use_cache": true,
#   "vocab_size": 32064
# }
#
# tokenizer config file saved in ./Phi-3.5/Phi-3.5-Mini_QLoRA/checkpoint-307/tokenizer_config.json
# Special tokens file saved in ./Phi-3.5/Phi-3.5-Mini_QLoRA/checkpoint-307/special_tokens_map.json
# Saving model checkpoint to ./Phi-3.5/Phi-3.5-Mini_QLoRA/checkpoint-307
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--microsoft--Phi-3.5-Mini-instruct/snapshots/64963004ad95869fa73a30279371c8778509ac84/config.json
# Model config Phi3Config {
#   "_name_or_path": "Phi-3.5-mini-instruct",
#   "architectures": [
#     "Phi3ForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "auto_map": {
#     "AutoConfig": "microsoft/Phi-3.5-Mini-instruct--configuration_phi3.Phi3Config",
#     "AutoModelForCausalLM": "microsoft/Phi-3.5-Mini-instruct--modeling_phi3.Phi3ForCausalLM"
#   },
#   "bos_token_id": 1,
#   "embd_pdrop": 0.0,
#   "eos_token_id": 32000,
#   "hidden_act": "silu",
#   "hidden_size": 3072,
#   "initializer_range": 0.02,
#   "intermediate_size": 8192,
#   "max_position_embeddings": 131072,
#   "model_type": "phi3",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 32,
#   "original_max_position_embeddings": 4096,
#   "pad_token_id": 32000,
#   "resid_pdrop": 0.0,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": {
#     "long_factor": [
#       1.0800000429153442,
#       1.1100000143051147,
#       1.1399999856948853,
#       1.340000033378601,
#       1.5899999141693115,
#       1.600000023841858,
#       1.6200000047683716,
#       2.620000123977661,
#       3.2300000190734863,
#       3.2300000190734863,
#       4.789999961853027,
#       7.400000095367432,
#       7.700000286102295,
#       9.09000015258789,
#       12.199999809265137,
#       17.670000076293945,
#       24.46000099182129,
#       28.57000160217285,
#       30.420001983642578,
#       30.840002059936523,
#       32.590003967285156,
#       32.93000411987305,
#       42.320003509521484,
#       44.96000289916992,
#       50.340003967285156,
#       50.45000457763672,
#       57.55000305175781,
#       57.93000411987305,
#       58.21000289916992,
#       60.1400032043457,
#       62.61000442504883,
#       62.62000274658203,
#       62.71000289916992,
#       63.1400032043457,
#       63.1400032043457,
#       63.77000427246094,
#       63.93000411987305,
#       63.96000289916992,
#       63.970001220703125,
#       64.02999877929688,
#       64.06999969482422,
#       64.08000183105469,
#       64.12000274658203,
#       64.41000366210938,
#       64.4800033569336,
#       64.51000213623047,
#       64.52999877929688,
#       64.83999633789062
#     ],
#     "short_factor": [
#       1.0,
#       1.0199999809265137,
#       1.0299999713897705,
#       1.0299999713897705,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0699999332427979,
#       1.0999999046325684,
#       1.1099998950958252,
#       1.1599998474121094,
#       1.1599998474121094,
#       1.1699998378753662,
#       1.2899998426437378,
#       1.339999794960022,
#       1.679999828338623,
#       1.7899998426437378,
#       1.8199998140335083,
#       1.8499997854232788,
#       1.8799997568130493,
#       1.9099997282028198,
#       1.9399996995925903,
#       1.9899996519088745,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0799996852874756,
#       2.0899996757507324,
#       2.189999580383301,
#       2.2199995517730713,
#       2.5899994373321533,
#       2.729999542236328,
#       2.749999523162842,
#       2.8399994373321533
#     ],
#     "type": "longrope"
#   },
#   "rope_theta": 10000.0,
#   "sliding_window": 262144,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.44.1",
#   "use_cache": true,
#   "vocab_size": 32064
# }
#
# tokenizer config file saved in ./Phi-3.5/Phi-3.5-Mini_QLoRA/checkpoint-307/tokenizer_config.json
# Special tokens file saved in ./Phi-3.5/Phi-3.5-Mini_QLoRA/checkpoint-307/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=307, training_loss=1.229702399685639, metrics={'train_runtime': 6800.8452, 'train_samples_per_second': 1.448, 'train_steps_per_second': 0.045, 'total_flos': 1.1181274994466816e+17, 'train_loss': 1.229702399685639, 'epoch': 0.9975629569455727})

# %% [markdown]
# ##QLoRA with AutoRound

# %% [markdown]
# * Requirements:
#  * same as QLoRA with bistandbytes

# %%
import torch
from datasets import load_dataset
from peft import LoraConfig, prepare_model_for_kbit_training
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    TrainingArguments,
)
from trl import SFTTrainer, SFTConfig

#use bf16 and FlashAttention if supported
if torch.cuda.is_bf16_supported():
  compute_dtype = torch.bfloat16
  attn_implementation = 'flash_attention_2'
else:
  compute_dtype = torch.float16
  attn_implementation = 'sdpa'

model_name = "kaitchup/Phi-3.5-Mini-instruct-AutoRound-4bit"

tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True, add_eos_token=True, use_fast=True)
tokenizer.pad_token = tokenizer.unk_token
tokenizer.pad_token_id = tokenizer.convert_tokens_to_ids(tokenizer.pad_token)
tokenizer.padding_side = 'left'

ds = load_dataset("timdettmers/openassistant-guanaco")


model = AutoModelForCausalLM.from_pretrained(
          model_name, trust_remote_code=True, device_map={"": 0}, attn_implementation=attn_implementation
)

model = prepare_model_for_kbit_training(model,gradient_checkpointing_kwargs={'use_reentrant':True})

peft_config = LoraConfig(
        lora_alpha=16,
        lora_dropout=0.05,
        r=16,
        bias="none",
        task_type="CAUSAL_LM",
        target_modules= ['k_proj', 'q_proj', 'v_proj', 'o_proj', "gate_proj", "down_proj", "up_proj"]
)


training_arguments = SFTConfig(
        output_dir="./Phi-3.5/Phi-3.5-Mini_QLoRA_AutoRound",
        eval_strategy="steps",
        do_eval=True,
        optim="paged_adamw_8bit",
        per_device_train_batch_size=8,
        gradient_accumulation_steps=4,
        per_device_eval_batch_size=8,
        log_level="debug",
        save_strategy="epoch",
        logging_steps=25,
        learning_rate=1e-4,
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        eval_steps=25,
        num_train_epochs=1,
        warmup_ratio=0.1,
        lr_scheduler_type="linear",
        dataset_text_field="text",
        max_seq_length=512
)

trainer = SFTTrainer(
        model=model,
        train_dataset=ds['train'],
        eval_dataset=ds['test'],
        peft_config=peft_config,
        tokenizer=tokenizer,
        args=training_arguments,
)

trainer.train()
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# configuration_phi3.py:   0%|          | 0.00/11.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/kaitchup/Phi-3.5-Mini-instruct-AutoRound-4bit:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_phi3.py:   0%|          | 0.00/73.8k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/kaitchup/Phi-3.5-Mini-instruct-AutoRound-4bit:
# - modeling_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda:CUDA extension not installed.
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda_old:CUDA extension not installed.
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:4674: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(
# Map:   0%|          | 0/9846 [00:00<?, ? examples/s]
# Map:   0%|          | 0/518 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:408: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(
# Using auto half precision backend
# Currently training with a batch size of: 8
# ***** Running training *****
#   Num examples = 9,846
#   Num Epochs = 1
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 4
#   Total optimization steps = 307
#   Number of trainable parameters = 8,912,896
# WARNING:transformers_modules.kaitchup.Phi-3.5-Mini-instruct-AutoRound-4bit.5a98599cb1d161271e100cb24021146327ad50ff.modeling_phi3:`use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
#     <div>
#
#       <progress value='307' max='307' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [307/307 1:37:05, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>1.573100</td>
#       <td>1.448355</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.293300</td>
#       <td>1.289964</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.238200</td>
#       <td>1.258594</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.215100</td>
#       <td>1.247414</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>1.194100</td>
#       <td>1.241973</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.159800</td>
#       <td>1.239165</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>1.183300</td>
#       <td>1.237587</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.184000</td>
#       <td>1.235978</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>1.184400</td>
#       <td>1.234958</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.203300</td>
#       <td>1.234782</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>1.159200</td>
#       <td>1.234255</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.154400</td>
#       <td>1.234058</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# Saving model checkpoint to ./Phi-3.5/Phi-3.5-Mini_QLoRA_AutoRound/checkpoint-307
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--kaitchup--Phi-3.5-Mini-instruct-AutoRound-4bit/snapshots/5a98599cb1d161271e100cb24021146327ad50ff/config.json
# Model config Phi3Config {
#   "_name_or_path": "./AutoRound/GPTQ-sym/",
#   "architectures": [
#     "Phi3ForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "auto_map": {
#     "AutoConfig": "kaitchup/Phi-3.5-Mini-instruct-AutoRound-4bit--configuration_phi3.Phi3Config",
#     "AutoModelForCausalLM": "kaitchup/Phi-3.5-Mini-instruct-AutoRound-4bit--modeling_phi3.Phi3ForCausalLM"
#   },
#   "bos_token_id": 1,
#   "embd_pdrop": 0.0,
#   "eos_token_id": 32000,
#   "hidden_act": "silu",
#   "hidden_size": 3072,
#   "initializer_range": 0.02,
#   "intermediate_size": 8192,
#   "max_position_embeddings": 131072,
#   "model_type": "phi3",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 32,
#   "original_max_position_embeddings": 4096,
#   "pad_token_id": 32000,
#   "quantization_config": {
#     "batch_size": 1,
#     "bits": 4,
#     "block_name_to_quantize": null,
#     "cache_block_outputs": true,
#     "damp_percent": 0.01,
#     "dataset": null,
#     "desc_act": false,
#     "exllama_config": {
#       "version": 1
#     },
#     "group_size": 128,
#     "max_input_length": null,
#     "model_seqlen": null,
#     "module_name_preceding_first_block": null,
#     "modules_in_block_to_quantize": null,
#     "pad_token_id": null,
#     "quant_method": "gptq",
#     "sym": true,
#     "tokenizer": null,
#     "true_sequential": false,
#     "use_cuda_fp16": false,
#     "use_exllama": true
#   },
#   "resid_pdrop": 0.0,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": {
#     "long_factor": [
#       1.0800000429153442,
#       1.1100000143051147,
#       1.1399999856948853,
#       1.340000033378601,
#       1.5899999141693115,
#       1.600000023841858,
#       1.6200000047683716,
#       2.620000123977661,
#       3.2300000190734863,
#       3.2300000190734863,
#       4.789999961853027,
#       7.400000095367432,
#       7.700000286102295,
#       9.09000015258789,
#       12.199999809265137,
#       17.670000076293945,
#       24.46000099182129,
#       28.57000160217285,
#       30.420001983642578,
#       30.840002059936523,
#       32.590003967285156,
#       32.93000411987305,
#       42.320003509521484,
#       44.96000289916992,
#       50.340003967285156,
#       50.45000457763672,
#       57.55000305175781,
#       57.93000411987305,
#       58.21000289916992,
#       60.1400032043457,
#       62.61000442504883,
#       62.62000274658203,
#       62.71000289916992,
#       63.1400032043457,
#       63.1400032043457,
#       63.77000427246094,
#       63.93000411987305,
#       63.96000289916992,
#       63.970001220703125,
#       64.02999877929688,
#       64.06999969482422,
#       64.08000183105469,
#       64.12000274658203,
#       64.41000366210938,
#       64.4800033569336,
#       64.51000213623047,
#       64.52999877929688,
#       64.83999633789062
#     ],
#     "short_factor": [
#       1.0,
#       1.0199999809265137,
#       1.0299999713897705,
#       1.0299999713897705,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0699999332427979,
#       1.0999999046325684,
#       1.1099998950958252,
#       1.1599998474121094,
#       1.1599998474121094,
#       1.1699998378753662,
#       1.2899998426437378,
#       1.339999794960022,
#       1.679999828338623,
#       1.7899998426437378,
#       1.8199998140335083,
#       1.8499997854232788,
#       1.8799997568130493,
#       1.9099997282028198,
#       1.9399996995925903,
#       1.9899996519088745,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0799996852874756,
#       2.0899996757507324,
#       2.189999580383301,
#       2.2199995517730713,
#       2.5899994373321533,
#       2.729999542236328,
#       2.749999523162842,
#       2.8399994373321533
#     ],
#     "type": "longrope"
#   },
#   "rope_theta": 10000.0,
#   "sliding_window": 262144,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.43.4",
#   "use_cache": true,
#   "vocab_size": 32064
# }
#
# tokenizer config file saved in ./Phi-3.5/Phi-3.5-Mini_QLoRA_AutoRound/checkpoint-307/tokenizer_config.json
# Special tokens file saved in ./Phi-3.5/Phi-3.5-Mini_QLoRA_AutoRound/checkpoint-307/special_tokens_map.json
# Saving model checkpoint to ./Phi-3.5/Phi-3.5-Mini_QLoRA_AutoRound/checkpoint-307
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--kaitchup--Phi-3.5-Mini-instruct-AutoRound-4bit/snapshots/5a98599cb1d161271e100cb24021146327ad50ff/config.json
# Model config Phi3Config {
#   "_name_or_path": "./AutoRound/GPTQ-sym/",
#   "architectures": [
#     "Phi3ForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "auto_map": {
#     "AutoConfig": "kaitchup/Phi-3.5-Mini-instruct-AutoRound-4bit--configuration_phi3.Phi3Config",
#     "AutoModelForCausalLM": "kaitchup/Phi-3.5-Mini-instruct-AutoRound-4bit--modeling_phi3.Phi3ForCausalLM"
#   },
#   "bos_token_id": 1,
#   "embd_pdrop": 0.0,
#   "eos_token_id": 32000,
#   "hidden_act": "silu",
#   "hidden_size": 3072,
#   "initializer_range": 0.02,
#   "intermediate_size": 8192,
#   "max_position_embeddings": 131072,
#   "model_type": "phi3",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 32,
#   "original_max_position_embeddings": 4096,
#   "pad_token_id": 32000,
#   "quantization_config": {
#     "batch_size": 1,
#     "bits": 4,
#     "block_name_to_quantize": null,
#     "cache_block_outputs": true,
#     "damp_percent": 0.01,
#     "dataset": null,
#     "desc_act": false,
#     "exllama_config": {
#       "version": 1
#     },
#     "group_size": 128,
#     "max_input_length": null,
#     "model_seqlen": null,
#     "module_name_preceding_first_block": null,
#     "modules_in_block_to_quantize": null,
#     "pad_token_id": null,
#     "quant_method": "gptq",
#     "sym": true,
#     "tokenizer": null,
#     "true_sequential": false,
#     "use_cuda_fp16": false,
#     "use_exllama": true
#   },
#   "resid_pdrop": 0.0,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": {
#     "long_factor": [
#       1.0800000429153442,
#       1.1100000143051147,
#       1.1399999856948853,
#       1.340000033378601,
#       1.5899999141693115,
#       1.600000023841858,
#       1.6200000047683716,
#       2.620000123977661,
#       3.2300000190734863,
#       3.2300000190734863,
#       4.789999961853027,
#       7.400000095367432,
#       7.700000286102295,
#       9.09000015258789,
#       12.199999809265137,
#       17.670000076293945,
#       24.46000099182129,
#       28.57000160217285,
#       30.420001983642578,
#       30.840002059936523,
#       32.590003967285156,
#       32.93000411987305,
#       42.320003509521484,
#       44.96000289916992,
#       50.340003967285156,
#       50.45000457763672,
#       57.55000305175781,
#       57.93000411987305,
#       58.21000289916992,
#       60.1400032043457,
#       62.61000442504883,
#       62.62000274658203,
#       62.71000289916992,
#       63.1400032043457,
#       63.1400032043457,
#       63.77000427246094,
#       63.93000411987305,
#       63.96000289916992,
#       63.970001220703125,
#       64.02999877929688,
#       64.06999969482422,
#       64.08000183105469,
#       64.12000274658203,
#       64.41000366210938,
#       64.4800033569336,
#       64.51000213623047,
#       64.52999877929688,
#       64.83999633789062
#     ],
#     "short_factor": [
#       1.0,
#       1.0199999809265137,
#       1.0299999713897705,
#       1.0299999713897705,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0699999332427979,
#       1.0999999046325684,
#       1.1099998950958252,
#       1.1599998474121094,
#       1.1599998474121094,
#       1.1699998378753662,
#       1.2899998426437378,
#       1.339999794960022,
#       1.679999828338623,
#       1.7899998426437378,
#       1.8199998140335083,
#       1.8499997854232788,
#       1.8799997568130493,
#       1.9099997282028198,
#       1.9399996995925903,
#       1.9899996519088745,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0799996852874756,
#       2.0899996757507324,
#       2.189999580383301,
#       2.2199995517730713,
#       2.5899994373321533,
#       2.729999542236328,
#       2.749999523162842,
#       2.8399994373321533
#     ],
#     "type": "longrope"
#   },
#   "rope_theta": 10000.0,
#   "sliding_window": 262144,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.43.4",
#   "use_cache": true,
#   "vocab_size": 32064
# }
#
# tokenizer config file saved in ./Phi-3.5/Phi-3.5-Mini_QLoRA_AutoRound/checkpoint-307/tokenizer_config.json
# Special tokens file saved in ./Phi-3.5/Phi-3.5-Mini_QLoRA_AutoRound/checkpoint-307/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=307, training_loss=1.2267252366006958, metrics={'train_runtime': 5841.9991, 'train_samples_per_second': 1.685, 'train_steps_per_second': 0.053, 'total_flos': 3224588596002816.0, 'train_loss': 1.2267252366006958, 'epoch': 0.9975629569455727})

# %% [markdown]
# ##LoRA
# * GPU requirements: 16 GB

# %%
import torch
from datasets import load_dataset
from peft import LoraConfig
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    TrainingArguments,
)
from trl import SFTTrainer, SFTConfig

#use bf16 and FlashAttention if supported
if torch.cuda.is_bf16_supported():
  compute_dtype = torch.bfloat16
  attn_implementation = 'flash_attention_2'
else:
  compute_dtype = torch.float16
  attn_implementation = 'sdpa'

model_name = "microsoft/Phi-3.5-Mini-instruct"

tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True, add_eos_token=True, use_fast=True)
tokenizer.pad_token = tokenizer.unk_token
tokenizer.pad_token_id = tokenizer.convert_tokens_to_ids(tokenizer.pad_token)
tokenizer.padding_side = 'left'

ds = load_dataset("timdettmers/openassistant-guanaco")


model = AutoModelForCausalLM.from_pretrained(
          model_name, torch_dtype=compute_dtype, trust_remote_code=True,  device_map={"": 0}, attn_implementation=attn_implementation
)

model.gradient_checkpointing_enable(gradient_checkpointing_kwargs={'use_reentrant':True})

peft_config = LoraConfig(
        lora_alpha=16,
        lora_dropout=0.05,
        r=16,
        bias="none",
        task_type="CAUSAL_LM",
        target_modules= ['k_proj', 'q_proj', 'v_proj', 'o_proj', "gate_proj", "down_proj", "up_proj"]
)


training_arguments = SFTConfig(
        output_dir="./Phi-3.5/Phi-3.5-Mini_LoRA",
        eval_strategy="steps",
        do_eval=True,
        optim="adamw_torch",
        per_device_train_batch_size=4,
        gradient_accumulation_steps=8,
        per_device_eval_batch_size=4,
        log_level="debug",
        save_strategy="epoch",
        logging_steps=25,
        learning_rate=1e-4,
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        eval_steps=25,
        num_train_epochs=1,
        warmup_ratio=0.1,
        lr_scheduler_type="linear",
        dataset_text_field="text",
        max_seq_length=512
)

trainer = SFTTrainer(
        model=model,
        train_dataset=ds['train'],
        eval_dataset=ds['test'],
        peft_config=peft_config,
        tokenizer=tokenizer,
        args=training_arguments,
)

trainer.train()
# Out:
# loading file tokenizer.model from cache at /root/.cache/huggingface/hub/models--microsoft--Phi-3.5-Mini-instruct/snapshots/64963004ad95869fa73a30279371c8778509ac84/tokenizer.model
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--microsoft--Phi-3.5-Mini-instruct/snapshots/64963004ad95869fa73a30279371c8778509ac84/tokenizer.json
# loading file added_tokens.json from cache at /root/.cache/huggingface/hub/models--microsoft--Phi-3.5-Mini-instruct/snapshots/64963004ad95869fa73a30279371c8778509ac84/added_tokens.json
# loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--microsoft--Phi-3.5-Mini-instruct/snapshots/64963004ad95869fa73a30279371c8778509ac84/special_tokens_map.json
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--microsoft--Phi-3.5-Mini-instruct/snapshots/64963004ad95869fa73a30279371c8778509ac84/tokenizer_config.json
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--microsoft--Phi-3.5-Mini-instruct/snapshots/64963004ad95869fa73a30279371c8778509ac84/config.json
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--microsoft--Phi-3.5-Mini-instruct/snapshots/64963004ad95869fa73a30279371c8778509ac84/config.json
# Model config Phi3Config {
#   "_name_or_path": "microsoft/Phi-3.5-Mini-instruct",
#   "architectures": [
#     "Phi3ForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "auto_map": {
#     "AutoConfig": "microsoft/Phi-3.5-Mini-instruct--configuration_phi3.Phi3Config",
#     "AutoModelForCausalLM": "microsoft/Phi-3.5-Mini-instruct--modeling_phi3.Phi3ForCausalLM"
#   },
#   "bos_token_id": 1,
#   "embd_pdrop": 0.0,
#   "eos_token_id": 32000,
#   "hidden_act": "silu",
#   "hidden_size": 3072,
#   "initializer_range": 0.02,
#   "intermediate_size": 8192,
#   "max_position_embeddings": 131072,
#   "model_type": "phi3",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 32,
#   "original_max_position_embeddings": 4096,
#   "pad_token_id": 32000,
#   "resid_pdrop": 0.0,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": {
#     "long_factor": [
#       1.0800000429153442,
#       1.1100000143051147,
#       1.1399999856948853,
#       1.340000033378601,
#       1.5899999141693115,
#       1.600000023841858,
#       1.6200000047683716,
#       2.620000123977661,
#       3.2300000190734863,
#       3.2300000190734863,
#       4.789999961853027,
#       7.400000095367432,
#       7.700000286102295,
#       9.09000015258789,
#       12.199999809265137,
#       17.670000076293945,
#       24.46000099182129,
#       28.57000160217285,
#       30.420001983642578,
#       30.840002059936523,
#       32.590003967285156,
#       32.93000411987305,
#       42.320003509521484,
#       44.96000289916992,
#       50.340003967285156,
#       50.45000457763672,
#       57.55000305175781,
#       57.93000411987305,
#       58.21000289916992,
#       60.1400032043457,
#       62.61000442504883,
#       62.62000274658203,
#       62.71000289916992,
#       63.1400032043457,
#       63.1400032043457,
#       63.77000427246094,
#       63.93000411987305,
#       63.96000289916992,
#       63.970001220703125,
#       64.02999877929688,
#       64.06999969482422,
#       64.08000183105469,
#       64.12000274658203,
#       64.41000366210938,
#       64.4800033569336,
#       64.51000213623047,
#       64.52999877929688,
#       64.83999633789062
#     ],
#     "short_factor": [
#       1.0,
#       1.0199999809265137,
#       1.0299999713897705,
#       1.0299999713897705,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0699999332427979,
#       1.0999999046325684,
#       1.1099998950958252,
#       1.1599998474121094,
#       1.1599998474121094,
#       1.1699998378753662,
#       1.2899998426437378,
#       1.339999794960022,
#       1.679999828338623,
#       1.7899998426437378,
#       1.8199998140335083,
#       1.8499997854232788,
#       1.8799997568130493,
#       1.9099997282028198,
#       1.9399996995925903,
#       1.9899996519088745,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0799996852874756,
#       2.0899996757507324,
#       2.189999580383301,
#       2.2199995517730713,
#       2.5899994373321533,
#       2.729999542236328,
#       2.749999523162842,
#       2.8399994373321533
#     ],
#     "type": "longrope"
#   },
#   "rope_theta": 10000.0,
#   "sliding_window": 262144,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.44.1",
#   "use_cache": true,
#   "vocab_size": 32064
# }
#
# loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--microsoft--Phi-3.5-Mini-instruct/snapshots/64963004ad95869fa73a30279371c8778509ac84/model.safetensors.index.json
# Instantiating Phi3ForCausalLM model under default dtype torch.bfloat16.
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "eos_token_id": 32000,
#   "pad_token_id": 32000
# }
#
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Detected flash_attn version: 2.6.3
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# All model checkpoint weights were used when initializing Phi3ForCausalLM.
#
# All the weights of Phi3ForCausalLM were initialized from the model checkpoint at microsoft/Phi-3.5-Mini-instruct.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use Phi3ForCausalLM for predictions without further training.
# loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--microsoft--Phi-3.5-Mini-instruct/snapshots/64963004ad95869fa73a30279371c8778509ac84/generation_config.json
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "eos_token_id": [
#     32007,
#     32001,
#     32000
#   ],
#   "pad_token_id": 32000
# }
#
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# Map:   0%|          | 0/518 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:408: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(
# Using auto half precision backend
# Currently training with a batch size of: 4
# ***** Running training *****
#   Num examples = 9,846
#   Num Epochs = 1
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 8
#   Total optimization steps = 307
#   Number of trainable parameters = 8,912,896
#     <div>
#
#       <progress value='307' max='307' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [307/307 1:07:27, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>1.596400</td>
#       <td>1.459000</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.269300</td>
#       <td>1.270693</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.209800</td>
#       <td>1.239383</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.188400</td>
#       <td>1.228382</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>1.166500</td>
#       <td>1.221909</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.132000</td>
#       <td>1.218116</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>1.153600</td>
#       <td>1.215834</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.156100</td>
#       <td>1.214221</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>1.148000</td>
#       <td>1.213173</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.166500</td>
#       <td>1.212524</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>1.127500</td>
#       <td>1.212019</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.125200</td>
#       <td>1.211828</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
#
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# Saving model checkpoint to ./Phi-3.5/Phi-3.5-Mini_LoRA/checkpoint-307
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--microsoft--Phi-3.5-Mini-instruct/snapshots/64963004ad95869fa73a30279371c8778509ac84/config.json
# Model config Phi3Config {
#   "_name_or_path": "Phi-3.5-mini-instruct",
#   "architectures": [
#     "Phi3ForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "auto_map": {
#     "AutoConfig": "microsoft/Phi-3.5-Mini-instruct--configuration_phi3.Phi3Config",
#     "AutoModelForCausalLM": "microsoft/Phi-3.5-Mini-instruct--modeling_phi3.Phi3ForCausalLM"
#   },
#   "bos_token_id": 1,
#   "embd_pdrop": 0.0,
#   "eos_token_id": 32000,
#   "hidden_act": "silu",
#   "hidden_size": 3072,
#   "initializer_range": 0.02,
#   "intermediate_size": 8192,
#   "max_position_embeddings": 131072,
#   "model_type": "phi3",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 32,
#   "original_max_position_embeddings": 4096,
#   "pad_token_id": 32000,
#   "resid_pdrop": 0.0,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": {
#     "long_factor": [
#       1.0800000429153442,
#       1.1100000143051147,
#       1.1399999856948853,
#       1.340000033378601,
#       1.5899999141693115,
#       1.600000023841858,
#       1.6200000047683716,
#       2.620000123977661,
#       3.2300000190734863,
#       3.2300000190734863,
#       4.789999961853027,
#       7.400000095367432,
#       7.700000286102295,
#       9.09000015258789,
#       12.199999809265137,
#       17.670000076293945,
#       24.46000099182129,
#       28.57000160217285,
#       30.420001983642578,
#       30.840002059936523,
#       32.590003967285156,
#       32.93000411987305,
#       42.320003509521484,
#       44.96000289916992,
#       50.340003967285156,
#       50.45000457763672,
#       57.55000305175781,
#       57.93000411987305,
#       58.21000289916992,
#       60.1400032043457,
#       62.61000442504883,
#       62.62000274658203,
#       62.71000289916992,
#       63.1400032043457,
#       63.1400032043457,
#       63.77000427246094,
#       63.93000411987305,
#       63.96000289916992,
#       63.970001220703125,
#       64.02999877929688,
#       64.06999969482422,
#       64.08000183105469,
#       64.12000274658203,
#       64.41000366210938,
#       64.4800033569336,
#       64.51000213623047,
#       64.52999877929688,
#       64.83999633789062
#     ],
#     "short_factor": [
#       1.0,
#       1.0199999809265137,
#       1.0299999713897705,
#       1.0299999713897705,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0699999332427979,
#       1.0999999046325684,
#       1.1099998950958252,
#       1.1599998474121094,
#       1.1599998474121094,
#       1.1699998378753662,
#       1.2899998426437378,
#       1.339999794960022,
#       1.679999828338623,
#       1.7899998426437378,
#       1.8199998140335083,
#       1.8499997854232788,
#       1.8799997568130493,
#       1.9099997282028198,
#       1.9399996995925903,
#       1.9899996519088745,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0799996852874756,
#       2.0899996757507324,
#       2.189999580383301,
#       2.2199995517730713,
#       2.5899994373321533,
#       2.729999542236328,
#       2.749999523162842,
#       2.8399994373321533
#     ],
#     "type": "longrope"
#   },
#   "rope_theta": 10000.0,
#   "sliding_window": 262144,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.44.1",
#   "use_cache": true,
#   "vocab_size": 32064
# }
#
# tokenizer config file saved in ./Phi-3.5/Phi-3.5-Mini_LoRA/checkpoint-307/tokenizer_config.json
# Special tokens file saved in ./Phi-3.5/Phi-3.5-Mini_LoRA/checkpoint-307/special_tokens_map.json
# Saving model checkpoint to ./Phi-3.5/Phi-3.5-Mini_LoRA/checkpoint-307
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--microsoft--Phi-3.5-Mini-instruct/snapshots/64963004ad95869fa73a30279371c8778509ac84/config.json
# Model config Phi3Config {
#   "_name_or_path": "Phi-3.5-mini-instruct",
#   "architectures": [
#     "Phi3ForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "auto_map": {
#     "AutoConfig": "microsoft/Phi-3.5-Mini-instruct--configuration_phi3.Phi3Config",
#     "AutoModelForCausalLM": "microsoft/Phi-3.5-Mini-instruct--modeling_phi3.Phi3ForCausalLM"
#   },
#   "bos_token_id": 1,
#   "embd_pdrop": 0.0,
#   "eos_token_id": 32000,
#   "hidden_act": "silu",
#   "hidden_size": 3072,
#   "initializer_range": 0.02,
#   "intermediate_size": 8192,
#   "max_position_embeddings": 131072,
#   "model_type": "phi3",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 32,
#   "original_max_position_embeddings": 4096,
#   "pad_token_id": 32000,
#   "resid_pdrop": 0.0,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": {
#     "long_factor": [
#       1.0800000429153442,
#       1.1100000143051147,
#       1.1399999856948853,
#       1.340000033378601,
#       1.5899999141693115,
#       1.600000023841858,
#       1.6200000047683716,
#       2.620000123977661,
#       3.2300000190734863,
#       3.2300000190734863,
#       4.789999961853027,
#       7.400000095367432,
#       7.700000286102295,
#       9.09000015258789,
#       12.199999809265137,
#       17.670000076293945,
#       24.46000099182129,
#       28.57000160217285,
#       30.420001983642578,
#       30.840002059936523,
#       32.590003967285156,
#       32.93000411987305,
#       42.320003509521484,
#       44.96000289916992,
#       50.340003967285156,
#       50.45000457763672,
#       57.55000305175781,
#       57.93000411987305,
#       58.21000289916992,
#       60.1400032043457,
#       62.61000442504883,
#       62.62000274658203,
#       62.71000289916992,
#       63.1400032043457,
#       63.1400032043457,
#       63.77000427246094,
#       63.93000411987305,
#       63.96000289916992,
#       63.970001220703125,
#       64.02999877929688,
#       64.06999969482422,
#       64.08000183105469,
#       64.12000274658203,
#       64.41000366210938,
#       64.4800033569336,
#       64.51000213623047,
#       64.52999877929688,
#       64.83999633789062
#     ],
#     "short_factor": [
#       1.0,
#       1.0199999809265137,
#       1.0299999713897705,
#       1.0299999713897705,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0499999523162842,
#       1.0699999332427979,
#       1.0999999046325684,
#       1.1099998950958252,
#       1.1599998474121094,
#       1.1599998474121094,
#       1.1699998378753662,
#       1.2899998426437378,
#       1.339999794960022,
#       1.679999828338623,
#       1.7899998426437378,
#       1.8199998140335083,
#       1.8499997854232788,
#       1.8799997568130493,
#       1.9099997282028198,
#       1.9399996995925903,
#       1.9899996519088745,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0199997425079346,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0299997329711914,
#       2.0799996852874756,
#       2.0899996757507324,
#       2.189999580383301,
#       2.2199995517730713,
#       2.5899994373321533,
#       2.729999542236328,
#       2.749999523162842,
#       2.8399994373321533
#     ],
#     "type": "longrope"
#   },
#   "rope_theta": 10000.0,
#   "sliding_window": 262144,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.44.1",
#   "use_cache": true,
#   "vocab_size": 32064
# }
#
# tokenizer config file saved in ./Phi-3.5/Phi-3.5-Mini_LoRA/checkpoint-307/tokenizer_config.json
# Special tokens file saved in ./Phi-3.5/Phi-3.5-Mini_LoRA/checkpoint-307/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=307, training_loss=1.2014875536244545, metrics={'train_runtime': 4058.6058, 'train_samples_per_second': 2.426, 'train_steps_per_second': 0.076, 'total_flos': 1.0693751107780608e+17, 'train_loss': 1.2014875536244545, 'epoch': 0.9975629569455727})

# %% [markdown]
# #Fine-tuning Phi-3.5 MoE

# %% [markdown]
# ##QLoRA with bitsandbytes

# %%
import torch
from datasets import load_dataset
from peft import LoraConfig, prepare_model_for_kbit_training
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
)
from trl import SFTTrainer, SFTConfig

#use bf16 and FlashAttention if supported
if torch.cuda.is_bf16_supported():
  compute_dtype = torch.bfloat16
  attn_implementation = 'flash_attention_2'
else:
  compute_dtype = torch.float16
  attn_implementation = 'sdpa'

model_name = "microsoft/Phi-3.5-MoE-instruct"

tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True, add_eos_token=True, use_fast=True)
tokenizer.pad_token = tokenizer.unk_token
tokenizer.pad_token_id = tokenizer.convert_tokens_to_ids(tokenizer.pad_token)
tokenizer.padding_side = 'left'

ds = load_dataset("timdettmers/openassistant-guanaco")

bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)
model = AutoModelForCausalLM.from_pretrained(
          model_name, torch_dtype=compute_dtype, trust_remote_code=True, quantization_config=bnb_config, device_map={"": 0}, attn_implementation=attn_implementation
)
print(model)
print(model.get_memory_footprint())


model = prepare_model_for_kbit_training(model,gradient_checkpointing_kwargs={'use_reentrant':True})

peft_config = LoraConfig(
        lora_alpha=16,
        lora_dropout=0.05,
        r=16,
        bias="none",
        task_type="CAUSAL_LM",
        target_modules= ['k_proj', 'q_proj', 'v_proj', 'o_proj', "gate_proj", "down_proj", "up_proj","gate","w1","w2","w3"]
)


training_arguments = SFTConfig(
        output_dir="./Phi-3.5/Phi-3.5-MoE_QLoRA",
        eval_strategy="steps",
        do_eval=True,
        optim="paged_adamw_8bit",
        per_device_train_batch_size=1,
        gradient_accumulation_steps=32,
        per_device_eval_batch_size=1,
        log_level="debug",
        save_strategy="epoch",
        logging_steps=25,
        learning_rate=1e-4,
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        eval_steps=25,
        num_train_epochs=1,
        warmup_ratio=0.1,
        lr_scheduler_type="linear",
        dataset_text_field="text",
        max_seq_length=512
)

trainer = SFTTrainer(
        model=model,
        train_dataset=ds['train'],
        eval_dataset=ds['test'],
        peft_config=peft_config,
        tokenizer=tokenizer,
        args=training_arguments,
)

trainer.train()
