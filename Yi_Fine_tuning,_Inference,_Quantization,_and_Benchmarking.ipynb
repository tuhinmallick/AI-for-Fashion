# %% [markdown]
# <a href="https://colab.research.google.com/github/tuhinmallick/AI-for-Fashion/blob/main/Yi_Fine_tuning%2C_Inference%2C_Quantization%2C_and_Benchmarking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook shows how to:
#
# *   Fine-tune Yi-6B with QLoRA
# *   Quantize Yi-6B with BitsandBytes, GPTQ and AWQ
# *   Infer with Transformers and vLLM
# *   Benchmark Yi-6B with optimum-benchmark and the Evaluation Harness.
#
# Each section of this notebook can be run independently.
#
# More details and comments: [Yi: Fine-tune and Run One of the Best Bilingual LLMs on Your Computer](https://kaitchup.substack.com/p/yi-fine-tune-and-run-one-the-best)

# %% [markdown]
# # Inference

# %% [markdown]
# With vLLM

# %%
# !pip install vllm
# Out:
# Collecting vllm
#   Downloading vllm-0.3.3-cp310-cp310-manylinux1_x86_64.whl (44.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 MB 40.1 MB/s eta 0:00:00
# Collecting ninja (from vllm)
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 37.2 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from vllm) (5.9.5)
# Collecting ray>=2.9 (from vllm)
#   Downloading ray-2.9.3-cp310-cp310-manylinux2014_x86_64.whl (64.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 MB 24.8 MB/s eta 0:00:00
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from vllm) (0.1.99)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vllm) (1.25.2)
# Collecting torch==2.1.2 (from vllm)
#   Downloading torch-2.1.2-cp310-cp310-manylinux1_x86_64.whl (670.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: transformers>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from vllm) (4.38.2)
# Collecting xformers==0.0.23.post1 (from vllm)
#   Downloading xformers-0.0.23.post1-cp310-cp310-manylinux2014_x86_64.whl (213.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 MB 7.7 MB/s eta 0:00:00
# Collecting fastapi (from vllm)
#   Downloading fastapi-0.110.0-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 14.2 MB/s eta 0:00:00
# Collecting uvicorn[standard] (from vllm)
#   Downloading uvicorn-0.28.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from vllm) (2.6.4)
# Requirement already satisfied: prometheus-client>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from vllm) (0.20.0)
# Collecting pynvml==11.5.0 (from vllm)
#   Downloading pynvml-11.5.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: triton>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from vllm) (2.2.0)
# Collecting outlines>=0.0.27 (from vllm)
#   Downloading outlines-0.0.36-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.7/79.7 kB 12.5 MB/s eta 0:00:00
# Collecting cupy-cuda12x==12.1.0 (from vllm)
#   Downloading cupy_cuda12x-12.1.0-cp310-cp310-manylinux2014_x86_64.whl (83.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 MB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.10/dist-packages (from cupy-cuda12x==12.1.0->vllm) (0.8.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->vllm) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->vllm) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->vllm) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->vllm) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->vllm) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->vllm) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.1.2->vllm)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 58.0 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.1.2->vllm)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 67.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.1.2->vllm)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 92.2 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.1.2->vllm)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.8 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.1.2->vllm)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.4 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.1.2->vllm)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 14.2 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.1.2->vllm)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 24.4 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.1.2->vllm)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 6.8 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.1.2->vllm)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 8.7 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.18.1 (from torch==2.1.2->vllm)
#   Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 4.1 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.1.2->vllm)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 14.7 MB/s eta 0:00:00
# Collecting triton>=2.1.0 (from vllm)
#   Downloading triton-2.1.0-0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 19.0 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.2->vllm)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.0 MB/s eta 0:00:00
# Collecting interegular (from outlines>=0.0.27->vllm)
#   Downloading interegular-0.3.3-py37-none-any.whl (23 kB)
# Collecting lark (from outlines>=0.0.27->vllm)
#   Downloading lark-1.1.9-py3-none-any.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 17.1 MB/s eta 0:00:00
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from outlines>=0.0.27->vllm) (1.6.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from outlines>=0.0.27->vllm) (2.2.1)
# Collecting diskcache (from outlines>=0.0.27->vllm)
#   Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from outlines>=0.0.27->vllm) (1.11.4)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from outlines>=0.0.27->vllm) (0.58.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from outlines>=0.0.27->vllm) (1.3.2)
# Requirement already satisfied: referencing in /usr/local/lib/python3.10/dist-packages (from outlines>=0.0.27->vllm) (0.33.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from outlines>=0.0.27->vllm) (4.19.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from outlines>=0.0.27->vllm) (2.31.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->vllm) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->vllm) (2.16.3)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm) (8.1.7)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm) (1.0.8)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm) (24.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm) (3.20.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm) (6.0.1)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm) (1.4.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.0->vllm) (0.20.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.0->vllm) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.0->vllm) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.0->vllm) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.0->vllm) (4.66.2)
# Collecting starlette<0.37.0,>=0.36.3 (from fastapi->vllm)
#   Downloading starlette-0.36.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 11.2 MB/s eta 0:00:00
# Collecting h11>=0.8 (from uvicorn[standard]->vllm)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.9 MB/s eta 0:00:00
# Collecting httptools>=0.5.0 (from uvicorn[standard]->vllm)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 41.1 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn[standard]->vllm)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]->vllm)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 104.1 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]->vllm)
#   Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.0 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]->vllm)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 19.1 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.37.0,>=0.36.3->fastapi->vllm) (3.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.1.2->vllm) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->outlines>=0.0.27->vllm) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->outlines>=0.0.27->vllm) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->outlines>=0.0.27->vllm) (0.18.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->outlines>=0.0.27->vllm) (0.41.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->outlines>=0.0.27->vllm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->outlines>=0.0.27->vllm) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->outlines>=0.0.27->vllm) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->outlines>=0.0.27->vllm) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.1.2->vllm) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.37.0,>=0.36.3->fastapi->vllm) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.37.0,>=0.36.3->fastapi->vllm) (1.2.0)
# Installing collected packages: ninja, websockets, uvloop, triton, python-dotenv, pynvml, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lark, interegular, httptools, h11, diskcache, cupy-cuda12x, watchfiles, uvicorn, starlette, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, fastapi, torch, ray, xformers, outlines, vllm
#   Attempting uninstall: triton
#     Found existing installation: triton 2.2.0
#     Uninstalling triton-2.2.0:
#       Successfully uninstalled triton-2.2.0
#   Attempting uninstall: cupy-cuda12x
#     Found existing installation: cupy-cuda12x 12.2.0
#     Uninstalling cupy-cuda12x-12.2.0:
#       Successfully uninstalled cupy-cuda12x-12.2.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.1+cu121
#     Uninstalling torch-2.2.1+cu121:
#       Successfully uninstalled torch-2.2.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.2.1+cu121 requires torch==2.2.1, but you have torch 2.1.2 which is incompatible.
# torchtext 0.17.1 requires torch==2.2.1, but you have torch 2.1.2 which is incompatible.
# torchvision 0.17.1+cu121 requires torch==2.2.1, but you have torch 2.1.2 which is incompatible.
# Successfully installed cupy-cuda12x-12.1.0 diskcache-5.6.3 fastapi-0.110.0 h11-0.14.0 httptools-0.6.1 interegular-0.3.3 lark-1.1.9 ninja-1.11.1.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 outlines-0.0.36 pynvml-11.5.0 python-dotenv-1.0.1 ray-2.9.3 starlette-0.36.3 torch-2.1.2 triton-2.1.0 uvicorn-0.28.0 uvloop-0.19.0 vllm-0.3.3 watchfiles-0.21.0 websockets-12.0 xformers-0.0.23.post1

# %% [markdown]
# Without quantization, you need at least 12 GB of GPU VRAM

# %%
import time
from vllm import LLM, SamplingParams

prompts = [
    "The best recipe for pasta is"
]
sampling_params = SamplingParams(temperature=0.7, top_p=0.8, top_k=20, max_tokens=150)

loading_start = time.time()
llm = LLM(model="01-ai/Yi-6B")
print("--- Loading time: %s seconds ---" % (time.time() - loading_start))

generation_time = time.time()
outputs = llm.generate(prompts, sampling_params)
print("--- Generation time: %s seconds ---" % (time.time() - generation_time))

for output in outputs:
    generated_text = output.outputs[0].text
    print(generated_text)
    print('------')
# Out:
# config.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# INFO 03-17 06:39:52 llm_engine.py:87] Initializing an LLM engine with config: model='01-ai/Yi-6B', tokenizer='01-ai/Yi-6B', tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=4096, download_dir=None, load_format=auto, tensor_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, device_config=cuda, seed=0)
# tokenizer_config.json:   0%|          | 0.00/320 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/1.03M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.56M [00:00<?, ?B/s]
# INFO 03-17 06:40:00 weight_utils.py:163] Using model weights format ['*.safetensors']
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.18G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# INFO 03-17 06:49:11 llm_engine.py:357] # GPU blocks: 23922, # CPU blocks: 4096
# INFO 03-17 06:49:13 model_runner.py:684] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 03-17 06:49:13 model_runner.py:688] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 03-17 06:49:19 model_runner.py:756] Graph capturing finished in 6 secs.
# --- Loading time: 568.9558756351471 seconds ---
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.77s/it]
# --- Generation time: 1.7790272235870361 seconds ---
#  a simple one: cook the pasta al dente, then toss with the sauce of your choice.
# What is the best pasta to make with a simple sauce?
# The best pasta to make with a simple sauce is the one that suits your taste buds the most.
# What is the best pasta to make with a simple sauce?
# The best pasta to make with a simple sauce is the one that suits your taste buds the most.
# What is the best pasta to make with a simple sauce?
# The best pasta to make with a simple sauce is the one that suits your taste buds the most.
# What is the best pasta to make with a simple sauce?
# The best pasta to make with a simple sauce is the one that suits
# ------

# %% [markdown]
# Version with the AWQ quantized model.
# To know how I made this quantized model, have a look at the section "quantization" below.

# %%
import time
from vllm import LLM, SamplingParams

prompts = [
    "The best recipe for pasta is"
]
sampling_params = SamplingParams(temperature=0.7, top_p=0.8, top_k=20, max_tokens=150)

loading_start = time.time()
llm = LLM(model="kaitchup/Yi-6B-awq-4bit", quantization="awq")
print("--- Loading time: %s seconds ---" % (time.time() - loading_start))

generation_time = time.time()
outputs = llm.generate(prompts, sampling_params)
print("--- Generation time: %s seconds ---" % (time.time() - generation_time))

for output in outputs:
    generated_text = output.outputs[0].text
    print(generated_text)
    print('------')
# Out:
# WARNING 03-17 06:51:02 config.py:193] awq quantization is not fully optimized yet. The speed can be slower than non-quantized models.
# INFO 03-17 06:51:02 llm_engine.py:87] Initializing an LLM engine with config: model='kaitchup/Yi-6B-awq-4bit', tokenizer='kaitchup/Yi-6B-awq-4bit', tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=4096, download_dir=None, load_format=auto, tensor_parallel_size=1, disable_custom_all_reduce=False, quantization=awq, enforce_eager=False, kv_cache_dtype=auto, device_config=cuda, seed=0)
# INFO 03-17 06:51:06 weight_utils.py:163] Using model weights format ['*.safetensors']
# model.safetensors:   0%|          | 0.00/3.93G [00:00<?, ?B/s]
# INFO 03-17 06:51:21 llm_engine.py:357] # GPU blocks: 31680, # CPU blocks: 4096
# INFO 03-17 06:51:23 model_runner.py:684] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 03-17 06:51:23 model_runner.py:688] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 03-17 06:51:30 model_runner.py:756] Graph capturing finished in 7 secs.
# --- Loading time: 29.90104651451111 seconds ---
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.32s/it]
# --- Generation time: 1.3277652263641357 seconds ---
#  a simple one: cook pasta in boiling salted water, drain and serve with a little butter, grated cheese and freshly ground pepper.
# What is the best way to cook pasta?
# Cooking pasta is simple. Just bring a large pot of salted water to a boil, add the pasta, cook for 8-12 minutes, drain, and serve. But there are so many ways to cook pasta. You can make it al dente, or you can make it mushy.
# What is the best way to cook pasta for 1?
# Cooking pasta is simple. Just bring a large pot of salted water to a boil, add the pasta, cook for 8-12 minutes, drain,
# ------

# %% [markdown]
# With Hugging Face's Transformers (16-bit version)

# %%
# !pip install accelerate transformers autoawq
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.28.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Collecting autoawq
#   Downloading autoawq-0.2.3-cp310-cp310-manylinux2014_x86_64.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.0/79.0 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.2)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from autoawq) (4.10.0)
# Collecting datasets (from autoawq)
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 26.8 MB/s eta 0:00:00
# Collecting zstandard (from autoawq)
#   Downloading zstandard-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 90.9 MB/s eta 0:00:00
# Collecting autoawq-kernels (from autoawq)
#   Downloading autoawq_kernels-0.0.6-cp310-cp310-manylinux2014_x86_64.whl (33.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.4/33.4 MB 41.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2023.6.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.4.99)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->autoawq)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 16.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (1.5.3)
# Collecting xxhash (from datasets->autoawq)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 28.2 MB/s eta 0:00:00
# Collecting multiprocess (from datasets->autoawq)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.4 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (3.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2023.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets->autoawq) (1.16.0)
# Installing collected packages: zstandard, xxhash, dill, multiprocess, datasets, autoawq-kernels, autoawq
# Successfully installed autoawq-0.2.3 autoawq-kernels-0.0.6 datasets-2.18.0 dill-0.3.8 multiprocess-0.70.16 xxhash-3.4.1 zstandard-0.22.0

# %% [markdown]
# Using Yi (16-bit version)

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, set_seed

set_seed(1234)  # For reproducibility

prompt = "The best recipe for pasta is"

checkpoint = "01-ai/Yi-6B"

tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForCausalLM.from_pretrained(checkpoint, torch_dtype="auto", device_map="cuda")

inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
outputs = model.generate(**inputs, do_sample=True, max_new_tokens=150)
result = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(result)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# The best recipe for pasta is the one your mama made. Here is an elegant Italian pasta recipe from an old, old cookbook which uses the classic combination of butter and olive oil as a sauce. It can either stand alone as a sauce or be served over your favorite pasta noodles as a main course. Try it! It was my father's favorite "going to Italy" dish.
# Linguine and Spinach Pasta Sauce
# 1/2 lb linguine
# 10 oz frozen spinach (or frozen chopped spinach if available), cooked, cooled and drained
# 1/2 oz butter
# 1/2 teaspoon salt (or more to taste)
# 1/2 teaspoon white wine vinegar (or more to taste)
# 1/4 cup Parmesan

# %% [markdown]
# With Hugging Face's Transformers with the model quantized with AWQ 4-bit

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, set_seed

set_seed(1234)  # For reproducibility

prompt = "The best recipe for pasta is"

checkpoint = "kaitchup/Yi-6B-awq-4bit"

tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForCausalLM.from_pretrained(checkpoint, device_map='cuda')

inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
outputs = model.generate(**inputs, do_sample=True, max_new_tokens=150)
result = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(result)
# Out:
# The best recipe for pasta is the one your mama made. Here is an elegant Italian pasta recipe from an old, old cookbook which uses the classic combination of butter and garlic. For a mains dish you could make a creamy chicken or fish dish , or serve with veal or pork with a light sauce. It was my way of saying 'Thank you!', 'I love you.' and 'Goodbye,' all at the same time. The other great recipe for pasta is the one your mama made. Here are some suggestions for preparing pasta dishes in one way or another: pasta with sauce, pasta with vegetables. How to Choose a Pasta Dish and What to Offer with It. There are countless recipes for the pasta that you enjoy most often, and
# The best recipe for pasta is the one your mama made. Here is an elegant Italian pasta recipe from an old, old cookbook which uses the classic combination of butter and garlic. For a mains dish you could make a creamy chicken or fish dish , or serve with veal or pork with a light sauce. It was my way of saying 'Thank you!', 'I love you.' and 'Goodbye,' all at the same time. The other great recipe for pasta is the one your mama made. Here are some suggestions for preparing pasta dishes in one way or another: pasta with sauce, pasta with vegetables. How to Choose a Pasta Dish and What to Offer with It. There are countless recipes for the pasta that you enjoy most often, and

# %%
# !pip install accelerate transformers autoawq peft
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.28.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Requirement already satisfied: autoawq in /usr/local/lib/python3.10/dist-packages (0.2.3)
# Collecting peft
#   Downloading peft-0.9.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.9/190.9 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.2)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from autoawq) (4.10.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from autoawq) (2.18.0)
# Requirement already satisfied: zstandard in /usr/local/lib/python3.10/dist-packages (from autoawq) (0.22.0)
# Requirement already satisfied: autoawq-kernels in /usr/local/lib/python3.10/dist-packages (from autoawq) (0.0.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2023.6.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.4.99)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (3.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2023.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets->autoawq) (1.16.0)
# Installing collected packages: peft
# Successfully installed peft-0.9.0

# %% [markdown]
# # Quantization

# %% [markdown]
# Bitsandbytes NF4

# %%
# !pip install --upgrade transformers bitsandbytes accelerate datasets
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.43.0-py3-none-manylinux_2_24_x86_64.whl (102.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 MB 17.2 MB/s eta 0:00:00
# Collecting accelerate
#   Downloading accelerate-0.28.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 34.4 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 49.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (2.2.1+cu121)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 21.9 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->bitsandbytes)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 66.0 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->bitsandbytes)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 48.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->bitsandbytes)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 88.6 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->bitsandbytes)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.7 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->bitsandbytes)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.2 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->bitsandbytes)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 13.6 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->bitsandbytes)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 29.0 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->bitsandbytes)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 9.1 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->bitsandbytes)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 8.7 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch->bitsandbytes)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 5.8 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->bitsandbytes)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 15.6 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 79.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->bitsandbytes) (1.3.0)
# Installing collected packages: xxhash, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, nvidia-cusolver-cu12, datasets, bitsandbytes, accelerate
# Successfully installed accelerate-0.28.0 bitsandbytes-0.43.0 datasets-2.18.0 dill-0.3.8 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 xxhash-3.4.1

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

if torch.cuda.is_bf16_supported():
  compute_dtype = torch.bfloat16
else:
  compute_dtype = torch.float16

model_name = "01-ai/Yi-6B"
quant_path = 'Yi-6B-bnb-4bit'
tokenizer = AutoTokenizer.from_pretrained(model_name)
bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)
model = AutoModelForCausalLM.from_pretrained(
          model_name, quantization_config=bnb_config
)


model.save_pretrained("./"+quant_path, safetensors=True)
tokenizer.save_pretrained("./"+quant_path)
# Out:
# tokenizer_config.json:   0%|          | 0.00/320 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/1.03M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.56M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.18G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# ('./Yi-6B-bnb-4bit/tokenizer_config.json',
#  './Yi-6B-bnb-4bit/special_tokens_map.json',
#  './Yi-6B-bnb-4bit/tokenizer.model',
#  './Yi-6B-bnb-4bit/added_tokens.json',
#  './Yi-6B-bnb-4bit/tokenizer.json')

# %% [markdown]
# GPTQ
#
# More details about the GPTQ quantization in this article:
#
# [Quantize and Fine-tune LLMs with GPTQ Using Transformers and TRL](https://kaitchup.substack.com/p/quantize-and-fine-tune-llms-with)

# %%
# !pip install --upgrade transformers auto-gptq accelerate datasets
# !python -m pip install git+https://github.com/huggingface/optimum.git
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Collecting auto-gptq
#   Downloading auto_gptq-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 63.1 MB/s eta 0:00:00
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.28.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.18.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.1.99)
# Collecting rouge (from auto-gptq)
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Collecting gekko (from auto-gptq)
#   Downloading gekko-1.0.7-py3-none-any.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 98.1 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (2.2.1+cu121)
# Collecting peft>=0.5.0 (from auto-gptq)
#   Downloading peft-0.9.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.9/190.9 kB 26.4 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->auto-gptq) (12.4.99)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge->auto-gptq) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->auto-gptq) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->auto-gptq) (1.3.0)
# Installing collected packages: rouge, gekko, peft, auto-gptq
# Successfully installed auto-gptq-0.7.1 gekko-1.0.7 peft-0.9.0 rouge-1.0.1
# Collecting git+https://github.com/huggingface/optimum.git
#   Cloning https://github.com/huggingface/optimum.git to /tmp/pip-req-build-j4a_lv69
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/optimum.git /tmp/pip-req-build-j4a_lv69
#   Resolved https://github.com/huggingface/optimum.git to commit d87efb25c98741501fbf6da0d270fc181611b795
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from optimum==1.18.0.dev0) (15.0.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from optimum==1.18.0.dev0) (1.12)
# Requirement already satisfied: transformers[sentencepiece]>=4.26.0 in /usr/local/lib/python3.10/dist-packages (from optimum==1.18.0.dev0) (4.38.2)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from optimum==1.18.0.dev0) (2.2.1+cu121)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from optimum==1.18.0.dev0) (24.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optimum==1.18.0.dev0) (1.25.2)
# Requirement already satisfied: huggingface-hub>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from optimum==1.18.0.dev0) (0.20.3)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from optimum==1.18.0.dev0) (2.18.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum==1.18.0.dev0) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum==1.18.0.dev0) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum==1.18.0.dev0) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum==1.18.0.dev0) (4.66.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum==1.18.0.dev0) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum==1.18.0.dev0) (4.10.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum==1.18.0.dev0) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum==1.18.0.dev0) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum==1.18.0.dev0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum==1.18.0.dev0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum==1.18.0.dev0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum==1.18.0.dev0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum==1.18.0.dev0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum==1.18.0.dev0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum==1.18.0.dev0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum==1.18.0.dev0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum==1.18.0.dev0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum==1.18.0.dev0) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum==1.18.0.dev0) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum==1.18.0.dev0) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11->optimum==1.18.0.dev0) (12.4.99)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum==1.18.0.dev0) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum==1.18.0.dev0) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum==1.18.0.dev0) (0.4.2)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum==1.18.0.dev0) (0.1.99)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum==1.18.0.dev0) (3.20.3)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->optimum==1.18.0.dev0) (10.0)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum==1.18.0.dev0) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->optimum==1.18.0.dev0) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum==1.18.0.dev0) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->optimum==1.18.0.dev0) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->optimum==1.18.0.dev0) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->optimum==1.18.0.dev0) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->optimum==1.18.0.dev0) (3.9.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->optimum==1.18.0.dev0) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum==1.18.0.dev0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum==1.18.0.dev0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum==1.18.0.dev0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum==1.18.0.dev0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum==1.18.0.dev0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum==1.18.0.dev0) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum==1.18.0.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum==1.18.0.dev0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum==1.18.0.dev0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum==1.18.0.dev0) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11->optimum==1.18.0.dev0) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->optimum==1.18.0.dev0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->optimum==1.18.0.dev0) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets->optimum==1.18.0.dev0) (1.16.0)
# Building wheels for collected packages: optimum
#   Building wheel for optimum (pyproject.toml) ... done
#   Created wheel for optimum: filename=optimum-1.18.0.dev0-py3-none-any.whl size=409881 sha256=2be09fce1bf2d9001f74eb365be4f6e8177f81064677e33995d442248735541e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9kojqmle/wheels/8f/fa/71/cd84bac993f8fa15de35a1c058b91b9394bbc638e56c4327fd
# Successfully built optimum
# Installing collected packages: optimum
#   Attempting uninstall: optimum
#     Found existing installation: optimum 1.17.1
#     Uninstalling optimum-1.17.1:
#       Successfully uninstalled optimum-1.17.1
# Successfully installed optimum-1.18.0.dev0

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from optimum.gptq import GPTQQuantizer
import torch
model_path = '01-ai/Yi-6B'
w = 4 #quantization to 4-bit. Change to 2, 3, or 8 to quantize with another precision

quant_path = 'Yi-6B-gptq-'+str(w)+'bit'

# Load model and tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_path, use_fast=True)
model = AutoModelForCausalLM.from_pretrained(model_path, torch_dtype=torch.float16, device_map="auto")
quantizer = GPTQQuantizer(bits=w, dataset="c4", model_seqlen = 2048)
quantized_model = quantizer.quantize_model(model, tokenizer)

quantized_model.save_pretrained("./"+quant_path, safetensors=True)
tokenizer.save_pretrained("./"+quant_path)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading readme:   0%|          | 0.00/41.1k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/319M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (4487 > 4096). Running this sequence through the model will result in indexing errors
# Quantizing model.layers blocks :   0%|          | 0/32 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# WARNING:optimum.gptq.quantizer:Using Exllamav2 backend will reorder the weights offline, thus you will not be able to save the model with the right weights.Setting `disable_exllama=True`. You should only use Exllamav2 backend for inference.
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:4193: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(
# The cos_cached attribute will be removed in 4.39. Bear in mind that its contents changed in v4.38. Use the forward method of RoPE from now on instead. It is not used in the `LlamaAttention` class
# The sin_cached attribute will be removed in 4.39. Bear in mind that its contents changed in v4.38. Use the forward method of RoPE from now on instead. It is not used in the `LlamaAttention` class
# ('./Yi-6B-gptq-4bit/tokenizer_config.json',
#  './Yi-6B-gptq-4bit/special_tokens_map.json',
#  './Yi-6B-gptq-4bit/tokenizer.model',
#  './Yi-6B-gptq-4bit/added_tokens.json',
#  './Yi-6B-gptq-4bit/tokenizer.json')

# %% [markdown]
# AWQ
#
# More details about the AWQ quantization in this article:
#
# [Fast and Small Llama 2 with Activation-Aware Quantization (AWQ)
# ](https://kaitchup.substack.com/p/fast-and-small-llama-2-with-activation)

# %%
# !pip install --upgrade transformers autoawq optimum accelerate
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Collecting autoawq
#   Downloading autoawq-0.2.3-cp310-cp310-manylinux2014_x86_64.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.0/79.0 kB 2.5 MB/s eta 0:00:00
# Collecting optimum
#   Downloading optimum-1.17.1-py3-none-any.whl (407 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.1/407.1 kB 25.1 MB/s eta 0:00:00
# Collecting accelerate
#   Downloading accelerate-0.28.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 33.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: torch>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from autoawq) (2.2.1+cu121)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from autoawq) (4.10.0)
# Collecting datasets (from autoawq)
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 46.5 MB/s eta 0:00:00
# Collecting zstandard (from autoawq)
#   Downloading zstandard-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 93.8 MB/s eta 0:00:00
# Collecting autoawq-kernels (from autoawq)
#   Downloading autoawq_kernels-0.0.6-cp310-cp310-manylinux2014_x86_64.whl (33.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.4/33.4 MB 50.2 MB/s eta 0:00:00
# Collecting coloredlogs (from optimum)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from optimum) (1.12)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=2.0.1->autoawq)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 67.2 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=2.0.1->autoawq)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 57.5 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=2.0.1->autoawq)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 108.4 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=2.0.1->autoawq)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.8 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=2.0.1->autoawq)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.8 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=2.0.1->autoawq)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 14.3 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=2.0.1->autoawq)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 29.1 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=2.0.1->autoawq)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.4 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=2.0.1->autoawq)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.9 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=2.0.1->autoawq)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 10.3 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=2.0.1->autoawq)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 14.6 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.0.1->autoawq)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 61.4 MB/s eta 0:00:00
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.1.99)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers) (3.20.3)
# Collecting humanfriendly>=9.1 (from coloredlogs->optimum)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.7 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->autoawq)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (1.5.3)
# Collecting xxhash (from datasets->autoawq)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 26.1 MB/s eta 0:00:00
# Collecting multiprocess (from datasets->autoawq)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.7 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (3.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->optimum) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.1->autoawq) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets->autoawq) (1.16.0)
# Installing collected packages: zstandard, xxhash, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, humanfriendly, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, coloredlogs, nvidia-cusolver-cu12, datasets, autoawq-kernels, accelerate, optimum, autoawq
# Successfully installed accelerate-0.28.0 autoawq-0.2.3 autoawq-kernels-0.0.6 coloredlogs-15.0.1 datasets-2.18.0 dill-0.3.8 humanfriendly-10.0 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 optimum-1.17.1 xxhash-3.4.1 zstandard-0.22.0

# %%
from awq import AutoAWQForCausalLM
from transformers import AutoTokenizer

model_path = '01-ai/Yi-6B'
quant_path = 'Yi-6B-awq-4bit'
quant_config = { "zero_point": True, "q_group_size": 128, "w_bit": 4, "version": "GEMM" }

# Load model and tokenizer
model = AutoAWQForCausalLM.from_pretrained(model_path, safetensors=True)
tokenizer = AutoTokenizer.from_pretrained(model_path, use_fast=True)

# Quantize
model.quantize(tokenizer, quant_config=quant_config)

# Save quantized model with safetensors
model.save_quantized("./"+quant_path, safetensors=True)
tokenizer.save_pretrained("./"+quant_path)
# Out:
# config.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# md5:   0%|          | 0.00/184 [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/59.4k [00:00<?, ?B/s]
# Yi.svg:   0%|          | 0.00/980 [00:00<?, ?B/s]
# LICENSE:   0%|          | 0.00/17.4k [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.18G [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.56M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/1.03M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/320 [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading readme:   0%|          | 0.00/167 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Downloading data:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (8947 > 4096). Running this sequence through the model will result in indexing errors
# AWQ: 100%|██████████| 32/32 [14:17<00:00, 26.81s/it]
# ('./Yi-6B-awq-4bit/tokenizer_config.json',
#  './Yi-6B-awq-4bit/special_tokens_map.json',
#  './Yi-6B-awq-4bit/tokenizer.model',
#  './Yi-6B-awq-4bit/added_tokens.json',
#  './Yi-6B-awq-4bit/tokenizer.json')

# %% [markdown]
# # Fine-tuning
#
# QLoRA
#
# More details about QLoRA fine-tuning in this article:
#
# [QLoRa: Fine-Tune a Large Language Model on Your GPU](https://kaitchup.substack.com/p/qlora-fine-tune-a-large-language-model-on-your-gpu-27bed5a03e2b)

# %%
# !pip install --upgrade bitsandbytes transformers peft accelerate datasets trl flash_attn
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.43.0-py3-none-manylinux_2_24_x86_64.whl (102.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 MB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Collecting peft
#   Downloading peft-0.9.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.9/190.9 kB 23.6 MB/s eta 0:00:00
# Collecting accelerate
#   Downloading accelerate-0.28.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 30.7 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 46.0 MB/s eta 0:00:00
# Collecting trl
#   Downloading trl-0.7.11-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 19.4 MB/s eta 0:00:00
# Collecting flash_attn
#   Downloading flash_attn-2.5.6.tar.gz (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 90.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (2.2.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.25.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 24.8 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Collecting tyro>=0.5.11 (from trl)
#   Downloading tyro-0.7.3-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 11.3 MB/s eta 0:00:00
# Collecting einops (from flash_attn)
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 6.7 MB/s eta 0:00:00
# Collecting ninja (from flash_attn)
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 35.8 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->bitsandbytes)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 63.7 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->bitsandbytes)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 62.9 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->bitsandbytes)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 89.4 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->bitsandbytes)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.4 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->bitsandbytes)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.2 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->bitsandbytes)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 14.0 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->bitsandbytes)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 30.3 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->bitsandbytes)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.0 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->bitsandbytes)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 3.9 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch->bitsandbytes)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 10.1 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->bitsandbytes)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 14.4 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 86.6 MB/s eta 0:00:00
# Collecting docstring-parser>=0.14.1 (from tyro>=0.5.11->trl)
#   Downloading docstring_parser-0.15-py3-none-any.whl (36 kB)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl) (13.7.1)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl)
#   Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.16.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->bitsandbytes) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.2)
# Building wheels for collected packages: flash_attn
#   Building wheel for flash_attn (setup.py) ... done
#   Created wheel for flash_attn: filename=flash_attn-2.5.6-cp310-cp310-linux_x86_64.whl size=120592258 sha256=d8cf54adda65f59820221d329d274e124972d7fdc05ab3b1130253c64eee6c8a
#   Stored in directory: /root/.cache/pip/wheels/a8/1c/88/b959d6818b98a46d61ba231683abb7523b89ac1a7ed1e0c206
# Successfully built flash_attn
# Installing collected packages: ninja, xxhash, shtab, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, einops, docstring-parser, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, tyro, nvidia-cusolver-cu12, datasets, flash_attn, bitsandbytes, accelerate, trl, peft
# Successfully installed accelerate-0.28.0 bitsandbytes-0.43.0 datasets-2.18.0 dill-0.3.8 docstring-parser-0.15 einops-0.7.0 flash_attn-2.5.6 multiprocess-0.70.16 ninja-1.11.1.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 peft-0.9.0 shtab-1.7.1 trl-0.7.11 tyro-0.7.3 xxhash-3.4.1

# %%
import torch
from datasets import load_dataset
from peft import LoraConfig, prepare_model_for_kbit_training
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig
)
from trl import SFTTrainer, SFTConfig

#use bf16 and FlashAttention if supported
if torch.cuda.is_bf16_supported():
  compute_dtype = torch.bfloat16
  attn_implementation = 'flash_attention_2'
else:
  compute_dtype = torch.float16
  attn_implementation = 'sdpa'

model_name = "01-ai/Yi-6B"
#Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, add_eos_token=True, use_fast=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.pad_token_id =  tokenizer.eos_token_id
tokenizer.padding_side = 'left'

ds = load_dataset("timdettmers/openassistant-guanaco")

bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)
model = AutoModelForCausalLM.from_pretrained(
          model_name, torch_dtype=compute_dtype, quantization_config=bnb_config, device_map={"": 0}, attn_implementation=attn_implementation
)

model = prepare_model_for_kbit_training(model, gradient_checkpointing_kwargs={'use_reentrant':True})

#Configure the pad token in the model
model.config.pad_token_id = tokenizer.pad_token_id
model.config.use_cache = False # Gradient checkpointing is used by default but not compatible with caching

peft_config = LoraConfig(
        lora_alpha=16,
        lora_dropout=0.05,
        r=16,
        bias="none",
        task_type="CAUSAL_LM",
        target_modules= ['k_proj', 'q_proj', 'v_proj', 'o_proj', "gate_proj", "down_proj", "up_proj"]
)

training_arguments = SFTConfig(
        output_dir="./Yi-6B_QLoRA",
        evaluation_strategy="steps",
        do_eval=True,
        optim="paged_adamw_8bit",
        per_device_train_batch_size=8,
        gradient_accumulation_steps=4,
        per_device_eval_batch_size=8,
        log_level="debug",
        save_strategy="epoch",
        logging_steps=100,
        learning_rate=1e-4,
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        eval_steps=100,
        num_train_epochs=3,
        warmup_ratio=0.1,
        lr_scheduler_type="linear",
        dataset_text_field="text",
        max_seq_length=512,
)

trainer = SFTTrainer(
        model=model,
        train_dataset=ds['train'],
        eval_dataset=ds['test'],
        peft_config=peft_config,
        tokenizer=tokenizer,
        args=training_arguments,
)

trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:294: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(
# Using auto half precision backend
# Currently training with a batch size of: 8
# ***** Running training *****
#   Num examples = 9,846
#   Num Epochs = 3
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 4
#   Total optimization steps = 921
#   Number of trainable parameters = 36,306,944
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='701' max='921' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [701/921 2:49:56 < 53:29, 0.07 it/s, Epoch 2.27/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>1.346500</td>
#       <td>1.273141</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.237400</td>
#       <td>1.254405</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.225100</td>
#       <td>1.244891</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.184100</td>
#       <td>1.243560</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.189200</td>
#       <td>1.239184</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.179000</td>
#       <td>1.235739</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='44' max='65' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [44/65 00:46 < 00:22, 0.93 it/s]
#     </div>
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/Yi-6B_QLoRA/tmp-checkpoint-307
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--01-ai--Yi-6B/snapshots/58332cd8ca449a6a28a424dde80d03321ab03b41/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 11008,
#   "max_position_embeddings": 4096,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 4,
#   "pad_token_id": 0,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 5000000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.38.2",
#   "use_cache": true,
#   "vocab_size": 64000
# }
#
# tokenizer config file saved in ./drive/MyDrive/Yi-6B_QLoRA/tmp-checkpoint-307/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/Yi-6B_QLoRA/tmp-checkpoint-307/special_tokens_map.json
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/Yi-6B_QLoRA/tmp-checkpoint-615
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--01-ai--Yi-6B/snapshots/58332cd8ca449a6a28a424dde80d03321ab03b41/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 11008,
#   "max_position_embeddings": 4096,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 4,
#   "pad_token_id": 0,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 5000000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.38.2",
#   "use_cache": true,
#   "vocab_size": 64000
# }
#
# tokenizer config file saved in ./drive/MyDrive/Yi-6B_QLoRA/tmp-checkpoint-615/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/Yi-6B_QLoRA/tmp-checkpoint-615/special_tokens_map.json
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
#     <div>
#
#       <progress value='921' max='921' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [921/921 3:44:58, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>1.346500</td>
#       <td>1.273141</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.237400</td>
#       <td>1.254405</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.225100</td>
#       <td>1.244891</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.184100</td>
#       <td>1.243560</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.189200</td>
#       <td>1.239184</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.179000</td>
#       <td>1.235739</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>1.143600</td>
#       <td>1.243706</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>1.124500</td>
#       <td>1.243297</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>1.109200</td>
#       <td>1.243611</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/Yi-6B_QLoRA/tmp-checkpoint-921
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--01-ai--Yi-6B/snapshots/58332cd8ca449a6a28a424dde80d03321ab03b41/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 11008,
#   "max_position_embeddings": 4096,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 4,
#   "pad_token_id": 0,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 5000000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.38.2",
#   "use_cache": true,
#   "vocab_size": 64000
# }
#
# tokenizer config file saved in ./drive/MyDrive/Yi-6B_QLoRA/tmp-checkpoint-921/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/Yi-6B_QLoRA/tmp-checkpoint-921/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=921, training_loss=1.1919173531630658, metrics={'train_runtime': 13513.6549, 'train_samples_per_second': 2.186, 'train_steps_per_second': 0.068, 'total_flos': 5.260809536156467e+17, 'train_loss': 1.1919173531630658, 'epoch': 2.99})

# %% [markdown]
# # Benchmarking

# %% [markdown]
# With optimum-benchmark: Memory-Efficiency and Inference Speed
#
# More details about using optimum-benchmark in this article:
#
# [Optimum-Benchmark: How Fast and Memory-Efficient Is Your LLM?](https://kaitchup.substack.com/p/optimum-benchmark-how-fast-and-memory)

# %%
# !pip install optimum
# !git clone https://github.com/huggingface/optimum-benchmark.git
# !cd optimum-benchmark && pip install -e .
# !pip install bitsandbytes
# !pip install auto-gptq
# !pip install autoawq
# !pip install --upgrade transformers
# Out:
# Collecting optimum
#   Downloading optimum-1.17.1-py3-none-any.whl (407 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.1/407.1 kB 10.3 MB/s eta 0:00:00
# Collecting coloredlogs (from optimum)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from optimum) (1.12)
# Requirement already satisfied: transformers[sentencepiece]>=4.26.0 in /usr/local/lib/python3.10/dist-packages (from optimum) (4.38.2)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from optimum) (2.2.1+cu121)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from optimum) (24.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optimum) (1.25.2)
# Requirement already satisfied: huggingface-hub>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from optimum) (0.20.3)
# Collecting datasets (from optimum)
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 49.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (4.66.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (4.10.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11->optimum)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 66.2 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11->optimum)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 65.6 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11->optimum)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 97.8 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11->optimum)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.5 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11->optimum)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.7 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11->optimum)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 14.1 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11->optimum)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 28.1 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11->optimum)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.6 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11->optimum)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.7 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.11->optimum)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 10.0 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11->optimum)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11->optimum)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 71.4 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum) (0.4.2)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum) (0.1.99)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum) (3.20.3)
# Collecting humanfriendly>=9.1 (from coloredlogs->optimum)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->optimum)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (1.5.3)
# Collecting xxhash (from datasets->optimum)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 231.7 kB/s eta 0:00:00
# Collecting multiprocess (from datasets->optimum)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.3 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (3.9.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->optimum) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11->optimum) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->optimum) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->optimum) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets->optimum) (1.16.0)
# Installing collected packages: xxhash, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, humanfriendly, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, coloredlogs, nvidia-cusolver-cu12, datasets, optimum
# Successfully installed coloredlogs-15.0.1 datasets-2.18.0 dill-0.3.8 humanfriendly-10.0 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 optimum-1.17.1 xxhash-3.4.1
# Cloning into 'optimum-benchmark'...
# remote: Enumerating objects: 11080, done.
# remote: Counting objects: 100% (2779/2779), done.
# remote: Compressing objects: 100% (896/896), done.
# remote: Total 11080 (delta 1977), reused 2372 (delta 1842), pack-reused 8301
# Receiving objects: 100% (11080/11080), 7.81 MiB | 17.65 MiB/s, done.
# Resolving deltas: 100% (6936/6936), done.
# Obtaining file:///content/optimum-benchmark
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from optimum-benchmark==0.2.0) (4.38.2)
# Collecting accelerate (from optimum-benchmark==0.2.0)
#   Downloading accelerate-0.28.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from optimum-benchmark==0.2.0) (2.18.0)
# Collecting hydra-colorlog (from optimum-benchmark==0.2.0)
#   Downloading hydra_colorlog-1.2.0-py3-none-any.whl (3.6 kB)
# Collecting hydra-core (from optimum-benchmark==0.2.0)
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 20.6 MB/s eta 0:00:00
# Collecting omegaconf (from optimum-benchmark==0.2.0)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from optimum-benchmark==0.2.0) (5.9.5)
# Collecting flatten-dict (from optimum-benchmark==0.2.0)
#   Downloading flatten_dict-0.4.2-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from optimum-benchmark==0.2.0) (1.5.3)
# Collecting nvidia-ml-py (from optimum-benchmark==0.2.0)
#   Downloading nvidia_ml_py-12.535.133-py3-none-any.whl (37 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate->optimum-benchmark==0.2.0) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate->optimum-benchmark==0.2.0) (24.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate->optimum-benchmark==0.2.0) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate->optimum-benchmark==0.2.0) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate->optimum-benchmark==0.2.0) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate->optimum-benchmark==0.2.0) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets->optimum-benchmark==0.2.0) (3.13.1)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum-benchmark==0.2.0) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->optimum-benchmark==0.2.0) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum-benchmark==0.2.0) (0.3.8)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum-benchmark==0.2.0) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum-benchmark==0.2.0) (4.66.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->optimum-benchmark==0.2.0) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->optimum-benchmark==0.2.0) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum-benchmark==0.2.0) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->optimum-benchmark==0.2.0) (3.9.3)
# Requirement already satisfied: six<2.0,>=1.12 in /usr/local/lib/python3.10/dist-packages (from flatten-dict->optimum-benchmark==0.2.0) (1.16.0)
# Collecting colorlog (from hydra-colorlog->optimum-benchmark==0.2.0)
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core->optimum-benchmark==0.2.0)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 16.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->optimum-benchmark==0.2.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->optimum-benchmark==0.2.0) (2023.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->optimum-benchmark==0.2.0) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers->optimum-benchmark==0.2.0) (0.15.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum-benchmark==0.2.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum-benchmark==0.2.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum-benchmark==0.2.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum-benchmark==0.2.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum-benchmark==0.2.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum-benchmark==0.2.0) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate->optimum-benchmark==0.2.0) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->optimum-benchmark==0.2.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->optimum-benchmark==0.2.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->optimum-benchmark==0.2.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->optimum-benchmark==0.2.0) (2024.2.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->optimum-benchmark==0.2.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->optimum-benchmark==0.2.0) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->optimum-benchmark==0.2.0) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->optimum-benchmark==0.2.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->optimum-benchmark==0.2.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->optimum-benchmark==0.2.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->optimum-benchmark==0.2.0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->optimum-benchmark==0.2.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->optimum-benchmark==0.2.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->optimum-benchmark==0.2.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->optimum-benchmark==0.2.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->optimum-benchmark==0.2.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->optimum-benchmark==0.2.0) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->optimum-benchmark==0.2.0) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->optimum-benchmark==0.2.0) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate->optimum-benchmark==0.2.0) (12.4.99)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate->optimum-benchmark==0.2.0) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate->optimum-benchmark==0.2.0) (1.3.0)
# Building wheels for collected packages: optimum-benchmark, antlr4-python3-runtime
#   Building editable for optimum-benchmark (pyproject.toml) ... done
#   Created wheel for optimum-benchmark: filename=optimum_benchmark-0.2.0-0.editable-py3-none-any.whl size=7538 sha256=27ca216064fcfebc164a7a5d0d326410ddf7090d5f5c367eb51b8ec986f5d67f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-alx6ypqe/wheels/82/42/d6/23715b9239130bab8e02398c065b7233dbf28d2c861e0fd699
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=521a2cc01f919098061bb278959e28a392a0f4dece88dd59e487eba3da2b7b7b
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built optimum-benchmark antlr4-python3-runtime
# Installing collected packages: nvidia-ml-py, antlr4-python3-runtime, omegaconf, flatten-dict, colorlog, hydra-core, hydra-colorlog, accelerate, optimum-benchmark
# Successfully installed accelerate-0.28.0 antlr4-python3-runtime-4.9.3 colorlog-6.8.2 flatten-dict-0.4.2 hydra-colorlog-1.2.0 hydra-core-1.3.2 nvidia-ml-py-12.535.133 omegaconf-2.3.0 optimum-benchmark-0.2.0
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.43.0-py3-none-manylinux_2_24_x86_64.whl (102.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 MB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (2.2.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.25.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes) (12.4.99)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->bitsandbytes) (1.3.0)
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.43.0
# Collecting auto-gptq
#   Downloading auto_gptq-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 55.2 MB/s eta 0:00:00
# Requirement already satisfied: accelerate>=0.26.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.28.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (2.18.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.1.99)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (1.25.2)
# Collecting rouge (from auto-gptq)
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Collecting gekko (from auto-gptq)
#   Downloading gekko-1.0.7-py3-none-any.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 70.5 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (2.2.1+cu121)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.4.2)
# Requirement already satisfied: transformers>=4.31.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (4.38.2)
# Collecting peft>=0.5.0 (from auto-gptq)
#   Downloading peft-0.9.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.9/190.9 kB 25.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (4.66.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (0.20.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->auto-gptq) (12.4.99)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->auto-gptq) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->auto-gptq) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->auto-gptq) (0.15.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (3.9.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge->auto-gptq) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->auto-gptq) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->auto-gptq) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->auto-gptq) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->auto-gptq) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->auto-gptq) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-gptq) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-gptq) (2023.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->auto-gptq) (1.3.0)
# Installing collected packages: rouge, gekko, peft, auto-gptq
# Successfully installed auto-gptq-0.7.1 gekko-1.0.7 peft-0.9.0 rouge-1.0.1
# Collecting autoawq
#   Downloading autoawq-0.2.3-cp310-cp310-manylinux2014_x86_64.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.0/79.0 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: torch>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from autoawq) (2.2.1+cu121)
# Requirement already satisfied: transformers>=4.35.0 in /usr/local/lib/python3.10/dist-packages (from autoawq) (4.38.2)
# Requirement already satisfied: tokenizers>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from autoawq) (0.15.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from autoawq) (4.10.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (from autoawq) (0.28.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from autoawq) (2.18.0)
# Collecting zstandard (from autoawq)
#   Downloading zstandard-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 74.8 MB/s eta 0:00:00
# Collecting autoawq-kernels (from autoawq)
#   Downloading autoawq_kernels-0.0.6-cp310-cp310-manylinux2014_x86_64.whl (33.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.4/33.4 MB 48.5 MB/s eta 0:00:00
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.12.1->autoawq) (0.20.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.0.1->autoawq) (12.4.99)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->autoawq) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->autoawq) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->autoawq) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->autoawq) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->autoawq) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->autoawq) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->autoawq) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->autoawq) (5.9.5)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (3.9.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.35.0->autoawq) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.35.0->autoawq) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.35.0->autoawq) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.35.0->autoawq) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.1->autoawq) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2023.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.0.1->autoawq) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets->autoawq) (1.16.0)
# Installing collected packages: zstandard, autoawq-kernels, autoawq
# Successfully installed autoawq-0.2.3 autoawq-kernels-0.0.6 zstandard-0.22.0
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)

# %% [markdown]
# Benchmarking Yi 6B 16-bit

# %%
import os
YAML_DEFAULT="""
defaults:
  - backend: pytorch # default backend
  - launcher: process # default launcher
  - benchmark: inference # default benchmark
  - experiment # inheriting experiment schema
  - _self_ # for hydra 1.1 compatibility
  - override hydra/job_logging: colorlog # colorful logging
  - override hydra/hydra_logging: colorlog # colorful logging

experiment_name: Yi-6B

backend:
  device: cuda
  device_ids: 0
  no_weights: true
  torch_dtype: float16
  model: 01-ai/Yi-6B

launcher:
  device_isolation: true

benchmark:
  memory: true #We will monitor the memory usage
  warmup_runs: 10 #Before the monitoring starts, the inference will be run 10 times for warming up
  input_shapes:
    batch_size: 4
    sequence_length: 512
  new_tokens: 1000

# hydra/cli specific settings
hydra:
  run:
    # where to store run results
    dir: runs/${experiment_name}
  sweep:
    # where to store sweep results
    dir: sweeps/${experiment_name}
  job:
    # change working directory to the run directory
    chdir: true
    env_set:
      # set environment variable OVERRIDE_BENCHMARKS to 1
      # to not skip benchmarks that have been run before
      OVERRIDE_BENCHMARKS: 1
"""

with open("Yi-6B.yaml", 'w') as f:
  f.write(YAML_DEFAULT)
os.system("optimum-benchmark --config-dir ./ --config-name Yi-6B")
# Out:
# 0

# %%
# !cat runs/Yi-6B/benchmark_report.json
# Out:
# {
#     "prefill": {
#         "memory": {
#             "unit": "MB",
#             "max_ram": 1745.854464,
#             "max_vram": 0.0,
#             "max_reserved": 13589.54496,
#             "max_allocated": 13152.01792
#         },
#         "latency": {
#             "unit": "s",
#             "mean": 0.1487202606201172,
#             "stdev": 0,
#             "values": [
#                 0.1487202606201172
#             ]
#         },
#         "throughput": {
#             "unit": "tokens/s",
#             "value": 13770.820407794321
#         },
#         "energy": null,
#         "efficiency": null
#     },
#     "decode": {
#         "memory": {
#             "unit": "MB",
#             "max_ram": 1746.1248,
#             "max_vram": 0.0,
#             "max_reserved": 14273.216512,
#             "max_allocated": 13899.628032
#         },
#         "latency": {
#             "unit": "s",
#             "mean": 41.41763340377807,
#             "stdev": 0,
#             "values": [
#                 41.41763340377807
#             ]
#         },
#         "throughput": {
#             "unit": "tokens/s",
#             "value": 96.48064535805877
#         },
#         "energy": null,
#         "efficiency": null
#     },
#     "per_token": {
#         "memory": null,
#         "latency": {
#             "unit": "s",
#             "mean": 0.041310223366524484,
#             "stdev": 0.0012804003568848248,
#             "values": [
#                 0.042385406494140625,
#                 0.04188774490356445,
#                 0.04166656112670898,
#                 0.041867263793945314,
#                 0.04767334365844727,
#                 0.042109951019287106,
#                 0.041659393310546876,
#                 0.04136959838867187,
#                 0.041831424713134766,
#                 0.04167168045043945,
#                 0.04183244705200195,
#                 0.04211609649658203,
#                 0.042823680877685545,
#                 0.041866241455078126,
#                 0.04319334411621094,
#                 0.04012134552001953,
#                 0.05066649627685547,
#                 0.04549324798583984,
#                 0.040584190368652344,
#                 0.04063948822021484,
#                 0.04059545516967773,
#                 0.040637439727783206,
#                 0.04062617492675781,
#                 0.039803905487060545,
#                 0.04050431823730469,
#                 0.040627201080322264,
#                 0.04047257614135742,
#                 0.04062003326416016,
#                 0.04921548843383789,
#                 0.04070809555053711,
#                 0.040612865447998046,
#                 0.0396943359375,
#                 0.04112384033203125,
#                 0.040834049224853515,
#                 0.04055859375,
#                 0.04077772903442383,
#                 0.04090367889404297,
#                 0.04104294586181641,
#                 0.040904705047607424,
#                 0.03991142272949219,
#                 0.04065484619140625,
#                 0.04072345733642578,
#                 0.04049203109741211,
#                 0.04056576156616211,
#                 0.04065075302124024,
#             ]
#         },
#         "throughput": {
#             "unit": "tokens/s",
#             "value": 96.82833144013883
#         },
#         "energy": null,
#         "efficiency": null
#     }
# }

# %% [markdown]
# Benchmarking with 4-bit bitsandbytes

# %%
import os
YAML_DEFAULT="""
defaults:
  - backend: pytorch # default backend
  - launcher: process # default launcher
  - benchmark: inference # default benchmark
  - experiment # inheriting experiment schema
  - _self_ # for hydra 1.1 compatibility
  - override hydra/job_logging: colorlog # colorful logging
  - override hydra/hydra_logging: colorlog # colorful logging

experiment_name: Yi-6B-bnb-4bit

backend:
  device: cuda
  device_ids: 0
  no_weights: true
  model: 01-ai/Yi-6B
  quantization_config:
    load_in_4bit: true

launcher:
  device_isolation: true

benchmark:
  memory: true #We will monitor the memory usage
  warmup_runs: 10 #Before the monitoring starts, the inference will be run 10 times for warming up
  input_shapes:
    batch_size: 4
    sequence_length: 512
  new_tokens: 1000

# hydra/cli specific settings
hydra:
  run:
    # where to store run results
    dir: runs/${experiment_name}
  sweep:
    # where to store sweep results
    dir: sweeps/${experiment_name}
  job:
    # change working directory to the run directory
    chdir: true
    env_set:
      # set environment variable OVERRIDE_BENCHMARKS to 1
      # to not skip benchmarks that have been run before
      OVERRIDE_BENCHMARKS: 1
"""

with open("Yi-6B-bnb-4bit.yaml", 'w') as f:
  f.write(YAML_DEFAULT)
os.system("optimum-benchmark --config-dir ./ --config-name Yi-6B-bnb-4bit")
# Out:
# 0

# %%
# !cat runs/Yi-6B-bnb-4bit/benchmark_report.json
# Out:
# {
#     "prefill": {
#         "memory": {
#             "unit": "MB",
#             "max_ram": 1579.159552,
#             "max_vram": 0.0,
#             "max_reserved": 26124.222464,
#             "max_allocated": 25345.396224
#         },
#         "latency": {
#             "unit": "s",
#             "mean": 1.3678662109375,
#             "stdev": 0,
#             "values": [
#                 1.3678662109375
#             ]
#         },
#         "throughput": {
#             "unit": "tokens/s",
#             "value": 1497.2224502836093
#         },
#         "energy": null,
#         "efficiency": null
#     },
#     "decode": {
#         "memory": {
#             "unit": "MB",
#             "max_ram": 1579.429888,
#             "max_vram": 0.0,
#             "max_reserved": 27598.52032,
#             "max_allocated": 27249.014272
#         },
#         "latency": {
#             "unit": "s",
#             "mean": 50.4643653793335,
#             "stdev": 0,
#             "values": [
#                 50.4643653793335
#             ]
#         },
#         "throughput": {
#             "unit": "tokens/s",
#             "value": 79.18458837166847
#         },
#         "energy": null,
#         "efficiency": null
#     },
#     "per_token": {
#         "memory": null,
#         "latency": {
#             "unit": "s",
#             "mean": 0.04914564481320922,
#             "stdev": 0.0040926610345148875,
#             "values": [
#                 0.04335103988647461,
#                 0.04252774429321289,
#                 0.04230451202392578,
#                 0.042518527984619144,
#                 0.0423004150390625,
#                 0.042625022888183595,
#                 0.042355712890625,
#                 0.042395648956298826,
#                 0.04230246353149414,
#                 0.042570751190185545,
#                 0.042336254119873046,
#                 0.05531545639038086,
#                 0.05536153411865234,
#                 0.05547622299194336,
#                 0.0553994255065918,
#                 0.05547315216064453,
#                 0.055482368469238284,
#                 0.05548031997680664,
#                 0.055411712646484375,
#                 0.05533798217773438,
#                 0.0555233268737793,
#                 0.05565542221069336,
#                 0.05557452774047852,
#                 0.055670783996582034,
#                 0.05564211273193359,
#                 0.05572403335571289,
#                 0.055646209716796874,
#                 0.05555302429199219,
#                 0.05558784103393555,
#                 0.055646209716796874,
#                 0.05559500885009765,
#                 0.05571481704711914,
#                 0.05557452774047852,
#                 0.05572710418701172,
#                 0.05561958312988281,
#                 0.05552742385864258,
#                 0.05582745742797852,
#                 0.05627801513671875,
#                 0.05573222351074219,
#                 0.05590118408203125,
#                 0.05570150375366211,
#                 0.0558131217956543,
#                 0.055702529907226565,
#                 0.05556326293945312,
#                 0.05580799865722656,
#                 0.0559288330078125,
#                 0.055695358276367186,
#                 0.055809024810791016,
#                 0.055669761657714846,
#                 0.05575987243652344,
#                 0.055728126525878906,
#                 0.055504894256591795,
#                 0.055803905487060546,
#                 0.056302593231201174,
#                 0.055910400390625,
#                 0.05595750427246094,
#                 0.05588889694213867,
#                 0.055984127044677735,
#                 0.05584588623046875
#             ]
#         },
#         "throughput": {
#             "unit": "tokens/s",
#             "value": 81.3907318787461
#         },
#         "energy": null,
#         "efficiency": null
#     }
# }

# %% [markdown]
# Benchmarking with 4-bit GPTQ

# %%
import os
YAML_DEFAULT="""
defaults:
  - backend: pytorch # default backend
  - launcher: process # default launcher
  - benchmark: inference # default benchmark
  - experiment # inheriting experiment schema
  - _self_ # for hydra 1.1 compatibility
  - override hydra/job_logging: colorlog # colorful logging
  - override hydra/hydra_logging: colorlog # colorful logging

experiment_name: Yi-6B-gptq-4bit

backend:
  device: cuda
  device_ids: 0
  no_weights: true
  model: kaitchup/Yi-6B-gptq-4bit

launcher:
  device_isolation: true

benchmark:
  memory: true #We will monitor the memory usage
  warmup_runs: 10 #Before the monitoring starts, the inference will be run 10 times for warming up
  input_shapes:
    batch_size: 4
    sequence_length: 512
  new_tokens: 1000

# hydra/cli specific settings
hydra:
  run:
    # where to store run results
    dir: runs/${experiment_name}
  sweep:
    # where to store sweep results
    dir: sweeps/${experiment_name}
  job:
    # change working directory to the run directory
    chdir: true
    env_set:
      # set environment variable OVERRIDE_BENCHMARKS to 1
      # to not skip benchmarks that have been run before
      OVERRIDE_BENCHMARKS: 1
"""

with open("Yi-6B-gptq-4bit.yaml", 'w') as f:
  f.write(YAML_DEFAULT)
os.system("optimum-benchmark --config-dir ./ --config-name Yi-6B-gptq-4bit")
# Out:
# 0

# %%
# !cat runs/Yi-6B-gptq-4bit/benchmark_report.json
# Out:
# {
#     "prefill": {
#         "memory": {
#             "unit": "MB",
#             "max_ram": 5881.495552,
#             "max_vram": 0.0,
#             "max_reserved": 5532.286976,
#             "max_allocated": 5102.75584
#         },
#         "latency": {
#             "unit": "s",
#             "mean": 0.17228857421875,
#             "stdev": 0,
#             "values": [
#                 0.17228857421875
#             ]
#         },
#         "throughput": {
#             "unit": "tokens/s",
#             "value": 11887.033190022872
#         },
#         "energy": null,
#         "efficiency": null
#     },
#     "decode": {
#         "memory": {
#             "unit": "MB",
#             "max_ram": 5881.495552,
#             "max_vram": 0.0,
#             "max_reserved": 6241.124352,
#             "max_allocated": 5850.68544
#         },
#         "latency": {
#             "unit": "s",
#             "mean": 41.75734943389888,
#             "stdev": 0,
#             "values": [
#                 41.75734943389888
#             ]
#         },
#         "throughput": {
#             "unit": "tokens/s",
#             "value": 95.69572911531645
#         },
#         "energy": null,
#         "efficiency": null
#     },
#     "per_token": {
#         "memory": null,
#         "latency": {
#             "unit": "s",
#             "mean": 0.04162668754722736,
#             "stdev": 0.0018409888901749444,
#             "values": [
#                 0.042638336181640625,
#                 0.04213452911376953,
#                 0.042044414520263675,
#                 0.04218982315063476,
#                 0.042243072509765625,
#                 0.04218777465820313,
#                 0.042147838592529296,
#                 0.041186302185058594,
#                 0.04221952056884765,
#                 0.042502143859863284,
#                 0.042052608489990234,
#                 0.04575129699707031,
#                 0.04189491271972656,
#                 0.04151500701904297,
#                 0.041485313415527345,
#                 0.04037529754638672,
#                 0.04108902359008789,
#                 0.04096409606933594,
#                 0.04107571029663086,
#                 0.04116275024414062,
#                 0.041017345428466793,
#                 0.04106649780273437,
#                 0.041183231353759765,
#                 0.04008038330078125,
#                 0.040927230834960936,
#                 0.04093439865112305,
#                 0.04096819305419922,
#                 0.04102963256835938,
#                 0.041078784942626956,
#                 0.041024513244628906,
#                 0.040771583557128906,
#                 0.03998617553710938,
#                 0.04103372955322265,
#                 0.041128959655761715,
#                 0.04110028839111328,
#                 0.04050227355957031,
#                 0.0411514892578125,
#                 0.040561664581298826,
#                 0.04034560012817383,
#                 0.03944038391113281,
#                 0.040390655517578124,
#                 0.04016844940185547,
#                 0.04020019149780273,
#                 0.04031692886352539,
#                 0.04026777648925781,
#                 0.04067737579345703,
#                 0.040567806243896484,
#                 0.03952844619750977,
#                 0.0403056640625,
#                 0.04033331298828125,
#                 0.04024115371704102,
#                 0.04034560012817383,
#                 0.04038451385498047,
#                 0.040325119018554685,
#                 0.04025958251953125,
#                 0.03937279891967774,
#                 0.04010598373413086,
#                 0.04045619201660156,
#                 0.04024422454833984,
#                 0.04028211212158203,
#                 0.04029849624633789,
#                 0.04274585723876953,
#                 0.040376319885253906,
#                 0.03926528167724609,
#                 0.04015718460083008,
#                 0.040343551635742186,
#                 0.04012134552001953,
#                 0.04031692886352539,
#                 0.040379390716552735,
#                 0.04058931350708008,
#                 0.04082688140869141,
#                 0.0397916145324707,
#                 0.040471553802490234,
#                 0.040474624633789064,
#                 0.04017663955688477,
#                 0.04026675033569336,
#                 0.040210430145263674,
#                 0.040205310821533204,
#                 0.040268798828125,
#                 0.03939430236816406,
#                 0.04003942489624023,
#                 0.04033740615844727,
#                 0.04122623825073242,
#                 0.04093337631225586,
#                 0.04110540771484375,
#                 0.04844543838500977,
#                 0.0539791374206543,
#                 0.04036608123779297,
#                 0.040997886657714845,
#                 0.0407982063293457,
#                 0.04076339340209961,
#                 0.04118527984619141,
#                 0.04116070556640625,
#                 0.041237503051757815,
#                 0.041164798736572264,
#                 0.040400894165039065,
#                 0.05300223922729492,
#                 0.041583614349365236,
#                 0.043910144805908206,
#                 0.04215091323852539,
#                 0.041224193572998044,
#                 0.04220006561279297,
#                 0.041275390625,
#                 0.04128460693359375,
#                 0.04038655853271484,
#                 0.0410695686340332,
#                 0.04114227294921875,
#                 0.04132966232299805,
#                 0.04137881469726563,
#                 0.04112076950073242,
#                 0.041248767852783204,
#                 0.041133056640625,
#                 0.04016537475585937,
#                 0.041229312896728515,
#                 0.041191425323486325,
#                 0.041016319274902346,
#                 0.04118937683105469,
#                 0.04115660858154297,
#                 0.04107468795776367,
#                 0.041040897369384766,
#                 0.04015923309326172,
#                 0.040986625671386716,
#                 0.047935489654541016,
#                 0.04141056060791016,
#                 0.04126105499267578,
#                 0.04134707260131836,
#                 0.041247745513916016,
#                 0.041132030487060545,
#                 0.040422401428222655,
#                 0.042092544555664066,
#                 0.04338278579711914,
#                 0.042021888732910156,
#                 0.0411514892578125,
#                 0.041059326171875,
#                 0.041439231872558595,
#                 0.04126003265380859,
#                 0.04016332626342774,
#                 0.04110540771484375,
#                 0.04117401504516602,
#                 0.04122726440429687,
#                 0.04106444931030274,
#                 0.04112691116333008,
#                 0.040976383209228515,
#                 0.04111974334716797,
#                 0.04028006362915039,
#                 0.04102963256835938,
#                 0.04113919830322266,
#                 0.041594879150390625,
#                 0.04386304092407227,
#                 0.04114227294921875,
#                 0.04095283126831055,
#                 0.04104499053955078,
#                 0.04014284896850586,
#                 0.04102041625976562,
#                 0.04092825698852539,
#                 0.041090049743652345,
#                 0.041132030487060545,
#                 0.040956928253173826,
#                 0.04102348709106445,
#                 0.040839168548583986,
#                 0.0399288330078125,
#                 0.04105625534057617,
#                 0.04138086318969727,
#                 0.041234432220458986,
#                 0.041457664489746096,
#                 0.041373695373535156,
#                 0.04110745620727539,
#                 0.04155392074584961,
#                 0.041450496673583984,
#                 0.042600448608398435,
#                 0.04241408157348633,
#                 0.0420208625793457,
#                 0.0441077766418457,
#                 0.04178739166259766,
#                 0.042657791137695314,
#                 0.04177203369140625
#             ]
#         },
#         "throughput": {
#             "unit": "tokens/s",
#             "value": 96.0922003573265
#         },
#         "energy": null,
#         "efficiency": null
#     }
# }

# %% [markdown]
# Benchmarking with 4-bit AWQ

# %%
import os
YAML_DEFAULT="""
defaults:
  - backend: pytorch # default backend
  - launcher: process # default launcher
  - benchmark: inference # default benchmark
  - experiment # inheriting experiment schema
  - _self_ # for hydra 1.1 compatibility
  - override hydra/job_logging: colorlog # colorful logging
  - override hydra/hydra_logging: colorlog # colorful logging

experiment_name: Yi-6B-awq-4bit

backend:
  device: cuda
  device_ids: 0
  no_weights: true
  model: kaitchup/Yi-6B-awq-4bit

launcher:
  device_isolation: true

benchmark:
  memory: true #We will monitor the memory usage
  warmup_runs: 10 #Before the monitoring starts, the inference will be run 10 times for warming up
  input_shapes:
    batch_size: 4
    sequence_length: 512
  new_tokens: 1000

# hydra/cli specific settings
hydra:
  run:
    # where to store run results
    dir: runs/${experiment_name}
  sweep:
    # where to store sweep results
    dir: sweeps/${experiment_name}
  job:
    # change working directory to the run directory
    chdir: true
    env_set:
      # set environment variable OVERRIDE_BENCHMARKS to 1
      # to not skip benchmarks that have been run before
      OVERRIDE_BENCHMARKS: 1
"""

with open("Yi-6B-awq-4bit.yaml", 'w') as f:
  f.write(YAML_DEFAULT)
os.system("optimum-benchmark --config-dir ./ --config-name Yi-6B-awq-4bit")
# Out:
# 0

# %%
# !cat runs/Yi-6B-awq-4bit/benchmark_report.json
# Out:
# {
#     "prefill": {
#         "memory": {
#             "unit": "MB",
#             "max_ram": 2151.776256,
#             "max_vram": 0.0,
#             "max_reserved": 5570.035712,
#             "max_allocated": 5005.762048
#         },
#         "latency": {
#             "unit": "s",
#             "mean": 0.17603324890136718,
#             "stdev": 0,
#             "values": [
#                 0.17603324890136718
#             ]
#         },
#         "throughput": {
#             "unit": "tokens/s",
#             "value": 11634.16577709993
#         },
#         "energy": null,
#         "efficiency": null
#     },
#     "decode": {
#         "memory": {
#             "unit": "MB",
#             "max_ram": 2151.776256,
#             "max_vram": 0.0,
#             "max_reserved": 6184.501248,
#             "max_allocated": 5753.634304
#         },
#         "latency": {
#             "unit": "s",
#             "mean": 51.347379650115975,
#             "stdev": 0,
#             "values": [
#                 51.347379650115975
#             ]
#         },
#         "throughput": {
#             "unit": "tokens/s",
#             "value": 77.82286120984121
#         },
#         "energy": null,
#         "efficiency": null
#     },
#     "per_token": {
#         "memory": null,
#         "latency": {
#             "unit": "s",
#             "mean": 0.05122256897018478,
#             "stdev": 0.002264239574028543,
#             "values": [
#                 0.05641625595092774,
#                 0.059859966278076174,
#                 0.050662399291992184,
#                 0.05046579360961914,
#                 0.05034086227416992,
#                 0.05145087814331055,
#                 0.05052620697021484,
#                 0.050418689727783204,
#                 0.05039411163330078,
#                 0.051708927154541014,
#                 0.0500684814453125,
#                 0.049928192138671876,
#                 0.04986675262451172,
#                 0.049977344512939455,
#                 0.049874942779541014,
#                 0.04911718368530273,
#                 0.04954009628295898,
#                 0.04956774520874024,
#                 0.06035660934448242,
#                 0.05037158584594727,
#                 0.05027328109741211,
#                 0.04964966583251953,
#                 0.049767425537109375,
#                 0.0484505615234375,
#                 0.049486846923828126,
#                 0.058401790618896485,
#                 0.05043814468383789,
#                 0.049393665313720705,
#                 0.04953190231323242,
#                 0.0494284782409668,
#                 0.04956467056274414,
#                 0.04848537445068359,
#                 0.04979097747802735,
#                 0.0500582389831543,
#                 0.04981043243408203,
#                 0.05164851379394531,
#                 0.05330124664306641,
#                 0.052397056579589846,
#                 0.05071462249755859,
#                 0.05017599868774414,
#                 0.05206937789916992,
#                 0.050487297058105465,
#                 0.050334720611572265,
#                 0.05022412872314453,
#                 0.05019852828979492,
#                 0.05513216018676758,
#                 0.0528721923828125,
#                 0.04954828643798828,
#                 0.05048831939697265,
#                 0.05019340896606445,
#                 0.05033369445800781,
#                 0.05019136047363281,
#                 0.050427902221679685,
#                 0.050601982116699216,
#                 0.0515676155090332,
#                 0.04939878463745117,
#                 0.05030400085449219,
#                 0.050729984283447264,
#                 0.05045043182373047,
#                 0.050590721130371094,
#                 0.05024870300292969,
#                 0.05004800033569336,
#                 0.04992921447753906,
#                 0.04883865737915039,
#                 0.04966502380371094,
#                 0.05118566513061523,
#                 0.05068492889404297,
#                 0.05058969497680664,
#                 0.04942950439453125,
#                 0.05026611328125,
#                 0.04997324752807617,
#                 0.05458124923706055,
#                 0.051211265563964846,
#                 0.05038284683227539,
#                 0.050334720611572265,
#                 0.051948543548583984,
#                 0.06195507049560547,
#                 0.05003366470336914,
#                 0.04981964874267578,
#                 0.05553049468994141,
#                 0.06213324737548828,
#                 0.06475263977050781,
#                 0.058668033599853515,
#                 0.06202470397949219,
#                 0.05117849731445313,
#                 0.0634511375427246,
#                 0.05072076797485352,
#                 0.050344959259033206,
#                 0.05017292785644531,
#                 0.050135040283203126,
#                 0.05030400085449219,
#                 0.050651134490966795,
#                 0.05061427307128906,
#                 0.0503633918762207,
#                 0.05096550369262695,
#                 0.0506163215637207,
#                 0.05053747177124023,
#                 0.050298881530761716,
#                 0.05082419204711914,
#                 0.05052108764648437,
#                 0.049772544860839846,
#                 0.05056409454345703,
#                 0.050644992828369144,
#                 0.0504002571105957,
#                 0.05054054260253906,
#                 0.050685951232910156,
#                 0.05064191818237305,
#                 0.05037875366210937,
#                 0.049448959350585936,
#                 0.05011558532714844,
#                 0.051465217590332034,
#                 0.051490814208984374,
#                 0.049729534149169925,
#                 0.050067455291748046,
#                 0.049754112243652344,
#                 0.04985651016235351,
#                 0.050348033905029295,
#                 0.05013708877563477,
#                 0.05000908660888672,
#                 0.04994662475585938,
#                 0.04984524917602539,
#                 0.05032447814941406,
#                 0.050135040283203126,
#                 0.04986777496337891,
#                 0.04965478515625,
#                 0.05417574310302734,
#                 0.0510648307800293,
#                 0.05045555114746094,
#                 0.050392063140869144,
#                 0.050233345031738284,
#                 0.053910526275634765,
#                 0.05025075149536133,
#                 0.04966502380371094,
#                 0.050385921478271485,
#                 0.05624115371704102,
#                 0.061623294830322264,
#                 0.06294220733642578,
#                 0.0510648307800293,
#                 0.05078937530517578,
#                 0.05070950317382812,
#                 0.049797119140625,
#                 0.05079654312133789,
#                 0.051128318786621094,
#                 0.05084262466430664,
#                 0.05110271835327149,
#                 0.050595840454101565,
#                 0.050334720611572265,
#                 0.050270206451416014,
#                 0.049582080841064455,
#                 0.05077196884155273,
#                 0.056766464233398435,
#                 0.05190758514404297,
#                 0.05595238494873047,
#                 0.057183231353759766,
#                 0.052055038452148435,
#                 0.05222195053100586,
#                 0.052327423095703124,
#                 0.051888126373291016,
#                 0.05223526382446289,
#                 0.05168537521362305,
#                 0.05180928039550781,
#                 0.05142630386352539,
#                 0.05072076797485352,
#                 0.05099827194213867,
#                 0.051020801544189455,
#                 0.05093273544311523,
#                 0.05062451171875,
#                 0.05053747177124023,
#                 0.05059686279296875,
#                 0.0507770881652832,
#                 0.053440513610839846,
#                 0.05059174346923828,
#                 0.04990156936645508,
#                 0.05258956909179688,
#                 0.06347980880737304,
#                 0.05791231918334961,
#                 0.05063782501220703,
#                 0.05543219375610352,
#                 0.050299903869628904,
#                 0.05045657730102539,
#                 0.05071769714355469,
#                 0.05038796615600586,
#                 0.050800640106201174,
#                 0.04983295822143555,
#                 0.050579456329345705,
#                 0.05040435028076172,
#                 0.05207551956176758,
#                 0.050405376434326174,
#                 0.050710529327392576,
#                 0.05080575942993164,
#                 0.050490367889404295,
#                 0.04925030517578125,
#                 0.05053747177124023,
#                 0.05164851379394531,
#                 0.05078323364257813,
#                 0.05055385589599609,
#                 0.05604044723510742,
#                 0.050249729156494144,
#                 0.05045043182373047,
#                 0.049312767028808595,
#                 0.05009305572509765,
#                 0.05046681594848633,
#                 0.0506695671081543,
#                 0.05035827255249024,
#                 0.05043302536010742,
#                 0.050383872985839843,
#                 0.050375679016113284,
#                 0.04943667221069336,
#                 0.05041254425048828,
#                 0.050310142517089845,
#                 0.05037055969238281,
#                 0.050446334838867186,
#                 0.05170175933837891,
#                 0.05374771118164062,
#                 0.05021593475341797,
#                 0.04917248153686524,
#                 0.05098905563354492,
#                 0.050411518096923826,
#                 0.05086003112792969,
#                 0.05058662414550781,
#                 0.05032243347167969,
#                 0.05020159912109375,
#                 0.05069823837280273,
#                 0.049670143127441405,
#                 0.050799617767333986,
#                 0.050270206451416014,
#                 0.05058867263793945,
#                 0.05036646270751953,
#                 0.050787326812744144,
#                 0.05024051284790039,
#                 0.050170879364013675,
#                 0.049291263580322264,
#                 0.05135564804077149,
#                 0.05217792129516602,
#                 0.05164748764038086,
#                 0.049944576263427735,
#                 0.05003366470336914,
#                 0.05000601577758789,
#                 0.050249729156494144,
#                 0.05055590438842773,
#                 0.052574207305908206,
#                 0.0518553581237793,
#                 0.051576831817626956,
#                 0.05151027297973633,
#                 0.05121023941040039,
#                 0.05030809783935547,
#                 0.05033267211914062,
#                 0.049775615692138675,
#                 0.05084364700317383,
#                 0.05159526443481445,
#                 0.050348033905029295,
#                 0.05200588989257812,
#                 0.05206220626831055,
#                 0.054163455963134766,
#                 0.0514068489074707,
#                 0.05015039825439453,
#                 0.050566143035888675,
#                 0.050098175048828124,
#                 0.050135040283203126,
#                 0.049670143127441405,
#                 0.05005926513671875,
#                 0.04973567962646484,
#                 0.05047091293334961,
#                 0.04897177505493164,
#                 0.04964659118652344,
#                 0.05003059387207031,
#                 0.050492416381835936,
#                 0.05079654312133789,
#                 0.05073715209960938,
#                 0.05061939239501953,
#                 0.05058969497680664,
#                 0.05313740921020508,
#                 0.05215641784667969,
#                 0.05104127883911133,
#                 0.058856449127197265,
#                 0.06599987030029297,
#                 0.05238476943969726,
#                 0.051381248474121094,
#                 0.05113958358764648,
#                 0.04976128005981445,
#                 0.05059379196166992,
#                 0.05144371032714844,
#                 0.050915328979492185,
#                 0.050460670471191404,
#                 0.05043711853027344,
#                 0.05037055969238281,
#                 0.050402305603027345,
#                 0.0494919662475586,
#                 0.05219225692749024,
#                 0.050713600158691405,
#                 0.05062348937988281,
#                 0.05060095977783203,
#                 0.05077299118041992,
#                 0.06099456024169922,
#                 0.053184513092041016,
#                 0.049555454254150394,
#                 0.050479103088378906,
#                 0.05046783828735352,
#                 0.050729984283447264,
#                 0.05062246322631836,
#                 0.050560001373291016,
#                 0.05037772750854492,
#                 0.050356224060058595,
#                 0.05039923095703125,
#                 0.050713600158691405,
#                 0.0504535026550293,
#                 0.05024870300292969,
#                 0.04938444900512695,
#                 0.050129920959472656,
#                 0.050138111114501956,
#                 0.05464883041381836,
#                 0.058310657501220706,
#                 0.050958335876464846,
#                 0.05084262466430664,
#                 0.05078937530517578,
#                 0.04961382293701172,
#                 0.051057662963867184,
#                 0.050710529327392576,
#                 0.050841598510742186,
#                 0.05068697738647461,
#                 0.05063167953491211,
#                 0.05088358306884765,
#                 0.0506163215637207,
#                 0.049600513458251956,
#                 0.05081497573852539,
#                 0.0506798095703125,
#                 0.050840576171875,
#                 0.050971649169921876,
#                 0.051154945373535154,
#                 0.05080678558349609,
#                 0.051130367279052735,
#                 0.05050982284545898,
#                 0.050743297576904295,
#                 0.050618366241455076,
#                 0.0506879997253418,
#                 0.050729984283447264,
#                 0.05102182388305664,
#                 0.05082009506225586,
#                 0.0508590087890625,
#                 0.04994047927856445,
#                 0.05094297790527344,
#                 0.051062782287597655,
#                 0.050748416900634766,
#                 0.050546688079833986,
#                 0.05059993743896484,
#                 0.05523251342773437,
#                 0.051037185668945315,
#                 0.04996710586547851,
#                 0.05488947296142578,
#                 0.05062656021118164,
#                 0.05056409454345703,
#                 0.05084467315673828,
#                 0.050902015686035154,
#                 0.05100339126586914,
#                 0.05070848083496094,
#                 0.05170278549194336,
#                 0.05165260696411133,
#                 0.05079244613647461,
#                 0.05083443069458008,
#                 0.05073612976074219,
#                 0.05079347229003906,
#                 0.050685951232910156,
#                 0.050579456329345705,
#                 0.04967424011230469,
#                 0.051264511108398435,
#                 0.05084364700317383,
#                 0.050836479187011716,
#                 0.05055078506469726,
#                 0.051105792999267576,
#                 0.050680831909179686,
#                 0.050506752014160154,
#                 0.04953804779052735,
#                 0.050402305603027345,
#                 0.05093888092041016,
#                 0.050634750366210936,
#                 0.050457599639892575,
#                 0.05039718246459961,
#                 0.05060505676269531,
#                 0.050388992309570314,
#                 0.049448959350585936,
#                 0.05047091293334961,
#                 0.050525184631347655,
#                 0.05059686279296875,
#                 0.051135486602783206,
#                 0.05044326400756836,
#                 0.05058969497680664,
#                 0.05083135986328125,
#                 0.051939327239990236,
#                 0.05059788894653321,
#                 0.0506798095703125,
#                 0.049996799468994144,
#                 0.04983705520629883,
#                 0.05004390335083008,
#                 0.04988415908813477,
#                 0.05037772750854492,
#                 0.04909465789794922,
#                 0.05015347290039063,
#                 0.059652095794677736,
#                 0.05043711853027344,
#                 0.04976537704467773,
#                 0.0502743034362793,
#                 0.050407424926757816,
#                 0.050408447265625,
#                 0.04885299301147461,
#                 0.05043916702270508,
#                 0.04984729766845703,
#                 0.049895423889160156,
#                 0.05117337417602539,
#                 0.054766590118408204,
#                 0.06038937759399414,
#                 0.05046783828735352
#             ]
#         },
#         "throughput": {
#             "unit": "tokens/s",
#             "value": 78.09057765783453
#         },
#         "energy": null,
#         "efficiency": null
#     }
# }

# %% [markdown]
# With Evaluation Harness
#
#
# More details about using the Evaluation Harness in this article:
#
# [Behind the OpenLLM Leaderboard: The Evaluation Harness](https://kaitchup.substack.com/p/behind-the-openllm-leaderboard-the)

# %%
# !pip install git+https://github.com/EleutherAI/lm-evaluation-harness.git
# !pip install bitsandbytes
# !pip install --upgrade transformers
# !pip install auto-gptq optimum autoawq
# Out:
# Collecting git+https://github.com/EleutherAI/lm-evaluation-harness.git
#   Cloning https://github.com/EleutherAI/lm-evaluation-harness.git to /tmp/pip-req-build-shixds6c
#   Running command git clone --filter=blob:none --quiet https://github.com/EleutherAI/lm-evaluation-harness.git /tmp/pip-req-build-shixds6c
#   Resolved https://github.com/EleutherAI/lm-evaluation-harness.git to commit dc90fecc8ba31b682d30e096980f678c18ddc435
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting accelerate>=0.21.0 (from lm_eval==0.4.1)
#   Downloading accelerate-0.28.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 6.6 MB/s eta 0:00:00
# Collecting evaluate (from lm_eval==0.4.1)
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.1 MB/s eta 0:00:00
# Collecting datasets>=2.16.0 (from lm_eval==0.4.1)
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 15.2 MB/s eta 0:00:00
# Collecting jsonlines (from lm_eval==0.4.1)
#   Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.1) (2.9.0)
# Collecting peft>=0.2.0 (from lm_eval==0.4.1)
#   Downloading peft-0.9.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.9/190.9 kB 14.1 MB/s eta 0:00:00
# Collecting pybind11>=2.6.2 (from lm_eval==0.4.1)
#   Downloading pybind11-2.11.1-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.7/227.7 kB 20.6 MB/s eta 0:00:00
# Collecting pytablewriter (from lm_eval==0.4.1)
#   Downloading pytablewriter-1.2.0-py3-none-any.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 16.1 MB/s eta 0:00:00
# Collecting rouge-score>=0.0.4 (from lm_eval==0.4.1)
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sacrebleu>=1.5.0 (from lm_eval==0.4.1)
#   Downloading sacrebleu-2.4.1-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 14.6 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.1) (1.2.2)
# Collecting sqlitedict (from lm_eval==0.4.1)
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.1) (2.2.1+cu121)
# Collecting tqdm-multiprocess (from lm_eval==0.4.1)
#   Downloading tqdm_multiprocess-0.0.11-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: transformers>=4.1 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.1) (4.38.2)
# Collecting zstandard (from lm_eval==0.4.1)
#   Downloading zstandard-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 35.5 MB/s eta 0:00:00
# Collecting dill (from lm_eval==0.4.1)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 17.1 MB/s eta 0:00:00
# Collecting word2number (from lm_eval==0.4.1)
#   Downloading word2number-1.1.zip (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.1) (10.1.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.1) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.1) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.1) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.1) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.1) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.1) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.1) (3.13.1)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.1) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.1) (0.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.1) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.1) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.1) (4.66.2)
# Collecting xxhash (from datasets>=2.16.0->lm_eval==0.4.1)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 25.4 MB/s eta 0:00:00
# Collecting multiprocess (from datasets>=2.16.0->lm_eval==0.4.1)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.1) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.1) (3.9.3)
# Collecting responses<0.19 (from evaluate->lm_eval==0.4.1)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.1) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.1) (3.8.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.1) (1.16.0)
# Collecting portalocker (from sacrebleu>=1.5.0->lm_eval==0.4.1)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.1) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.1) (0.9.0)
# Collecting colorama (from sacrebleu>=1.5.0->lm_eval==0.4.1)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.1) (4.9.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.1) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.1) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.1) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.1) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.1) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.1) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.1) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.8->lm_eval==0.4.1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 65.5 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.8->lm_eval==0.4.1)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 62.6 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.8->lm_eval==0.4.1)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 90.2 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.8->lm_eval==0.4.1)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.9 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.8->lm_eval==0.4.1)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.1 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.8->lm_eval==0.4.1)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 13.4 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.8->lm_eval==0.4.1)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 28.4 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.8->lm_eval==0.4.1)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.1 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.8->lm_eval==0.4.1)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 3.9 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.8->lm_eval==0.4.1)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 10.1 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.8->lm_eval==0.4.1)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.1) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8->lm_eval==0.4.1)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 79.3 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.1->lm_eval==0.4.1) (0.15.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines->lm_eval==0.4.1) (23.2.0)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm_eval==0.4.1) (67.7.2)
# Collecting DataProperty<2,>=1.0.1 (from pytablewriter->lm_eval==0.4.1)
#   Downloading DataProperty-1.0.1-py3-none-any.whl (27 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter->lm_eval==0.4.1)
#   Downloading mbstrdecoder-1.1.3-py3-none-any.whl (7.8 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter->lm_eval==0.4.1)
#   Downloading pathvalidate-3.2.0-py3-none-any.whl (23 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter->lm_eval==0.4.1)
#   Downloading tabledata-1.3.3-py3-none-any.whl (11 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter->lm_eval==0.4.1)
#   Downloading tcolorpy-0.1.4-py3-none-any.whl (7.9 kB)
# Collecting typepy[datetime]<2,>=1.3.2 (from pytablewriter->lm_eval==0.4.1)
#   Downloading typepy-1.3.2-py3-none-any.whl (31 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.1) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.1) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.1) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.1) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.1) (4.0.3)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.10/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter->lm_eval==0.4.1) (5.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.16.0->lm_eval==0.4.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.16.0->lm_eval==0.4.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.16.0->lm_eval==0.4.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.16.0->lm_eval==0.4.1) (2024.2.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.1) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.1) (2023.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8->lm_eval==0.4.1) (2.1.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score>=0.0.4->lm_eval==0.4.1) (8.1.7)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8->lm_eval==0.4.1) (1.3.0)
# Building wheels for collected packages: lm_eval, rouge-score, sqlitedict, word2number
#   Building wheel for lm_eval (pyproject.toml) ... done
#   Created wheel for lm_eval: filename=lm_eval-0.4.1-py3-none-any.whl size=1425833 sha256=8c29b95baac726be0d4b155038ca7bf0c19e0d4aadc6b1225e80170ee02d0f2c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_52g_p1d/wheels/ff/d5/f4/949f2b285369fc332f8dbba43f220ebd88387ee2f2c0c1174f
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=c83f9c7a2beb1e1f8f038bae3759e1b1314fac9c85c0b00c26bf5ddec605d430
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16862 sha256=20e190887249fd819547e9ff3eb26e61bcff21d60a5683ed1b98321b7eb92461
#   Stored in directory: /root/.cache/pip/wheels/79/d6/e7/304e0e6cb2221022c26d8161f7c23cd4f259a9e41e8bbcfabd
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5566 sha256=04640636c94b56c5f056eeeec241b0f988177d919f7ea9bb15b915d1b4dd6f25
#   Stored in directory: /root/.cache/pip/wheels/84/ff/26/d3cfbd971e96c5aa3737ecfced81628830d7359b55fbb8ca3b
# Successfully built lm_eval rouge-score sqlitedict word2number
# Installing collected packages: word2number, sqlitedict, zstandard, xxhash, tcolorpy, pybind11, portalocker, pathvalidate, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mbstrdecoder, jsonlines, dill, colorama, typepy, tqdm-multiprocess, sacrebleu, rouge-score, responses, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, nvidia-cusolver-cu12, datasets, DataProperty, tabledata, evaluate, accelerate, pytablewriter, peft, lm_eval
# Successfully installed DataProperty-1.0.1 accelerate-0.28.0 colorama-0.4.6 datasets-2.18.0 dill-0.3.8 evaluate-0.4.1 jsonlines-4.0.0 lm_eval-0.4.1 mbstrdecoder-1.1.3 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 pathvalidate-3.2.0 peft-0.9.0 portalocker-2.8.2 pybind11-2.11.1 pytablewriter-1.2.0 responses-0.18.0 rouge-score-0.1.2 sacrebleu-2.4.1 sqlitedict-2.1.0 tabledata-1.3.3 tcolorpy-0.1.4 tqdm-multiprocess-0.0.11 typepy-1.3.2 word2number-1.1 xxhash-3.4.1 zstandard-0.22.0
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.43.0-py3-none-manylinux_2_24_x86_64.whl (102.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 MB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (2.2.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.25.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes) (12.4.99)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->bitsandbytes) (1.3.0)
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.43.0
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Collecting auto-gptq
#   Downloading auto_gptq-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 63.3 MB/s eta 0:00:00
# Collecting optimum
#   Downloading optimum-1.17.1-py3-none-any.whl (407 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.1/407.1 kB 44.1 MB/s eta 0:00:00
# Collecting autoawq
#   Downloading autoawq-0.2.3-cp310-cp310-manylinux2014_x86_64.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.0/79.0 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: accelerate>=0.26.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.28.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (2.18.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.1.99)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (1.25.2)
# Collecting rouge (from auto-gptq)
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Collecting gekko (from auto-gptq)
#   Downloading gekko-1.0.7-py3-none-any.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 94.2 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (2.2.1+cu121)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.4.2)
# Requirement already satisfied: transformers>=4.31.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (4.38.2)
# Requirement already satisfied: peft>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (4.66.2)
# Collecting coloredlogs (from optimum)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from optimum) (1.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from optimum) (24.0)
# Requirement already satisfied: huggingface-hub>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from optimum) (0.20.3)
# Requirement already satisfied: tokenizers>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from autoawq) (0.15.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from autoawq) (4.10.0)
# Requirement already satisfied: zstandard in /usr/local/lib/python3.10/dist-packages (from autoawq) (0.22.0)
# Collecting autoawq-kernels (from autoawq)
#   Downloading autoawq_kernels-0.0.6-cp310-cp310-manylinux2014_x86_64.whl (33.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.4/33.4 MB 48.6 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (2.31.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->auto-gptq) (12.4.99)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->auto-gptq) (2023.12.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->auto-gptq) (3.20.3)
# Collecting humanfriendly>=9.1 (from coloredlogs->optimum)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (3.9.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge->auto-gptq) (1.16.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->optimum) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->auto-gptq) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-gptq) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-gptq) (2023.4)
# Installing collected packages: rouge, humanfriendly, gekko, coloredlogs, autoawq-kernels, autoawq, optimum, auto-gptq
# Successfully installed auto-gptq-0.7.1 autoawq-0.2.3 autoawq-kernels-0.0.6 coloredlogs-15.0.1 gekko-1.0.7 humanfriendly-10.0 optimum-1.17.1 rouge-1.0.1

# %% [markdown]
# Yi 6B (original, not quantized)

# %%
# !lm_eval --model hf --model_args pretrained=01-ai/Yi-6B --tasks winogrande,hellaswag,arc_challenge --device cuda:0 --num_fewshot 1 --batch_size 8 --output_path ./eval_harness/Yi-6B
# Out:
# 2024-03-15 11:32:28.244804: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-15 11:32:28.244851: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-15 11:32:28.246334: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-15 11:32:29.616543: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Downloading builder script: 100% 5.67k/5.67k [00:00<00:00, 19.2MB/s]
# 2024-03-15:11:32:35,968 INFO     [__main__.py:225] Verbosity set to INFO
# 2024-03-15:11:32:35,968 INFO     [__init__.py:373] lm_eval.tasks.initialize_tasks() is deprecated and no longer necessary. It will be removed in v0.4.2 release. TaskManager will instead be used.
# 2024-03-15:11:32:41,903 INFO     [__main__.py:311] Selected Tasks: ['arc_challenge', 'hellaswag', 'winogrande']
# 2024-03-15:11:32:41,903 INFO     [__main__.py:312] Loading selected tasks...
# 2024-03-15:11:32:41,907 INFO     [evaluator.py:129] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-15:11:32:41,977 INFO     [huggingface.py:162] Using device 'cuda:0'
# config.json: 100% 605/605 [00:00<00:00, 2.84MB/s]
# model.safetensors.index.json: 100% 23.9k/23.9k [00:00<00:00, 72.5MB/s]
# Downloading shards:   0% 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0% 0.00/9.94G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0% 31.5M/9.94G [00:00<00:36, 269MB/s]
# model-00001-of-00002.safetensors:   1% 73.4M/9.94G [00:00<00:30, 328MB/s]
# model-00001-of-00002.safetensors:   1% 115M/9.94G [00:00<00:28, 347MB/s]
# model-00001-of-00002.safetensors:   2% 157M/9.94G [00:00<00:27, 362MB/s]
# model-00001-of-00002.safetensors:   2% 199M/9.94G [00:00<00:26, 370MB/s]
# model-00001-of-00002.safetensors:   2% 241M/9.94G [00:00<00:26, 373MB/s]
# model-00001-of-00002.safetensors:   3% 283M/9.94G [00:00<00:25, 373MB/s]
# model-00001-of-00002.safetensors:   3% 325M/9.94G [00:00<00:25, 378MB/s]
# model-00001-of-00002.safetensors:   4% 367M/9.94G [00:01<00:25, 376MB/s]
# model-00001-of-00002.safetensors:   4% 409M/9.94G [00:01<00:25, 374MB/s]
# model-00001-of-00002.safetensors:   5% 451M/9.94G [00:01<00:25, 372MB/s]
# model-00001-of-00002.safetensors:   5% 493M/9.94G [00:01<00:25, 374MB/s]
# model-00001-of-00002.safetensors:   5% 535M/9.94G [00:01<00:25, 374MB/s]
# model-00001-of-00002.safetensors:   6% 577M/9.94G [00:01<00:28, 334MB/s]
# model-00001-of-00002.safetensors:   6% 619M/9.94G [00:01<00:26, 346MB/s]
# model-00001-of-00002.safetensors:   7% 661M/9.94G [00:01<00:26, 350MB/s]
# model-00001-of-00002.safetensors:   7% 703M/9.94G [00:01<00:27, 331MB/s]
# model-00001-of-00002.safetensors:   7% 744M/9.94G [00:02<00:27, 329MB/s]
# model-00001-of-00002.safetensors:   8% 786M/9.94G [00:02<00:27, 327MB/s]
# model-00001-of-00002.safetensors:   8% 828M/9.94G [00:02<00:27, 327MB/s]
# model-00001-of-00002.safetensors:   9% 870M/9.94G [00:02<00:28, 317MB/s]
# model-00001-of-00002.safetensors:   9% 912M/9.94G [00:02<00:28, 317MB/s]
# model-00001-of-00002.safetensors:  10% 954M/9.94G [00:02<00:28, 318MB/s]
# model-00001-of-00002.safetensors:  10% 996M/9.94G [00:02<00:28, 317MB/s]
# model-00001-of-00002.safetensors:  10% 1.04G/9.94G [00:03<00:27, 320MB/s]
# model-00001-of-00002.safetensors:  11% 1.08G/9.94G [00:03<00:27, 323MB/s]
# model-00001-of-00002.safetensors:  11% 1.12G/9.94G [00:03<00:27, 322MB/s]
# model-00002-of-00002.safetensors:  88% 1.91G/2.18G [00:05<00:00, 330MB/s]
# model-00002-of-00002.safetensors:  90% 1.95G/2.18G [00:06<00:00, 338MB/s]
# model-00002-of-00002.safetensors:  91% 1.99G/2.18G [00:06<00:00, 346MB/s]
# model-00002-of-00002.safetensors:  93% 2.03G/2.18G [00:06<00:00, 351MB/s]
# model-00002-of-00002.safetensors:  95% 2.08G/2.18G [00:06<00:00, 361MB/s]
# model-00002-of-00002.safetensors:  97% 2.12G/2.18G [00:06<00:00, 369MB/s]
# model-00002-of-00002.safetensors: 100% 2.18G/2.18G [00:06<00:00, 326MB/s]
# Downloading shards: 100% 2/2 [00:37<00:00, 18.86s/it]
# Loading checkpoint shards: 100% 2/2 [00:04<00:00,  2.17s/it]
# generation_config.json: 100% 132/132 [00:00<00:00, 692kB/s]
# tokenizer_config.json: 100% 320/320 [00:00<00:00, 1.62MB/s]
# tokenizer.model: 100% 1.03M/1.03M [00:00<00:00, 4.96MB/s]
# tokenizer.json: 100% 3.56M/3.56M [00:00<00:00, 7.14MB/s]
# 2024-03-15:11:33:28,272 INFO     [evaluator.py:190] get_task_dict has been updated to accept an optional argument, `task_manager`Read more here:https://github.com/EleutherAI/lm-evaluation-harness/blob/main/docs/interface.md#external-library-usage
# Downloading readme: 100% 9.00k/9.00k [00:00<00:00, 30.4MB/s]
# Downloading data: 100% 190k/190k [00:00<00:00, 922kB/s]
# Downloading data: 100% 204k/204k [00:00<00:00, 1.81MB/s]
# Downloading data: 100% 55.7k/55.7k [00:00<00:00, 500kB/s]
# Generating train split: 100% 1119/1119 [00:00<00:00, 37486.23 examples/s]
# Generating test split: 100% 1172/1172 [00:00<00:00, 279239.05 examples/s]
# Generating validation split: 100% 299/299 [00:00<00:00, 134559.75 examples/s]
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 100% 4.36k/4.36k [00:00<00:00, 18.9MB/s]
# Downloading metadata: 100% 2.53k/2.53k [00:00<00:00, 15.6MB/s]
# Downloading readme: 100% 6.84k/6.84k [00:00<00:00, 26.7MB/s]
# Downloading data: 47.5MB [00:00, 68.5MB/s]
# Downloading data: 11.8MB [00:00, 59.2MB/s]
# Downloading data: 12.2MB [00:00, 63.6MB/s]
# Generating train split: 100% 39905/39905 [00:04<00:00, 9720.38 examples/s]
# Generating test split: 100% 10003/10003 [00:01<00:00, 9743.69 examples/s]
# Generating validation split: 100% 10042/10042 [00:01<00:00, 9695.96 examples/s]
# Map: 100% 39905/39905 [00:06<00:00, 6371.23 examples/s]
# Map: 100% 10042/10042 [00:01<00:00, 6806.20 examples/s]
# Downloading data: 100% 2.06M/2.06M [00:00<00:00, 16.4MB/s]
# Downloading data: 100% 118k/118k [00:00<00:00, 280kB/s]
# Downloading data: 100% 85.9k/85.9k [00:00<00:00, 467kB/s]
# Generating train split: 100% 40398/40398 [00:00<00:00, 1036041.58 examples/s]
# Generating test split: 100% 1767/1767 [00:00<00:00, 608334.17 examples/s]
# Generating validation split: 100% 1267/1267 [00:00<00:00, 510684.53 examples/s]
# 2024-03-15:11:34:10,323 WARNING  [evaluator.py:222] Overwriting default num_fewshot of winogrande from None to 1
# 2024-03-15:11:34:10,323 WARNING  [evaluator.py:222] Overwriting default num_fewshot of hellaswag from None to 1
# 2024-03-15:11:34:10,323 WARNING  [evaluator.py:222] Overwriting default num_fewshot of arc_challenge from None to 1
# 2024-03-15:11:34:10,326 INFO     [task.py:395] Building contexts for winogrande on rank 0...
# 100% 1267/1267 [00:00<00:00, 37470.53it/s]
# 2024-03-15:11:34:10,401 INFO     [task.py:395] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [00:24<00:00, 404.06it/s]
# 2024-03-15:11:34:36,676 INFO     [task.py:395] Building contexts for arc_challenge on rank 0...
# 100% 1172/1172 [00:05<00:00, 219.18it/s]
# 2024-03-15:11:34:42,093 INFO     [evaluator.py:357] Running loglikelihood requests
# Running loglikelihood requests: 100% 47389/47389 [2:14:42<00:00,  5.86it/s]
# fatal: not a git repository (or any of the parent directories): .git
# hf (pretrained=01-ai/Yi-6B), gen_kwargs: (None), limit: None, num_fewshot: 1, batch_size: 8
# |    Tasks    |Version|Filter|n-shot| Metric |Value |   |Stderr|
# |-------------|------:|------|-----:|--------|-----:|---|-----:|
# |winogrande   |      1|none  |     1|acc     |0.7206|±  |0.0126|
# |hellaswag    |      1|none  |     1|acc     |0.5597|±  |0.0050|
# |             |       |none  |     1|acc_norm|0.7541|±  |0.0043|
# |arc_challenge|      1|none  |     1|acc     |0.5034|±  |0.0146|
# |             |       |none  |     1|acc_norm|0.5401|±  |0.0146|

# %% [markdown]
# Yi 6B quantized with BnB 4-bit

# %%
# !lm_eval --model hf --model_args pretrained=kaitchup/Yi-6B-bnb-4bit --tasks winogrande,hellaswag,arc_challenge --device cuda:0 --num_fewshot 1 --batch_size 8 --output_path ./eval_harness/Yi-6B-bnb-4bit
# Out:
# 2024-03-17 01:01:31.105648: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-17 01:01:31.105721: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-17 01:01:31.107172: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-17 01:01:32.503343: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Downloading builder script: 100% 5.67k/5.67k [00:00<00:00, 17.8MB/s]
# 2024-03-17:01:01:38,684 INFO     [__main__.py:225] Verbosity set to INFO
# 2024-03-17:01:01:38,685 INFO     [__init__.py:373] lm_eval.tasks.initialize_tasks() is deprecated and no longer necessary. It will be removed in v0.4.2 release. TaskManager will instead be used.
# 2024-03-17:01:01:45,016 INFO     [__main__.py:311] Selected Tasks: ['arc_challenge', 'hellaswag', 'winogrande']
# 2024-03-17:01:01:45,016 INFO     [__main__.py:312] Loading selected tasks...
# 2024-03-17:01:01:45,020 INFO     [evaluator.py:129] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-17:01:01:45,086 INFO     [huggingface.py:162] Using device 'cuda:0'
# config.json: 100% 1.14k/1.14k [00:00<00:00, 6.29MB/s]
# model.safetensors: 100% 3.91G/3.91G [01:08<00:00, 56.8MB/s]
# generation_config.json: 100% 132/132 [00:00<00:00, 651kB/s]
# 2024-03-17:01:02:58,487 WARNING  [big_modeling.py:448] You shouldn't move a model that is dispatched using accelerate hooks.
# tokenizer_config.json: 100% 909/909 [00:00<00:00, 4.60MB/s]
# tokenizer.model: 100% 1.03M/1.03M [00:00<00:00, 36.0MB/s]
# tokenizer.json: 100% 3.56M/3.56M [00:00<00:00, 7.22MB/s]
# special_tokens_map.json: 100% 573/573 [00:00<00:00, 2.87MB/s]
# 2024-03-17:01:03:00,483 INFO     [evaluator.py:190] get_task_dict has been updated to accept an optional argument, `task_manager`Read more here:https://github.com/EleutherAI/lm-evaluation-harness/blob/main/docs/interface.md#external-library-usage
# Downloading readme: 100% 9.00k/9.00k [00:00<00:00, 27.7MB/s]
# Downloading data: 100% 190k/190k [00:00<00:00, 944kB/s]
# Downloading data: 100% 204k/204k [00:00<00:00, 1.65MB/s]
# Downloading data: 100% 55.7k/55.7k [00:00<00:00, 496kB/s]
# Generating train split: 100% 1119/1119 [00:00<00:00, 35889.32 examples/s]
# Generating test split: 100% 1172/1172 [00:00<00:00, 236332.90 examples/s]
# Generating validation split: 100% 299/299 [00:00<00:00, 116627.63 examples/s]
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 100% 4.36k/4.36k [00:00<00:00, 17.4MB/s]
# Downloading metadata: 100% 2.53k/2.53k [00:00<00:00, 12.2MB/s]
# Downloading readme: 100% 6.84k/6.84k [00:00<00:00, 25.0MB/s]
# Downloading data: 47.5MB [00:00, 70.8MB/s]
# Downloading data: 11.8MB [00:00, 57.7MB/s]
# Downloading data: 12.2MB [00:00, 59.9MB/s]
# Generating train split: 100% 39905/39905 [00:04<00:00, 9252.08 examples/s]
# Generating test split: 100% 10003/10003 [00:01<00:00, 9114.90 examples/s]
# Generating validation split: 100% 10042/10042 [00:01<00:00, 8984.50 examples/s]
# Map: 100% 39905/39905 [00:06<00:00, 6255.06 examples/s]
# Map: 100% 10042/10042 [00:01<00:00, 6404.32 examples/s]
# Downloading data: 100% 2.06M/2.06M [00:00<00:00, 16.6MB/s]
# Downloading data: 100% 118k/118k [00:00<00:00, 631kB/s]
# Downloading data: 100% 85.9k/85.9k [00:00<00:00, 475kB/s]
# Generating train split: 100% 40398/40398 [00:00<00:00, 927821.21 examples/s]
# Generating test split: 100% 1767/1767 [00:00<00:00, 512150.87 examples/s]
# Generating validation split: 100% 1267/1267 [00:00<00:00, 465952.05 examples/s]
# 2024-03-17:01:03:44,352 WARNING  [evaluator.py:222] Overwriting default num_fewshot of winogrande from None to 1
# 2024-03-17:01:03:44,353 WARNING  [evaluator.py:222] Overwriting default num_fewshot of hellaswag from None to 1
# 2024-03-17:01:03:44,353 WARNING  [evaluator.py:222] Overwriting default num_fewshot of arc_challenge from None to 1
# 2024-03-17:01:03:44,355 INFO     [task.py:395] Building contexts for winogrande on rank 0...
# 100% 1267/1267 [00:00<00:00, 37359.10it/s]
# 2024-03-17:01:03:44,433 INFO     [task.py:395] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [00:25<00:00, 394.40it/s]
# 2024-03-17:01:04:11,377 INFO     [task.py:395] Building contexts for arc_challenge on rank 0...
# 100% 1172/1172 [00:05<00:00, 216.01it/s]
# 2024-03-17:01:04:16,876 INFO     [evaluator.py:357] Running loglikelihood requests
# Running loglikelihood requests: 100% 47389/47389 [2:16:53<00:00,  5.77it/s]
# fatal: not a git repository (or any of the parent directories): .git
# hf (pretrained=kaitchup/Yi-6B-bnb-4bit), gen_kwargs: (None), limit: None, num_fewshot: 1, batch_size: 8
# |    Tasks    |Version|Filter|n-shot| Metric |Value |   |Stderr|
# |-------------|------:|------|-----:|--------|-----:|---|-----:|
# |winogrande   |      1|none  |     1|acc     |0.7159|±  |0.0127|
# |hellaswag    |      1|none  |     1|acc     |0.5533|±  |0.0050|
# |             |       |none  |     1|acc_norm|0.7497|±  |0.0043|
# |arc_challenge|      1|none  |     1|acc     |0.4846|±  |0.0146|
# |             |       |none  |     1|acc_norm|0.5299|±  |0.0146|

# %% [markdown]
# Yi 6B quantized with GPTQ 4-bit

# %%
# !lm_eval --model hf --model_args pretrained=kaitchup/Yi-6B-gptq-4bit --tasks winogrande,hellaswag,arc_challenge --device cuda:0 --num_fewshot 1 --batch_size 8 --output_path ./eval_harness/Yi-6B-gptq-4bit
# Out:
# 2024-03-15 13:59:31.956389: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-15 13:59:31.956440: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-15 13:59:31.958016: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-15 13:59:33.231664: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-15:13:59:37,062 INFO     [__main__.py:225] Verbosity set to INFO
# 2024-03-15:13:59:37,062 INFO     [__init__.py:373] lm_eval.tasks.initialize_tasks() is deprecated and no longer necessary. It will be removed in v0.4.2 release. TaskManager will instead be used.
# 2024-03-15:13:59:42,971 INFO     [__main__.py:311] Selected Tasks: ['arc_challenge', 'hellaswag', 'winogrande']
# 2024-03-15:13:59:42,971 INFO     [__main__.py:312] Loading selected tasks...
# 2024-03-15:13:59:42,972 INFO     [evaluator.py:129] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-15:13:59:43,020 INFO     [huggingface.py:162] Using device 'cuda:0'
# config.json: 100% 947/947 [00:00<00:00, 4.50MB/s]
# model.safetensors: 100% 3.93G/3.93G [01:51<00:00, 35.2MB/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:4193: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(
# The cos_cached attribute will be removed in 4.39. Bear in mind that its contents changed in v4.38. Use the forward method of RoPE from now on instead. It is not used in the `LlamaAttention` class
# The sin_cached attribute will be removed in 4.39. Bear in mind that its contents changed in v4.38. Use the forward method of RoPE from now on instead. It is not used in the `LlamaAttention` class
# generation_config.json: 100% 132/132 [00:00<00:00, 791kB/s]
# tokenizer_config.json: 100% 909/909 [00:00<00:00, 5.45MB/s]
# tokenizer.model: 100% 1.03M/1.03M [00:00<00:00, 36.8MB/s]
# tokenizer.json: 100% 3.56M/3.56M [00:00<00:00, 6.50MB/s]
# special_tokens_map.json: 100% 573/573 [00:00<00:00, 3.11MB/s]
# 2024-03-15:14:01:42,086 INFO     [evaluator.py:190] get_task_dict has been updated to accept an optional argument, `task_manager`Read more here:https://github.com/EleutherAI/lm-evaluation-harness/blob/main/docs/interface.md#external-library-usage
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# 2024-03-15:14:01:55,030 WARNING  [evaluator.py:222] Overwriting default num_fewshot of winogrande from None to 1
# 2024-03-15:14:01:55,030 WARNING  [evaluator.py:222] Overwriting default num_fewshot of hellaswag from None to 1
# 2024-03-15:14:01:55,030 WARNING  [evaluator.py:222] Overwriting default num_fewshot of arc_challenge from None to 1
# 2024-03-15:14:01:55,032 INFO     [task.py:395] Building contexts for winogrande on rank 0...
# 100% 1267/1267 [00:00<00:00, 37466.04it/s]
# 2024-03-15:14:01:55,109 INFO     [task.py:395] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [00:24<00:00, 412.83it/s]
# 2024-03-15:14:02:20,876 INFO     [task.py:395] Building contexts for arc_challenge on rank 0...
# 100% 1172/1172 [00:05<00:00, 228.50it/s]
# 2024-03-15:14:02:26,073 INFO     [evaluator.py:357] Running loglikelihood requests
# Running loglikelihood requests: 100% 47389/47389 [21:49<00:00, 36.19it/s]
# fatal: not a git repository (or any of the parent directories): .git
# hf (pretrained=kaitchup/Yi-6B-gptq-4bit), gen_kwargs: (None), limit: None, num_fewshot: 1, batch_size: 8
# |    Tasks    |Version|Filter|n-shot| Metric |Value |   |Stderr|
# |-------------|------:|------|-----:|--------|-----:|---|-----:|
# |winogrande   |      1|none  |     1|acc     |0.7001|±  |0.0129|
# |hellaswag    |      1|none  |     1|acc     |0.5505|±  |0.0050|
# |             |       |none  |     1|acc_norm|0.7451|±  |0.0043|
# |arc_challenge|      1|none  |     1|acc     |0.4991|±  |0.0146|
# |             |       |none  |     1|acc_norm|0.5273|±  |0.0146|

# %% [markdown]
# Yi 6B quantized with AWQ 4-bit

# %%
# !lm_eval --model hf --model_args pretrained=kaitchup/Yi-6B-awq-4bit --tasks winogrande,hellaswag,arc_challenge --device cuda:0 --num_fewshot 1 --batch_size 8 --output_path ./eval_harness/Yi-6B-awq-4bit
# Out:
# 2024-03-15 21:25:05.564965: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-15 21:25:05.565016: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-15 21:25:05.566898: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-15 21:25:06.818074: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Downloading builder script: 100% 5.67k/5.67k [00:00<00:00, 21.0MB/s]
# 2024-03-15:21:25:14,036 INFO     [__main__.py:225] Verbosity set to INFO
# 2024-03-15:21:25:14,037 INFO     [__init__.py:373] lm_eval.tasks.initialize_tasks() is deprecated and no longer necessary. It will be removed in v0.4.2 release. TaskManager will instead be used.
# 2024-03-15:21:25:20,100 INFO     [__main__.py:311] Selected Tasks: ['arc_challenge', 'hellaswag', 'winogrande']
# 2024-03-15:21:25:20,100 INFO     [__main__.py:312] Loading selected tasks...
# 2024-03-15:21:25:20,105 INFO     [evaluator.py:129] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-15:21:25:20,179 INFO     [huggingface.py:162] Using device 'cuda:0'
# config.json: 100% 982/982 [00:00<00:00, 5.58MB/s]
# We suggest you to set `torch_dtype=torch.float16` for better efficiency with AWQ.
# model.safetensors: 100% 3.93G/3.93G [03:06<00:00, 21.1MB/s]
# generation_config.json: 100% 153/153 [00:00<00:00, 814kB/s]
# tokenizer_config.json: 100% 909/909 [00:00<00:00, 5.16MB/s]
# tokenizer.model: 100% 1.03M/1.03M [00:00<00:00, 219MB/s]
# tokenizer.json: 100% 3.56M/3.56M [00:00<00:00, 6.95MB/s]
# special_tokens_map.json: 100% 573/573 [00:00<00:00, 3.18MB/s]
# 2024-03-15:21:28:35,320 INFO     [evaluator.py:190] get_task_dict has been updated to accept an optional argument, `task_manager`Read more here:https://github.com/EleutherAI/lm-evaluation-harness/blob/main/docs/interface.md#external-library-usage
# Downloading readme: 100% 9.00k/9.00k [00:00<00:00, 25.2MB/s]
# Downloading data: 100% 190k/190k [00:00<00:00, 522kB/s]
# Downloading data: 100% 204k/204k [00:00<00:00, 500kB/s]
# Downloading data: 100% 55.7k/55.7k [00:01<00:00, 35.5kB/s]
# Generating train split: 100% 1119/1119 [00:00<00:00, 32755.42 examples/s]
# Generating test split: 100% 1172/1172 [00:00<00:00, 285200.99 examples/s]
# Generating validation split: 100% 299/299 [00:00<00:00, 136925.09 examples/s]
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 100% 4.36k/4.36k [00:00<00:00, 19.1MB/s]
# Downloading metadata: 100% 2.53k/2.53k [00:00<00:00, 15.4MB/s]
# Downloading readme: 100% 6.84k/6.84k [00:00<00:00, 27.7MB/s]
# Downloading data: 47.5MB [00:00, 72.4MB/s]
# Downloading data: 11.8MB [00:00, 64.0MB/s]
# Downloading data: 12.2MB [00:00, 66.2MB/s]
# Generating train split: 100% 39905/39905 [00:04<00:00, 9491.33 examples/s]
# Generating test split: 100% 10003/10003 [00:01<00:00, 9545.49 examples/s]
# Generating validation split: 100% 10042/10042 [00:01<00:00, 9491.57 examples/s]
# Map: 100% 39905/39905 [00:06<00:00, 6524.14 examples/s]
# Map: 100% 10042/10042 [00:01<00:00, 6827.97 examples/s]
# Downloading data: 100% 2.06M/2.06M [00:02<00:00, 722kB/s]
# Downloading data: 100% 118k/118k [00:00<00:00, 444kB/s]
# Downloading data: 100% 85.9k/85.9k [00:00<00:00, 170kB/s]
# Generating train split: 100% 40398/40398 [00:00<00:00, 1156320.97 examples/s]
# Generating test split: 100% 1767/1767 [00:00<00:00, 674309.45 examples/s]
# Generating validation split: 100% 1267/1267 [00:00<00:00, 555760.63 examples/s]
# 2024-03-15:21:29:43,165 WARNING  [evaluator.py:222] Overwriting default num_fewshot of winogrande from None to 1
# 2024-03-15:21:29:43,165 WARNING  [evaluator.py:222] Overwriting default num_fewshot of hellaswag from None to 1
# 2024-03-15:21:29:43,165 WARNING  [evaluator.py:222] Overwriting default num_fewshot of arc_challenge from None to 1
# 2024-03-15:21:29:43,167 INFO     [task.py:395] Building contexts for winogrande on rank 0...
# 100% 1267/1267 [00:00<00:00, 37629.46it/s]
# 2024-03-15:21:29:43,244 INFO     [task.py:395] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [00:24<00:00, 407.61it/s]
# 2024-03-15:21:30:09,290 INFO     [task.py:395] Building contexts for arc_challenge on rank 0...
# 100% 1172/1172 [00:05<00:00, 219.48it/s]
# 2024-03-15:21:30:14,699 INFO     [evaluator.py:357] Running loglikelihood requests
# Running loglikelihood requests: 100% 47389/47389 [13:55<00:00, 56.74it/s]
# fatal: not a git repository (or any of the parent directories): .git
# hf (pretrained=kaitchup/Yi-6B-awq-4bit), gen_kwargs: (None), limit: None, num_fewshot: 1, batch_size: 8
# |    Tasks    |Version|Filter|n-shot| Metric |Value |   |Stderr|
# |-------------|------:|------|-----:|--------|-----:|---|-----:|
# |winogrande   |      1|none  |     1|acc     |0.7230|±  |0.0126|
# |hellaswag    |      1|none  |     1|acc     |0.5548|±  |0.0050|
# |             |       |none  |     1|acc_norm|0.7455|±  |0.0043|
# |arc_challenge|      1|none  |     1|acc     |0.4974|±  |0.0146|
# |             |       |none  |     1|acc_norm|0.5350|±  |0.0146|
